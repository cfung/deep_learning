# %% [markdown]
# # Language Translation
# In this project, you’re going to take a peek into the realm of neural network machine translation.  You’ll be training a sequence to sequence model on a dataset of English and French sentences that can translate new sentences from English to French.
# ## Get the Data
# Since translating the whole language of English to French will take lots of time to train, we have provided you with a small portion of the English corpus.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import helper
import problem_unittests as tests

source_path = 'data/small_vocab_en'
target_path = 'data/small_vocab_fr'
source_text = helper.load_data(source_path)
target_text = helper.load_data(target_path)

# %% [markdown]
# ## Explore the Data
# Play around with view_sentence_range to view different parts of the data.

# %%
view_sentence_range = (0, 10)

"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import numpy as np

print('Dataset Stats')
print('Roughly the number of unique words: {}'.format(len({word: None for word in source_text.split()})))

sentences = source_text.split('\n')
word_counts = [len(sentence.split()) for sentence in sentences]
print('Number of sentences: {}'.format(len(sentences)))
print('Average number of words in a sentence: {}'.format(np.average(word_counts)))

print()
print('English sentences {} to {}:'.format(*view_sentence_range))
print('\n'.join(source_text.split('\n')[view_sentence_range[0]:view_sentence_range[1]]))
print()
print('French sentences {} to {}:'.format(*view_sentence_range))
print('\n'.join(target_text.split('\n')[view_sentence_range[0]:view_sentence_range[1]]))
# Out:
# Dataset Stats
# Roughly the number of unique words: 227
# Number of sentences: 137861
# Average number of words in a sentence: 13.225277634719028
#
# English sentences 0 to 10:
# new jersey is sometimes quiet during autumn , and it is snowy in april .
# the united states is usually chilly during july , and it is usually freezing in november .
# california is usually quiet during march , and it is usually hot in june .
# the united states is sometimes mild during june , and it is cold in september .
# your least liked fruit is the grape , but my least liked is the apple .
# his favorite fruit is the orange , but my favorite is the grape .
# paris is relaxing during december , but it is usually chilly in july .
# new jersey is busy during spring , and it is never hot in march .
# our least liked fruit is the lemon , but my least liked is the grape .
# the united states is sometimes busy during january , and it is sometimes warm in november .
#
# French sentences 0 to 10:
# new jersey est parfois calme pendant l' automne , et il est neigeux en avril .
# les états-unis est généralement froid en juillet , et il gèle habituellement en novembre .
# california est généralement calme en mars , et il est généralement chaud en juin .
# les états-unis est parfois légère en juin , et il fait froid en septembre .
# votre moins aimé fruit est le raisin , mais mon moins aimé est la pomme .
# son fruit préféré est l'orange , mais mon préféré est le raisin .
# paris est relaxant en décembre , mais il est généralement froid en juillet .
# new jersey est occupé au printemps , et il est jamais chaude en mars .
# notre fruit est moins aimé le citron , mais mon moins aimé est le raisin .
# les états-unis est parfois occupé en janvier , et il est parfois chaud en novembre .

# %% [markdown]
# ## Implement Preprocessing Function
# ### Text to Word Ids
# As you did with other RNNs, you must turn the text into a number so the computer can understand it. In the function `text_to_ids()`, you'll turn `source_text` and `target_text` from words to ids.  However, you need to add the `<EOS>` word id at the end of `target_text`.  This will help the neural network predict when the sentence should end.
#
# You can get the `<EOS>` word id by doing:
# ```python
# target_vocab_to_int['<EOS>']
# ```
# You can get other word ids using `source_vocab_to_int` and `target_vocab_to_int`.

# %%
def text_to_ids(source_text, target_text, source_vocab_to_int, target_vocab_to_int):
    """
    Convert source and target text to proper word ids
    :param source_text: String that contains all the source text.
    :param target_text: String that contains all the target text.
    :param source_vocab_to_int: Dictionary to go from the source words to an id
    :param target_vocab_to_int: Dictionary to go from the target words to an id
    :return: A tuple of lists (source_id_text, target_id_text)
    """
    # TODO: Implement Function

    source_id_text = [[source_vocab_to_int[word] for word in n.split()] for n in source_text.split("\n")]
    target_id_text = [[target_vocab_to_int[word] for word in n.split()]+[target_vocab_to_int['<EOS>']] for n in target_text.split("\n")]
    return source_id_text, target_id_text
    
"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_text_to_ids(text_to_ids)
# Out:
# Tests Passed

# %% [markdown]
# ### Preprocess all the data and save it
# Running the code cell below will preprocess all the data and save it to file.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
helper.preprocess_and_save_data(source_path, target_path, text_to_ids)

# %% [markdown]
# # Check Point
# This is your first checkpoint. If you ever decide to come back to this notebook or have to restart the notebook, you can start from here. The preprocessed data has been saved to disk.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import numpy as np
import helper
import problem_unittests as tests

(source_int_text, target_int_text), (source_vocab_to_int, target_vocab_to_int), _ = helper.load_preprocess()

# %% [markdown]
# ### Check the Version of TensorFlow and Access to GPU
# This will check to make sure you have the correct version of TensorFlow and access to a GPU

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
from distutils.version import LooseVersion
import warnings
import tensorflow as tf
from tensorflow.python.layers.core import Dense

# Check TensorFlow Version
assert LooseVersion(tf.__version__) >= LooseVersion('1.1'), 'Please use TensorFlow version 1.1 or newer'
print('TensorFlow Version: {}'.format(tf.__version__))

# Check for a GPU
if not tf.test.gpu_device_name():
    warnings.warn('No GPU found. Please use a GPU to train your neural network.')
else:
    print('Default GPU Device: {}'.format(tf.test.gpu_device_name()))
# Out:
# TensorFlow Version: 1.1.0
# Default GPU Device: /gpu:0

# %% [markdown]
# ## Build the Neural Network
# You'll build the components necessary to build a Sequence-to-Sequence model by implementing the following functions below:
# - `model_inputs`
# - `process_decoder_input`
# - `encoding_layer`
# - `decoding_layer_train`
# - `decoding_layer_infer`
# - `decoding_layer`
# - `seq2seq_model`
#
# ### Input
# Implement the `model_inputs()` function to create TF Placeholders for the Neural Network. It should create the following placeholders:
#
# - Input text placeholder named "input" using the TF Placeholder name parameter with rank 2.
# - Targets placeholder with rank 2.
# - Learning rate placeholder with rank 0.
# - Keep probability placeholder named "keep_prob" using the TF Placeholder name parameter with rank 0.
# - Target sequence length placeholder named "target_sequence_length" with rank 1
# - Max target sequence length tensor named "max_target_len" getting its value from applying tf.reduce_max on the target_sequence_length placeholder. Rank 0.
# - Source sequence length placeholder named "source_sequence_length" with rank 1
#
# Return the placeholders in the following the tuple (input, targets, learning rate, keep probability, target sequence length, max target sequence length, source sequence length)

# %%
def model_inputs():
    """
    Create TF Placeholders for input, targets, learning rate, and lengths of source and target sequences.
    :return: Tuple (input, targets, learning rate, keep probability, target sequence length,
    max target sequence length, source sequence length)
    """
    # TODO: Implement Function
    Input = tf.placeholder(tf.int32, shape=[None,None],name='input')
    targets = tf.placeholder(tf.int32, shape=[None,None],name='Targets')
    learning_rate = tf.placeholder(tf.float32, name="LearningRate")
    keep_prob = tf.placeholder(tf.float32, name="keep_prob")
    target_seq_length = tf.placeholder(tf.int32, (None,),name="target_sequence_length")
    max_target_seq_length = tf.reduce_max(target_seq_length,name="max_target_len")
    source_seq_length = tf.placeholder(tf.int32, (None,), name="source_sequence_length")
    return (Input, targets, learning_rate, keep_prob, target_seq_length, max_target_seq_length, source_seq_length)

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_model_inputs(model_inputs)
# Out:
# Tests Passed

# %% [markdown]
# ### Process Decoder Input
# Implement `process_decoder_input` by removing the last word id from each batch in `target_data` and concat the GO ID to the begining of each batch.

# %%
def process_decoder_input(target_data, target_vocab_to_int, batch_size):
    """
    Preprocess target data for encoding
    :param target_data: Target Placehoder
    :param target_vocab_to_int: Dictionary to go from the target words to an id
    :param batch_size: Batch Size
    :return: Preprocessed target data
    """
    # TODO: Implement Function
    ending = tf.strided_slice(target_data, [0, 0], [batch_size, -1], [1, 1])
    dec_input = tf.concat([tf.fill([batch_size, 1], target_vocab_to_int['<GO>']), ending], 1)
   
    return dec_input

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_process_encoding_input(process_decoder_input)
# Out:
# Tests Passed

# %% [markdown]
# ### Encoding
# Implement `encoding_layer()` to create a Encoder RNN layer:
#  * Embed the encoder input using [`tf.contrib.layers.embed_sequence`](https://www.tensorflow.org/api_docs/python/tf/contrib/layers/embed_sequence)
#  * Construct a [stacked](https://github.com/tensorflow/tensorflow/blob/6947f65a374ebf29e74bb71e36fd82760056d82c/tensorflow/docs_src/tutorials/recurrent.md#stacking-multiple-lstms) [`tf.contrib.rnn.LSTMCell`](https://www.tensorflow.org/api_docs/python/tf/contrib/rnn/LSTMCell) wrapped in a [`tf.contrib.rnn.DropoutWrapper`](https://www.tensorflow.org/api_docs/python/tf/contrib/rnn/DropoutWrapper)
#  * Pass cell and embedded input to [`tf.nn.dynamic_rnn()`](https://www.tensorflow.org/api_docs/python/tf/nn/dynamic_rnn)

# %%
from imp import reload
reload(tests)

def encoding_layer(rnn_inputs, rnn_size, num_layers, keep_prob, 
                   source_sequence_length, source_vocab_size, 
                   encoding_embedding_size):
    """
    Create encoding layer
    :param rnn_inputs: Inputs for the RNN
    :param rnn_size: RNN Size
    :param num_layers: Number of layers
    :param keep_prob: Dropout keep probability
    :param source_sequence_length: a list of the lengths of each sequence in the batch
    :param source_vocab_size: vocabulary size of source data
    :param encoding_embedding_size: embedding size of source data
    :return: tuple (RNN output, RNN state)
    """
    # TODO: Implement Function
    inputs =tf.contrib.layers.embed_sequence(rnn_inputs,source_vocab_size,encoding_embedding_size)
    cell = tf.contrib.rnn.BasicLSTMCell(rnn_size)
    dropout = tf.contrib.rnn.DropoutWrapper(cell,output_keep_prob=keep_prob)
    cell = tf.contrib.rnn.MultiRNNCell([tf.contrib.rnn.BasicLSTMCell(rnn_size) for _ in range(num_layers)])
    output, state = tf.nn.dynamic_rnn(cell,inputs,dtype=tf.float32)
    return output, state

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_encoding_layer(encoding_layer)
# Out:
# Tests Passed

# %% [markdown]
# ### Decoding - Training
# Create a training decoding layer:
# * Create a [`tf.contrib.seq2seq.TrainingHelper`](https://www.tensorflow.org/api_docs/python/tf/contrib/seq2seq/TrainingHelper)
# * Create a [`tf.contrib.seq2seq.BasicDecoder`](https://www.tensorflow.org/api_docs/python/tf/contrib/seq2seq/BasicDecoder)
# * Obtain the decoder outputs from [`tf.contrib.seq2seq.dynamic_decode`](https://www.tensorflow.org/api_docs/python/tf/contrib/seq2seq/dynamic_decode)

# %%
def decoding_layer_train(encoder_state, dec_cell, dec_embed_input, 
                         target_sequence_length, max_summary_length, 
                         output_layer, keep_prob):
    """
    Create a decoding layer for training
    :param encoder_state: Encoder State
    :param dec_cell: Decoder RNN Cell
    :param dec_embed_input: Decoder embedded input
    :param target_sequence_length: The lengths of each sequence in the target batch
    :param max_summary_length: The length of the longest sequence in the batch
    :param output_layer: Function to apply the output layer
    :param keep_prob: Dropout keep probability
    :return: BasicDecoderOutput containing training logits and sample_id
    """
    # TODO: Implement Function
    training_helper = tf.contrib.seq2seq.TrainingHelper(dec_embed_input, target_sequence_length)
    training_decoder = tf.contrib.seq2seq.BasicDecoder(dec_cell, training_helper, encoder_state, output_layer)
    training_decoder_output = tf.contrib.seq2seq.dynamic_decode(training_decoder, impute_finished=True, maximum_iterations=max_summary_length)[0]
    
    return training_decoder_output




"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_decoding_layer_train(decoding_layer_train)
# Out:
# Tests Passed

# %% [markdown]
# ### Decoding - Inference
# Create inference decoder:
# * Create a [`tf.contrib.seq2seq.GreedyEmbeddingHelper`](https://www.tensorflow.org/api_docs/python/tf/contrib/seq2seq/GreedyEmbeddingHelper)
# * Create a [`tf.contrib.seq2seq.BasicDecoder`](https://www.tensorflow.org/api_docs/python/tf/contrib/seq2seq/BasicDecoder)
# * Obtain the decoder outputs from [`tf.contrib.seq2seq.dynamic_decode`](https://www.tensorflow.org/api_docs/python/tf/contrib/seq2seq/dynamic_decode)

# %%
def decoding_layer_infer(encoder_state, dec_cell, dec_embeddings, start_of_sequence_id,
                         end_of_sequence_id, max_target_sequence_length,
                         vocab_size, output_layer, batch_size, keep_prob):
    """
    Create a decoding layer for inference
    :param encoder_state: Encoder state
    :param dec_cell: Decoder RNN Cell
    :param dec_embeddings: Decoder embeddings
    :param start_of_sequence_id: GO ID
    :param end_of_sequence_id: EOS Id
    :param max_target_sequence_length: Maximum length of target sequences
    :param vocab_size: Size of decoder/target vocabulary
    :param decoding_scope: TenorFlow Variable Scope for decoding
    :param output_layer: Function to apply the output layer
    :param batch_size: Batch size
    :param keep_prob: Dropout keep probability
    :return: BasicDecoderOutput containing inference logits and sample_id
    """
    # TODO: Implement Function
    #with tf.variable_scope("decoding", reuse=None) as decoding_scope:
        # Inference Decoder
    #    infer_decoder_fn = tf.contrib.seq2seq.simple_decoder_fn_inference(
    #        output_fn, encoder_state, dec_embeddings, start_of_sequence_id, end_of_sequence_id,
    #        maximum_length, vocab_size, dtype=tf.int32)
    #    inference_logits, _, _ = tf.contrib.seq2seq.dynamic_rnn_decoder(dec_cell, infer_decoder_fn, scope=decoding_scope)
    #    inference_logits_with_dropout = tf.nn.dropout(inference_logits, keep_prob)
    #return inference_logits_with_dropout


        
    start_tokens = tf.tile(tf.constant([start_of_sequence_id], dtype=tf.int32), [batch_size], name='start_tokens')
        
    # Helper for the inference process.
    inference_helper = tf.contrib.seq2seq.GreedyEmbeddingHelper(dec_embeddings,
                                                                start_tokens,
                                                                end_of_sequence_id)

    # Basic decoder
    inference_decoder = tf.contrib.seq2seq.BasicDecoder(dec_cell,
                                                        inference_helper,
                                                        encoder_state,
                                                        output_layer)
        
    # Perform dynamic decoding using the decoder
    inference_decoder_output, _ = tf.contrib.seq2seq.dynamic_decode(inference_decoder,
                                                                    impute_finished=True,
                                                                    maximum_iterations=max_target_sequence_length)
    
    
    #infer_decoder_fn = tf.contrib.seq2seq.simple_decoder_fn_inference(
    #output_fn, encoder_state, dec_embeddings, start_of_sequence_id, end_of_sequence_id, maximum_length, vocab_size)
    #inference_logits = tf.contrib.seq2seq.dynamicrnn_decoder(dec_cell, infer_decoder_fn, scope=decoding_scope)
    return inference_decoder_output



"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_decoding_layer_infer(decoding_layer_infer)
# Out:
# Tests Passed

# %% [markdown]
# ### Build the Decoding Layer
# Implement `decoding_layer()` to create a Decoder RNN layer.
#
# * Embed the target sequences
# * Construct the decoder LSTM cell (just like you constructed the encoder cell above)
# * Create an output layer to map the outputs of the decoder to the elements of our vocabulary
# * Use the your `decoding_layer_train(encoder_state, dec_cell, dec_embed_input, target_sequence_length, max_target_sequence_length, output_layer, keep_prob)` function to get the training logits.
# * Use your `decoding_layer_infer(encoder_state, dec_cell, dec_embeddings, start_of_sequence_id, end_of_sequence_id, max_target_sequence_length, vocab_size, output_layer, batch_size, keep_prob)` function to get the inference logits.
#
# Note: You'll need to use [tf.variable_scope](https://www.tensorflow.org/api_docs/python/tf/variable_scope) to share variables between training and inference.

# %%
def decoding_layer(dec_input, encoder_state,
               target_sequence_length, max_target_sequence_length,
               rnn_size,
               num_layers, target_vocab_to_int, target_vocab_size,
               batch_size, keep_prob, decoding_embedding_size):
    """
    Create decoding layer
    :param dec_input: Decoder input
    :param encoder_state: Encoder state
    :param target_sequence_length: The lengths of each sequence in the target batch
    :param max_target_sequence_length: Maximum length of target sequences
    :param rnn_size: RNN Size
    :param num_layers: Number of layers
    :param target_vocab_to_int: Dictionary to go from the target words to an id
    :param target_vocab_size: Size of target vocabulary
    :param batch_size: The size of the batch
    :param keep_prob: Dropout keep probability
    :param decoding_embedding_size: Decoding embedding size
    :return: Tuple of (Training BasicDecoderOutput, Inference BasicDecoderOutput)
    """
    # TODO: Implement Function
    #return None, None

    # Decoder embedding
    #target_vocab_size = len(target_vocab_to_int)
    dec_embeddings = tf.Variable(tf.random_uniform([target_vocab_size, decoding_embedding_size]))
    dec_embed_input = tf.nn.embedding_lookup(dec_embeddings, dec_input)  

    # Create decoder cell
    def make_cell(rnn_size):
        dec_cell = tf.contrib.rnn.LSTMCell(rnn_size, \
                                           initializer=tf.random_uniform_initializer(-0.1, 0.1, seed=2))
        return dec_cell
    dec_cell = tf.contrib.rnn.MultiRNNCell([make_cell(rnn_size) for _ in range(num_layers)])   

    # Create Dense layer to translate decoder's output at each time
    output_layer = Dense(target_vocab_size, \
                         kernel_initializer = tf.truncated_normal_initializer(mean=0.0, stddev=0.1))   

    # Training decoder
    with tf.variable_scope("decode") as decoding_scope:

        #output_layer = Dense(target_vocab_size, \
        #                 kernel_initializer = tf.truncated_normal_initializer(mean=0.0, stddev=0.1))

        training_decoder_output = decoding_layer_train(encoder_state, dec_cell, dec_embed_input, 
                         target_sequence_length, max_target_sequence_length, 
                         output_layer, keep_prob)
        
        

    # Inference decoder
    with tf.variable_scope("decode", reuse=True) as decoding_scope:
        start_of_sequence_id = target_vocab_to_int['<GO>']
        end_of_sequence_id = target_vocab_to_int['<EOS>']

        inference_decoder_output = decoding_layer_infer(encoder_state, dec_cell, dec_embeddings, start_of_sequence_id,
                             end_of_sequence_id, max_target_sequence_length,
                             target_vocab_size, output_layer, batch_size, keep_prob)
        
        

    return training_decoder_output, inference_decoder_output

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_decoding_layer(decoding_layer)
# Out:
# Tests Passed

# %% [markdown]
# ### Build the Neural Network
# Apply the functions you implemented above to:
#
# - Encode the input using your `encoding_layer(rnn_inputs, rnn_size, num_layers, keep_prob,  source_sequence_length, source_vocab_size, encoding_embedding_size)`.
# - Process target data using your `process_decoder_input(target_data, target_vocab_to_int, batch_size)` function.
# - Decode the encoded input using your `decoding_layer(dec_input, enc_state, target_sequence_length, max_target_sentence_length, rnn_size, num_layers, target_vocab_to_int, target_vocab_size, batch_size, keep_prob, dec_embedding_size)` function.

# %%
def seq2seq_model(input_data, target_data, keep_prob, batch_size,
                  source_sequence_length, target_sequence_length,
                  max_target_sentence_length,
                  source_vocab_size, target_vocab_size,
                  enc_embedding_size, dec_embedding_size,
                  rnn_size, num_layers, target_vocab_to_int):
    """
    Build the Sequence-to-Sequence part of the neural network
    :param input_data: Input placeholder
    :param target_data: Target placeholder
    :param keep_prob: Dropout keep probability placeholder
    :param batch_size: Batch Size
    :param source_sequence_length: Sequence Lengths of source sequences in the batch
    :param target_sequence_length: Sequence Lengths of target sequences in the batch
    :param source_vocab_size: Source vocabulary size
    :param target_vocab_size: Target vocabulary size
    :param enc_embedding_size: Decoder embedding size
    :param dec_embedding_size: Encoder embedding size
    :param rnn_size: RNN Size
    :param num_layers: Number of layers
    :param target_vocab_to_int: Dictionary to go from the target words to an id
    :return: Tuple of (Training BasicDecoderOutput, Inference BasicDecoderOutput)
    """
    
    # Pass the input data through the encoder. We'll ignore the encoder output, but use the state
    encoder_output, encoder_state = encoding_layer(input_data, rnn_size, num_layers, keep_prob, 
                                                   source_sequence_length, source_vocab_size, enc_embedding_size)
    
    processed_input = process_decoder_input(target_data, target_vocab_to_int, batch_size)
    
    max_target_sequence_length = tf.reduce_max(target_sequence_length)
    output_train, output_inference = decoding_layer(processed_input, encoder_state, 
                                                    target_sequence_length, max_target_sequence_length, 
                                                    rnn_size, num_layers, target_vocab_to_int, 
                                                    target_vocab_size, batch_size, keep_prob, dec_embedding_size)
    
    return output_train, output_inference
"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_seq2seq_model(seq2seq_model)
# Out:
# Tests Passed

# %% [markdown]
# ## Neural Network Training
# ### Hyperparameters
# Tune the following parameters:
#
# - Set `epochs` to the number of epochs.
# - Set `batch_size` to the batch size.
# - Set `rnn_size` to the size of the RNNs.
# - Set `num_layers` to the number of layers.
# - Set `encoding_embedding_size` to the size of the embedding for the encoder.
# - Set `decoding_embedding_size` to the size of the embedding for the decoder.
# - Set `learning_rate` to the learning rate.
# - Set `keep_probability` to the Dropout keep probability
# - Set `display_step` to state how many steps between each debug output statement

# %%
# Number of Epochs
epochs = 7
# Batch Size
batch_size = 128
# RNN Size
rnn_size = 50
# Number of Layers
num_layers = 2
# Embedding Size
encoding_embedding_size = 15
decoding_embedding_size = 15
# Learning Rate
learning_rate = 0.001
# Dropout Keep Probability
keep_probability = 0.65
display_step = 5

# %% [markdown]
# ### Build the Graph
# Build the graph using the neural network you implemented.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
save_path = 'checkpoints/dev'
(source_int_text, target_int_text), (source_vocab_to_int, target_vocab_to_int), _ = helper.load_preprocess()
max_target_sentence_length = max([len(sentence) for sentence in source_int_text])

train_graph = tf.Graph()
with train_graph.as_default():
    input_data, targets, lr, keep_prob, target_sequence_length, max_target_sequence_length, source_sequence_length = model_inputs()

    #sequence_length = tf.placeholder_with_default(max_target_sentence_length, None, name='sequence_length')
    input_shape = tf.shape(input_data)

    train_logits, inference_logits = seq2seq_model(tf.reverse(input_data, [-1]),
                                                   targets,
                                                   keep_prob,
                                                   batch_size,
                                                   source_sequence_length,
                                                   target_sequence_length,
                                                   max_target_sequence_length,
                                                   len(source_vocab_to_int),
                                                   len(target_vocab_to_int),
                                                   encoding_embedding_size,
                                                   decoding_embedding_size,
                                                   rnn_size,
                                                   num_layers,
                                                   target_vocab_to_int)


    training_logits = tf.identity(train_logits.rnn_output, name='logits')
    inference_logits = tf.identity(inference_logits.sample_id, name='predictions')

    masks = tf.sequence_mask(target_sequence_length, max_target_sequence_length, dtype=tf.float32, name='masks')

    with tf.name_scope("optimization"):
        # Loss function
        cost = tf.contrib.seq2seq.sequence_loss(
            training_logits,
            targets,
            masks)

        # Optimizer
        optimizer = tf.train.AdamOptimizer(lr)

        # Gradient Clipping
        gradients = optimizer.compute_gradients(cost)
        capped_gradients = [(tf.clip_by_value(grad, -1., 1.), var) for grad, var in gradients if grad is not None]
        train_op = optimizer.apply_gradients(capped_gradients)

# %% [markdown]
# Batch and pad the source and target sequences

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
def pad_sentence_batch(sentence_batch, pad_int):
    """Pad sentences with <PAD> so that each sentence of a batch has the same length"""
    max_sentence = max([len(sentence) for sentence in sentence_batch])
    return [sentence + [pad_int] * (max_sentence - len(sentence)) for sentence in sentence_batch]


def get_batches(sources, targets, batch_size, source_pad_int, target_pad_int):
    """Batch targets, sources, and the lengths of their sentences together"""
    for batch_i in range(0, len(sources)//batch_size):
        start_i = batch_i * batch_size

        # Slice the right amount for the batch
        sources_batch = sources[start_i:start_i + batch_size]
        targets_batch = targets[start_i:start_i + batch_size]

        # Pad
        pad_sources_batch = np.array(pad_sentence_batch(sources_batch, source_pad_int))
        pad_targets_batch = np.array(pad_sentence_batch(targets_batch, target_pad_int))

        # Need the lengths for the _lengths parameters
        pad_targets_lengths = []
        for target in pad_targets_batch:
            pad_targets_lengths.append(len(target))

        pad_source_lengths = []
        for source in pad_sources_batch:
            pad_source_lengths.append(len(source))

        yield pad_sources_batch, pad_targets_batch, pad_source_lengths, pad_targets_lengths

# %% [markdown]
# ### Train
# Train the neural network on the preprocessed data. If you have a hard time getting a good loss, check the forms to see if anyone is having the same problem.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
def get_accuracy(target, logits):
    """
    Calculate accuracy
    """
    max_seq = max(target.shape[1], logits.shape[1])
    if max_seq - target.shape[1]:
        target = np.pad(
            target,
            [(0,0),(0,max_seq - target.shape[1])],
            'constant')
    if max_seq - logits.shape[1]:
        logits = np.pad(
            logits,
            [(0,0),(0,max_seq - logits.shape[1])],
            'constant')

    return np.mean(np.equal(target, logits))

# Split data to training and validation sets
train_source = source_int_text[batch_size:]
train_target = target_int_text[batch_size:]
valid_source = source_int_text[:batch_size]
valid_target = target_int_text[:batch_size]
(valid_sources_batch, valid_targets_batch, valid_sources_lengths, valid_targets_lengths ) = next(get_batches(valid_source,
                                                                                                             valid_target,
                                                                                                             batch_size,
                                                                                                             source_vocab_to_int['<PAD>'],
                                                                                                             target_vocab_to_int['<PAD>']))                                                                                                  
with tf.Session(graph=train_graph) as sess:
    sess.run(tf.global_variables_initializer())

    for epoch_i in range(epochs):
        for batch_i, (source_batch, target_batch, sources_lengths, targets_lengths) in enumerate(
                get_batches(train_source, train_target, batch_size,
                            source_vocab_to_int['<PAD>'],
                            target_vocab_to_int['<PAD>'])):

            _, loss = sess.run(
                [train_op, cost],
                {input_data: source_batch,
                 targets: target_batch,
                 lr: learning_rate,
                 target_sequence_length: targets_lengths,
                 source_sequence_length: sources_lengths,
                 keep_prob: keep_probability})


            if batch_i % display_step == 0 and batch_i > 0:


                batch_train_logits = sess.run(
                    inference_logits,
                    {input_data: source_batch,
                     source_sequence_length: sources_lengths,
                     target_sequence_length: targets_lengths,
                     keep_prob: 1.0})


                batch_valid_logits = sess.run(
                    inference_logits,
                    {input_data: valid_sources_batch,
                     source_sequence_length: valid_sources_lengths,
                     target_sequence_length: valid_targets_lengths,
                     keep_prob: 1.0})

                train_acc = get_accuracy(target_batch, batch_train_logits)

                valid_acc = get_accuracy(valid_targets_batch, batch_valid_logits)

                print('Epoch {:>3} Batch {:>4}/{} - Train Accuracy: {:>6.4f}, Validation Accuracy: {:>6.4f}, Loss: {:>6.4f}'
                      .format(epoch_i, batch_i, len(source_int_text) // batch_size, train_acc, valid_acc, loss))

    # Save Model
    saver = tf.train.Saver()
    saver.save(sess, save_path)
    print('Model Trained and Saved')
# Out:
# Epoch   0 Batch    5/1077 - Train Accuracy: 0.2605, Validation Accuracy: 0.3050, Loss: 5.7846
# Epoch   0 Batch   10/1077 - Train Accuracy: 0.1982, Validation Accuracy: 0.3050, Loss: 5.5929
# Epoch   0 Batch   15/1077 - Train Accuracy: 0.2355, Validation Accuracy: 0.3050, Loss: 5.1193
# Epoch   0 Batch   20/1077 - Train Accuracy: 0.2316, Validation Accuracy: 0.3050, Loss: 4.7348
# Epoch   0 Batch   25/1077 - Train Accuracy: 0.2383, Validation Accuracy: 0.3050, Loss: 4.3907
# Epoch   0 Batch   30/1077 - Train Accuracy: 0.2277, Validation Accuracy: 0.3050, Loss: 4.1056
# Epoch   0 Batch   35/1077 - Train Accuracy: 0.2340, Validation Accuracy: 0.3050, Loss: 3.8830
# Epoch   0 Batch   40/1077 - Train Accuracy: 0.2637, Validation Accuracy: 0.3349, Loss: 3.7591
# Epoch   0 Batch   45/1077 - Train Accuracy: 0.2648, Validation Accuracy: 0.3356, Loss: 3.6574
# Epoch   0 Batch   50/1077 - Train Accuracy: 0.2602, Validation Accuracy: 0.3363, Loss: 3.6055
# Epoch   0 Batch   55/1077 - Train Accuracy: 0.2914, Validation Accuracy: 0.3366, Loss: 3.4275
# Epoch   0 Batch   60/1077 - Train Accuracy: 0.2987, Validation Accuracy: 0.3366, Loss: 3.3522
# Epoch   0 Batch   65/1077 - Train Accuracy: 0.2290, Validation Accuracy: 0.3366, Loss: 3.5653
# Epoch   0 Batch   70/1077 - Train Accuracy: 0.2307, Validation Accuracy: 0.3366, Loss: 3.5191
# Epoch   0 Batch   75/1077 - Train Accuracy: 0.2816, Validation Accuracy: 0.3366, Loss: 3.3040
# Epoch   0 Batch   80/1077 - Train Accuracy: 0.2719, Validation Accuracy: 0.3366, Loss: 3.2819
# Epoch   0 Batch   85/1077 - Train Accuracy: 0.2797, Validation Accuracy: 0.3363, Loss: 3.1878
# Epoch   0 Batch   90/1077 - Train Accuracy: 0.2668, Validation Accuracy: 0.3363, Loss: 3.2616
# Epoch   0 Batch   95/1077 - Train Accuracy: 0.3188, Validation Accuracy: 0.3363, Loss: 3.0939
# Epoch   0 Batch  100/1077 - Train Accuracy: 0.2711, Validation Accuracy: 0.3430, Loss: 3.2262
# Epoch   0 Batch  105/1077 - Train Accuracy: 0.2988, Validation Accuracy: 0.3473, Loss: 3.1322
# Epoch   0 Batch  110/1077 - Train Accuracy: 0.3023, Validation Accuracy: 0.3512, Loss: 3.1163
# Epoch   0 Batch  115/1077 - Train Accuracy: 0.2957, Validation Accuracy: 0.3498, Loss: 3.1455
# Epoch   0 Batch  120/1077 - Train Accuracy: 0.2824, Validation Accuracy: 0.3494, Loss: 3.1293
# Epoch   0 Batch  125/1077 - Train Accuracy: 0.3162, Validation Accuracy: 0.3572, Loss: 3.0413
# Epoch   0 Batch  130/1077 - Train Accuracy: 0.3233, Validation Accuracy: 0.3647, Loss: 2.9815
# Epoch   0 Batch  135/1077 - Train Accuracy: 0.3092, Validation Accuracy: 0.3835, Loss: 3.1386
# Epoch   0 Batch  140/1077 - Train Accuracy: 0.2911, Validation Accuracy: 0.3849, Loss: 3.2020
# Epoch   0 Batch  145/1077 - Train Accuracy: 0.3523, Validation Accuracy: 0.4031, Loss: 2.9967
# Epoch   0 Batch  150/1077 - Train Accuracy: 0.3869, Validation Accuracy: 0.4055, Loss: 2.8907
# Epoch   0 Batch  155/1077 - Train Accuracy: 0.3570, Validation Accuracy: 0.4066, Loss: 2.9816
# Epoch   0 Batch  160/1077 - Train Accuracy: 0.3547, Validation Accuracy: 0.4105, Loss: 2.9496
# Epoch   0 Batch  165/1077 - Train Accuracy: 0.3414, Validation Accuracy: 0.4087, Loss: 2.9851
# Epoch   0 Batch  170/1077 - Train Accuracy: 0.3371, Validation Accuracy: 0.4151, Loss: 3.0353
# Epoch   0 Batch  175/1077 - Train Accuracy: 0.3848, Validation Accuracy: 0.4190, Loss: 2.8732
# Epoch   0 Batch  180/1077 - Train Accuracy: 0.3637, Validation Accuracy: 0.4208, Loss: 2.9128
# Epoch   0 Batch  185/1077 - Train Accuracy: 0.3609, Validation Accuracy: 0.4180, Loss: 2.9101
# Epoch   0 Batch  190/1077 - Train Accuracy: 0.3605, Validation Accuracy: 0.4197, Loss: 2.9146
# Epoch   0 Batch  195/1077 - Train Accuracy: 0.3566, Validation Accuracy: 0.4265, Loss: 2.9128
# Epoch   0 Batch  200/1077 - Train Accuracy: 0.3703, Validation Accuracy: 0.4276, Loss: 2.8510
# Epoch   0 Batch  205/1077 - Train Accuracy: 0.3785, Validation Accuracy: 0.4276, Loss: 2.8320
# Epoch   0 Batch  210/1077 - Train Accuracy: 0.4007, Validation Accuracy: 0.4315, Loss: 2.7587
# Epoch   0 Batch  215/1077 - Train Accuracy: 0.3684, Validation Accuracy: 0.4336, Loss: 2.8388
# Epoch   0 Batch  220/1077 - Train Accuracy: 0.3618, Validation Accuracy: 0.4325, Loss: 2.8774
# Epoch   0 Batch  225/1077 - Train Accuracy: 0.3770, Validation Accuracy: 0.4322, Loss: 2.7973
# Epoch   0 Batch  230/1077 - Train Accuracy: 0.4167, Validation Accuracy: 0.4329, Loss: 2.6106
# Epoch   0 Batch  235/1077 - Train Accuracy: 0.4200, Validation Accuracy: 0.4286, Loss: 2.5949
# Epoch   0 Batch  240/1077 - Train Accuracy: 0.3953, Validation Accuracy: 0.4315, Loss: 2.6749
# Epoch   0 Batch  245/1077 - Train Accuracy: 0.3988, Validation Accuracy: 0.4311, Loss: 2.6194
# Epoch   0 Batch  250/1077 - Train Accuracy: 0.4254, Validation Accuracy: 0.4336, Loss: 2.5301
# Epoch   0 Batch  255/1077 - Train Accuracy: 0.3824, Validation Accuracy: 0.4315, Loss: 2.6978
# Epoch   0 Batch  260/1077 - Train Accuracy: 0.4074, Validation Accuracy: 0.4354, Loss: 2.5746
# Epoch   0 Batch  265/1077 - Train Accuracy: 0.3914, Validation Accuracy: 0.4357, Loss: 2.6152
# Epoch   0 Batch  270/1077 - Train Accuracy: 0.3539, Validation Accuracy: 0.4329, Loss: 2.7780
# Epoch   0 Batch  275/1077 - Train Accuracy: 0.4222, Validation Accuracy: 0.4336, Loss: 2.4939
# Epoch   0 Batch  280/1077 - Train Accuracy: 0.3879, Validation Accuracy: 0.4396, Loss: 2.6114
# Epoch   0 Batch  285/1077 - Train Accuracy: 0.4156, Validation Accuracy: 0.4325, Loss: 2.4759
# Epoch   0 Batch  290/1077 - Train Accuracy: 0.4113, Validation Accuracy: 0.4535, Loss: 2.6147
# Epoch   0 Batch  295/1077 - Train Accuracy: 0.3754, Validation Accuracy: 0.4407, Loss: 2.6799
# Epoch   0 Batch  300/1077 - Train Accuracy: 0.3779, Validation Accuracy: 0.4549, Loss: 2.7032
# Epoch   0 Batch  305/1077 - Train Accuracy: 0.4074, Validation Accuracy: 0.4521, Loss: 2.5530
# Epoch   0 Batch  310/1077 - Train Accuracy: 0.3914, Validation Accuracy: 0.4602, Loss: 2.5984
# Epoch   0 Batch  315/1077 - Train Accuracy: 0.4208, Validation Accuracy: 0.4524, Loss: 2.4738
# Epoch   0 Batch  320/1077 - Train Accuracy: 0.4145, Validation Accuracy: 0.4588, Loss: 2.5571
# Epoch   0 Batch  325/1077 - Train Accuracy: 0.4542, Validation Accuracy: 0.4663, Loss: 2.3705
# Epoch   0 Batch  330/1077 - Train Accuracy: 0.4336, Validation Accuracy: 0.4606, Loss: 2.4888
# Epoch   0 Batch  335/1077 - Train Accuracy: 0.4513, Validation Accuracy: 0.4592, Loss: 2.3149
# Epoch   0 Batch  340/1077 - Train Accuracy: 0.3820, Validation Accuracy: 0.4645, Loss: 2.6141
# Epoch   0 Batch  345/1077 - Train Accuracy: 0.4312, Validation Accuracy: 0.4656, Loss: 2.4161
# Epoch   0 Batch  350/1077 - Train Accuracy: 0.4070, Validation Accuracy: 0.4648, Loss: 2.5632
# Epoch   0 Batch  355/1077 - Train Accuracy: 0.4312, Validation Accuracy: 0.4648, Loss: 2.4602
# Epoch   0 Batch  360/1077 - Train Accuracy: 0.4172, Validation Accuracy: 0.4670, Loss: 2.4671
# Epoch   0 Batch  365/1077 - Train Accuracy: 0.4043, Validation Accuracy: 0.4698, Loss: 2.5154
# Epoch   0 Batch  370/1077 - Train Accuracy: 0.4275, Validation Accuracy: 0.4666, Loss: 2.4130
# Epoch   0 Batch  375/1077 - Train Accuracy: 0.4716, Validation Accuracy: 0.4691, Loss: 2.2476
# Epoch   0 Batch  380/1077 - Train Accuracy: 0.4309, Validation Accuracy: 0.4712, Loss: 2.3823
# Epoch   0 Batch  385/1077 - Train Accuracy: 0.4215, Validation Accuracy: 0.4666, Loss: 2.4446
# Epoch   0 Batch  390/1077 - Train Accuracy: 0.4043, Validation Accuracy: 0.4680, Loss: 2.5280
# Epoch   0 Batch  395/1077 - Train Accuracy: 0.4479, Validation Accuracy: 0.4663, Loss: 2.2893
# Epoch   0 Batch  400/1077 - Train Accuracy: 0.4230, Validation Accuracy: 0.4766, Loss: 2.4329
# Epoch   0 Batch  405/1077 - Train Accuracy: 0.4202, Validation Accuracy: 0.4787, Loss: 2.4314
# Epoch   0 Batch  410/1077 - Train Accuracy: 0.3993, Validation Accuracy: 0.4769, Loss: 2.4646
# Epoch   0 Batch  415/1077 - Train Accuracy: 0.4643, Validation Accuracy: 0.4741, Loss: 2.2689
# Epoch   0 Batch  420/1077 - Train Accuracy: 0.4305, Validation Accuracy: 0.4769, Loss: 2.3705
# Epoch   0 Batch  425/1077 - Train Accuracy: 0.4520, Validation Accuracy: 0.4847, Loss: 2.2840
# Epoch   0 Batch  430/1077 - Train Accuracy: 0.4293, Validation Accuracy: 0.4854, Loss: 2.3219
# Epoch   0 Batch  435/1077 - Train Accuracy: 0.4104, Validation Accuracy: 0.4833, Loss: 2.4707
# Epoch   0 Batch  440/1077 - Train Accuracy: 0.4418, Validation Accuracy: 0.4815, Loss: 2.3011
# Epoch   0 Batch  445/1077 - Train Accuracy: 0.4215, Validation Accuracy: 0.4862, Loss: 2.4219
# Epoch   0 Batch  450/1077 - Train Accuracy: 0.4445, Validation Accuracy: 0.4830, Loss: 2.2999
# Epoch   0 Batch  455/1077 - Train Accuracy: 0.4755, Validation Accuracy: 0.4879, Loss: 2.1174
# Epoch   0 Batch  460/1077 - Train Accuracy: 0.4215, Validation Accuracy: 0.4826, Loss: 2.3280
# Epoch   0 Batch  465/1077 - Train Accuracy: 0.3988, Validation Accuracy: 0.4862, Loss: 2.4792
# Epoch   0 Batch  470/1077 - Train Accuracy: 0.4186, Validation Accuracy: 0.4812, Loss: 2.3446
# Epoch   0 Batch  475/1077 - Train Accuracy: 0.4652, Validation Accuracy: 0.4812, Loss: 2.1476
# Epoch   0 Batch  480/1077 - Train Accuracy: 0.4248, Validation Accuracy: 0.4862, Loss: 2.3031
# Epoch   0 Batch  485/1077 - Train Accuracy: 0.4437, Validation Accuracy: 0.4819, Loss: 2.2547
# Epoch   0 Batch  490/1077 - Train Accuracy: 0.4266, Validation Accuracy: 0.4851, Loss: 2.2773
# Epoch   0 Batch  495/1077 - Train Accuracy: 0.4410, Validation Accuracy: 0.4904, Loss: 2.1959
# Epoch   0 Batch  500/1077 - Train Accuracy: 0.4598, Validation Accuracy: 0.4876, Loss: 2.1911
# Epoch   0 Batch  505/1077 - Train Accuracy: 0.4781, Validation Accuracy: 0.4918, Loss: 2.0799
# Epoch   0 Batch  510/1077 - Train Accuracy: 0.4523, Validation Accuracy: 0.4833, Loss: 2.1494
# Epoch   0 Batch  515/1077 - Train Accuracy: 0.4297, Validation Accuracy: 0.4830, Loss: 2.2221
# Epoch   0 Batch  520/1077 - Train Accuracy: 0.4751, Validation Accuracy: 0.4918, Loss: 2.0737
# Epoch   0 Batch  525/1077 - Train Accuracy: 0.4297, Validation Accuracy: 0.4854, Loss: 2.2080
# Epoch   0 Batch  530/1077 - Train Accuracy: 0.4301, Validation Accuracy: 0.4922, Loss: 2.2254
# Epoch   0 Batch  535/1077 - Train Accuracy: 0.4367, Validation Accuracy: 0.4908, Loss: 2.1408
# Epoch   0 Batch  540/1077 - Train Accuracy: 0.4562, Validation Accuracy: 0.4989, Loss: 2.0568
# Epoch   0 Batch  545/1077 - Train Accuracy: 0.4242, Validation Accuracy: 0.4904, Loss: 2.2249
# Epoch   0 Batch  550/1077 - Train Accuracy: 0.4168, Validation Accuracy: 0.4925, Loss: 2.2008
# Epoch   0 Batch  555/1077 - Train Accuracy: 0.4547, Validation Accuracy: 0.4886, Loss: 2.0706
# Epoch   0 Batch  560/1077 - Train Accuracy: 0.4555, Validation Accuracy: 0.4936, Loss: 2.0650
# Epoch   0 Batch  565/1077 - Train Accuracy: 0.4613, Validation Accuracy: 0.4972, Loss: 2.0707
# Epoch   0 Batch  570/1077 - Train Accuracy: 0.4433, Validation Accuracy: 0.4964, Loss: 2.1424
# Epoch   0 Batch  575/1077 - Train Accuracy: 0.4866, Validation Accuracy: 0.4957, Loss: 1.9958
# Epoch   0 Batch  580/1077 - Train Accuracy: 0.4814, Validation Accuracy: 0.4989, Loss: 1.9819
# Epoch   0 Batch  585/1077 - Train Accuracy: 0.4721, Validation Accuracy: 0.4972, Loss: 1.9162
# Epoch   0 Batch  590/1077 - Train Accuracy: 0.4202, Validation Accuracy: 0.4922, Loss: 2.1175
# Epoch   0 Batch  595/1077 - Train Accuracy: 0.4313, Validation Accuracy: 0.4925, Loss: 2.1098
# Epoch   0 Batch  600/1077 - Train Accuracy: 0.4862, Validation Accuracy: 0.4986, Loss: 1.9267
# Epoch   0 Batch  605/1077 - Train Accuracy: 0.4453, Validation Accuracy: 0.5085, Loss: 2.0916
# Epoch   0 Batch  610/1077 - Train Accuracy: 0.4396, Validation Accuracy: 0.5036, Loss: 2.0711
# Epoch   0 Batch  615/1077 - Train Accuracy: 0.4902, Validation Accuracy: 0.5014, Loss: 1.9513
# Epoch   0 Batch  620/1077 - Train Accuracy: 0.4555, Validation Accuracy: 0.5060, Loss: 1.9948
# Epoch   0 Batch  625/1077 - Train Accuracy: 0.4828, Validation Accuracy: 0.5060, Loss: 1.9541
# Epoch   0 Batch  630/1077 - Train Accuracy: 0.4648, Validation Accuracy: 0.5064, Loss: 1.9550
# Epoch   0 Batch  635/1077 - Train Accuracy: 0.4326, Validation Accuracy: 0.5188, Loss: 2.0598
# Epoch   0 Batch  640/1077 - Train Accuracy: 0.4654, Validation Accuracy: 0.5103, Loss: 1.9084
# Epoch   0 Batch  645/1077 - Train Accuracy: 0.4821, Validation Accuracy: 0.5085, Loss: 1.8759
# Epoch   0 Batch  650/1077 - Train Accuracy: 0.4590, Validation Accuracy: 0.5206, Loss: 1.9702
# Epoch   0 Batch  655/1077 - Train Accuracy: 0.4738, Validation Accuracy: 0.5224, Loss: 1.9251
# Epoch   0 Batch  660/1077 - Train Accuracy: 0.4695, Validation Accuracy: 0.5188, Loss: 1.9605
# Epoch   0 Batch  665/1077 - Train Accuracy: 0.4629, Validation Accuracy: 0.5206, Loss: 1.9363
# Epoch   0 Batch  670/1077 - Train Accuracy: 0.5423, Validation Accuracy: 0.5192, Loss: 1.6974
# Epoch   0 Batch  675/1077 - Train Accuracy: 0.4706, Validation Accuracy: 0.5117, Loss: 1.8397
# Epoch   0 Batch  680/1077 - Train Accuracy: 0.4773, Validation Accuracy: 0.5210, Loss: 1.8540
# Epoch   0 Batch  685/1077 - Train Accuracy: 0.4387, Validation Accuracy: 0.5082, Loss: 1.9609
# Epoch   0 Batch  690/1077 - Train Accuracy: 0.4641, Validation Accuracy: 0.5124, Loss: 1.8554
# Epoch   0 Batch  695/1077 - Train Accuracy: 0.4789, Validation Accuracy: 0.5124, Loss: 1.8369
# Epoch   0 Batch  700/1077 - Train Accuracy: 0.4617, Validation Accuracy: 0.5188, Loss: 1.8438
# Epoch   0 Batch  705/1077 - Train Accuracy: 0.4659, Validation Accuracy: 0.5131, Loss: 1.9410
# Epoch   0 Batch  710/1077 - Train Accuracy: 0.4559, Validation Accuracy: 0.5256, Loss: 1.8756
# Epoch   0 Batch  715/1077 - Train Accuracy: 0.4535, Validation Accuracy: 0.5018, Loss: 1.8924
# Epoch   0 Batch  720/1077 - Train Accuracy: 0.4831, Validation Accuracy: 0.5344, Loss: 1.9542
# Epoch   0 Batch  725/1077 - Train Accuracy: 0.4807, Validation Accuracy: 0.5273, Loss: 1.7664
# Epoch   0 Batch  730/1077 - Train Accuracy: 0.4527, Validation Accuracy: 0.5060, Loss: 1.8175
# Epoch   0 Batch  735/1077 - Train Accuracy: 0.4574, Validation Accuracy: 0.5206, Loss: 1.8494
# Epoch   0 Batch  740/1077 - Train Accuracy: 0.4836, Validation Accuracy: 0.5089, Loss: 1.7923
# Epoch   0 Batch  745/1077 - Train Accuracy: 0.4801, Validation Accuracy: 0.5128, Loss: 1.7739
# Epoch   0 Batch  750/1077 - Train Accuracy: 0.4672, Validation Accuracy: 0.5131, Loss: 1.7995
# Epoch   0 Batch  755/1077 - Train Accuracy: 0.4680, Validation Accuracy: 0.5025, Loss: 1.7645
# Epoch   0 Batch  760/1077 - Train Accuracy: 0.4789, Validation Accuracy: 0.5163, Loss: 1.8044
# Epoch   0 Batch  765/1077 - Train Accuracy: 0.4906, Validation Accuracy: 0.5234, Loss: 1.7311
# Epoch   0 Batch  770/1077 - Train Accuracy: 0.4903, Validation Accuracy: 0.5117, Loss: 1.7150
# Epoch   0 Batch  775/1077 - Train Accuracy: 0.4781, Validation Accuracy: 0.5199, Loss: 1.7478
# Epoch   0 Batch  780/1077 - Train Accuracy: 0.4715, Validation Accuracy: 0.5249, Loss: 1.7813
# Epoch   0 Batch  785/1077 - Train Accuracy: 0.5052, Validation Accuracy: 0.5330, Loss: 1.7004
# Epoch   0 Batch  790/1077 - Train Accuracy: 0.4297, Validation Accuracy: 0.5241, Loss: 1.8605
# Epoch   0 Batch  795/1077 - Train Accuracy: 0.4695, Validation Accuracy: 0.5174, Loss: 1.7752
# Epoch   0 Batch  800/1077 - Train Accuracy: 0.4617, Validation Accuracy: 0.5213, Loss: 1.7987
# Epoch   0 Batch  805/1077 - Train Accuracy: 0.4938, Validation Accuracy: 0.5234, Loss: 1.7379
# Epoch   0 Batch  810/1077 - Train Accuracy: 0.5060, Validation Accuracy: 0.5146, Loss: 1.6311
# Epoch   0 Batch  815/1077 - Train Accuracy: 0.4711, Validation Accuracy: 0.5234, Loss: 1.6931
# Epoch   0 Batch  820/1077 - Train Accuracy: 0.4355, Validation Accuracy: 0.5210, Loss: 1.7616
# Epoch   0 Batch  825/1077 - Train Accuracy: 0.4516, Validation Accuracy: 0.5181, Loss: 1.7348
# Epoch   0 Batch  830/1077 - Train Accuracy: 0.4625, Validation Accuracy: 0.5256, Loss: 1.6915
# Epoch   0 Batch  835/1077 - Train Accuracy: 0.4844, Validation Accuracy: 0.5241, Loss: 1.7319
# Epoch   0 Batch  840/1077 - Train Accuracy: 0.4762, Validation Accuracy: 0.5391, Loss: 1.7147
# Epoch   0 Batch  845/1077 - Train Accuracy: 0.4824, Validation Accuracy: 0.5305, Loss: 1.6942
# Epoch   0 Batch  850/1077 - Train Accuracy: 0.4978, Validation Accuracy: 0.5376, Loss: 1.7087
# Epoch   0 Batch  855/1077 - Train Accuracy: 0.4684, Validation Accuracy: 0.5312, Loss: 1.6609
# Epoch   0 Batch  860/1077 - Train Accuracy: 0.4784, Validation Accuracy: 0.5234, Loss: 1.6243
# Epoch   0 Batch  865/1077 - Train Accuracy: 0.5263, Validation Accuracy: 0.5344, Loss: 1.5099
# Epoch   0 Batch  870/1077 - Train Accuracy: 0.4342, Validation Accuracy: 0.5160, Loss: 1.7855
# Epoch   0 Batch  875/1077 - Train Accuracy: 0.4723, Validation Accuracy: 0.5210, Loss: 1.6619
# Epoch   0 Batch  880/1077 - Train Accuracy: 0.4879, Validation Accuracy: 0.5142, Loss: 1.5980
# Epoch   0 Batch  885/1077 - Train Accuracy: 0.5195, Validation Accuracy: 0.5227, Loss: 1.4807
# Epoch   0 Batch  890/1077 - Train Accuracy: 0.5238, Validation Accuracy: 0.5224, Loss: 1.4981
# Epoch   0 Batch  895/1077 - Train Accuracy: 0.4652, Validation Accuracy: 0.5224, Loss: 1.6358
# Epoch   0 Batch  900/1077 - Train Accuracy: 0.4617, Validation Accuracy: 0.5291, Loss: 1.7001
# Epoch   0 Batch  905/1077 - Train Accuracy: 0.4793, Validation Accuracy: 0.5259, Loss: 1.6260
# Epoch   0 Batch  910/1077 - Train Accuracy: 0.4810, Validation Accuracy: 0.5266, Loss: 1.5746
# Epoch   0 Batch  915/1077 - Train Accuracy: 0.4186, Validation Accuracy: 0.5181, Loss: 1.7552
# Epoch   0 Batch  920/1077 - Train Accuracy: 0.4641, Validation Accuracy: 0.5107, Loss: 1.6277
# Epoch   0 Batch  925/1077 - Train Accuracy: 0.4624, Validation Accuracy: 0.5213, Loss: 1.5710
# Epoch   0 Batch  930/1077 - Train Accuracy: 0.4688, Validation Accuracy: 0.5224, Loss: 1.5835
# Epoch   0 Batch  935/1077 - Train Accuracy: 0.4766, Validation Accuracy: 0.5266, Loss: 1.6414
# Epoch   0 Batch  940/1077 - Train Accuracy: 0.4707, Validation Accuracy: 0.5263, Loss: 1.6491
# Epoch   0 Batch  945/1077 - Train Accuracy: 0.4984, Validation Accuracy: 0.5320, Loss: 1.5948
# Epoch   0 Batch  950/1077 - Train Accuracy: 0.4758, Validation Accuracy: 0.5138, Loss: 1.5839
# Epoch   0 Batch  955/1077 - Train Accuracy: 0.4746, Validation Accuracy: 0.5234, Loss: 1.5897
# Epoch   0 Batch  960/1077 - Train Accuracy: 0.5011, Validation Accuracy: 0.5277, Loss: 1.5038
# Epoch   0 Batch  965/1077 - Train Accuracy: 0.4285, Validation Accuracy: 0.5288, Loss: 1.7201
# Epoch   0 Batch  970/1077 - Train Accuracy: 0.4648, Validation Accuracy: 0.5199, Loss: 1.5935
# Epoch   0 Batch  975/1077 - Train Accuracy: 0.5190, Validation Accuracy: 0.5352, Loss: 1.4541
# Epoch   0 Batch  980/1077 - Train Accuracy: 0.5066, Validation Accuracy: 0.5330, Loss: 1.5239
# Epoch   0 Batch  985/1077 - Train Accuracy: 0.5266, Validation Accuracy: 0.5405, Loss: 1.5330
# Epoch   0 Batch  990/1077 - Train Accuracy: 0.4696, Validation Accuracy: 0.5206, Loss: 1.6022
# Epoch   0 Batch  995/1077 - Train Accuracy: 0.5305, Validation Accuracy: 0.5320, Loss: 1.4840
# Epoch   0 Batch 1000/1077 - Train Accuracy: 0.5346, Validation Accuracy: 0.5071, Loss: 1.4543
# Epoch   0 Batch 1005/1077 - Train Accuracy: 0.4676, Validation Accuracy: 0.5199, Loss: 1.5612
# Epoch   0 Batch 1010/1077 - Train Accuracy: 0.4527, Validation Accuracy: 0.5121, Loss: 1.5702
# Epoch   0 Batch 1015/1077 - Train Accuracy: 0.4633, Validation Accuracy: 0.5210, Loss: 1.5536
# Epoch   0 Batch 1020/1077 - Train Accuracy: 0.4570, Validation Accuracy: 0.5202, Loss: 1.5057
# Epoch   0 Batch 1025/1077 - Train Accuracy: 0.4959, Validation Accuracy: 0.5369, Loss: 1.4687
# Epoch   0 Batch 1030/1077 - Train Accuracy: 0.4648, Validation Accuracy: 0.5217, Loss: 1.5505
# Epoch   0 Batch 1035/1077 - Train Accuracy: 0.5082, Validation Accuracy: 0.5309, Loss: 1.4475
# Epoch   0 Batch 1040/1077 - Train Accuracy: 0.4535, Validation Accuracy: 0.5096, Loss: 1.5636
# Epoch   0 Batch 1045/1077 - Train Accuracy: 0.4352, Validation Accuracy: 0.5241, Loss: 1.5563
# Epoch   0 Batch 1050/1077 - Train Accuracy: 0.4430, Validation Accuracy: 0.5234, Loss: 1.5756
# Epoch   0 Batch 1055/1077 - Train Accuracy: 0.4965, Validation Accuracy: 0.4879, Loss: 1.5118
# Epoch   0 Batch 1060/1077 - Train Accuracy: 0.4832, Validation Accuracy: 0.5195, Loss: 1.4909
# Epoch   0 Batch 1065/1077 - Train Accuracy: 0.4867, Validation Accuracy: 0.5217, Loss: 1.4639
# Epoch   0 Batch 1070/1077 - Train Accuracy: 0.4520, Validation Accuracy: 0.5039, Loss: 1.5126
# Epoch   0 Batch 1075/1077 - Train Accuracy: 0.4659, Validation Accuracy: 0.5149, Loss: 1.5306
# Epoch   1 Batch    5/1077 - Train Accuracy: 0.4738, Validation Accuracy: 0.5217, Loss: 1.4795
# Epoch   1 Batch   10/1077 - Train Accuracy: 0.4453, Validation Accuracy: 0.5117, Loss: 1.5531
# Epoch   1 Batch   15/1077 - Train Accuracy: 0.4695, Validation Accuracy: 0.5110, Loss: 1.4449
# Epoch   1 Batch   20/1077 - Train Accuracy: 0.4730, Validation Accuracy: 0.5181, Loss: 1.4052
# Epoch   1 Batch   25/1077 - Train Accuracy: 0.4527, Validation Accuracy: 0.5185, Loss: 1.4459
# Epoch   1 Batch   30/1077 - Train Accuracy: 0.4824, Validation Accuracy: 0.5121, Loss: 1.4078
# Epoch   1 Batch   35/1077 - Train Accuracy: 0.4809, Validation Accuracy: 0.5210, Loss: 1.4395
# Epoch   1 Batch   40/1077 - Train Accuracy: 0.4727, Validation Accuracy: 0.5188, Loss: 1.4304
# Epoch   1 Batch   45/1077 - Train Accuracy: 0.4715, Validation Accuracy: 0.5149, Loss: 1.4574
# Epoch   1 Batch   50/1077 - Train Accuracy: 0.4473, Validation Accuracy: 0.5078, Loss: 1.4793
# Epoch   1 Batch   55/1077 - Train Accuracy: 0.5109, Validation Accuracy: 0.5064, Loss: 1.3732
# Epoch   1 Batch   60/1077 - Train Accuracy: 0.4647, Validation Accuracy: 0.5014, Loss: 1.3762
# Epoch   1 Batch   65/1077 - Train Accuracy: 0.4313, Validation Accuracy: 0.5025, Loss: 1.4946
# Epoch   1 Batch   70/1077 - Train Accuracy: 0.4478, Validation Accuracy: 0.5067, Loss: 1.4834
# Epoch   1 Batch   75/1077 - Train Accuracy: 0.4852, Validation Accuracy: 0.5099, Loss: 1.3522
# Epoch   1 Batch   80/1077 - Train Accuracy: 0.4703, Validation Accuracy: 0.5245, Loss: 1.4080
# Epoch   1 Batch   85/1077 - Train Accuracy: 0.5000, Validation Accuracy: 0.5245, Loss: 1.3298
# Epoch   1 Batch   90/1077 - Train Accuracy: 0.4598, Validation Accuracy: 0.5025, Loss: 1.4467
# Epoch   1 Batch   95/1077 - Train Accuracy: 0.5123, Validation Accuracy: 0.5167, Loss: 1.3660
# Epoch   1 Batch  100/1077 - Train Accuracy: 0.4898, Validation Accuracy: 0.5181, Loss: 1.3797
# Epoch   1 Batch  105/1077 - Train Accuracy: 0.4852, Validation Accuracy: 0.5210, Loss: 1.3237
# Epoch   1 Batch  110/1077 - Train Accuracy: 0.5117, Validation Accuracy: 0.5210, Loss: 1.3311
# Epoch   1 Batch  115/1077 - Train Accuracy: 0.4762, Validation Accuracy: 0.5167, Loss: 1.4021
# Epoch   1 Batch  120/1077 - Train Accuracy: 0.4750, Validation Accuracy: 0.5131, Loss: 1.3692
# Epoch   1 Batch  125/1077 - Train Accuracy: 0.4874, Validation Accuracy: 0.5099, Loss: 1.3659
# Epoch   1 Batch  130/1077 - Train Accuracy: 0.4747, Validation Accuracy: 0.5089, Loss: 1.2723
# Epoch   1 Batch  135/1077 - Train Accuracy: 0.4897, Validation Accuracy: 0.5288, Loss: 1.3969
# Epoch   1 Batch  140/1077 - Train Accuracy: 0.4404, Validation Accuracy: 0.5050, Loss: 1.4372
# Epoch   1 Batch  145/1077 - Train Accuracy: 0.4871, Validation Accuracy: 0.5014, Loss: 1.2943
# Epoch   1 Batch  150/1077 - Train Accuracy: 0.4959, Validation Accuracy: 0.5032, Loss: 1.2761
# Epoch   1 Batch  155/1077 - Train Accuracy: 0.4684, Validation Accuracy: 0.5082, Loss: 1.3375
# Epoch   1 Batch  160/1077 - Train Accuracy: 0.4914, Validation Accuracy: 0.5117, Loss: 1.3163
# Epoch   1 Batch  165/1077 - Train Accuracy: 0.4621, Validation Accuracy: 0.5092, Loss: 1.3322
# Epoch   1 Batch  170/1077 - Train Accuracy: 0.4484, Validation Accuracy: 0.4968, Loss: 1.3645
# Epoch   1 Batch  175/1077 - Train Accuracy: 0.4891, Validation Accuracy: 0.4964, Loss: 1.2666
# Epoch   1 Batch  180/1077 - Train Accuracy: 0.4719, Validation Accuracy: 0.4964, Loss: 1.2939
# Epoch   1 Batch  185/1077 - Train Accuracy: 0.4426, Validation Accuracy: 0.5018, Loss: 1.3116
# Epoch   1 Batch  190/1077 - Train Accuracy: 0.4914, Validation Accuracy: 0.5099, Loss: 1.3043
# Epoch   1 Batch  195/1077 - Train Accuracy: 0.4465, Validation Accuracy: 0.5043, Loss: 1.3091
# Epoch   1 Batch  200/1077 - Train Accuracy: 0.4492, Validation Accuracy: 0.4964, Loss: 1.2977
# Epoch   1 Batch  205/1077 - Train Accuracy: 0.4734, Validation Accuracy: 0.4890, Loss: 1.2932
# Epoch   1 Batch  210/1077 - Train Accuracy: 0.4911, Validation Accuracy: 0.4989, Loss: 1.2926
# Epoch   1 Batch  215/1077 - Train Accuracy: 0.4484, Validation Accuracy: 0.4947, Loss: 1.2991
# Epoch   1 Batch  220/1077 - Train Accuracy: 0.4556, Validation Accuracy: 0.5000, Loss: 1.3114
# Epoch   1 Batch  225/1077 - Train Accuracy: 0.4664, Validation Accuracy: 0.4943, Loss: 1.2875
# Epoch   1 Batch  230/1077 - Train Accuracy: 0.4795, Validation Accuracy: 0.5004, Loss: 1.1959
# Epoch   1 Batch  235/1077 - Train Accuracy: 0.4840, Validation Accuracy: 0.4915, Loss: 1.1889
# Epoch   1 Batch  240/1077 - Train Accuracy: 0.4617, Validation Accuracy: 0.4858, Loss: 1.2278
# Epoch   1 Batch  245/1077 - Train Accuracy: 0.4557, Validation Accuracy: 0.4933, Loss: 1.2169
# Epoch   1 Batch  250/1077 - Train Accuracy: 0.4918, Validation Accuracy: 0.4972, Loss: 1.1758
# Epoch   1 Batch  255/1077 - Train Accuracy: 0.4543, Validation Accuracy: 0.4929, Loss: 1.2679
# Epoch   1 Batch  260/1077 - Train Accuracy: 0.4989, Validation Accuracy: 0.5121, Loss: 1.1975
# Epoch   1 Batch  265/1077 - Train Accuracy: 0.4656, Validation Accuracy: 0.5082, Loss: 1.2265
# Epoch   1 Batch  270/1077 - Train Accuracy: 0.4164, Validation Accuracy: 0.5025, Loss: 1.3228
# Epoch   1 Batch  275/1077 - Train Accuracy: 0.4710, Validation Accuracy: 0.4901, Loss: 1.1699
# Epoch   1 Batch  280/1077 - Train Accuracy: 0.4500, Validation Accuracy: 0.4854, Loss: 1.2556
# Epoch   1 Batch  285/1077 - Train Accuracy: 0.4769, Validation Accuracy: 0.4602, Loss: 1.1534
# Epoch   1 Batch  290/1077 - Train Accuracy: 0.4398, Validation Accuracy: 0.4954, Loss: 1.2453
# Epoch   1 Batch  295/1077 - Train Accuracy: 0.4507, Validation Accuracy: 0.5028, Loss: 1.2941
# Epoch   1 Batch  300/1077 - Train Accuracy: 0.4227, Validation Accuracy: 0.4840, Loss: 1.2837
# Epoch   1 Batch  305/1077 - Train Accuracy: 0.4727, Validation Accuracy: 0.4943, Loss: 1.2155
# Epoch   1 Batch  310/1077 - Train Accuracy: 0.4355, Validation Accuracy: 0.4872, Loss: 1.2288
# Epoch   1 Batch  315/1077 - Train Accuracy: 0.4702, Validation Accuracy: 0.4790, Loss: 1.1790
# Epoch   1 Batch  320/1077 - Train Accuracy: 0.4461, Validation Accuracy: 0.4762, Loss: 1.2252
# Epoch   1 Batch  325/1077 - Train Accuracy: 0.4836, Validation Accuracy: 0.4819, Loss: 1.1161
# Epoch   1 Batch  330/1077 - Train Accuracy: 0.4340, Validation Accuracy: 0.4844, Loss: 1.2023
# Epoch   1 Batch  335/1077 - Train Accuracy: 0.4792, Validation Accuracy: 0.4769, Loss: 1.0867
# Epoch   1 Batch  340/1077 - Train Accuracy: 0.3951, Validation Accuracy: 0.4762, Loss: 1.2280
# Epoch   1 Batch  345/1077 - Train Accuracy: 0.4394, Validation Accuracy: 0.4727, Loss: 1.1565
# Epoch   1 Batch  350/1077 - Train Accuracy: 0.3992, Validation Accuracy: 0.4819, Loss: 1.2663
# Epoch   1 Batch  355/1077 - Train Accuracy: 0.4468, Validation Accuracy: 0.4801, Loss: 1.1953
# Epoch   1 Batch  360/1077 - Train Accuracy: 0.3992, Validation Accuracy: 0.4837, Loss: 1.1814
# Epoch   1 Batch  365/1077 - Train Accuracy: 0.4105, Validation Accuracy: 0.4869, Loss: 1.2038
# Epoch   1 Batch  370/1077 - Train Accuracy: 0.3988, Validation Accuracy: 0.4606, Loss: 1.1450
# Epoch   1 Batch  375/1077 - Train Accuracy: 0.4822, Validation Accuracy: 0.4879, Loss: 1.0878
# Epoch   1 Batch  380/1077 - Train Accuracy: 0.4586, Validation Accuracy: 0.5092, Loss: 1.1395
# Epoch   1 Batch  385/1077 - Train Accuracy: 0.4156, Validation Accuracy: 0.4883, Loss: 1.1940
# Epoch   1 Batch  390/1077 - Train Accuracy: 0.4164, Validation Accuracy: 0.4908, Loss: 1.2248
# Epoch   1 Batch  395/1077 - Train Accuracy: 0.4721, Validation Accuracy: 0.4819, Loss: 1.0891
# Epoch   1 Batch  400/1077 - Train Accuracy: 0.4504, Validation Accuracy: 0.4950, Loss: 1.1857
# Epoch   1 Batch  405/1077 - Train Accuracy: 0.3988, Validation Accuracy: 0.4531, Loss: 1.1900
# Epoch   1 Batch  410/1077 - Train Accuracy: 0.3791, Validation Accuracy: 0.4680, Loss: 1.1907
# Epoch   1 Batch  415/1077 - Train Accuracy: 0.4587, Validation Accuracy: 0.4734, Loss: 1.1116
# Epoch   1 Batch  420/1077 - Train Accuracy: 0.4203, Validation Accuracy: 0.4840, Loss: 1.1548
# Epoch   1 Batch  425/1077 - Train Accuracy: 0.4606, Validation Accuracy: 0.4808, Loss: 1.1086
# Epoch   1 Batch  430/1077 - Train Accuracy: 0.4402, Validation Accuracy: 0.4936, Loss: 1.1289
# Epoch   1 Batch  435/1077 - Train Accuracy: 0.4202, Validation Accuracy: 0.4954, Loss: 1.2151
# Epoch   1 Batch  440/1077 - Train Accuracy: 0.4699, Validation Accuracy: 0.5117, Loss: 1.1514
# Epoch   1 Batch  445/1077 - Train Accuracy: 0.4342, Validation Accuracy: 0.5050, Loss: 1.2091
# Epoch   1 Batch  450/1077 - Train Accuracy: 0.4555, Validation Accuracy: 0.4641, Loss: 1.1305
# Epoch   1 Batch  455/1077 - Train Accuracy: 0.4712, Validation Accuracy: 0.4627, Loss: 1.0538
# Epoch   1 Batch  460/1077 - Train Accuracy: 0.3898, Validation Accuracy: 0.4854, Loss: 1.1452
# Epoch   1 Batch  465/1077 - Train Accuracy: 0.3886, Validation Accuracy: 0.4766, Loss: 1.2159
# Epoch   1 Batch  470/1077 - Train Accuracy: 0.4387, Validation Accuracy: 0.4879, Loss: 1.1661
# Epoch   1 Batch  475/1077 - Train Accuracy: 0.4598, Validation Accuracy: 0.4776, Loss: 1.0534
# Epoch   1 Batch  480/1077 - Train Accuracy: 0.4239, Validation Accuracy: 0.4822, Loss: 1.1562
# Epoch   1 Batch  485/1077 - Train Accuracy: 0.4602, Validation Accuracy: 0.5032, Loss: 1.1085
# Epoch   1 Batch  490/1077 - Train Accuracy: 0.4523, Validation Accuracy: 0.4847, Loss: 1.1353
# Epoch   1 Batch  495/1077 - Train Accuracy: 0.4508, Validation Accuracy: 0.4901, Loss: 1.0932
# Epoch   1 Batch  500/1077 - Train Accuracy: 0.4539, Validation Accuracy: 0.4830, Loss: 1.1015
# Epoch   1 Batch  505/1077 - Train Accuracy: 0.4859, Validation Accuracy: 0.4968, Loss: 1.0137
# Epoch   1 Batch  510/1077 - Train Accuracy: 0.4977, Validation Accuracy: 0.5036, Loss: 1.0858
# Epoch   1 Batch  515/1077 - Train Accuracy: 0.4242, Validation Accuracy: 0.4837, Loss: 1.1281
# Epoch   1 Batch  520/1077 - Train Accuracy: 0.4565, Validation Accuracy: 0.4631, Loss: 1.0428
# Epoch   1 Batch  525/1077 - Train Accuracy: 0.4289, Validation Accuracy: 0.4663, Loss: 1.1132
# Epoch   1 Batch  530/1077 - Train Accuracy: 0.4383, Validation Accuracy: 0.4890, Loss: 1.1084
# Epoch   1 Batch  535/1077 - Train Accuracy: 0.4676, Validation Accuracy: 0.5096, Loss: 1.0750
# Epoch   1 Batch  540/1077 - Train Accuracy: 0.4504, Validation Accuracy: 0.4833, Loss: 1.0556
# Epoch   1 Batch  545/1077 - Train Accuracy: 0.4395, Validation Accuracy: 0.4776, Loss: 1.1502
# Epoch   1 Batch  550/1077 - Train Accuracy: 0.4230, Validation Accuracy: 0.4925, Loss: 1.1170
# Epoch   1 Batch  555/1077 - Train Accuracy: 0.4715, Validation Accuracy: 0.4908, Loss: 1.0538
# Epoch   1 Batch  560/1077 - Train Accuracy: 0.4715, Validation Accuracy: 0.4865, Loss: 1.0516
# Epoch   1 Batch  565/1077 - Train Accuracy: 0.4900, Validation Accuracy: 0.4925, Loss: 1.0680
# Epoch   1 Batch  570/1077 - Train Accuracy: 0.4474, Validation Accuracy: 0.4929, Loss: 1.0986
# Epoch   1 Batch  575/1077 - Train Accuracy: 0.4840, Validation Accuracy: 0.4893, Loss: 1.0414
# Epoch   1 Batch  580/1077 - Train Accuracy: 0.4661, Validation Accuracy: 0.4851, Loss: 1.0177
# Epoch   1 Batch  585/1077 - Train Accuracy: 0.4740, Validation Accuracy: 0.4879, Loss: 0.9805
# Epoch   1 Batch  590/1077 - Train Accuracy: 0.4174, Validation Accuracy: 0.4950, Loss: 1.1014
# Epoch   1 Batch  595/1077 - Train Accuracy: 0.4504, Validation Accuracy: 0.5039, Loss: 1.1165
# Epoch   1 Batch  600/1077 - Train Accuracy: 0.4862, Validation Accuracy: 0.5000, Loss: 1.0245
# Epoch   1 Batch  605/1077 - Train Accuracy: 0.4387, Validation Accuracy: 0.4897, Loss: 1.1074
# Epoch   1 Batch  610/1077 - Train Accuracy: 0.4264, Validation Accuracy: 0.4595, Loss: 1.1020
# Epoch   1 Batch  615/1077 - Train Accuracy: 0.4602, Validation Accuracy: 0.4727, Loss: 1.0232
# Epoch   1 Batch  620/1077 - Train Accuracy: 0.4344, Validation Accuracy: 0.4570, Loss: 1.0545
# Epoch   1 Batch  625/1077 - Train Accuracy: 0.4750, Validation Accuracy: 0.4734, Loss: 1.0450
# Epoch   1 Batch  630/1077 - Train Accuracy: 0.4758, Validation Accuracy: 0.4989, Loss: 1.0408
# Epoch   1 Batch  635/1077 - Train Accuracy: 0.4507, Validation Accuracy: 0.5053, Loss: 1.1113
# Epoch   1 Batch  640/1077 - Train Accuracy: 0.4609, Validation Accuracy: 0.5131, Loss: 1.0085
# Epoch   1 Batch  645/1077 - Train Accuracy: 0.4751, Validation Accuracy: 0.4893, Loss: 1.0224
# Epoch   1 Batch  650/1077 - Train Accuracy: 0.4246, Validation Accuracy: 0.4840, Loss: 1.0609
# Epoch   1 Batch  655/1077 - Train Accuracy: 0.4508, Validation Accuracy: 0.4769, Loss: 1.0397
# Epoch   1 Batch  660/1077 - Train Accuracy: 0.4367, Validation Accuracy: 0.4787, Loss: 1.0584
# Epoch   1 Batch  665/1077 - Train Accuracy: 0.4336, Validation Accuracy: 0.4776, Loss: 1.0437
# Epoch   1 Batch  670/1077 - Train Accuracy: 0.5192, Validation Accuracy: 0.4624, Loss: 0.9378
# Epoch   1 Batch  675/1077 - Train Accuracy: 0.4650, Validation Accuracy: 0.4641, Loss: 1.0043
# Epoch   1 Batch  680/1077 - Train Accuracy: 0.4594, Validation Accuracy: 0.4521, Loss: 1.0144
# Epoch   1 Batch  685/1077 - Train Accuracy: 0.4227, Validation Accuracy: 0.4759, Loss: 1.0665
# Epoch   1 Batch  690/1077 - Train Accuracy: 0.4648, Validation Accuracy: 0.4922, Loss: 1.0206
# Epoch   1 Batch  695/1077 - Train Accuracy: 0.4852, Validation Accuracy: 0.4798, Loss: 0.9938
# Epoch   1 Batch  700/1077 - Train Accuracy: 0.4773, Validation Accuracy: 0.4801, Loss: 0.9996
# Epoch   1 Batch  705/1077 - Train Accuracy: 0.4227, Validation Accuracy: 0.4819, Loss: 1.0798
# Epoch   1 Batch  710/1077 - Train Accuracy: 0.4512, Validation Accuracy: 0.4950, Loss: 1.0178
# Epoch   1 Batch  715/1077 - Train Accuracy: 0.4500, Validation Accuracy: 0.4684, Loss: 1.0875
# Epoch   1 Batch  720/1077 - Train Accuracy: 0.3984, Validation Accuracy: 0.4904, Loss: 1.0963
# Epoch   1 Batch  725/1077 - Train Accuracy: 0.4475, Validation Accuracy: 0.4723, Loss: 0.9631
# Epoch   1 Batch  730/1077 - Train Accuracy: 0.4652, Validation Accuracy: 0.5050, Loss: 0.9998
# Epoch   1 Batch  735/1077 - Train Accuracy: 0.4535, Validation Accuracy: 0.5039, Loss: 1.0315
# Epoch   1 Batch  740/1077 - Train Accuracy: 0.4723, Validation Accuracy: 0.4833, Loss: 0.9916
# Epoch   1 Batch  745/1077 - Train Accuracy: 0.4840, Validation Accuracy: 0.5025, Loss: 0.9949
# Epoch   1 Batch  750/1077 - Train Accuracy: 0.4625, Validation Accuracy: 0.4950, Loss: 0.9979
# Epoch   1 Batch  755/1077 - Train Accuracy: 0.4559, Validation Accuracy: 0.4947, Loss: 0.9829
# Epoch   1 Batch  760/1077 - Train Accuracy: 0.4836, Validation Accuracy: 0.4993, Loss: 1.0333
# Epoch   1 Batch  765/1077 - Train Accuracy: 0.4703, Validation Accuracy: 0.5039, Loss: 0.9563
# Epoch   1 Batch  770/1077 - Train Accuracy: 0.4688, Validation Accuracy: 0.4929, Loss: 0.9599
# Epoch   1 Batch  775/1077 - Train Accuracy: 0.4895, Validation Accuracy: 0.5014, Loss: 0.9900
# Epoch   1 Batch  780/1077 - Train Accuracy: 0.4168, Validation Accuracy: 0.4545, Loss: 1.0249
# Epoch   1 Batch  785/1077 - Train Accuracy: 0.4557, Validation Accuracy: 0.4833, Loss: 0.9458
# Epoch   1 Batch  790/1077 - Train Accuracy: 0.4008, Validation Accuracy: 0.4801, Loss: 1.0575
# Epoch   1 Batch  795/1077 - Train Accuracy: 0.4289, Validation Accuracy: 0.4815, Loss: 1.0197
# Epoch   1 Batch  800/1077 - Train Accuracy: 0.4418, Validation Accuracy: 0.4652, Loss: 1.0177
# Epoch   1 Batch  805/1077 - Train Accuracy: 0.4512, Validation Accuracy: 0.4847, Loss: 0.9905
# Epoch   1 Batch  810/1077 - Train Accuracy: 0.4926, Validation Accuracy: 0.5021, Loss: 0.9322
# Epoch   1 Batch  815/1077 - Train Accuracy: 0.4434, Validation Accuracy: 0.4911, Loss: 0.9641
# Epoch   1 Batch  820/1077 - Train Accuracy: 0.4059, Validation Accuracy: 0.4940, Loss: 1.0161
# Epoch   1 Batch  825/1077 - Train Accuracy: 0.4656, Validation Accuracy: 0.4940, Loss: 0.9829
# Epoch   1 Batch  830/1077 - Train Accuracy: 0.4535, Validation Accuracy: 0.5011, Loss: 0.9710
# Epoch   1 Batch  835/1077 - Train Accuracy: 0.4449, Validation Accuracy: 0.4858, Loss: 0.9967
# Epoch   1 Batch  840/1077 - Train Accuracy: 0.4301, Validation Accuracy: 0.4698, Loss: 0.9700
# Epoch   1 Batch  845/1077 - Train Accuracy: 0.4340, Validation Accuracy: 0.4705, Loss: 0.9721
# Epoch   1 Batch  850/1077 - Train Accuracy: 0.4379, Validation Accuracy: 0.4645, Loss: 1.0170
# Epoch   1 Batch  855/1077 - Train Accuracy: 0.4500, Validation Accuracy: 0.4933, Loss: 0.9615
# Epoch   1 Batch  860/1077 - Train Accuracy: 0.4766, Validation Accuracy: 0.4925, Loss: 0.9432
# Epoch   1 Batch  865/1077 - Train Accuracy: 0.4929, Validation Accuracy: 0.4833, Loss: 0.8744
# Epoch   1 Batch  870/1077 - Train Accuracy: 0.4301, Validation Accuracy: 0.4769, Loss: 1.0419
# Epoch   1 Batch  875/1077 - Train Accuracy: 0.4750, Validation Accuracy: 0.5018, Loss: 0.9761
# Epoch   1 Batch  880/1077 - Train Accuracy: 0.4715, Validation Accuracy: 0.4783, Loss: 0.9368
# Epoch   1 Batch  885/1077 - Train Accuracy: 0.5369, Validation Accuracy: 0.4886, Loss: 0.8502
# Epoch   1 Batch  890/1077 - Train Accuracy: 0.4959, Validation Accuracy: 0.4936, Loss: 0.9021
# Epoch   1 Batch  895/1077 - Train Accuracy: 0.4309, Validation Accuracy: 0.4830, Loss: 0.9628
# Epoch   1 Batch  900/1077 - Train Accuracy: 0.4562, Validation Accuracy: 0.4940, Loss: 0.9935
# Epoch   1 Batch  905/1077 - Train Accuracy: 0.4230, Validation Accuracy: 0.4815, Loss: 0.9353
# Epoch   1 Batch  910/1077 - Train Accuracy: 0.4959, Validation Accuracy: 0.5188, Loss: 0.9376
# Epoch   1 Batch  915/1077 - Train Accuracy: 0.4034, Validation Accuracy: 0.4844, Loss: 1.0191
# Epoch   1 Batch  920/1077 - Train Accuracy: 0.4617, Validation Accuracy: 0.4801, Loss: 0.9688
# Epoch   1 Batch  925/1077 - Train Accuracy: 0.4940, Validation Accuracy: 0.5231, Loss: 0.9106
# Epoch   1 Batch  930/1077 - Train Accuracy: 0.4512, Validation Accuracy: 0.4723, Loss: 0.9370
# Epoch   1 Batch  935/1077 - Train Accuracy: 0.4527, Validation Accuracy: 0.4822, Loss: 0.9626
# Epoch   1 Batch  940/1077 - Train Accuracy: 0.4770, Validation Accuracy: 0.5128, Loss: 0.9665
# Epoch   1 Batch  945/1077 - Train Accuracy: 0.4637, Validation Accuracy: 0.4933, Loss: 0.9372
# Epoch   1 Batch  950/1077 - Train Accuracy: 0.4807, Validation Accuracy: 0.5131, Loss: 0.9353
# Epoch   1 Batch  955/1077 - Train Accuracy: 0.4984, Validation Accuracy: 0.5373, Loss: 0.9452
# Epoch   1 Batch  960/1077 - Train Accuracy: 0.5141, Validation Accuracy: 0.5192, Loss: 0.9041
# Epoch   1 Batch  965/1077 - Train Accuracy: 0.4453, Validation Accuracy: 0.5479, Loss: 1.0149
# Epoch   1 Batch  970/1077 - Train Accuracy: 0.5164, Validation Accuracy: 0.5270, Loss: 0.9617
# Epoch   1 Batch  975/1077 - Train Accuracy: 0.5260, Validation Accuracy: 0.5305, Loss: 0.8708
# Epoch   1 Batch  980/1077 - Train Accuracy: 0.5184, Validation Accuracy: 0.5256, Loss: 0.9203
# Epoch   1 Batch  985/1077 - Train Accuracy: 0.5066, Validation Accuracy: 0.5263, Loss: 0.9194
# Epoch   1 Batch  990/1077 - Train Accuracy: 0.4794, Validation Accuracy: 0.5135, Loss: 0.9725
# Epoch   1 Batch  995/1077 - Train Accuracy: 0.5208, Validation Accuracy: 0.5202, Loss: 0.8895
# Epoch   1 Batch 1000/1077 - Train Accuracy: 0.5227, Validation Accuracy: 0.5110, Loss: 0.8664
# Epoch   1 Batch 1005/1077 - Train Accuracy: 0.4730, Validation Accuracy: 0.5249, Loss: 0.9353
# Epoch   1 Batch 1010/1077 - Train Accuracy: 0.5043, Validation Accuracy: 0.5369, Loss: 0.9389
# Epoch   1 Batch 1015/1077 - Train Accuracy: 0.4906, Validation Accuracy: 0.5419, Loss: 0.9406
# Epoch   1 Batch 1020/1077 - Train Accuracy: 0.4996, Validation Accuracy: 0.5362, Loss: 0.9065
# Epoch   1 Batch 1025/1077 - Train Accuracy: 0.5275, Validation Accuracy: 0.5298, Loss: 0.8935
# Epoch   1 Batch 1030/1077 - Train Accuracy: 0.4867, Validation Accuracy: 0.5490, Loss: 0.9338
# Epoch   1 Batch 1035/1077 - Train Accuracy: 0.5249, Validation Accuracy: 0.5359, Loss: 0.8578
# Epoch   1 Batch 1040/1077 - Train Accuracy: 0.5078, Validation Accuracy: 0.5469, Loss: 0.9463
# Epoch   1 Batch 1045/1077 - Train Accuracy: 0.4766, Validation Accuracy: 0.5533, Loss: 0.9409
# Epoch   1 Batch 1050/1077 - Train Accuracy: 0.4508, Validation Accuracy: 0.5504, Loss: 0.9536
# Epoch   1 Batch 1055/1077 - Train Accuracy: 0.4457, Validation Accuracy: 0.5568, Loss: 0.9365
# Epoch   1 Batch 1060/1077 - Train Accuracy: 0.5191, Validation Accuracy: 0.5518, Loss: 0.8944
# Epoch   1 Batch 1065/1077 - Train Accuracy: 0.5137, Validation Accuracy: 0.5536, Loss: 0.8898
# Epoch   1 Batch 1070/1077 - Train Accuracy: 0.4793, Validation Accuracy: 0.5419, Loss: 0.9344
# Epoch   1 Batch 1075/1077 - Train Accuracy: 0.4799, Validation Accuracy: 0.5582, Loss: 0.9476
# Epoch   2 Batch    5/1077 - Train Accuracy: 0.4793, Validation Accuracy: 0.5437, Loss: 0.9122
# Epoch   2 Batch   10/1077 - Train Accuracy: 0.4827, Validation Accuracy: 0.5511, Loss: 0.9424
# Epoch   2 Batch   15/1077 - Train Accuracy: 0.5074, Validation Accuracy: 0.5568, Loss: 0.8773
# Epoch   2 Batch   20/1077 - Train Accuracy: 0.5195, Validation Accuracy: 0.5653, Loss: 0.8639
# Epoch   2 Batch   25/1077 - Train Accuracy: 0.4988, Validation Accuracy: 0.5550, Loss: 0.8698
# Epoch   2 Batch   30/1077 - Train Accuracy: 0.5180, Validation Accuracy: 0.5582, Loss: 0.8751
# Epoch   2 Batch   35/1077 - Train Accuracy: 0.5227, Validation Accuracy: 0.5625, Loss: 0.8828
# Epoch   2 Batch   40/1077 - Train Accuracy: 0.5145, Validation Accuracy: 0.5465, Loss: 0.8944
# Epoch   2 Batch   45/1077 - Train Accuracy: 0.5090, Validation Accuracy: 0.5600, Loss: 0.9051
# Epoch   2 Batch   50/1077 - Train Accuracy: 0.4992, Validation Accuracy: 0.5554, Loss: 0.9169
# Epoch   2 Batch   55/1077 - Train Accuracy: 0.5395, Validation Accuracy: 0.5540, Loss: 0.8651
# Epoch   2 Batch   60/1077 - Train Accuracy: 0.5197, Validation Accuracy: 0.5643, Loss: 0.8519
# Epoch   2 Batch   65/1077 - Train Accuracy: 0.4881, Validation Accuracy: 0.5629, Loss: 0.9237
# Epoch   2 Batch   70/1077 - Train Accuracy: 0.5292, Validation Accuracy: 0.5597, Loss: 0.9117
# Epoch   2 Batch   75/1077 - Train Accuracy: 0.5328, Validation Accuracy: 0.5696, Loss: 0.8545
# Epoch   2 Batch   80/1077 - Train Accuracy: 0.5355, Validation Accuracy: 0.5668, Loss: 0.8993
# Epoch   2 Batch   85/1077 - Train Accuracy: 0.5582, Validation Accuracy: 0.5763, Loss: 0.8360
# Epoch   2 Batch   90/1077 - Train Accuracy: 0.5129, Validation Accuracy: 0.5579, Loss: 0.9164
# Epoch   2 Batch   95/1077 - Train Accuracy: 0.5312, Validation Accuracy: 0.5632, Loss: 0.8908
# Epoch   2 Batch  100/1077 - Train Accuracy: 0.5371, Validation Accuracy: 0.5657, Loss: 0.8787
# Epoch   2 Batch  105/1077 - Train Accuracy: 0.5238, Validation Accuracy: 0.5533, Loss: 0.8548
# Epoch   2 Batch  110/1077 - Train Accuracy: 0.5484, Validation Accuracy: 0.5614, Loss: 0.8396
# Epoch   2 Batch  115/1077 - Train Accuracy: 0.5445, Validation Accuracy: 0.5597, Loss: 0.8890
# Epoch   2 Batch  120/1077 - Train Accuracy: 0.5055, Validation Accuracy: 0.5692, Loss: 0.8780
# Epoch   2 Batch  125/1077 - Train Accuracy: 0.5499, Validation Accuracy: 0.5597, Loss: 0.8582
# Epoch   2 Batch  130/1077 - Train Accuracy: 0.5480, Validation Accuracy: 0.5554, Loss: 0.8065
# Epoch   2 Batch  135/1077 - Train Accuracy: 0.5325, Validation Accuracy: 0.5586, Loss: 0.8970
# Epoch   2 Batch  140/1077 - Train Accuracy: 0.4864, Validation Accuracy: 0.5671, Loss: 0.8981
# Epoch   2 Batch  145/1077 - Train Accuracy: 0.5723, Validation Accuracy: 0.5575, Loss: 0.8444
# Epoch   2 Batch  150/1077 - Train Accuracy: 0.5766, Validation Accuracy: 0.5636, Loss: 0.8147
# Epoch   2 Batch  155/1077 - Train Accuracy: 0.5309, Validation Accuracy: 0.5714, Loss: 0.8625
# Epoch   2 Batch  160/1077 - Train Accuracy: 0.5305, Validation Accuracy: 0.5600, Loss: 0.8447
# Epoch   2 Batch  165/1077 - Train Accuracy: 0.5203, Validation Accuracy: 0.5671, Loss: 0.8489
# Epoch   2 Batch  170/1077 - Train Accuracy: 0.5191, Validation Accuracy: 0.5689, Loss: 0.8910
# Epoch   2 Batch  175/1077 - Train Accuracy: 0.5625, Validation Accuracy: 0.5682, Loss: 0.8050
# Epoch   2 Batch  180/1077 - Train Accuracy: 0.5574, Validation Accuracy: 0.5717, Loss: 0.8315
# Epoch   2 Batch  185/1077 - Train Accuracy: 0.5148, Validation Accuracy: 0.5607, Loss: 0.8603
# Epoch   2 Batch  190/1077 - Train Accuracy: 0.5730, Validation Accuracy: 0.5636, Loss: 0.8273
# Epoch   2 Batch  195/1077 - Train Accuracy: 0.4973, Validation Accuracy: 0.5547, Loss: 0.8436
# Epoch   2 Batch  200/1077 - Train Accuracy: 0.4965, Validation Accuracy: 0.5685, Loss: 0.8432
# Epoch   2 Batch  205/1077 - Train Accuracy: 0.5637, Validation Accuracy: 0.5707, Loss: 0.8400
# Epoch   2 Batch  210/1077 - Train Accuracy: 0.5450, Validation Accuracy: 0.5685, Loss: 0.8311
# Epoch   2 Batch  215/1077 - Train Accuracy: 0.5191, Validation Accuracy: 0.5636, Loss: 0.8548
# Epoch   2 Batch  220/1077 - Train Accuracy: 0.5300, Validation Accuracy: 0.5678, Loss: 0.8575
# Epoch   2 Batch  225/1077 - Train Accuracy: 0.5363, Validation Accuracy: 0.5636, Loss: 0.8427
# Epoch   2 Batch  230/1077 - Train Accuracy: 0.5580, Validation Accuracy: 0.5728, Loss: 0.7920
# Epoch   2 Batch  235/1077 - Train Accuracy: 0.5647, Validation Accuracy: 0.5763, Loss: 0.7715
# Epoch   2 Batch  240/1077 - Train Accuracy: 0.5352, Validation Accuracy: 0.5700, Loss: 0.8077
# Epoch   2 Batch  245/1077 - Train Accuracy: 0.5502, Validation Accuracy: 0.5664, Loss: 0.7902
# Epoch   2 Batch  250/1077 - Train Accuracy: 0.5334, Validation Accuracy: 0.5661, Loss: 0.7853
# Epoch   2 Batch  255/1077 - Train Accuracy: 0.5105, Validation Accuracy: 0.5607, Loss: 0.8346
# Epoch   2 Batch  260/1077 - Train Accuracy: 0.5495, Validation Accuracy: 0.5646, Loss: 0.7814
# Epoch   2 Batch  265/1077 - Train Accuracy: 0.5234, Validation Accuracy: 0.5703, Loss: 0.8259
# Epoch   2 Batch  270/1077 - Train Accuracy: 0.5148, Validation Accuracy: 0.5721, Loss: 0.8742
# Epoch   2 Batch  275/1077 - Train Accuracy: 0.5424, Validation Accuracy: 0.5707, Loss: 0.7695
# Epoch   2 Batch  280/1077 - Train Accuracy: 0.5492, Validation Accuracy: 0.5632, Loss: 0.8431
# Epoch   2 Batch  285/1077 - Train Accuracy: 0.5588, Validation Accuracy: 0.5650, Loss: 0.7734
# Epoch   2 Batch  290/1077 - Train Accuracy: 0.5305, Validation Accuracy: 0.5696, Loss: 0.8298
# Epoch   2 Batch  295/1077 - Train Accuracy: 0.5572, Validation Accuracy: 0.5742, Loss: 0.8692
# Epoch   2 Batch  300/1077 - Train Accuracy: 0.5160, Validation Accuracy: 0.5724, Loss: 0.8455
# Epoch   2 Batch  305/1077 - Train Accuracy: 0.5664, Validation Accuracy: 0.5710, Loss: 0.8056
# Epoch   2 Batch  310/1077 - Train Accuracy: 0.5141, Validation Accuracy: 0.5692, Loss: 0.8363
# Epoch   2 Batch  315/1077 - Train Accuracy: 0.5506, Validation Accuracy: 0.5717, Loss: 0.7781
# Epoch   2 Batch  320/1077 - Train Accuracy: 0.5516, Validation Accuracy: 0.5703, Loss: 0.8285
# Epoch   2 Batch  325/1077 - Train Accuracy: 0.5778, Validation Accuracy: 0.5749, Loss: 0.7646
# Epoch   2 Batch  330/1077 - Train Accuracy: 0.5793, Validation Accuracy: 0.5756, Loss: 0.8099
# Epoch   2 Batch  335/1077 - Train Accuracy: 0.5874, Validation Accuracy: 0.5778, Loss: 0.7431
# Epoch   2 Batch  340/1077 - Train Accuracy: 0.5255, Validation Accuracy: 0.5870, Loss: 0.8194
# Epoch   2 Batch  345/1077 - Train Accuracy: 0.5640, Validation Accuracy: 0.5803, Loss: 0.7839
# Epoch   2 Batch  350/1077 - Train Accuracy: 0.4977, Validation Accuracy: 0.5700, Loss: 0.8478
# Epoch   2 Batch  355/1077 - Train Accuracy: 0.5532, Validation Accuracy: 0.5732, Loss: 0.8086
# Epoch   2 Batch  360/1077 - Train Accuracy: 0.5617, Validation Accuracy: 0.5849, Loss: 0.8147
# Epoch   2 Batch  365/1077 - Train Accuracy: 0.5051, Validation Accuracy: 0.5700, Loss: 0.8000
# Epoch   2 Batch  370/1077 - Train Accuracy: 0.5394, Validation Accuracy: 0.5717, Loss: 0.7780
# Epoch   2 Batch  375/1077 - Train Accuracy: 0.5827, Validation Accuracy: 0.5849, Loss: 0.7392
# Epoch   2 Batch  380/1077 - Train Accuracy: 0.5445, Validation Accuracy: 0.5746, Loss: 0.7743
# Epoch   2 Batch  385/1077 - Train Accuracy: 0.5426, Validation Accuracy: 0.5792, Loss: 0.8152
# Epoch   2 Batch  390/1077 - Train Accuracy: 0.5207, Validation Accuracy: 0.5806, Loss: 0.8367
# Epoch   2 Batch  395/1077 - Train Accuracy: 0.5632, Validation Accuracy: 0.5788, Loss: 0.7343
# Epoch   2 Batch  400/1077 - Train Accuracy: 0.5379, Validation Accuracy: 0.5724, Loss: 0.8099
# ...
# Epoch   6 Batch  235/1077 - Train Accuracy: 0.7284, Validation Accuracy: 0.6900, Loss: 0.3444
# Epoch   6 Batch  240/1077 - Train Accuracy: 0.7348, Validation Accuracy: 0.6815, Loss: 0.3427
# Epoch   6 Batch  245/1077 - Train Accuracy: 0.7087, Validation Accuracy: 0.6942, Loss: 0.3436
# Epoch   6 Batch  250/1077 - Train Accuracy: 0.6460, Validation Accuracy: 0.6836, Loss: 0.3496
# Epoch   6 Batch  255/1077 - Train Accuracy: 0.6984, Validation Accuracy: 0.7003, Loss: 0.3584
# Epoch   6 Batch  260/1077 - Train Accuracy: 0.6879, Validation Accuracy: 0.6861, Loss: 0.3368
# Epoch   6 Batch  265/1077 - Train Accuracy: 0.6430, Validation Accuracy: 0.6861, Loss: 0.3664
# Epoch   6 Batch  270/1077 - Train Accuracy: 0.6687, Validation Accuracy: 0.6797, Loss: 0.3843
# Epoch   6 Batch  275/1077 - Train Accuracy: 0.6741, Validation Accuracy: 0.6822, Loss: 0.3471
# Epoch   6 Batch  280/1077 - Train Accuracy: 0.6977, Validation Accuracy: 0.6903, Loss: 0.3701
# Epoch   6 Batch  285/1077 - Train Accuracy: 0.6894, Validation Accuracy: 0.6754, Loss: 0.3468
# Epoch   6 Batch  290/1077 - Train Accuracy: 0.6598, Validation Accuracy: 0.6879, Loss: 0.3758
# Epoch   6 Batch  295/1077 - Train Accuracy: 0.6928, Validation Accuracy: 0.6932, Loss: 0.3746
# Epoch   6 Batch  300/1077 - Train Accuracy: 0.6414, Validation Accuracy: 0.6839, Loss: 0.3583
# Epoch   6 Batch  305/1077 - Train Accuracy: 0.7203, Validation Accuracy: 0.6697, Loss: 0.3551
# Epoch   6 Batch  310/1077 - Train Accuracy: 0.6699, Validation Accuracy: 0.6655, Loss: 0.3735
# Epoch   6 Batch  315/1077 - Train Accuracy: 0.7121, Validation Accuracy: 0.6843, Loss: 0.3390
# Epoch   6 Batch  320/1077 - Train Accuracy: 0.6824, Validation Accuracy: 0.6832, Loss: 0.3742
# Epoch   6 Batch  325/1077 - Train Accuracy: 0.7240, Validation Accuracy: 0.6786, Loss: 0.3393
# Epoch   6 Batch  330/1077 - Train Accuracy: 0.7332, Validation Accuracy: 0.6864, Loss: 0.3650
# Epoch   6 Batch  335/1077 - Train Accuracy: 0.7184, Validation Accuracy: 0.6861, Loss: 0.3389
# Epoch   6 Batch  340/1077 - Train Accuracy: 0.6863, Validation Accuracy: 0.6822, Loss: 0.3667
# Epoch   6 Batch  345/1077 - Train Accuracy: 0.7165, Validation Accuracy: 0.6946, Loss: 0.3481
# Epoch   6 Batch  350/1077 - Train Accuracy: 0.6809, Validation Accuracy: 0.6868, Loss: 0.3687
# Epoch   6 Batch  355/1077 - Train Accuracy: 0.7028, Validation Accuracy: 0.6839, Loss: 0.3613
# Epoch   6 Batch  360/1077 - Train Accuracy: 0.6844, Validation Accuracy: 0.6829, Loss: 0.3583
# Epoch   6 Batch  365/1077 - Train Accuracy: 0.6336, Validation Accuracy: 0.6815, Loss: 0.3478
# Epoch   6 Batch  370/1077 - Train Accuracy: 0.6711, Validation Accuracy: 0.6886, Loss: 0.3455
# Epoch   6 Batch  375/1077 - Train Accuracy: 0.6896, Validation Accuracy: 0.6740, Loss: 0.3327
# Epoch   6 Batch  380/1077 - Train Accuracy: 0.7047, Validation Accuracy: 0.6854, Loss: 0.3410
# Epoch   6 Batch  385/1077 - Train Accuracy: 0.7125, Validation Accuracy: 0.7038, Loss: 0.3567
# Epoch   6 Batch  390/1077 - Train Accuracy: 0.6887, Validation Accuracy: 0.7074, Loss: 0.3770
# Epoch   6 Batch  395/1077 - Train Accuracy: 0.6901, Validation Accuracy: 0.6712, Loss: 0.3271
# Epoch   6 Batch  400/1077 - Train Accuracy: 0.7109, Validation Accuracy: 0.6786, Loss: 0.3667
# Epoch   6 Batch  405/1077 - Train Accuracy: 0.7249, Validation Accuracy: 0.6935, Loss: 0.3735
# Epoch   6 Batch  410/1077 - Train Accuracy: 0.6682, Validation Accuracy: 0.6950, Loss: 0.3729
# Epoch   6 Batch  415/1077 - Train Accuracy: 0.7068, Validation Accuracy: 0.6868, Loss: 0.3399
# Epoch   6 Batch  420/1077 - Train Accuracy: 0.7199, Validation Accuracy: 0.6914, Loss: 0.3335
# Epoch   6 Batch  425/1077 - Train Accuracy: 0.6949, Validation Accuracy: 0.6911, Loss: 0.3387
# Epoch   6 Batch  430/1077 - Train Accuracy: 0.6910, Validation Accuracy: 0.6857, Loss: 0.3476
# Epoch   6 Batch  435/1077 - Train Accuracy: 0.7311, Validation Accuracy: 0.6875, Loss: 0.3753
# Epoch   6 Batch  440/1077 - Train Accuracy: 0.6625, Validation Accuracy: 0.6857, Loss: 0.3592
# Epoch   6 Batch  445/1077 - Train Accuracy: 0.6715, Validation Accuracy: 0.6950, Loss: 0.3669
# Epoch   6 Batch  450/1077 - Train Accuracy: 0.6832, Validation Accuracy: 0.6733, Loss: 0.3418
# Epoch   6 Batch  455/1077 - Train Accuracy: 0.6637, Validation Accuracy: 0.6808, Loss: 0.3381
# Epoch   6 Batch  460/1077 - Train Accuracy: 0.6992, Validation Accuracy: 0.6836, Loss: 0.3624
# Epoch   6 Batch  465/1077 - Train Accuracy: 0.6776, Validation Accuracy: 0.6882, Loss: 0.4013
# Epoch   6 Batch  470/1077 - Train Accuracy: 0.6896, Validation Accuracy: 0.6900, Loss: 0.3597
# Epoch   6 Batch  475/1077 - Train Accuracy: 0.7180, Validation Accuracy: 0.6829, Loss: 0.3403
# Epoch   6 Batch  480/1077 - Train Accuracy: 0.7175, Validation Accuracy: 0.6939, Loss: 0.3578
# Epoch   6 Batch  485/1077 - Train Accuracy: 0.7070, Validation Accuracy: 0.6861, Loss: 0.3605
# Epoch   6 Batch  490/1077 - Train Accuracy: 0.6945, Validation Accuracy: 0.6893, Loss: 0.3600
# Epoch   6 Batch  495/1077 - Train Accuracy: 0.6762, Validation Accuracy: 0.6726, Loss: 0.3337
# Epoch   6 Batch  500/1077 - Train Accuracy: 0.6926, Validation Accuracy: 0.6914, Loss: 0.3432
# Epoch   6 Batch  505/1077 - Train Accuracy: 0.7281, Validation Accuracy: 0.6868, Loss: 0.3128
# Epoch   6 Batch  510/1077 - Train Accuracy: 0.7207, Validation Accuracy: 0.6889, Loss: 0.3394
# Epoch   6 Batch  515/1077 - Train Accuracy: 0.6656, Validation Accuracy: 0.6953, Loss: 0.3754
# Epoch   6 Batch  520/1077 - Train Accuracy: 0.7243, Validation Accuracy: 0.6758, Loss: 0.3144
# Epoch   6 Batch  525/1077 - Train Accuracy: 0.6996, Validation Accuracy: 0.6779, Loss: 0.3397
# Epoch   6 Batch  530/1077 - Train Accuracy: 0.6492, Validation Accuracy: 0.6790, Loss: 0.3633
# Epoch   6 Batch  535/1077 - Train Accuracy: 0.7055, Validation Accuracy: 0.6772, Loss: 0.3401
# Epoch   6 Batch  540/1077 - Train Accuracy: 0.6910, Validation Accuracy: 0.6907, Loss: 0.3183
# Epoch   6 Batch  545/1077 - Train Accuracy: 0.6965, Validation Accuracy: 0.6825, Loss: 0.3741
# Epoch   6 Batch  550/1077 - Train Accuracy: 0.6539, Validation Accuracy: 0.6871, Loss: 0.3637
# Epoch   6 Batch  555/1077 - Train Accuracy: 0.7273, Validation Accuracy: 0.6925, Loss: 0.3519
# Epoch   6 Batch  560/1077 - Train Accuracy: 0.6934, Validation Accuracy: 0.6839, Loss: 0.3376
# Epoch   6 Batch  565/1077 - Train Accuracy: 0.6782, Validation Accuracy: 0.6875, Loss: 0.3569
# Epoch   6 Batch  570/1077 - Train Accuracy: 0.6706, Validation Accuracy: 0.6857, Loss: 0.3621
# Epoch   6 Batch  575/1077 - Train Accuracy: 0.6842, Validation Accuracy: 0.6825, Loss: 0.3399
# Epoch   6 Batch  580/1077 - Train Accuracy: 0.7467, Validation Accuracy: 0.6893, Loss: 0.3086
# Epoch   6 Batch  585/1077 - Train Accuracy: 0.7117, Validation Accuracy: 0.6850, Loss: 0.3234
# Epoch   6 Batch  590/1077 - Train Accuracy: 0.6924, Validation Accuracy: 0.6797, Loss: 0.3575
# Epoch   6 Batch  595/1077 - Train Accuracy: 0.6488, Validation Accuracy: 0.6680, Loss: 0.3588
# Epoch   6 Batch  600/1077 - Train Accuracy: 0.7303, Validation Accuracy: 0.6786, Loss: 0.3344
# Epoch   6 Batch  605/1077 - Train Accuracy: 0.7109, Validation Accuracy: 0.6861, Loss: 0.3545
# Epoch   6 Batch  610/1077 - Train Accuracy: 0.6974, Validation Accuracy: 0.6953, Loss: 0.3554
# Epoch   6 Batch  615/1077 - Train Accuracy: 0.7078, Validation Accuracy: 0.6868, Loss: 0.3277
# Epoch   6 Batch  620/1077 - Train Accuracy: 0.6754, Validation Accuracy: 0.6850, Loss: 0.3347
# Epoch   6 Batch  625/1077 - Train Accuracy: 0.7027, Validation Accuracy: 0.6932, Loss: 0.3411
# Epoch   6 Batch  630/1077 - Train Accuracy: 0.6828, Validation Accuracy: 0.6882, Loss: 0.3434
# Epoch   6 Batch  635/1077 - Train Accuracy: 0.6994, Validation Accuracy: 0.6868, Loss: 0.3594
# Epoch   6 Batch  640/1077 - Train Accuracy: 0.7258, Validation Accuracy: 0.6783, Loss: 0.3217
# Epoch   6 Batch  645/1077 - Train Accuracy: 0.7400, Validation Accuracy: 0.6918, Loss: 0.3219
# Epoch   6 Batch  650/1077 - Train Accuracy: 0.6941, Validation Accuracy: 0.6932, Loss: 0.3554
# Epoch   6 Batch  655/1077 - Train Accuracy: 0.6695, Validation Accuracy: 0.6907, Loss: 0.3570
# Epoch   6 Batch  660/1077 - Train Accuracy: 0.7176, Validation Accuracy: 0.6932, Loss: 0.3422
# Epoch   6 Batch  665/1077 - Train Accuracy: 0.6687, Validation Accuracy: 0.6928, Loss: 0.3435
# Epoch   6 Batch  670/1077 - Train Accuracy: 0.7450, Validation Accuracy: 0.6996, Loss: 0.3135
# Epoch   6 Batch  675/1077 - Train Accuracy: 0.6987, Validation Accuracy: 0.6882, Loss: 0.3403
# Epoch   6 Batch  680/1077 - Train Accuracy: 0.7113, Validation Accuracy: 0.6889, Loss: 0.3443
# Epoch   6 Batch  685/1077 - Train Accuracy: 0.6695, Validation Accuracy: 0.6868, Loss: 0.3499
# Epoch   6 Batch  690/1077 - Train Accuracy: 0.7340, Validation Accuracy: 0.7028, Loss: 0.3310
# Epoch   6 Batch  695/1077 - Train Accuracy: 0.7168, Validation Accuracy: 0.6825, Loss: 0.3225
# Epoch   6 Batch  700/1077 - Train Accuracy: 0.6574, Validation Accuracy: 0.6793, Loss: 0.3213
# Epoch   6 Batch  705/1077 - Train Accuracy: 0.6961, Validation Accuracy: 0.6612, Loss: 0.3855
# Epoch   6 Batch  710/1077 - Train Accuracy: 0.6980, Validation Accuracy: 0.6804, Loss: 0.3420
# Epoch   6 Batch  715/1077 - Train Accuracy: 0.6937, Validation Accuracy: 0.6634, Loss: 0.3624
# Epoch   6 Batch  720/1077 - Train Accuracy: 0.6822, Validation Accuracy: 0.6793, Loss: 0.3607
# Epoch   6 Batch  725/1077 - Train Accuracy: 0.6834, Validation Accuracy: 0.6594, Loss: 0.3164
# Epoch   6 Batch  730/1077 - Train Accuracy: 0.6906, Validation Accuracy: 0.6726, Loss: 0.3395
# Epoch   6 Batch  735/1077 - Train Accuracy: 0.7023, Validation Accuracy: 0.6928, Loss: 0.3429
# Epoch   6 Batch  740/1077 - Train Accuracy: 0.7031, Validation Accuracy: 0.6847, Loss: 0.3271
# Epoch   6 Batch  745/1077 - Train Accuracy: 0.7758, Validation Accuracy: 0.6889, Loss: 0.3220
# Epoch   6 Batch  750/1077 - Train Accuracy: 0.6969, Validation Accuracy: 0.6950, Loss: 0.3339
# Epoch   6 Batch  755/1077 - Train Accuracy: 0.7125, Validation Accuracy: 0.6882, Loss: 0.3325
# Epoch   6 Batch  760/1077 - Train Accuracy: 0.6859, Validation Accuracy: 0.6864, Loss: 0.3384
# Epoch   6 Batch  765/1077 - Train Accuracy: 0.7016, Validation Accuracy: 0.6839, Loss: 0.3240
# Epoch   6 Batch  770/1077 - Train Accuracy: 0.7366, Validation Accuracy: 0.6754, Loss: 0.3032
# Epoch   6 Batch  775/1077 - Train Accuracy: 0.7363, Validation Accuracy: 0.6914, Loss: 0.3236
# Epoch   6 Batch  780/1077 - Train Accuracy: 0.7117, Validation Accuracy: 0.6811, Loss: 0.3405
# Epoch   6 Batch  785/1077 - Train Accuracy: 0.7228, Validation Accuracy: 0.6882, Loss: 0.3060
# Epoch   6 Batch  790/1077 - Train Accuracy: 0.6633, Validation Accuracy: 0.6850, Loss: 0.3575
# Epoch   6 Batch  795/1077 - Train Accuracy: 0.6859, Validation Accuracy: 0.6776, Loss: 0.3467
# Epoch   6 Batch  800/1077 - Train Accuracy: 0.7113, Validation Accuracy: 0.6889, Loss: 0.3254
# Epoch   6 Batch  805/1077 - Train Accuracy: 0.7156, Validation Accuracy: 0.6928, Loss: 0.3265
# Epoch   6 Batch  810/1077 - Train Accuracy: 0.6901, Validation Accuracy: 0.6804, Loss: 0.3088
# Epoch   6 Batch  815/1077 - Train Accuracy: 0.7191, Validation Accuracy: 0.6786, Loss: 0.3256
# Epoch   6 Batch  820/1077 - Train Accuracy: 0.6645, Validation Accuracy: 0.6861, Loss: 0.3550
# Epoch   6 Batch  825/1077 - Train Accuracy: 0.7082, Validation Accuracy: 0.6786, Loss: 0.3284
# Epoch   6 Batch  830/1077 - Train Accuracy: 0.6473, Validation Accuracy: 0.6875, Loss: 0.3338
# Epoch   6 Batch  835/1077 - Train Accuracy: 0.7168, Validation Accuracy: 0.7013, Loss: 0.3290
# Epoch   6 Batch  840/1077 - Train Accuracy: 0.7168, Validation Accuracy: 0.6836, Loss: 0.3172
# Epoch   6 Batch  845/1077 - Train Accuracy: 0.7293, Validation Accuracy: 0.6822, Loss: 0.3207
# Epoch   6 Batch  850/1077 - Train Accuracy: 0.6637, Validation Accuracy: 0.6829, Loss: 0.3498
# Epoch   6 Batch  855/1077 - Train Accuracy: 0.7031, Validation Accuracy: 0.6871, Loss: 0.3382
# Epoch   6 Batch  860/1077 - Train Accuracy: 0.7106, Validation Accuracy: 0.6921, Loss: 0.3399
# Epoch   6 Batch  865/1077 - Train Accuracy: 0.7507, Validation Accuracy: 0.6843, Loss: 0.2924
# Epoch   6 Batch  870/1077 - Train Accuracy: 0.6830, Validation Accuracy: 0.6911, Loss: 0.3413
# Epoch   6 Batch  875/1077 - Train Accuracy: 0.7211, Validation Accuracy: 0.6811, Loss: 0.3165
# Epoch   6 Batch  880/1077 - Train Accuracy: 0.7664, Validation Accuracy: 0.6914, Loss: 0.3116
# Epoch   6 Batch  885/1077 - Train Accuracy: 0.7276, Validation Accuracy: 0.6907, Loss: 0.2803
# Epoch   6 Batch  890/1077 - Train Accuracy: 0.7593, Validation Accuracy: 0.6854, Loss: 0.3437
# Epoch   6 Batch  895/1077 - Train Accuracy: 0.6434, Validation Accuracy: 0.6559, Loss: 0.3444
# Epoch   6 Batch  900/1077 - Train Accuracy: 0.7215, Validation Accuracy: 0.6768, Loss: 0.3323
# Epoch   6 Batch  905/1077 - Train Accuracy: 0.7172, Validation Accuracy: 0.6953, Loss: 0.3154
# Epoch   6 Batch  910/1077 - Train Accuracy: 0.7098, Validation Accuracy: 0.6800, Loss: 0.3178
# Epoch   6 Batch  915/1077 - Train Accuracy: 0.6933, Validation Accuracy: 0.6737, Loss: 0.3634
# Epoch   6 Batch  920/1077 - Train Accuracy: 0.7105, Validation Accuracy: 0.6861, Loss: 0.3327
# Epoch   6 Batch  925/1077 - Train Accuracy: 0.6968, Validation Accuracy: 0.6591, Loss: 0.3027
# Epoch   6 Batch  930/1077 - Train Accuracy: 0.7266, Validation Accuracy: 0.6683, Loss: 0.3118
# Epoch   6 Batch  935/1077 - Train Accuracy: 0.6867, Validation Accuracy: 0.6800, Loss: 0.3353
# Epoch   6 Batch  940/1077 - Train Accuracy: 0.7078, Validation Accuracy: 0.6935, Loss: 0.3275
# Epoch   6 Batch  945/1077 - Train Accuracy: 0.7426, Validation Accuracy: 0.6932, Loss: 0.3049
# Epoch   6 Batch  950/1077 - Train Accuracy: 0.7184, Validation Accuracy: 0.6950, Loss: 0.3048
# Epoch   6 Batch  955/1077 - Train Accuracy: 0.7270, Validation Accuracy: 0.6740, Loss: 0.3101
# Epoch   6 Batch  960/1077 - Train Accuracy: 0.7206, Validation Accuracy: 0.6896, Loss: 0.3019
# Epoch   6 Batch  965/1077 - Train Accuracy: 0.6990, Validation Accuracy: 0.6861, Loss: 0.3441
# Epoch   6 Batch  970/1077 - Train Accuracy: 0.7242, Validation Accuracy: 0.6939, Loss: 0.3315
# Epoch   6 Batch  975/1077 - Train Accuracy: 0.7608, Validation Accuracy: 0.6733, Loss: 0.2921
# Epoch   6 Batch  980/1077 - Train Accuracy: 0.6898, Validation Accuracy: 0.6882, Loss: 0.3188
# Epoch   6 Batch  985/1077 - Train Accuracy: 0.7227, Validation Accuracy: 0.6896, Loss: 0.3108
# Epoch   6 Batch  990/1077 - Train Accuracy: 0.6953, Validation Accuracy: 0.6772, Loss: 0.3284
# Epoch   6 Batch  995/1077 - Train Accuracy: 0.7414, Validation Accuracy: 0.6971, Loss: 0.3021
# Epoch   6 Batch 1000/1077 - Train Accuracy: 0.7481, Validation Accuracy: 0.6879, Loss: 0.2917
# Epoch   6 Batch 1005/1077 - Train Accuracy: 0.7133, Validation Accuracy: 0.6896, Loss: 0.3221
# Epoch   6 Batch 1010/1077 - Train Accuracy: 0.7000, Validation Accuracy: 0.6829, Loss: 0.3212
# Epoch   6 Batch 1015/1077 - Train Accuracy: 0.6973, Validation Accuracy: 0.6779, Loss: 0.3361
# Epoch   6 Batch 1020/1077 - Train Accuracy: 0.7148, Validation Accuracy: 0.6843, Loss: 0.3074
# Epoch   6 Batch 1025/1077 - Train Accuracy: 0.7188, Validation Accuracy: 0.6964, Loss: 0.3013
# Epoch   6 Batch 1030/1077 - Train Accuracy: 0.7199, Validation Accuracy: 0.6850, Loss: 0.3272
# Epoch   6 Batch 1035/1077 - Train Accuracy: 0.7649, Validation Accuracy: 0.6605, Loss: 0.2822
# Epoch   6 Batch 1040/1077 - Train Accuracy: 0.7101, Validation Accuracy: 0.6886, Loss: 0.3274
# Epoch   6 Batch 1045/1077 - Train Accuracy: 0.6934, Validation Accuracy: 0.6854, Loss: 0.3346
# Epoch   6 Batch 1050/1077 - Train Accuracy: 0.6719, Validation Accuracy: 0.6921, Loss: 0.3203
# Epoch   6 Batch 1055/1077 - Train Accuracy: 0.7180, Validation Accuracy: 0.6658, Loss: 0.3636
# Epoch   6 Batch 1060/1077 - Train Accuracy: 0.7398, Validation Accuracy: 0.6793, Loss: 0.3124
# Epoch   6 Batch 1065/1077 - Train Accuracy: 0.7301, Validation Accuracy: 0.7006, Loss: 0.3375
# Epoch   6 Batch 1070/1077 - Train Accuracy: 0.6887, Validation Accuracy: 0.6854, Loss: 0.3310
# Epoch   6 Batch 1075/1077 - Train Accuracy: 0.7192, Validation Accuracy: 0.6857, Loss: 0.3337
# Model Trained and Saved

# %% [markdown]
# ### Save Parameters
# Save the `batch_size` and `save_path` parameters for inference.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# Save parameters for checkpoint
helper.save_params(save_path)

# %% [markdown]
# # Checkpoint

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import tensorflow as tf
import numpy as np
import helper
import problem_unittests as tests

_, (source_vocab_to_int, target_vocab_to_int), (source_int_to_vocab, target_int_to_vocab) = helper.load_preprocess()
load_path = helper.load_params()

# %% [markdown]
# ## Sentence to Sequence
# To feed a sentence into the model for translation, you first need to preprocess it.  Implement the function `sentence_to_seq()` to preprocess new sentences.
#
# - Convert the sentence to lowercase
# - Convert words into ids using `vocab_to_int`
#  - Convert words not in the vocabulary, to the `<UNK>` word id.

# %%
def sentence_to_seq(sentence, vocab_to_int):
    """
    Convert a sentence to a sequence of ids
    :param sentence: String
    :param vocab_to_int: Dictionary to go from the words to an id
    :return: List of word ids
    """
    # TODO: Implement Function
    word_list = []
    
    for word in sentence.lower().split():
        #print (word)
        if word in vocab_to_int.keys():
            word_list.append(vocab_to_int[word])
        else:
            word_list.append(vocab_to_int['<UNK>'])
    
    #print (word_list)
    return word_list


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_sentence_to_seq(sentence_to_seq)
# Out:
# Tests Passed

# %% [markdown]
# ## Translate
# This will translate `translate_sentence` from English to French.

# %%
translate_sentence = 'he saw a old yellow truck .'


"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
translate_sentence = sentence_to_seq(translate_sentence, source_vocab_to_int)

loaded_graph = tf.Graph()
with tf.Session(graph=loaded_graph) as sess:
    # Load saved model
    loader = tf.train.import_meta_graph(load_path + '.meta')
    loader.restore(sess, load_path)

    input_data = loaded_graph.get_tensor_by_name('input:0')
    logits = loaded_graph.get_tensor_by_name('predictions:0')
    target_sequence_length = loaded_graph.get_tensor_by_name('target_sequence_length:0')
    source_sequence_length = loaded_graph.get_tensor_by_name('source_sequence_length:0')
    keep_prob = loaded_graph.get_tensor_by_name('keep_prob:0')

    translate_logits = sess.run(logits, {input_data: [translate_sentence]*batch_size,
                                         target_sequence_length: [len(translate_sentence)*2]*batch_size,
                                         source_sequence_length: [len(translate_sentence)]*batch_size,
                                         keep_prob: 1.0})[0]

print('Input')
print('  Word Ids:      {}'.format([i for i in translate_sentence]))
print('  English Words: {}'.format([source_int_to_vocab[i] for i in translate_sentence]))

print('\nPrediction')
print('  Word Ids:      {}'.format([i for i in translate_logits]))
print('  French Words: {}'.format(" ".join([target_int_to_vocab[i] for i in translate_logits])))
# Out:
# INFO:tensorflow:Restoring parameters from checkpoints/dev
# Input
#   Word Ids:      [5, 50, 79, 22, 126, 88, 113]
#   English Words: ['he', 'saw', 'a', 'old', 'yellow', 'truck', '.']
#
# Prediction
#   Word Ids:      [307, 38, 283, 175, 205, 236, 322, 1]
#   French Words: il a un nouvelle camion jaune . <EOS>

# %% [markdown]
# ## Imperfect Translation
# You might notice that some sentences translate better than others.  Since the dataset you're using only has a vocabulary of 227 English words of the thousands that you use, you're only going to see good results using these words.  For this project, you don't need a perfect translation. However, if you want to create a better translation model, you'll need better data.
#
# You can train on the [WMT10 French-English corpus](http://www.statmt.org/wmt10/training-giga-fren.tar).  This dataset has more vocabulary and richer in topics discussed.  However, this will take you days to train, so make sure you've a GPU and the neural network is performing well on dataset we provided.  Just make sure you play with the WMT10 corpus after you've submitted this project.
# ## Submitting This Project
# When submitting this project, make sure to run all the cells before saving the notebook. Save the notebook file as "dlnd_language_translation.ipynb" and save it as a HTML file under "File" -> "Download as". Include the "helper.py" and "problem_unittests.py" files in your submission.
