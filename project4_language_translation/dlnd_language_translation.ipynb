# %% [markdown]
# # Language Translation
# In this project, you’re going to take a peek into the realm of neural network machine translation.  You’ll be training a sequence to sequence model on a dataset of English and French sentences that can translate new sentences from English to French.
# ## Get the Data
# Since translating the whole language of English to French will take lots of time to train, we have provided you with a small portion of the English corpus.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import helper
import problem_unittests as tests

source_path = 'data/small_vocab_en'
target_path = 'data/small_vocab_fr'
source_text = helper.load_data(source_path)
target_text = helper.load_data(target_path)

# %% [markdown]
# ## Explore the Data
# Play around with view_sentence_range to view different parts of the data.

# %%
view_sentence_range = (0, 10)

"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import numpy as np

print('Dataset Stats')
print('Roughly the number of unique words: {}'.format(len({word: None for word in source_text.split()})))

sentences = source_text.split('\n')
word_counts = [len(sentence.split()) for sentence in sentences]
print('Number of sentences: {}'.format(len(sentences)))
print('Average number of words in a sentence: {}'.format(np.average(word_counts)))

print()
print('English sentences {} to {}:'.format(*view_sentence_range))
print('\n'.join(source_text.split('\n')[view_sentence_range[0]:view_sentence_range[1]]))
print()
print('French sentences {} to {}:'.format(*view_sentence_range))
print('\n'.join(target_text.split('\n')[view_sentence_range[0]:view_sentence_range[1]]))
# Out:
# Dataset Stats
# Roughly the number of unique words: 227
# Number of sentences: 137861
# Average number of words in a sentence: 13.225277634719028
#
# English sentences 0 to 10:
# new jersey is sometimes quiet during autumn , and it is snowy in april .
# the united states is usually chilly during july , and it is usually freezing in november .
# california is usually quiet during march , and it is usually hot in june .
# the united states is sometimes mild during june , and it is cold in september .
# your least liked fruit is the grape , but my least liked is the apple .
# his favorite fruit is the orange , but my favorite is the grape .
# paris is relaxing during december , but it is usually chilly in july .
# new jersey is busy during spring , and it is never hot in march .
# our least liked fruit is the lemon , but my least liked is the grape .
# the united states is sometimes busy during january , and it is sometimes warm in november .
#
# French sentences 0 to 10:
# new jersey est parfois calme pendant l' automne , et il est neigeux en avril .
# les états-unis est généralement froid en juillet , et il gèle habituellement en novembre .
# california est généralement calme en mars , et il est généralement chaud en juin .
# les états-unis est parfois légère en juin , et il fait froid en septembre .
# votre moins aimé fruit est le raisin , mais mon moins aimé est la pomme .
# son fruit préféré est l'orange , mais mon préféré est le raisin .
# paris est relaxant en décembre , mais il est généralement froid en juillet .
# new jersey est occupé au printemps , et il est jamais chaude en mars .
# notre fruit est moins aimé le citron , mais mon moins aimé est le raisin .
# les états-unis est parfois occupé en janvier , et il est parfois chaud en novembre .

# %% [markdown]
# ## Implement Preprocessing Function
# ### Text to Word Ids
# As you did with other RNNs, you must turn the text into a number so the computer can understand it. In the function `text_to_ids()`, you'll turn `source_text` and `target_text` from words to ids.  However, you need to add the `<EOS>` word id at the end of `target_text`.  This will help the neural network predict when the sentence should end.
#
# You can get the `<EOS>` word id by doing:
# ```python
# target_vocab_to_int['<EOS>']
# ```
# You can get other word ids using `source_vocab_to_int` and `target_vocab_to_int`.

# %%
def text_to_ids(source_text, target_text, source_vocab_to_int, target_vocab_to_int):
    """
    Convert source and target text to proper word ids
    :param source_text: String that contains all the source text.
    :param target_text: String that contains all the target text.
    :param source_vocab_to_int: Dictionary to go from the source words to an id
    :param target_vocab_to_int: Dictionary to go from the target words to an id
    :return: A tuple of lists (source_id_text, target_id_text)
    """
    # TODO: Implement Function

    source_id_text = [[source_vocab_to_int[word] for word in n.split()] for n in source_text.split("\n")]
    target_id_text = [[target_vocab_to_int[word] for word in n.split()]+[target_vocab_to_int['<EOS>']] for n in target_text.split("\n")]
    return source_id_text, target_id_text
    
"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_text_to_ids(text_to_ids)
# Out:
# Tests Passed

# %% [markdown]
# ### Preprocess all the data and save it
# Running the code cell below will preprocess all the data and save it to file.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
helper.preprocess_and_save_data(source_path, target_path, text_to_ids)

# %% [markdown]
# # Check Point
# This is your first checkpoint. If you ever decide to come back to this notebook or have to restart the notebook, you can start from here. The preprocessed data has been saved to disk.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import numpy as np
import helper
import problem_unittests as tests

(source_int_text, target_int_text), (source_vocab_to_int, target_vocab_to_int), _ = helper.load_preprocess()

# %% [markdown]
# ### Check the Version of TensorFlow and Access to GPU
# This will check to make sure you have the correct version of TensorFlow and access to a GPU

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
from distutils.version import LooseVersion
import warnings
import tensorflow as tf
from tensorflow.python.layers.core import Dense

# Check TensorFlow Version
assert LooseVersion(tf.__version__) >= LooseVersion('1.1'), 'Please use TensorFlow version 1.1 or newer'
print('TensorFlow Version: {}'.format(tf.__version__))

# Check for a GPU
if not tf.test.gpu_device_name():
    warnings.warn('No GPU found. Please use a GPU to train your neural network.')
else:
    print('Default GPU Device: {}'.format(tf.test.gpu_device_name()))
# Out:
# TensorFlow Version: 1.1.0
# Default GPU Device: /gpu:0

# %% [markdown]
# ## Build the Neural Network
# You'll build the components necessary to build a Sequence-to-Sequence model by implementing the following functions below:
# - `model_inputs`
# - `process_decoder_input`
# - `encoding_layer`
# - `decoding_layer_train`
# - `decoding_layer_infer`
# - `decoding_layer`
# - `seq2seq_model`
#
# ### Input
# Implement the `model_inputs()` function to create TF Placeholders for the Neural Network. It should create the following placeholders:
#
# - Input text placeholder named "input" using the TF Placeholder name parameter with rank 2.
# - Targets placeholder with rank 2.
# - Learning rate placeholder with rank 0.
# - Keep probability placeholder named "keep_prob" using the TF Placeholder name parameter with rank 0.
# - Target sequence length placeholder named "target_sequence_length" with rank 1
# - Max target sequence length tensor named "max_target_len" getting its value from applying tf.reduce_max on the target_sequence_length placeholder. Rank 0.
# - Source sequence length placeholder named "source_sequence_length" with rank 1
#
# Return the placeholders in the following the tuple (input, targets, learning rate, keep probability, target sequence length, max target sequence length, source sequence length)

# %%
def model_inputs():
    """
    Create TF Placeholders for input, targets, learning rate, and lengths of source and target sequences.
    :return: Tuple (input, targets, learning rate, keep probability, target sequence length,
    max target sequence length, source sequence length)
    """
    # TODO: Implement Function
    Input = tf.placeholder(tf.int32, shape=[None,None],name='input')
    targets = tf.placeholder(tf.int32, shape=[None,None],name='Targets')
    learning_rate = tf.placeholder(tf.float32, name="LearningRate")
    keep_prob = tf.placeholder(tf.float32, name="keep_prob")
    target_seq_length = tf.placeholder(tf.int32, (None,),name="target_sequence_length")
    max_target_seq_length = tf.reduce_max(target_seq_length,name="max_target_len")
    source_seq_length = tf.placeholder(tf.int32, (None,), name="source_sequence_length")
    return (Input, targets, learning_rate, keep_prob, target_seq_length, max_target_seq_length, source_seq_length)

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_model_inputs(model_inputs)
# Out:
# Tests Passed

# %% [markdown]
# ### Process Decoder Input
# Implement `process_decoder_input` by removing the last word id from each batch in `target_data` and concat the GO ID to the begining of each batch.

# %%
def process_decoder_input(target_data, target_vocab_to_int, batch_size):
    """
    Preprocess target data for encoding
    :param target_data: Target Placehoder
    :param target_vocab_to_int: Dictionary to go from the target words to an id
    :param batch_size: Batch Size
    :return: Preprocessed target data
    """
    # TODO: Implement Function
    ending = tf.strided_slice(target_data, [0, 0], [batch_size, -1], [1, 1])
    dec_input = tf.concat([tf.fill([batch_size, 1], target_vocab_to_int['<GO>']), ending], 1)
   
    return dec_input

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_process_encoding_input(process_decoder_input)
# Out:
# Tests Passed

# %% [markdown]
# ### Encoding
# Implement `encoding_layer()` to create a Encoder RNN layer:
#  * Embed the encoder input using [`tf.contrib.layers.embed_sequence`](https://www.tensorflow.org/api_docs/python/tf/contrib/layers/embed_sequence)
#  * Construct a [stacked](https://github.com/tensorflow/tensorflow/blob/6947f65a374ebf29e74bb71e36fd82760056d82c/tensorflow/docs_src/tutorials/recurrent.md#stacking-multiple-lstms) [`tf.contrib.rnn.LSTMCell`](https://www.tensorflow.org/api_docs/python/tf/contrib/rnn/LSTMCell) wrapped in a [`tf.contrib.rnn.DropoutWrapper`](https://www.tensorflow.org/api_docs/python/tf/contrib/rnn/DropoutWrapper)
#  * Pass cell and embedded input to [`tf.nn.dynamic_rnn()`](https://www.tensorflow.org/api_docs/python/tf/nn/dynamic_rnn)

# %%
from imp import reload
reload(tests)

def encoding_layer(rnn_inputs, rnn_size, num_layers, keep_prob, 
                   source_sequence_length, source_vocab_size, 
                   encoding_embedding_size):
    """
    Create encoding layer
    :param rnn_inputs: Inputs for the RNN
    :param rnn_size: RNN Size
    :param num_layers: Number of layers
    :param keep_prob: Dropout keep probability
    :param source_sequence_length: a list of the lengths of each sequence in the batch
    :param source_vocab_size: vocabulary size of source data
    :param encoding_embedding_size: embedding size of source data
    :return: tuple (RNN output, RNN state)
    """
    # TODO: Implement Function
    inputs =tf.contrib.layers.embed_sequence(rnn_inputs,source_vocab_size,encoding_embedding_size)
    cell = tf.contrib.rnn.BasicLSTMCell(rnn_size)
    dropout = tf.contrib.rnn.DropoutWrapper(cell,output_keep_prob=keep_prob)
    cell = tf.contrib.rnn.MultiRNNCell([tf.contrib.rnn.BasicLSTMCell(rnn_size) for _ in range(num_layers)])
    output, state = tf.nn.dynamic_rnn(cell,inputs,dtype=tf.float32)
    return output, state

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_encoding_layer(encoding_layer)
# Out:
# Tests Passed

# %% [markdown]
# ### Decoding - Training
# Create a training decoding layer:
# * Create a [`tf.contrib.seq2seq.TrainingHelper`](https://www.tensorflow.org/api_docs/python/tf/contrib/seq2seq/TrainingHelper)
# * Create a [`tf.contrib.seq2seq.BasicDecoder`](https://www.tensorflow.org/api_docs/python/tf/contrib/seq2seq/BasicDecoder)
# * Obtain the decoder outputs from [`tf.contrib.seq2seq.dynamic_decode`](https://www.tensorflow.org/api_docs/python/tf/contrib/seq2seq/dynamic_decode)

# %%
def decoding_layer_train(encoder_state, dec_cell, dec_embed_input, 
                         target_sequence_length, max_summary_length, 
                         output_layer, keep_prob):
    """
    Create a decoding layer for training
    :param encoder_state: Encoder State
    :param dec_cell: Decoder RNN Cell
    :param dec_embed_input: Decoder embedded input
    :param target_sequence_length: The lengths of each sequence in the target batch
    :param max_summary_length: The length of the longest sequence in the batch
    :param output_layer: Function to apply the output layer
    :param keep_prob: Dropout keep probability
    :return: BasicDecoderOutput containing training logits and sample_id
    """
    # TODO: Implement Function
    training_helper = tf.contrib.seq2seq.TrainingHelper(dec_embed_input, target_sequence_length)
    training_decoder = tf.contrib.seq2seq.BasicDecoder(dec_cell, training_helper, encoder_state, output_layer)
    training_decoder_output = tf.contrib.seq2seq.dynamic_decode(training_decoder, impute_finished=True, maximum_iterations=max_summary_length)[0]
    
    return training_decoder_output




"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_decoding_layer_train(decoding_layer_train)
# Out:
# Tests Passed

# %% [markdown]
# ### Decoding - Inference
# Create inference decoder:
# * Create a [`tf.contrib.seq2seq.GreedyEmbeddingHelper`](https://www.tensorflow.org/api_docs/python/tf/contrib/seq2seq/GreedyEmbeddingHelper)
# * Create a [`tf.contrib.seq2seq.BasicDecoder`](https://www.tensorflow.org/api_docs/python/tf/contrib/seq2seq/BasicDecoder)
# * Obtain the decoder outputs from [`tf.contrib.seq2seq.dynamic_decode`](https://www.tensorflow.org/api_docs/python/tf/contrib/seq2seq/dynamic_decode)

# %%
def decoding_layer_infer(encoder_state, dec_cell, dec_embeddings, start_of_sequence_id,
                         end_of_sequence_id, max_target_sequence_length,
                         vocab_size, output_layer, batch_size, keep_prob):
    """
    Create a decoding layer for inference
    :param encoder_state: Encoder state
    :param dec_cell: Decoder RNN Cell
    :param dec_embeddings: Decoder embeddings
    :param start_of_sequence_id: GO ID
    :param end_of_sequence_id: EOS Id
    :param max_target_sequence_length: Maximum length of target sequences
    :param vocab_size: Size of decoder/target vocabulary
    :param decoding_scope: TenorFlow Variable Scope for decoding
    :param output_layer: Function to apply the output layer
    :param batch_size: Batch size
    :param keep_prob: Dropout keep probability
    :return: BasicDecoderOutput containing inference logits and sample_id
    """
    # TODO: Implement Function
    #with tf.variable_scope("decoding", reuse=None) as decoding_scope:
        # Inference Decoder
    #    infer_decoder_fn = tf.contrib.seq2seq.simple_decoder_fn_inference(
    #        output_fn, encoder_state, dec_embeddings, start_of_sequence_id, end_of_sequence_id,
    #        maximum_length, vocab_size, dtype=tf.int32)
    #    inference_logits, _, _ = tf.contrib.seq2seq.dynamic_rnn_decoder(dec_cell, infer_decoder_fn, scope=decoding_scope)
    #    inference_logits_with_dropout = tf.nn.dropout(inference_logits, keep_prob)
    #return inference_logits_with_dropout


        
    start_tokens = tf.tile(tf.constant([start_of_sequence_id], dtype=tf.int32), [batch_size], name='start_tokens')
        
    # Helper for the inference process.
    inference_helper = tf.contrib.seq2seq.GreedyEmbeddingHelper(dec_embeddings,
                                                                start_tokens,
                                                                end_of_sequence_id)

    # Basic decoder
    inference_decoder = tf.contrib.seq2seq.BasicDecoder(dec_cell,
                                                        inference_helper,
                                                        encoder_state,
                                                        output_layer)
        
    # Perform dynamic decoding using the decoder
    inference_decoder_output, _ = tf.contrib.seq2seq.dynamic_decode(inference_decoder,
                                                                    impute_finished=True,
                                                                    maximum_iterations=max_target_sequence_length)
    
    
    #infer_decoder_fn = tf.contrib.seq2seq.simple_decoder_fn_inference(
    #output_fn, encoder_state, dec_embeddings, start_of_sequence_id, end_of_sequence_id, maximum_length, vocab_size)
    #inference_logits = tf.contrib.seq2seq.dynamicrnn_decoder(dec_cell, infer_decoder_fn, scope=decoding_scope)
    return inference_decoder_output



"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_decoding_layer_infer(decoding_layer_infer)
# Out:
# Tests Passed

# %% [markdown]
# ### Build the Decoding Layer
# Implement `decoding_layer()` to create a Decoder RNN layer.
#
# * Embed the target sequences
# * Construct the decoder LSTM cell (just like you constructed the encoder cell above)
# * Create an output layer to map the outputs of the decoder to the elements of our vocabulary
# * Use the your `decoding_layer_train(encoder_state, dec_cell, dec_embed_input, target_sequence_length, max_target_sequence_length, output_layer, keep_prob)` function to get the training logits.
# * Use your `decoding_layer_infer(encoder_state, dec_cell, dec_embeddings, start_of_sequence_id, end_of_sequence_id, max_target_sequence_length, vocab_size, output_layer, batch_size, keep_prob)` function to get the inference logits.
#
# Note: You'll need to use [tf.variable_scope](https://www.tensorflow.org/api_docs/python/tf/variable_scope) to share variables between training and inference.

# %%
def decoding_layer(dec_input, encoder_state,
               target_sequence_length, max_target_sequence_length,
               rnn_size,
               num_layers, target_vocab_to_int, target_vocab_size,
               batch_size, keep_prob, decoding_embedding_size):
    """
    Create decoding layer
    :param dec_input: Decoder input
    :param encoder_state: Encoder state
    :param target_sequence_length: The lengths of each sequence in the target batch
    :param max_target_sequence_length: Maximum length of target sequences
    :param rnn_size: RNN Size
    :param num_layers: Number of layers
    :param target_vocab_to_int: Dictionary to go from the target words to an id
    :param target_vocab_size: Size of target vocabulary
    :param batch_size: The size of the batch
    :param keep_prob: Dropout keep probability
    :param decoding_embedding_size: Decoding embedding size
    :return: Tuple of (Training BasicDecoderOutput, Inference BasicDecoderOutput)
    """
    # TODO: Implement Function
    #return None, None

    # Decoder embedding
    #target_vocab_size = len(target_vocab_to_int)
    dec_embeddings = tf.Variable(tf.random_uniform([target_vocab_size, decoding_embedding_size]))
    dec_embed_input = tf.nn.embedding_lookup(dec_embeddings, dec_input)  

    # Create decoder cell
    def make_cell(rnn_size):
        dec_cell = tf.contrib.rnn.LSTMCell(rnn_size, \
                                           initializer=tf.random_uniform_initializer(-0.1, 0.1, seed=2))
        return dec_cell
    dec_cell = tf.contrib.rnn.MultiRNNCell([make_cell(rnn_size) for _ in range(num_layers)])   

    # Create Dense layer to translate decoder's output at each time
    output_layer = Dense(target_vocab_size, \
                         kernel_initializer = tf.truncated_normal_initializer(mean=0.0, stddev=0.1))   

    # Training decoder
    with tf.variable_scope("decode") as decoding_scope:

        #output_layer = Dense(target_vocab_size, \
        #                 kernel_initializer = tf.truncated_normal_initializer(mean=0.0, stddev=0.1))

        training_decoder_output = decoding_layer_train(encoder_state, dec_cell, dec_embed_input, 
                         target_sequence_length, max_target_sequence_length, 
                         output_layer, keep_prob)
        
        

    # Inference decoder
    with tf.variable_scope("decode", reuse=True) as decoding_scope:
        start_of_sequence_id = target_vocab_to_int['<GO>']
        end_of_sequence_id = target_vocab_to_int['<EOS>']

        inference_decoder_output = decoding_layer_infer(encoder_state, dec_cell, dec_embeddings, start_of_sequence_id,
                             end_of_sequence_id, max_target_sequence_length,
                             target_vocab_size, output_layer, batch_size, keep_prob)
        
        

    return training_decoder_output, inference_decoder_output

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_decoding_layer(decoding_layer)
# Out:
# Tests Passed

# %% [markdown]
# ### Build the Neural Network
# Apply the functions you implemented above to:
#
# - Encode the input using your `encoding_layer(rnn_inputs, rnn_size, num_layers, keep_prob,  source_sequence_length, source_vocab_size, encoding_embedding_size)`.
# - Process target data using your `process_decoder_input(target_data, target_vocab_to_int, batch_size)` function.
# - Decode the encoded input using your `decoding_layer(dec_input, enc_state, target_sequence_length, max_target_sentence_length, rnn_size, num_layers, target_vocab_to_int, target_vocab_size, batch_size, keep_prob, dec_embedding_size)` function.

# %%
def seq2seq_model(input_data, target_data, keep_prob, batch_size,
                  source_sequence_length, target_sequence_length,
                  max_target_sentence_length,
                  source_vocab_size, target_vocab_size,
                  enc_embedding_size, dec_embedding_size,
                  rnn_size, num_layers, target_vocab_to_int):
    """
    Build the Sequence-to-Sequence part of the neural network
    :param input_data: Input placeholder
    :param target_data: Target placeholder
    :param keep_prob: Dropout keep probability placeholder
    :param batch_size: Batch Size
    :param source_sequence_length: Sequence Lengths of source sequences in the batch
    :param target_sequence_length: Sequence Lengths of target sequences in the batch
    :param source_vocab_size: Source vocabulary size
    :param target_vocab_size: Target vocabulary size
    :param enc_embedding_size: Decoder embedding size
    :param dec_embedding_size: Encoder embedding size
    :param rnn_size: RNN Size
    :param num_layers: Number of layers
    :param target_vocab_to_int: Dictionary to go from the target words to an id
    :return: Tuple of (Training BasicDecoderOutput, Inference BasicDecoderOutput)
    """
    
    # Pass the input data through the encoder. We'll ignore the encoder output, but use the state
    encoder_output, encoder_state = encoding_layer(input_data, rnn_size, num_layers, keep_prob, 
                                                   source_sequence_length, source_vocab_size, enc_embedding_size)
    
    processed_input = process_decoder_input(target_data, target_vocab_to_int, batch_size)
    
    max_target_sequence_length = tf.reduce_max(target_sequence_length)
    output_train, output_inference = decoding_layer(processed_input, encoder_state, 
                                                    target_sequence_length, max_target_sequence_length, 
                                                    rnn_size, num_layers, target_vocab_to_int, 
                                                    target_vocab_size, batch_size, keep_prob, dec_embedding_size)
    
    return output_train, output_inference
"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_seq2seq_model(seq2seq_model)
# Out:
# Tests Passed

# %% [markdown]
# ## Neural Network Training
# ### Hyperparameters
# Tune the following parameters:
#
# - Set `epochs` to the number of epochs.
# - Set `batch_size` to the batch size.
# - Set `rnn_size` to the size of the RNNs.
# - Set `num_layers` to the number of layers.
# - Set `encoding_embedding_size` to the size of the embedding for the encoder.
# - Set `decoding_embedding_size` to the size of the embedding for the decoder.
# - Set `learning_rate` to the learning rate.
# - Set `keep_probability` to the Dropout keep probability
# - Set `display_step` to state how many steps between each debug output statement

# %%
# Number of Epochs
epochs = 3
# Batch Size
batch_size = 128
# RNN Size
rnn_size = 50
# Number of Layers
num_layers = 2
# Embedding Size
encoding_embedding_size = 15
decoding_embedding_size = 15
# Learning Rate
learning_rate = 0.1
# Dropout Keep Probability
keep_probability = 0.65
display_step = 5

# %% [markdown]
# ### Build the Graph
# Build the graph using the neural network you implemented.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
save_path = 'checkpoints/dev'
(source_int_text, target_int_text), (source_vocab_to_int, target_vocab_to_int), _ = helper.load_preprocess()
max_target_sentence_length = max([len(sentence) for sentence in source_int_text])

train_graph = tf.Graph()
with train_graph.as_default():
    input_data, targets, lr, keep_prob, target_sequence_length, max_target_sequence_length, source_sequence_length = model_inputs()

    #sequence_length = tf.placeholder_with_default(max_target_sentence_length, None, name='sequence_length')
    input_shape = tf.shape(input_data)

    train_logits, inference_logits = seq2seq_model(tf.reverse(input_data, [-1]),
                                                   targets,
                                                   keep_prob,
                                                   batch_size,
                                                   source_sequence_length,
                                                   target_sequence_length,
                                                   max_target_sequence_length,
                                                   len(source_vocab_to_int),
                                                   len(target_vocab_to_int),
                                                   encoding_embedding_size,
                                                   decoding_embedding_size,
                                                   rnn_size,
                                                   num_layers,
                                                   target_vocab_to_int)


    training_logits = tf.identity(train_logits.rnn_output, name='logits')
    inference_logits = tf.identity(inference_logits.sample_id, name='predictions')

    masks = tf.sequence_mask(target_sequence_length, max_target_sequence_length, dtype=tf.float32, name='masks')

    with tf.name_scope("optimization"):
        # Loss function
        cost = tf.contrib.seq2seq.sequence_loss(
            training_logits,
            targets,
            masks)

        # Optimizer
        optimizer = tf.train.AdamOptimizer(lr)

        # Gradient Clipping
        gradients = optimizer.compute_gradients(cost)
        capped_gradients = [(tf.clip_by_value(grad, -1., 1.), var) for grad, var in gradients if grad is not None]
        train_op = optimizer.apply_gradients(capped_gradients)

# %% [markdown]
# Batch and pad the source and target sequences

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
def pad_sentence_batch(sentence_batch, pad_int):
    """Pad sentences with <PAD> so that each sentence of a batch has the same length"""
    max_sentence = max([len(sentence) for sentence in sentence_batch])
    return [sentence + [pad_int] * (max_sentence - len(sentence)) for sentence in sentence_batch]


def get_batches(sources, targets, batch_size, source_pad_int, target_pad_int):
    """Batch targets, sources, and the lengths of their sentences together"""
    for batch_i in range(0, len(sources)//batch_size):
        start_i = batch_i * batch_size

        # Slice the right amount for the batch
        sources_batch = sources[start_i:start_i + batch_size]
        targets_batch = targets[start_i:start_i + batch_size]

        # Pad
        pad_sources_batch = np.array(pad_sentence_batch(sources_batch, source_pad_int))
        pad_targets_batch = np.array(pad_sentence_batch(targets_batch, target_pad_int))

        # Need the lengths for the _lengths parameters
        pad_targets_lengths = []
        for target in pad_targets_batch:
            pad_targets_lengths.append(len(target))

        pad_source_lengths = []
        for source in pad_sources_batch:
            pad_source_lengths.append(len(source))

        yield pad_sources_batch, pad_targets_batch, pad_source_lengths, pad_targets_lengths

# %% [markdown]
# ### Train
# Train the neural network on the preprocessed data. If you have a hard time getting a good loss, check the forms to see if anyone is having the same problem.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
def get_accuracy(target, logits):
    """
    Calculate accuracy
    """
    max_seq = max(target.shape[1], logits.shape[1])
    if max_seq - target.shape[1]:
        target = np.pad(
            target,
            [(0,0),(0,max_seq - target.shape[1])],
            'constant')
    if max_seq - logits.shape[1]:
        logits = np.pad(
            logits,
            [(0,0),(0,max_seq - logits.shape[1])],
            'constant')

    return np.mean(np.equal(target, logits))

# Split data to training and validation sets
train_source = source_int_text[batch_size:]
train_target = target_int_text[batch_size:]
valid_source = source_int_text[:batch_size]
valid_target = target_int_text[:batch_size]
(valid_sources_batch, valid_targets_batch, valid_sources_lengths, valid_targets_lengths ) = next(get_batches(valid_source,
                                                                                                             valid_target,
                                                                                                             batch_size,
                                                                                                             source_vocab_to_int['<PAD>'],
                                                                                                             target_vocab_to_int['<PAD>']))                                                                                                  
with tf.Session(graph=train_graph) as sess:
    sess.run(tf.global_variables_initializer())

    for epoch_i in range(epochs):
        for batch_i, (source_batch, target_batch, sources_lengths, targets_lengths) in enumerate(
                get_batches(train_source, train_target, batch_size,
                            source_vocab_to_int['<PAD>'],
                            target_vocab_to_int['<PAD>'])):

            _, loss = sess.run(
                [train_op, cost],
                {input_data: source_batch,
                 targets: target_batch,
                 lr: learning_rate,
                 target_sequence_length: targets_lengths,
                 source_sequence_length: sources_lengths,
                 keep_prob: keep_probability})


            if batch_i % display_step == 0 and batch_i > 0:


                batch_train_logits = sess.run(
                    inference_logits,
                    {input_data: source_batch,
                     source_sequence_length: sources_lengths,
                     target_sequence_length: targets_lengths,
                     keep_prob: 1.0})


                batch_valid_logits = sess.run(
                    inference_logits,
                    {input_data: valid_sources_batch,
                     source_sequence_length: valid_sources_lengths,
                     target_sequence_length: valid_targets_lengths,
                     keep_prob: 1.0})

                train_acc = get_accuracy(target_batch, batch_train_logits)

                valid_acc = get_accuracy(valid_targets_batch, batch_valid_logits)

                print('Epoch {:>3} Batch {:>4}/{} - Train Accuracy: {:>6.4f}, Validation Accuracy: {:>6.4f}, Loss: {:>6.4f}'
                      .format(epoch_i, batch_i, len(source_int_text) // batch_size, train_acc, valid_acc, loss))

    # Save Model
    saver = tf.train.Saver()
    saver.save(sess, save_path)
    print('Model Trained and Saved')
# Out:
# Epoch   0 Batch    5/1077 - Train Accuracy: 0.2605, Validation Accuracy: 0.3050, Loss: 3.7888
# Epoch   0 Batch   10/1077 - Train Accuracy: 0.2434, Validation Accuracy: 0.3448, Loss: 3.8153
# Epoch   0 Batch   15/1077 - Train Accuracy: 0.2832, Validation Accuracy: 0.3501, Loss: 3.3116
# Epoch   0 Batch   20/1077 - Train Accuracy: 0.2832, Validation Accuracy: 0.3516, Loss: 3.1083
# Epoch   0 Batch   25/1077 - Train Accuracy: 0.3082, Validation Accuracy: 0.3814, Loss: 3.0252
# Epoch   0 Batch   30/1077 - Train Accuracy: 0.3215, Validation Accuracy: 0.3817, Loss: 2.7360
# Epoch   0 Batch   35/1077 - Train Accuracy: 0.3305, Validation Accuracy: 0.3793, Loss: 2.5563
# Epoch   0 Batch   40/1077 - Train Accuracy: 0.3074, Validation Accuracy: 0.3619, Loss: 2.3524
# Epoch   0 Batch   45/1077 - Train Accuracy: 0.3137, Validation Accuracy: 0.3860, Loss: 2.1867
# Epoch   0 Batch   50/1077 - Train Accuracy: 0.3262, Validation Accuracy: 0.4023, Loss: 2.0372
# Epoch   0 Batch   55/1077 - Train Accuracy: 0.3430, Validation Accuracy: 0.3761, Loss: 1.7663
# Epoch   0 Batch   60/1077 - Train Accuracy: 0.3475, Validation Accuracy: 0.3750, Loss: 1.5982
# Epoch   0 Batch   65/1077 - Train Accuracy: 0.3084, Validation Accuracy: 0.4165, Loss: 1.5962
# Epoch   0 Batch   70/1077 - Train Accuracy: 0.2998, Validation Accuracy: 0.3942, Loss: 1.4377
# Epoch   0 Batch   75/1077 - Train Accuracy: 0.3812, Validation Accuracy: 0.4315, Loss: 1.2758
# Epoch   0 Batch   80/1077 - Train Accuracy: 0.4199, Validation Accuracy: 0.4496, Loss: 1.2277
# Epoch   0 Batch   85/1077 - Train Accuracy: 0.4551, Validation Accuracy: 0.4876, Loss: 1.1203
# Epoch   0 Batch   90/1077 - Train Accuracy: 0.4027, Validation Accuracy: 0.4872, Loss: 1.2327
# Epoch   0 Batch   95/1077 - Train Accuracy: 0.4676, Validation Accuracy: 0.4844, Loss: 1.1921
# Epoch   0 Batch  100/1077 - Train Accuracy: 0.4426, Validation Accuracy: 0.4950, Loss: 1.1454
# Epoch   0 Batch  105/1077 - Train Accuracy: 0.4664, Validation Accuracy: 0.4915, Loss: 1.0638
# Epoch   0 Batch  110/1077 - Train Accuracy: 0.4660, Validation Accuracy: 0.5004, Loss: 1.0409
# Epoch   0 Batch  115/1077 - Train Accuracy: 0.4082, Validation Accuracy: 0.4904, Loss: 1.1179
# Epoch   0 Batch  120/1077 - Train Accuracy: 0.4172, Validation Accuracy: 0.5092, Loss: 1.0719
# Epoch   0 Batch  125/1077 - Train Accuracy: 0.4576, Validation Accuracy: 0.4908, Loss: 0.9908
# Epoch   0 Batch  130/1077 - Train Accuracy: 0.4758, Validation Accuracy: 0.4986, Loss: 0.9545
# Epoch   0 Batch  135/1077 - Train Accuracy: 0.4445, Validation Accuracy: 0.4989, Loss: 1.0376
# Epoch   0 Batch  140/1077 - Train Accuracy: 0.3960, Validation Accuracy: 0.4972, Loss: 1.0486
# Epoch   0 Batch  145/1077 - Train Accuracy: 0.5133, Validation Accuracy: 0.5085, Loss: 0.9862
# Epoch   0 Batch  150/1077 - Train Accuracy: 0.4818, Validation Accuracy: 0.5014, Loss: 0.9444
# Epoch   0 Batch  155/1077 - Train Accuracy: 0.4191, Validation Accuracy: 0.5075, Loss: 0.9696
# Epoch   0 Batch  160/1077 - Train Accuracy: 0.4434, Validation Accuracy: 0.5000, Loss: 0.9163
# Epoch   0 Batch  165/1077 - Train Accuracy: 0.4246, Validation Accuracy: 0.4975, Loss: 0.8851
# Epoch   0 Batch  170/1077 - Train Accuracy: 0.4316, Validation Accuracy: 0.5036, Loss: 0.9491
# Epoch   0 Batch  175/1077 - Train Accuracy: 0.4707, Validation Accuracy: 0.5032, Loss: 0.9069
# Epoch   0 Batch  180/1077 - Train Accuracy: 0.4699, Validation Accuracy: 0.5124, Loss: 0.9264
# Epoch   0 Batch  185/1077 - Train Accuracy: 0.4402, Validation Accuracy: 0.5121, Loss: 0.8995
# Epoch   0 Batch  190/1077 - Train Accuracy: 0.4699, Validation Accuracy: 0.5142, Loss: 0.8863
# Epoch   0 Batch  195/1077 - Train Accuracy: 0.4484, Validation Accuracy: 0.5146, Loss: 0.8520
# Epoch   0 Batch  200/1077 - Train Accuracy: 0.4430, Validation Accuracy: 0.5178, Loss: 0.9028
# Epoch   0 Batch  205/1077 - Train Accuracy: 0.4504, Validation Accuracy: 0.5032, Loss: 0.8847
# Epoch   0 Batch  210/1077 - Train Accuracy: 0.5082, Validation Accuracy: 0.5415, Loss: 0.8683
# Epoch   0 Batch  215/1077 - Train Accuracy: 0.4719, Validation Accuracy: 0.5234, Loss: 0.8569
# Epoch   0 Batch  220/1077 - Train Accuracy: 0.4659, Validation Accuracy: 0.5263, Loss: 0.8617
# Epoch   0 Batch  225/1077 - Train Accuracy: 0.4832, Validation Accuracy: 0.5337, Loss: 0.8526
# Epoch   0 Batch  230/1077 - Train Accuracy: 0.5231, Validation Accuracy: 0.5270, Loss: 0.8285
# Epoch   0 Batch  235/1077 - Train Accuracy: 0.5197, Validation Accuracy: 0.5529, Loss: 0.7517
# Epoch   0 Batch  240/1077 - Train Accuracy: 0.5023, Validation Accuracy: 0.5451, Loss: 0.8274
# Epoch   0 Batch  245/1077 - Train Accuracy: 0.4751, Validation Accuracy: 0.5085, Loss: 0.7614
# Epoch   0 Batch  250/1077 - Train Accuracy: 0.4805, Validation Accuracy: 0.5337, Loss: 0.7527
# Epoch   0 Batch  255/1077 - Train Accuracy: 0.4781, Validation Accuracy: 0.5295, Loss: 0.8200
# Epoch   0 Batch  260/1077 - Train Accuracy: 0.4807, Validation Accuracy: 0.5160, Loss: 0.7565
# Epoch   0 Batch  265/1077 - Train Accuracy: 0.4867, Validation Accuracy: 0.5359, Loss: 0.7765
# Epoch   0 Batch  270/1077 - Train Accuracy: 0.4648, Validation Accuracy: 0.5210, Loss: 0.8170
# Epoch   0 Batch  275/1077 - Train Accuracy: 0.4981, Validation Accuracy: 0.5135, Loss: 0.7665
# Epoch   0 Batch  280/1077 - Train Accuracy: 0.5184, Validation Accuracy: 0.5447, Loss: 0.8125
# Epoch   0 Batch  285/1077 - Train Accuracy: 0.5182, Validation Accuracy: 0.5146, Loss: 0.7599
# Epoch   0 Batch  290/1077 - Train Accuracy: 0.4617, Validation Accuracy: 0.5174, Loss: 0.8138
# Epoch   0 Batch  295/1077 - Train Accuracy: 0.5021, Validation Accuracy: 0.5355, Loss: 0.8382
# Epoch   0 Batch  300/1077 - Train Accuracy: 0.4638, Validation Accuracy: 0.5518, Loss: 0.7904
# Epoch   0 Batch  305/1077 - Train Accuracy: 0.4883, Validation Accuracy: 0.4872, Loss: 0.7520
# Epoch   0 Batch  310/1077 - Train Accuracy: 0.4652, Validation Accuracy: 0.5330, Loss: 0.7866
# Epoch   0 Batch  315/1077 - Train Accuracy: 0.4777, Validation Accuracy: 0.5092, Loss: 0.7215
# Epoch   0 Batch  320/1077 - Train Accuracy: 0.5199, Validation Accuracy: 0.5423, Loss: 0.7651
# Epoch   0 Batch  325/1077 - Train Accuracy: 0.5472, Validation Accuracy: 0.5511, Loss: 0.7557
# Epoch   0 Batch  330/1077 - Train Accuracy: 0.5098, Validation Accuracy: 0.5419, Loss: 0.7477
# Epoch   0 Batch  335/1077 - Train Accuracy: 0.5513, Validation Accuracy: 0.5046, Loss: 0.7218
# Epoch   0 Batch  340/1077 - Train Accuracy: 0.4511, Validation Accuracy: 0.5277, Loss: 0.7935
# Epoch   0 Batch  345/1077 - Train Accuracy: 0.5242, Validation Accuracy: 0.5362, Loss: 0.7498
# Epoch   0 Batch  350/1077 - Train Accuracy: 0.4574, Validation Accuracy: 0.5376, Loss: 0.8356
# Epoch   0 Batch  355/1077 - Train Accuracy: 0.4781, Validation Accuracy: 0.5107, Loss: 0.8381
# Epoch   0 Batch  360/1077 - Train Accuracy: 0.4574, Validation Accuracy: 0.5160, Loss: 0.8029
# Epoch   0 Batch  365/1077 - Train Accuracy: 0.4492, Validation Accuracy: 0.5220, Loss: 0.7896
# Epoch   0 Batch  370/1077 - Train Accuracy: 0.4795, Validation Accuracy: 0.5458, Loss: 0.7684
# Epoch   0 Batch  375/1077 - Train Accuracy: 0.5430, Validation Accuracy: 0.5281, Loss: 0.7329
# Epoch   0 Batch  380/1077 - Train Accuracy: 0.5047, Validation Accuracy: 0.5423, Loss: 0.7546
# Epoch   0 Batch  385/1077 - Train Accuracy: 0.5273, Validation Accuracy: 0.5511, Loss: 0.7431
# Epoch   0 Batch  390/1077 - Train Accuracy: 0.4570, Validation Accuracy: 0.5529, Loss: 0.7778
# Epoch   0 Batch  395/1077 - Train Accuracy: 0.5246, Validation Accuracy: 0.5078, Loss: 0.7124
# Epoch   0 Batch  400/1077 - Train Accuracy: 0.4656, Validation Accuracy: 0.5192, Loss: 0.7540
# Epoch   0 Batch  405/1077 - Train Accuracy: 0.4737, Validation Accuracy: 0.5362, Loss: 0.8074
# Epoch   0 Batch  410/1077 - Train Accuracy: 0.4716, Validation Accuracy: 0.5490, Loss: 0.7625
# Epoch   0 Batch  415/1077 - Train Accuracy: 0.4926, Validation Accuracy: 0.5263, Loss: 0.6820
# Epoch   0 Batch  420/1077 - Train Accuracy: 0.4492, Validation Accuracy: 0.5195, Loss: 0.7236
# Epoch   0 Batch  425/1077 - Train Accuracy: 0.5052, Validation Accuracy: 0.5373, Loss: 0.7068
# Epoch   0 Batch  430/1077 - Train Accuracy: 0.4848, Validation Accuracy: 0.5401, Loss: 0.7332
# Epoch   0 Batch  435/1077 - Train Accuracy: 0.4762, Validation Accuracy: 0.5217, Loss: 0.7887
# Epoch   0 Batch  440/1077 - Train Accuracy: 0.5031, Validation Accuracy: 0.5359, Loss: 0.7547
# Epoch   0 Batch  445/1077 - Train Accuracy: 0.4285, Validation Accuracy: 0.5032, Loss: 0.7547
# Epoch   0 Batch  450/1077 - Train Accuracy: 0.4730, Validation Accuracy: 0.5341, Loss: 0.7313
# Epoch   0 Batch  455/1077 - Train Accuracy: 0.5341, Validation Accuracy: 0.5433, Loss: 0.6953
# Epoch   0 Batch  460/1077 - Train Accuracy: 0.4668, Validation Accuracy: 0.5384, Loss: 0.7487
# Epoch   0 Batch  465/1077 - Train Accuracy: 0.4424, Validation Accuracy: 0.5494, Loss: 0.7728
# Epoch   0 Batch  470/1077 - Train Accuracy: 0.4593, Validation Accuracy: 0.5305, Loss: 0.7618
# Epoch   0 Batch  475/1077 - Train Accuracy: 0.5320, Validation Accuracy: 0.5589, Loss: 0.7108
# Epoch   0 Batch  480/1077 - Train Accuracy: 0.4786, Validation Accuracy: 0.5252, Loss: 0.7319
# Epoch   0 Batch  485/1077 - Train Accuracy: 0.5215, Validation Accuracy: 0.5479, Loss: 0.7268
# Epoch   0 Batch  490/1077 - Train Accuracy: 0.4672, Validation Accuracy: 0.5202, Loss: 0.7084
# Epoch   0 Batch  495/1077 - Train Accuracy: 0.5031, Validation Accuracy: 0.5359, Loss: 0.6865
# Epoch   0 Batch  500/1077 - Train Accuracy: 0.5434, Validation Accuracy: 0.5732, Loss: 0.6956
# Epoch   0 Batch  505/1077 - Train Accuracy: 0.5219, Validation Accuracy: 0.5440, Loss: 0.6416
# Epoch   0 Batch  510/1077 - Train Accuracy: 0.5105, Validation Accuracy: 0.5174, Loss: 0.6933
# Epoch   0 Batch  515/1077 - Train Accuracy: 0.5027, Validation Accuracy: 0.5430, Loss: 0.7310
# Epoch   0 Batch  520/1077 - Train Accuracy: 0.5365, Validation Accuracy: 0.5384, Loss: 0.6647
# Epoch   0 Batch  525/1077 - Train Accuracy: 0.4848, Validation Accuracy: 0.5376, Loss: 0.7047
# Epoch   0 Batch  530/1077 - Train Accuracy: 0.4766, Validation Accuracy: 0.5323, Loss: 0.7273
# Epoch   0 Batch  535/1077 - Train Accuracy: 0.4801, Validation Accuracy: 0.5330, Loss: 0.7045
# Epoch   0 Batch  540/1077 - Train Accuracy: 0.5000, Validation Accuracy: 0.5419, Loss: 0.6452
# Epoch   0 Batch  545/1077 - Train Accuracy: 0.4762, Validation Accuracy: 0.5458, Loss: 0.7277
# Epoch   0 Batch  550/1077 - Train Accuracy: 0.4840, Validation Accuracy: 0.5518, Loss: 0.7359
# Epoch   0 Batch  555/1077 - Train Accuracy: 0.5301, Validation Accuracy: 0.5270, Loss: 0.6773
# Epoch   0 Batch  560/1077 - Train Accuracy: 0.4945, Validation Accuracy: 0.5487, Loss: 0.6742
# Epoch   0 Batch  565/1077 - Train Accuracy: 0.5294, Validation Accuracy: 0.5625, Loss: 0.6788
# Epoch   0 Batch  570/1077 - Train Accuracy: 0.4910, Validation Accuracy: 0.5259, Loss: 0.7274
# Epoch   0 Batch  575/1077 - Train Accuracy: 0.5502, Validation Accuracy: 0.5625, Loss: 0.6922
# Epoch   0 Batch  580/1077 - Train Accuracy: 0.5253, Validation Accuracy: 0.5426, Loss: 0.6288
# Epoch   0 Batch  585/1077 - Train Accuracy: 0.5331, Validation Accuracy: 0.5192, Loss: 0.6309
# Epoch   0 Batch  590/1077 - Train Accuracy: 0.4885, Validation Accuracy: 0.5490, Loss: 0.7192
# Epoch   0 Batch  595/1077 - Train Accuracy: 0.4848, Validation Accuracy: 0.5401, Loss: 0.6976
# Epoch   0 Batch  600/1077 - Train Accuracy: 0.5499, Validation Accuracy: 0.5465, Loss: 0.6355
# Epoch   0 Batch  605/1077 - Train Accuracy: 0.5325, Validation Accuracy: 0.5504, Loss: 0.7323
# Epoch   0 Batch  610/1077 - Train Accuracy: 0.5115, Validation Accuracy: 0.5458, Loss: 0.7091
# Epoch   0 Batch  615/1077 - Train Accuracy: 0.5449, Validation Accuracy: 0.5717, Loss: 0.6744
# Epoch   0 Batch  620/1077 - Train Accuracy: 0.4883, Validation Accuracy: 0.5412, Loss: 0.6499
# Epoch   0 Batch  625/1077 - Train Accuracy: 0.5324, Validation Accuracy: 0.5653, Loss: 0.6702
# Epoch   0 Batch  630/1077 - Train Accuracy: 0.5504, Validation Accuracy: 0.5522, Loss: 0.6753
# Epoch   0 Batch  635/1077 - Train Accuracy: 0.5086, Validation Accuracy: 0.5447, Loss: 0.7074
# Epoch   0 Batch  640/1077 - Train Accuracy: 0.5134, Validation Accuracy: 0.5721, Loss: 0.6919
# Epoch   0 Batch  645/1077 - Train Accuracy: 0.5253, Validation Accuracy: 0.5621, Loss: 0.6588
# Epoch   0 Batch  650/1077 - Train Accuracy: 0.4867, Validation Accuracy: 0.5724, Loss: 0.6923
# Epoch   0 Batch  655/1077 - Train Accuracy: 0.5012, Validation Accuracy: 0.5621, Loss: 0.7050
# Epoch   0 Batch  660/1077 - Train Accuracy: 0.5273, Validation Accuracy: 0.5607, Loss: 0.6834
# Epoch   0 Batch  665/1077 - Train Accuracy: 0.4945, Validation Accuracy: 0.5433, Loss: 0.6786
# Epoch   0 Batch  670/1077 - Train Accuracy: 0.5746, Validation Accuracy: 0.5792, Loss: 0.6464
# Epoch   0 Batch  675/1077 - Train Accuracy: 0.5636, Validation Accuracy: 0.5810, Loss: 0.6431
# Epoch   0 Batch  680/1077 - Train Accuracy: 0.4926, Validation Accuracy: 0.5394, Loss: 0.6527
# Epoch   0 Batch  685/1077 - Train Accuracy: 0.5145, Validation Accuracy: 0.5515, Loss: 0.6789
# Epoch   0 Batch  690/1077 - Train Accuracy: 0.5336, Validation Accuracy: 0.5636, Loss: 0.6624
# Epoch   0 Batch  695/1077 - Train Accuracy: 0.5418, Validation Accuracy: 0.5643, Loss: 0.6511
# Epoch   0 Batch  700/1077 - Train Accuracy: 0.5422, Validation Accuracy: 0.5529, Loss: 0.6682
# Epoch   0 Batch  705/1077 - Train Accuracy: 0.5424, Validation Accuracy: 0.5671, Loss: 0.7357
# Epoch   0 Batch  710/1077 - Train Accuracy: 0.4781, Validation Accuracy: 0.5430, Loss: 0.6593
# Epoch   0 Batch  715/1077 - Train Accuracy: 0.5051, Validation Accuracy: 0.5582, Loss: 0.6678
# Epoch   0 Batch  720/1077 - Train Accuracy: 0.5053, Validation Accuracy: 0.5664, Loss: 0.7180
# Epoch   0 Batch  725/1077 - Train Accuracy: 0.5428, Validation Accuracy: 0.5593, Loss: 0.6387
# Epoch   0 Batch  730/1077 - Train Accuracy: 0.5160, Validation Accuracy: 0.5618, Loss: 0.6910
# Epoch   0 Batch  735/1077 - Train Accuracy: 0.4945, Validation Accuracy: 0.5597, Loss: 0.6563
# Epoch   0 Batch  740/1077 - Train Accuracy: 0.5289, Validation Accuracy: 0.5593, Loss: 0.6512
# Epoch   0 Batch  745/1077 - Train Accuracy: 0.5426, Validation Accuracy: 0.5550, Loss: 0.6610
# Epoch   0 Batch  750/1077 - Train Accuracy: 0.5234, Validation Accuracy: 0.5533, Loss: 0.6509
# Epoch   0 Batch  755/1077 - Train Accuracy: 0.5305, Validation Accuracy: 0.5703, Loss: 0.6838
# Epoch   0 Batch  760/1077 - Train Accuracy: 0.5152, Validation Accuracy: 0.5522, Loss: 0.6703
# Epoch   0 Batch  765/1077 - Train Accuracy: 0.5621, Validation Accuracy: 0.5632, Loss: 0.6402
# Epoch   0 Batch  770/1077 - Train Accuracy: 0.5238, Validation Accuracy: 0.5508, Loss: 0.6306
# Epoch   0 Batch  775/1077 - Train Accuracy: 0.5465, Validation Accuracy: 0.5735, Loss: 0.6545
# Epoch   0 Batch  780/1077 - Train Accuracy: 0.4684, Validation Accuracy: 0.5455, Loss: 0.7665
# Epoch   0 Batch  785/1077 - Train Accuracy: 0.5223, Validation Accuracy: 0.5398, Loss: 0.6803
# Epoch   0 Batch  790/1077 - Train Accuracy: 0.4527, Validation Accuracy: 0.5543, Loss: 0.7606
# Epoch   0 Batch  795/1077 - Train Accuracy: 0.4824, Validation Accuracy: 0.5465, Loss: 0.7613
# Epoch   0 Batch  800/1077 - Train Accuracy: 0.4574, Validation Accuracy: 0.5440, Loss: 0.7942
# Epoch   0 Batch  805/1077 - Train Accuracy: 0.4828, Validation Accuracy: 0.5458, Loss: 0.8196
# Epoch   0 Batch  810/1077 - Train Accuracy: 0.5439, Validation Accuracy: 0.5433, Loss: 0.6987
# Epoch   0 Batch  815/1077 - Train Accuracy: 0.5207, Validation Accuracy: 0.5433, Loss: 0.7428
# Epoch   0 Batch  820/1077 - Train Accuracy: 0.4840, Validation Accuracy: 0.5533, Loss: 0.7614
# Epoch   0 Batch  825/1077 - Train Accuracy: 0.5031, Validation Accuracy: 0.5692, Loss: 0.6838
# Epoch   0 Batch  830/1077 - Train Accuracy: 0.4840, Validation Accuracy: 0.5256, Loss: 0.7220
# Epoch   0 Batch  835/1077 - Train Accuracy: 0.5086, Validation Accuracy: 0.5536, Loss: 0.7099
# Epoch   0 Batch  840/1077 - Train Accuracy: 0.5074, Validation Accuracy: 0.5323, Loss: 0.6964
# Epoch   0 Batch  845/1077 - Train Accuracy: 0.5070, Validation Accuracy: 0.5348, Loss: 0.6939
# Epoch   0 Batch  850/1077 - Train Accuracy: 0.4896, Validation Accuracy: 0.5206, Loss: 0.7568
# Epoch   0 Batch  855/1077 - Train Accuracy: 0.4965, Validation Accuracy: 0.5643, Loss: 0.7013
# Epoch   0 Batch  860/1077 - Train Accuracy: 0.5327, Validation Accuracy: 0.5472, Loss: 0.6812
# Epoch   0 Batch  865/1077 - Train Accuracy: 0.5710, Validation Accuracy: 0.5451, Loss: 0.6277
# Epoch   0 Batch  870/1077 - Train Accuracy: 0.4762, Validation Accuracy: 0.5526, Loss: 0.7341
# Epoch   0 Batch  875/1077 - Train Accuracy: 0.5098, Validation Accuracy: 0.5398, Loss: 0.6994
# Epoch   0 Batch  880/1077 - Train Accuracy: 0.5566, Validation Accuracy: 0.5618, Loss: 0.6850
# Epoch   0 Batch  885/1077 - Train Accuracy: 0.5256, Validation Accuracy: 0.4876, Loss: 0.5922
# Epoch   0 Batch  890/1077 - Train Accuracy: 0.5844, Validation Accuracy: 0.5565, Loss: 0.6504
# Epoch   0 Batch  895/1077 - Train Accuracy: 0.4969, Validation Accuracy: 0.5710, Loss: 0.6700
# Epoch   0 Batch  900/1077 - Train Accuracy: 0.4809, Validation Accuracy: 0.5263, Loss: 0.7477
# Epoch   0 Batch  905/1077 - Train Accuracy: 0.5230, Validation Accuracy: 0.5373, Loss: 0.6695
# Epoch   0 Batch  910/1077 - Train Accuracy: 0.5145, Validation Accuracy: 0.5579, Loss: 0.6885
# Epoch   0 Batch  915/1077 - Train Accuracy: 0.4803, Validation Accuracy: 0.5749, Loss: 0.7150
# Epoch   0 Batch  920/1077 - Train Accuracy: 0.5125, Validation Accuracy: 0.5561, Loss: 0.7041
# Epoch   0 Batch  925/1077 - Train Accuracy: 0.5376, Validation Accuracy: 0.5614, Loss: 0.6653
# Epoch   0 Batch  930/1077 - Train Accuracy: 0.5047, Validation Accuracy: 0.5195, Loss: 0.6619
# Epoch   0 Batch  935/1077 - Train Accuracy: 0.5109, Validation Accuracy: 0.5664, Loss: 0.7053
# Epoch   0 Batch  940/1077 - Train Accuracy: 0.4988, Validation Accuracy: 0.5376, Loss: 0.6662
# Epoch   0 Batch  945/1077 - Train Accuracy: 0.5598, Validation Accuracy: 0.5714, Loss: 0.6390
# Epoch   0 Batch  950/1077 - Train Accuracy: 0.4937, Validation Accuracy: 0.5391, Loss: 0.6362
# Epoch   0 Batch  955/1077 - Train Accuracy: 0.4887, Validation Accuracy: 0.5444, Loss: 0.6815
# Epoch   0 Batch  960/1077 - Train Accuracy: 0.5539, Validation Accuracy: 0.5732, Loss: 0.6485
# Epoch   0 Batch  965/1077 - Train Accuracy: 0.4634, Validation Accuracy: 0.5792, Loss: 0.7119
# Epoch   0 Batch  970/1077 - Train Accuracy: 0.5305, Validation Accuracy: 0.5717, Loss: 0.6886
# Epoch   0 Batch  975/1077 - Train Accuracy: 0.5402, Validation Accuracy: 0.5327, Loss: 0.6209
# Epoch   0 Batch  980/1077 - Train Accuracy: 0.5371, Validation Accuracy: 0.5650, Loss: 0.6769
# Epoch   0 Batch  985/1077 - Train Accuracy: 0.5234, Validation Accuracy: 0.5558, Loss: 0.6477
# Epoch   0 Batch  990/1077 - Train Accuracy: 0.4967, Validation Accuracy: 0.5501, Loss: 0.7079
# Epoch   0 Batch  995/1077 - Train Accuracy: 0.5655, Validation Accuracy: 0.5902, Loss: 0.6313
# Epoch   0 Batch 1000/1077 - Train Accuracy: 0.5491, Validation Accuracy: 0.5366, Loss: 0.6036
# Epoch   0 Batch 1005/1077 - Train Accuracy: 0.4992, Validation Accuracy: 0.5561, Loss: 0.6643
# Epoch   0 Batch 1010/1077 - Train Accuracy: 0.4934, Validation Accuracy: 0.5511, Loss: 0.6566
# Epoch   0 Batch 1015/1077 - Train Accuracy: 0.4844, Validation Accuracy: 0.5380, Loss: 0.7039
# Epoch   0 Batch 1020/1077 - Train Accuracy: 0.5215, Validation Accuracy: 0.5554, Loss: 0.6514
# Epoch   0 Batch 1025/1077 - Train Accuracy: 0.5260, Validation Accuracy: 0.5653, Loss: 0.6354
# Epoch   0 Batch 1030/1077 - Train Accuracy: 0.4605, Validation Accuracy: 0.5366, Loss: 0.6562
# Epoch   0 Batch 1035/1077 - Train Accuracy: 0.5063, Validation Accuracy: 0.5043, Loss: 0.6045
# Epoch   0 Batch 1040/1077 - Train Accuracy: 0.5481, Validation Accuracy: 0.5653, Loss: 0.6905
# Epoch   0 Batch 1045/1077 - Train Accuracy: 0.4750, Validation Accuracy: 0.5653, Loss: 0.6651
# Epoch   0 Batch 1050/1077 - Train Accuracy: 0.4496, Validation Accuracy: 0.5426, Loss: 0.6718
# Epoch   0 Batch 1055/1077 - Train Accuracy: 0.5266, Validation Accuracy: 0.5675, Loss: 0.6577
# Epoch   0 Batch 1060/1077 - Train Accuracy: 0.5355, Validation Accuracy: 0.5824, Loss: 0.6224
# Epoch   0 Batch 1065/1077 - Train Accuracy: 0.5336, Validation Accuracy: 0.5586, Loss: 0.6567
# Epoch   0 Batch 1070/1077 - Train Accuracy: 0.5141, Validation Accuracy: 0.5898, Loss: 0.6527
# Epoch   0 Batch 1075/1077 - Train Accuracy: 0.4745, Validation Accuracy: 0.5447, Loss: 0.7234
# Epoch   1 Batch    5/1077 - Train Accuracy: 0.5289, Validation Accuracy: 0.5746, Loss: 0.6745
# Epoch   1 Batch   10/1077 - Train Accuracy: 0.4836, Validation Accuracy: 0.5664, Loss: 0.6818
# Epoch   1 Batch   15/1077 - Train Accuracy: 0.5449, Validation Accuracy: 0.5767, Loss: 0.6348
# Epoch   1 Batch   20/1077 - Train Accuracy: 0.5223, Validation Accuracy: 0.5554, Loss: 0.6343
# Epoch   1 Batch   25/1077 - Train Accuracy: 0.5242, Validation Accuracy: 0.5835, Loss: 0.6077
# Epoch   1 Batch   30/1077 - Train Accuracy: 0.5043, Validation Accuracy: 0.5423, Loss: 0.6556
# Epoch   1 Batch   35/1077 - Train Accuracy: 0.5168, Validation Accuracy: 0.5518, Loss: 0.6488
# Epoch   1 Batch   40/1077 - Train Accuracy: 0.5102, Validation Accuracy: 0.5806, Loss: 0.6630
# Epoch   1 Batch   45/1077 - Train Accuracy: 0.5363, Validation Accuracy: 0.5682, Loss: 0.6513
# Epoch   1 Batch   50/1077 - Train Accuracy: 0.5074, Validation Accuracy: 0.5678, Loss: 0.6639
# Epoch   1 Batch   55/1077 - Train Accuracy: 0.5527, Validation Accuracy: 0.5607, Loss: 0.6353
# Epoch   1 Batch   60/1077 - Train Accuracy: 0.5182, Validation Accuracy: 0.5348, Loss: 0.6151
# Epoch   1 Batch   65/1077 - Train Accuracy: 0.5074, Validation Accuracy: 0.5700, Loss: 0.6715
# Epoch   1 Batch   70/1077 - Train Accuracy: 0.5345, Validation Accuracy: 0.5657, Loss: 0.6665
# Epoch   1 Batch   75/1077 - Train Accuracy: 0.5430, Validation Accuracy: 0.5668, Loss: 0.6643
# Epoch   1 Batch   80/1077 - Train Accuracy: 0.5465, Validation Accuracy: 0.5600, Loss: 0.6552
# Epoch   1 Batch   85/1077 - Train Accuracy: 0.5418, Validation Accuracy: 0.5568, Loss: 0.6229
# Epoch   1 Batch   90/1077 - Train Accuracy: 0.5172, Validation Accuracy: 0.5639, Loss: 0.6645
# Epoch   1 Batch   95/1077 - Train Accuracy: 0.5398, Validation Accuracy: 0.5781, Loss: 0.6548
# Epoch   1 Batch  100/1077 - Train Accuracy: 0.5613, Validation Accuracy: 0.5874, Loss: 0.6463
# Epoch   1 Batch  105/1077 - Train Accuracy: 0.5445, Validation Accuracy: 0.5408, Loss: 0.6456
# Epoch   1 Batch  110/1077 - Train Accuracy: 0.5996, Validation Accuracy: 0.5558, Loss: 0.6064
# Epoch   1 Batch  115/1077 - Train Accuracy: 0.5016, Validation Accuracy: 0.5597, Loss: 0.6817
# Epoch   1 Batch  120/1077 - Train Accuracy: 0.5109, Validation Accuracy: 0.5458, Loss: 0.6838
# Epoch   1 Batch  125/1077 - Train Accuracy: 0.5208, Validation Accuracy: 0.5689, Loss: 0.6244
# Epoch   1 Batch  130/1077 - Train Accuracy: 0.5286, Validation Accuracy: 0.5465, Loss: 0.6315
# Epoch   1 Batch  135/1077 - Train Accuracy: 0.5107, Validation Accuracy: 0.5533, Loss: 0.6509
# Epoch   1 Batch  140/1077 - Train Accuracy: 0.4881, Validation Accuracy: 0.5533, Loss: 0.6692
# Epoch   1 Batch  145/1077 - Train Accuracy: 0.5523, Validation Accuracy: 0.5316, Loss: 0.6852
# Epoch   1 Batch  150/1077 - Train Accuracy: 0.5432, Validation Accuracy: 0.5661, Loss: 0.6422
# Epoch   1 Batch  155/1077 - Train Accuracy: 0.5191, Validation Accuracy: 0.5735, Loss: 0.6485
# Epoch   1 Batch  160/1077 - Train Accuracy: 0.5320, Validation Accuracy: 0.5785, Loss: 0.6513
# Epoch   1 Batch  165/1077 - Train Accuracy: 0.4961, Validation Accuracy: 0.5685, Loss: 0.6562
# Epoch   1 Batch  170/1077 - Train Accuracy: 0.4902, Validation Accuracy: 0.5692, Loss: 0.6869
# Epoch   1 Batch  175/1077 - Train Accuracy: 0.5723, Validation Accuracy: 0.5902, Loss: 0.6250
# Epoch   1 Batch  180/1077 - Train Accuracy: 0.5289, Validation Accuracy: 0.5362, Loss: 0.6517
# Epoch   1 Batch  185/1077 - Train Accuracy: 0.4801, Validation Accuracy: 0.5458, Loss: 0.6730
# Epoch   1 Batch  190/1077 - Train Accuracy: 0.5398, Validation Accuracy: 0.5643, Loss: 0.6372
# Epoch   1 Batch  195/1077 - Train Accuracy: 0.5070, Validation Accuracy: 0.5884, Loss: 0.6665
# Epoch   1 Batch  200/1077 - Train Accuracy: 0.5027, Validation Accuracy: 0.5472, Loss: 0.6803
# Epoch   1 Batch  205/1077 - Train Accuracy: 0.5426, Validation Accuracy: 0.5653, Loss: 0.6427
# Epoch   1 Batch  210/1077 - Train Accuracy: 0.5179, Validation Accuracy: 0.5440, Loss: 0.6449
# Epoch   1 Batch  215/1077 - Train Accuracy: 0.5039, Validation Accuracy: 0.5689, Loss: 0.6681
# Epoch   1 Batch  220/1077 - Train Accuracy: 0.5169, Validation Accuracy: 0.5621, Loss: 0.6744
# Epoch   1 Batch  225/1077 - Train Accuracy: 0.5168, Validation Accuracy: 0.5558, Loss: 0.6589
# Epoch   1 Batch  230/1077 - Train Accuracy: 0.5592, Validation Accuracy: 0.5795, Loss: 0.6501
# Epoch   1 Batch  235/1077 - Train Accuracy: 0.5595, Validation Accuracy: 0.5469, Loss: 0.5898
# Epoch   1 Batch  240/1077 - Train Accuracy: 0.5516, Validation Accuracy: 0.5795, Loss: 0.6359
# Epoch   1 Batch  245/1077 - Train Accuracy: 0.5246, Validation Accuracy: 0.5302, Loss: 0.6012
# Epoch   1 Batch  250/1077 - Train Accuracy: 0.5593, Validation Accuracy: 0.5831, Loss: 0.6054
# Epoch   1 Batch  255/1077 - Train Accuracy: 0.5320, Validation Accuracy: 0.5778, Loss: 0.6388
# Epoch   1 Batch  260/1077 - Train Accuracy: 0.5093, Validation Accuracy: 0.5302, Loss: 0.6259
# Epoch   1 Batch  265/1077 - Train Accuracy: 0.4969, Validation Accuracy: 0.5547, Loss: 0.6442
# Epoch   1 Batch  270/1077 - Train Accuracy: 0.5000, Validation Accuracy: 0.5692, Loss: 0.6549
# Epoch   1 Batch  275/1077 - Train Accuracy: 0.5353, Validation Accuracy: 0.5682, Loss: 0.6137
# Epoch   1 Batch  280/1077 - Train Accuracy: 0.5539, Validation Accuracy: 0.5629, Loss: 0.6384
# Epoch   1 Batch  285/1077 - Train Accuracy: 0.5830, Validation Accuracy: 0.5696, Loss: 0.6294
# Epoch   1 Batch  290/1077 - Train Accuracy: 0.5219, Validation Accuracy: 0.5682, Loss: 0.6550
# Epoch   1 Batch  295/1077 - Train Accuracy: 0.5370, Validation Accuracy: 0.5803, Loss: 0.6790
# Epoch   1 Batch  300/1077 - Train Accuracy: 0.5127, Validation Accuracy: 0.5803, Loss: 0.6542
# Epoch   1 Batch  305/1077 - Train Accuracy: 0.5660, Validation Accuracy: 0.5650, Loss: 0.6113
# Epoch   1 Batch  310/1077 - Train Accuracy: 0.4977, Validation Accuracy: 0.5469, Loss: 0.6636
# Epoch   1 Batch  315/1077 - Train Accuracy: 0.5484, Validation Accuracy: 0.5593, Loss: 0.5990
# Epoch   1 Batch  320/1077 - Train Accuracy: 0.5449, Validation Accuracy: 0.5589, Loss: 0.6166
# Epoch   1 Batch  325/1077 - Train Accuracy: 0.5867, Validation Accuracy: 0.5799, Loss: 0.6198
# Epoch   1 Batch  330/1077 - Train Accuracy: 0.5539, Validation Accuracy: 0.5515, Loss: 0.6217
# Epoch   1 Batch  335/1077 - Train Accuracy: 0.5844, Validation Accuracy: 0.5277, Loss: 0.6087
# Epoch   1 Batch  340/1077 - Train Accuracy: 0.5103, Validation Accuracy: 0.5600, Loss: 0.6556
# Epoch   1 Batch  345/1077 - Train Accuracy: 0.5670, Validation Accuracy: 0.5689, Loss: 0.6061
# Epoch   1 Batch  350/1077 - Train Accuracy: 0.4738, Validation Accuracy: 0.5558, Loss: 0.6617
# Epoch   1 Batch  355/1077 - Train Accuracy: 0.5439, Validation Accuracy: 0.5806, Loss: 0.6391
# Epoch   1 Batch  360/1077 - Train Accuracy: 0.5348, Validation Accuracy: 0.5742, Loss: 0.6442
# Epoch   1 Batch  365/1077 - Train Accuracy: 0.5004, Validation Accuracy: 0.5579, Loss: 0.6356
# Epoch   1 Batch  370/1077 - Train Accuracy: 0.5446, Validation Accuracy: 0.5618, Loss: 0.6450
# Epoch   1 Batch  375/1077 - Train Accuracy: 0.5739, Validation Accuracy: 0.5597, Loss: 0.6015
# Epoch   1 Batch  380/1077 - Train Accuracy: 0.5191, Validation Accuracy: 0.5668, Loss: 0.6627
# Epoch   1 Batch  385/1077 - Train Accuracy: 0.5609, Validation Accuracy: 0.5866, Loss: 0.6266
# Epoch   1 Batch  390/1077 - Train Accuracy: 0.5059, Validation Accuracy: 0.5611, Loss: 0.6873
# Epoch   1 Batch  395/1077 - Train Accuracy: 0.5513, Validation Accuracy: 0.5682, Loss: 0.6239
# Epoch   1 Batch  400/1077 - Train Accuracy: 0.5234, Validation Accuracy: 0.5487, Loss: 0.6503
# Epoch   1 Batch  405/1077 - Train Accuracy: 0.5012, Validation Accuracy: 0.5387, Loss: 0.7056
# Epoch   1 Batch  410/1077 - Train Accuracy: 0.5078, Validation Accuracy: 0.5604, Loss: 0.6723
# Epoch   1 Batch  415/1077 - Train Accuracy: 0.5562, Validation Accuracy: 0.5692, Loss: 0.5892
# Epoch   1 Batch  420/1077 - Train Accuracy: 0.4988, Validation Accuracy: 0.5646, Loss: 0.6201
# Epoch   1 Batch  425/1077 - Train Accuracy: 0.5636, Validation Accuracy: 0.5561, Loss: 0.6412
# Epoch   1 Batch  430/1077 - Train Accuracy: 0.5184, Validation Accuracy: 0.5550, Loss: 0.6405
# Epoch   1 Batch  435/1077 - Train Accuracy: 0.5325, Validation Accuracy: 0.5678, Loss: 0.6584
# Epoch   1 Batch  440/1077 - Train Accuracy: 0.5387, Validation Accuracy: 0.5788, Loss: 0.6653
# Epoch   1 Batch  445/1077 - Train Accuracy: 0.4934, Validation Accuracy: 0.5668, Loss: 0.6689
# Epoch   1 Batch  450/1077 - Train Accuracy: 0.5059, Validation Accuracy: 0.5426, Loss: 0.6358
# Epoch   1 Batch  455/1077 - Train Accuracy: 0.5394, Validation Accuracy: 0.5536, Loss: 0.6289
# Epoch   1 Batch  460/1077 - Train Accuracy: 0.4996, Validation Accuracy: 0.5362, Loss: 0.6768
# Epoch   1 Batch  465/1077 - Train Accuracy: 0.4905, Validation Accuracy: 0.5692, Loss: 0.6993
# Epoch   1 Batch  470/1077 - Train Accuracy: 0.4955, Validation Accuracy: 0.5671, Loss: 0.6914
# Epoch   1 Batch  475/1077 - Train Accuracy: 0.5535, Validation Accuracy: 0.5781, Loss: 0.6557
# Epoch   1 Batch  480/1077 - Train Accuracy: 0.5304, Validation Accuracy: 0.5597, Loss: 0.6654
# Epoch   1 Batch  485/1077 - Train Accuracy: 0.5629, Validation Accuracy: 0.5870, Loss: 0.6637
# Epoch   1 Batch  490/1077 - Train Accuracy: 0.5172, Validation Accuracy: 0.5540, Loss: 0.6604
# Epoch   1 Batch  495/1077 - Train Accuracy: 0.5145, Validation Accuracy: 0.5419, Loss: 0.6253
# Epoch   1 Batch  500/1077 - Train Accuracy: 0.5383, Validation Accuracy: 0.5643, Loss: 0.6399
# Epoch   1 Batch  505/1077 - Train Accuracy: 0.5666, Validation Accuracy: 0.5668, Loss: 0.5901
# Epoch   1 Batch  510/1077 - Train Accuracy: 0.5430, Validation Accuracy: 0.5629, Loss: 0.6637
# Epoch   1 Batch  515/1077 - Train Accuracy: 0.5441, Validation Accuracy: 0.5749, Loss: 0.6626
# Epoch   1 Batch  520/1077 - Train Accuracy: 0.5841, Validation Accuracy: 0.5625, Loss: 0.5974
# Epoch   1 Batch  525/1077 - Train Accuracy: 0.5176, Validation Accuracy: 0.5558, Loss: 0.6326
# Epoch   1 Batch  530/1077 - Train Accuracy: 0.5059, Validation Accuracy: 0.5373, Loss: 0.6698
# Epoch   1 Batch  535/1077 - Train Accuracy: 0.5301, Validation Accuracy: 0.5962, Loss: 0.6458
# Epoch   1 Batch  540/1077 - Train Accuracy: 0.5238, Validation Accuracy: 0.5643, Loss: 0.6038
# Epoch   1 Batch  545/1077 - Train Accuracy: 0.5203, Validation Accuracy: 0.5717, Loss: 0.7047
# Epoch   1 Batch  550/1077 - Train Accuracy: 0.5031, Validation Accuracy: 0.5838, Loss: 0.6798
# Epoch   1 Batch  555/1077 - Train Accuracy: 0.5668, Validation Accuracy: 0.5710, Loss: 0.6244
# Epoch   1 Batch  560/1077 - Train Accuracy: 0.5078, Validation Accuracy: 0.5685, Loss: 0.6487
# Epoch   1 Batch  565/1077 - Train Accuracy: 0.5312, Validation Accuracy: 0.5582, Loss: 0.6205
# Epoch   1 Batch  570/1077 - Train Accuracy: 0.4971, Validation Accuracy: 0.5384, Loss: 0.7090
# Epoch   1 Batch  575/1077 - Train Accuracy: 0.5368, Validation Accuracy: 0.5632, Loss: 0.6659
# Epoch   1 Batch  580/1077 - Train Accuracy: 0.5733, Validation Accuracy: 0.5643, Loss: 0.6015
# Epoch   1 Batch  585/1077 - Train Accuracy: 0.5353, Validation Accuracy: 0.5440, Loss: 0.6160
# Epoch   1 Batch  590/1077 - Train Accuracy: 0.4762, Validation Accuracy: 0.5430, Loss: 0.7002
# Epoch   1 Batch  595/1077 - Train Accuracy: 0.4934, Validation Accuracy: 0.5600, Loss: 0.6738
# Epoch   1 Batch  600/1077 - Train Accuracy: 0.5562, Validation Accuracy: 0.5604, Loss: 0.6120
# Epoch   1 Batch  605/1077 - Train Accuracy: 0.5090, Validation Accuracy: 0.5771, Loss: 0.7167
# Epoch   1 Batch  610/1077 - Train Accuracy: 0.5160, Validation Accuracy: 0.5415, Loss: 0.6741
# Epoch   1 Batch  615/1077 - Train Accuracy: 0.5398, Validation Accuracy: 0.5678, Loss: 0.6426
# Epoch   1 Batch  620/1077 - Train Accuracy: 0.4855, Validation Accuracy: 0.5391, Loss: 0.6266
# Epoch   1 Batch  625/1077 - Train Accuracy: 0.5594, Validation Accuracy: 0.5700, Loss: 0.6408
# Epoch   1 Batch  630/1077 - Train Accuracy: 0.5375, Validation Accuracy: 0.5515, Loss: 0.6321
# Epoch   1 Batch  635/1077 - Train Accuracy: 0.4893, Validation Accuracy: 0.5451, Loss: 0.6834
# Epoch   1 Batch  640/1077 - Train Accuracy: 0.5253, Validation Accuracy: 0.5756, Loss: 0.6130
# Epoch   1 Batch  645/1077 - Train Accuracy: 0.5316, Validation Accuracy: 0.5458, Loss: 0.6201
# Epoch   1 Batch  650/1077 - Train Accuracy: 0.5039, Validation Accuracy: 0.5515, Loss: 0.6618
# Epoch   1 Batch  655/1077 - Train Accuracy: 0.5230, Validation Accuracy: 0.5472, Loss: 0.6644
# Epoch   1 Batch  660/1077 - Train Accuracy: 0.5113, Validation Accuracy: 0.5387, Loss: 0.6441
# Epoch   1 Batch  665/1077 - Train Accuracy: 0.5039, Validation Accuracy: 0.5575, Loss: 0.6468
# Epoch   1 Batch  670/1077 - Train Accuracy: 0.5969, Validation Accuracy: 0.5675, Loss: 0.6074
# Epoch   1 Batch  675/1077 - Train Accuracy: 0.5696, Validation Accuracy: 0.5810, Loss: 0.6230
# Epoch   1 Batch  680/1077 - Train Accuracy: 0.5298, Validation Accuracy: 0.5827, Loss: 0.6325
# Epoch   1 Batch  685/1077 - Train Accuracy: 0.5113, Validation Accuracy: 0.5550, Loss: 0.6487
# Epoch   1 Batch  690/1077 - Train Accuracy: 0.5254, Validation Accuracy: 0.5405, Loss: 0.6386
# Epoch   1 Batch  695/1077 - Train Accuracy: 0.5359, Validation Accuracy: 0.5696, Loss: 0.6279
# Epoch   1 Batch  700/1077 - Train Accuracy: 0.5113, Validation Accuracy: 0.5593, Loss: 0.6536
# Epoch   1 Batch  705/1077 - Train Accuracy: 0.5415, Validation Accuracy: 0.5572, Loss: 0.7217
# Epoch   1 Batch  710/1077 - Train Accuracy: 0.4520, Validation Accuracy: 0.4549, Loss: 0.6325
# Epoch   1 Batch  715/1077 - Train Accuracy: 0.4867, Validation Accuracy: 0.5327, Loss: 0.6392
# Epoch   1 Batch  720/1077 - Train Accuracy: 0.5218, Validation Accuracy: 0.5373, Loss: 0.6820
# Epoch   1 Batch  725/1077 - Train Accuracy: 0.5268, Validation Accuracy: 0.5742, Loss: 0.6341
# Epoch   1 Batch  730/1077 - Train Accuracy: 0.4680, Validation Accuracy: 0.5018, Loss: 0.6684
# Epoch   1 Batch  735/1077 - Train Accuracy: 0.5062, Validation Accuracy: 0.5447, Loss: 0.6469
# Epoch   1 Batch  740/1077 - Train Accuracy: 0.5281, Validation Accuracy: 0.5440, Loss: 0.6274
# Epoch   1 Batch  745/1077 - Train Accuracy: 0.5555, Validation Accuracy: 0.5650, Loss: 0.6480
# Epoch   1 Batch  750/1077 - Train Accuracy: 0.4906, Validation Accuracy: 0.5465, Loss: 0.6675
# Epoch   1 Batch  755/1077 - Train Accuracy: 0.5316, Validation Accuracy: 0.5668, Loss: 0.6830
# Epoch   1 Batch  760/1077 - Train Accuracy: 0.5258, Validation Accuracy: 0.5291, Loss: 0.6594
# Epoch   1 Batch  765/1077 - Train Accuracy: 0.5484, Validation Accuracy: 0.5572, Loss: 0.6294
# Epoch   1 Batch  770/1077 - Train Accuracy: 0.5420, Validation Accuracy: 0.5462, Loss: 0.5941
# Epoch   1 Batch  775/1077 - Train Accuracy: 0.5320, Validation Accuracy: 0.5611, Loss: 0.6675
# Epoch   1 Batch  780/1077 - Train Accuracy: 0.5211, Validation Accuracy: 0.5749, Loss: 0.6676
# Epoch   1 Batch  785/1077 - Train Accuracy: 0.5499, Validation Accuracy: 0.5494, Loss: 0.6420
# Epoch   1 Batch  790/1077 - Train Accuracy: 0.4555, Validation Accuracy: 0.5611, Loss: 0.7029
# Epoch   1 Batch  795/1077 - Train Accuracy: 0.5129, Validation Accuracy: 0.5664, Loss: 0.6687
# Epoch   1 Batch  800/1077 - Train Accuracy: 0.5098, Validation Accuracy: 0.5703, Loss: 0.6469
# Epoch   1 Batch  805/1077 - Train Accuracy: 0.5305, Validation Accuracy: 0.5696, Loss: 0.6436
# Epoch   1 Batch  810/1077 - Train Accuracy: 0.5800, Validation Accuracy: 0.5948, Loss: 0.6118
# Epoch   1 Batch  815/1077 - Train Accuracy: 0.5191, Validation Accuracy: 0.5682, Loss: 0.6443
# Epoch   1 Batch  820/1077 - Train Accuracy: 0.4949, Validation Accuracy: 0.5419, Loss: 0.6854
# Epoch   1 Batch  825/1077 - Train Accuracy: 0.4926, Validation Accuracy: 0.5710, Loss: 0.6052
# Epoch   1 Batch  830/1077 - Train Accuracy: 0.5219, Validation Accuracy: 0.5320, Loss: 0.6486
# Epoch   1 Batch  835/1077 - Train Accuracy: 0.5477, Validation Accuracy: 0.5774, Loss: 0.6159
# Epoch   1 Batch  840/1077 - Train Accuracy: 0.5105, Validation Accuracy: 0.5692, Loss: 0.6268
# Epoch   1 Batch  845/1077 - Train Accuracy: 0.5434, Validation Accuracy: 0.5597, Loss: 0.6267
# Epoch   1 Batch  850/1077 - Train Accuracy: 0.5130, Validation Accuracy: 0.5664, Loss: 0.6683
# Epoch   1 Batch  855/1077 - Train Accuracy: 0.4902, Validation Accuracy: 0.5565, Loss: 0.6394
# Epoch   1 Batch  860/1077 - Train Accuracy: 0.5290, Validation Accuracy: 0.5604, Loss: 0.6377
# Epoch   1 Batch  865/1077 - Train Accuracy: 0.5739, Validation Accuracy: 0.5611, Loss: 0.5792
# Epoch   1 Batch  870/1077 - Train Accuracy: 0.4762, Validation Accuracy: 0.5362, Loss: 0.6839
# Epoch   1 Batch  875/1077 - Train Accuracy: 0.5133, Validation Accuracy: 0.5611, Loss: 0.6568
# Epoch   1 Batch  880/1077 - Train Accuracy: 0.5621, Validation Accuracy: 0.5842, Loss: 0.6430
# Epoch   1 Batch  885/1077 - Train Accuracy: 0.4901, Validation Accuracy: 0.4531, Loss: 0.5614
# Epoch   1 Batch  890/1077 - Train Accuracy: 0.5867, Validation Accuracy: 0.5636, Loss: 0.6132
# Epoch   1 Batch  895/1077 - Train Accuracy: 0.4195, Validation Accuracy: 0.4972, Loss: 0.6464
# Epoch   1 Batch  900/1077 - Train Accuracy: 0.5102, Validation Accuracy: 0.5384, Loss: 0.6764
# Epoch   1 Batch  905/1077 - Train Accuracy: 0.4461, Validation Accuracy: 0.4606, Loss: 0.6178
# Epoch   1 Batch  910/1077 - Train Accuracy: 0.5045, Validation Accuracy: 0.5533, Loss: 0.6344
# Epoch   1 Batch  915/1077 - Train Accuracy: 0.4852, Validation Accuracy: 0.5668, Loss: 0.6771
# Epoch   1 Batch  920/1077 - Train Accuracy: 0.5238, Validation Accuracy: 0.5575, Loss: 0.6515
# Epoch   1 Batch  925/1077 - Train Accuracy: 0.5383, Validation Accuracy: 0.5778, Loss: 0.6346
# Epoch   1 Batch  930/1077 - Train Accuracy: 0.5445, Validation Accuracy: 0.5749, Loss: 0.6597
# Epoch   1 Batch  935/1077 - Train Accuracy: 0.4906, Validation Accuracy: 0.5373, Loss: 0.6775
# Epoch   1 Batch  940/1077 - Train Accuracy: 0.5223, Validation Accuracy: 0.5621, Loss: 0.6559
# Epoch   1 Batch  945/1077 - Train Accuracy: 0.5418, Validation Accuracy: 0.5419, Loss: 0.6007
# Epoch   1 Batch  950/1077 - Train Accuracy: 0.5037, Validation Accuracy: 0.5352, Loss: 0.6315
# Epoch   1 Batch  955/1077 - Train Accuracy: 0.5527, Validation Accuracy: 0.5792, Loss: 0.6775
# Epoch   1 Batch  960/1077 - Train Accuracy: 0.5286, Validation Accuracy: 0.5252, Loss: 0.6264
# Epoch   1 Batch  965/1077 - Train Accuracy: 0.4766, Validation Accuracy: 0.5909, Loss: 0.7201
# Epoch   1 Batch  970/1077 - Train Accuracy: 0.5340, Validation Accuracy: 0.5625, Loss: 0.6878
# Epoch   1 Batch  975/1077 - Train Accuracy: 0.5536, Validation Accuracy: 0.5533, Loss: 0.6235
# Epoch   1 Batch  980/1077 - Train Accuracy: 0.5539, Validation Accuracy: 0.5657, Loss: 0.6502
# Epoch   1 Batch  985/1077 - Train Accuracy: 0.5250, Validation Accuracy: 0.5636, Loss: 0.6371
# Epoch   1 Batch  990/1077 - Train Accuracy: 0.5037, Validation Accuracy: 0.5518, Loss: 0.6991
# Epoch   1 Batch  995/1077 - Train Accuracy: 0.5863, Validation Accuracy: 0.5742, Loss: 0.6199
# Epoch   1 Batch 1000/1077 - Train Accuracy: 0.5234, Validation Accuracy: 0.5178, Loss: 0.6014
# Epoch   1 Batch 1005/1077 - Train Accuracy: 0.5086, Validation Accuracy: 0.5614, Loss: 0.6373
# Epoch   1 Batch 1010/1077 - Train Accuracy: 0.4172, Validation Accuracy: 0.4819, Loss: 0.6449
# Epoch   1 Batch 1015/1077 - Train Accuracy: 0.5121, Validation Accuracy: 0.5369, Loss: 0.6865
# Epoch   1 Batch 1020/1077 - Train Accuracy: 0.5281, Validation Accuracy: 0.5614, Loss: 0.6361
# Epoch   1 Batch 1025/1077 - Train Accuracy: 0.5353, Validation Accuracy: 0.5778, Loss: 0.6155
# Epoch   1 Batch 1030/1077 - Train Accuracy: 0.4973, Validation Accuracy: 0.5558, Loss: 0.6674
# Epoch   1 Batch 1035/1077 - Train Accuracy: 0.5454, Validation Accuracy: 0.5675, Loss: 0.5817
# Epoch   1 Batch 1040/1077 - Train Accuracy: 0.5193, Validation Accuracy: 0.5714, Loss: 0.6823
# Epoch   1 Batch 1045/1077 - Train Accuracy: 0.4988, Validation Accuracy: 0.5742, Loss: 0.6785
# Epoch   1 Batch 1050/1077 - Train Accuracy: 0.4504, Validation Accuracy: 0.5380, Loss: 0.6734
# Epoch   1 Batch 1055/1077 - Train Accuracy: 0.5445, Validation Accuracy: 0.5742, Loss: 0.6671
# Epoch   1 Batch 1060/1077 - Train Accuracy: 0.5211, Validation Accuracy: 0.5671, Loss: 0.6128
# Epoch   1 Batch 1065/1077 - Train Accuracy: 0.5266, Validation Accuracy: 0.5760, Loss: 0.6701
# Epoch   1 Batch 1070/1077 - Train Accuracy: 0.4895, Validation Accuracy: 0.5515, Loss: 0.6541
# Epoch   1 Batch 1075/1077 - Train Accuracy: 0.4478, Validation Accuracy: 0.5117, Loss: 0.7274
# Epoch   2 Batch    5/1077 - Train Accuracy: 0.5074, Validation Accuracy: 0.5763, Loss: 0.6659
# Epoch   2 Batch   10/1077 - Train Accuracy: 0.5197, Validation Accuracy: 0.5746, Loss: 0.6766
# Epoch   2 Batch   15/1077 - Train Accuracy: 0.5422, Validation Accuracy: 0.5685, Loss: 0.6239
# Epoch   2 Batch   20/1077 - Train Accuracy: 0.5332, Validation Accuracy: 0.5675, Loss: 0.6351
# Epoch   2 Batch   25/1077 - Train Accuracy: 0.5301, Validation Accuracy: 0.5792, Loss: 0.6072
# Epoch   2 Batch   30/1077 - Train Accuracy: 0.5180, Validation Accuracy: 0.5618, Loss: 0.6512
# Epoch   2 Batch   35/1077 - Train Accuracy: 0.5207, Validation Accuracy: 0.5579, Loss: 0.6484
# Epoch   2 Batch   40/1077 - Train Accuracy: 0.5297, Validation Accuracy: 0.5650, Loss: 0.6602
# Epoch   2 Batch   45/1077 - Train Accuracy: 0.5371, Validation Accuracy: 0.5423, Loss: 0.6469
# Epoch   2 Batch   50/1077 - Train Accuracy: 0.5133, Validation Accuracy: 0.5604, Loss: 0.6530
# Epoch   2 Batch   55/1077 - Train Accuracy: 0.5156, Validation Accuracy: 0.5096, Loss: 0.6458
# Epoch   2 Batch   60/1077 - Train Accuracy: 0.5112, Validation Accuracy: 0.5487, Loss: 0.6102
# Epoch   2 Batch   65/1077 - Train Accuracy: 0.5062, Validation Accuracy: 0.5611, Loss: 0.6686
# Epoch   2 Batch   70/1077 - Train Accuracy: 0.5136, Validation Accuracy: 0.5501, Loss: 0.6589
# Epoch   2 Batch   75/1077 - Train Accuracy: 0.5230, Validation Accuracy: 0.5518, Loss: 0.6586
# Epoch   2 Batch   80/1077 - Train Accuracy: 0.5289, Validation Accuracy: 0.5597, Loss: 0.6468
# Epoch   2 Batch   85/1077 - Train Accuracy: 0.5406, Validation Accuracy: 0.5629, Loss: 0.6047
# Epoch   2 Batch   90/1077 - Train Accuracy: 0.5051, Validation Accuracy: 0.5636, Loss: 0.6647
# Epoch   2 Batch   95/1077 - Train Accuracy: 0.5666, Validation Accuracy: 0.5827, Loss: 0.6634
# Epoch   2 Batch  100/1077 - Train Accuracy: 0.5617, Validation Accuracy: 0.5888, Loss: 0.6524
# Epoch   2 Batch  105/1077 - Train Accuracy: 0.5625, Validation Accuracy: 0.5550, Loss: 0.6319
# Epoch   2 Batch  110/1077 - Train Accuracy: 0.5902, Validation Accuracy: 0.5831, Loss: 0.5938
# Epoch   2 Batch  115/1077 - Train Accuracy: 0.5113, Validation Accuracy: 0.5589, Loss: 0.6549
# Epoch   2 Batch  120/1077 - Train Accuracy: 0.5055, Validation Accuracy: 0.5504, Loss: 0.6573
# Epoch   2 Batch  125/1077 - Train Accuracy: 0.5551, Validation Accuracy: 0.5714, Loss: 0.6087
# Epoch   2 Batch  130/1077 - Train Accuracy: 0.5632, Validation Accuracy: 0.5643, Loss: 0.5984
# Epoch   2 Batch  135/1077 - Train Accuracy: 0.5201, Validation Accuracy: 0.5369, Loss: 0.6420
# Epoch   2 Batch  140/1077 - Train Accuracy: 0.5275, Validation Accuracy: 0.5863, Loss: 0.6519
# Epoch   2 Batch  145/1077 - Train Accuracy: 0.5828, Validation Accuracy: 0.5611, Loss: 0.6659
# Epoch   2 Batch  150/1077 - Train Accuracy: 0.5651, Validation Accuracy: 0.5561, Loss: 0.6388
# Epoch   2 Batch  155/1077 - Train Accuracy: 0.5234, Validation Accuracy: 0.5437, Loss: 0.6479
# Epoch   2 Batch  160/1077 - Train Accuracy: 0.5355, Validation Accuracy: 0.5749, Loss: 0.6209
# Epoch   2 Batch  165/1077 - Train Accuracy: 0.5090, Validation Accuracy: 0.5536, Loss: 0.6268
# Epoch   2 Batch  170/1077 - Train Accuracy: 0.4660, Validation Accuracy: 0.5376, Loss: 0.6632
# Epoch   2 Batch  175/1077 - Train Accuracy: 0.5531, Validation Accuracy: 0.5799, Loss: 0.6148
# Epoch   2 Batch  180/1077 - Train Accuracy: 0.5398, Validation Accuracy: 0.5579, Loss: 0.6413
# Epoch   2 Batch  185/1077 - Train Accuracy: 0.5160, Validation Accuracy: 0.5817, Loss: 0.6481
# Epoch   2 Batch  190/1077 - Train Accuracy: 0.5648, Validation Accuracy: 0.5703, Loss: 0.6107
# Epoch   2 Batch  195/1077 - Train Accuracy: 0.5082, Validation Accuracy: 0.5810, Loss: 0.6323
# Epoch   2 Batch  200/1077 - Train Accuracy: 0.4871, Validation Accuracy: 0.5487, Loss: 0.6643
# Epoch   2 Batch  205/1077 - Train Accuracy: 0.5508, Validation Accuracy: 0.5742, Loss: 0.6409
# Epoch   2 Batch  210/1077 - Train Accuracy: 0.5491, Validation Accuracy: 0.5650, Loss: 0.6137
# Epoch   2 Batch  215/1077 - Train Accuracy: 0.5266, Validation Accuracy: 0.5799, Loss: 0.6541
# Epoch   2 Batch  220/1077 - Train Accuracy: 0.5341, Validation Accuracy: 0.5675, Loss: 0.6418
# Epoch   2 Batch  225/1077 - Train Accuracy: 0.5363, Validation Accuracy: 0.5700, Loss: 0.6408
# Epoch   2 Batch  230/1077 - Train Accuracy: 0.5312, Validation Accuracy: 0.5650, Loss: 0.6383
# Epoch   2 Batch  235/1077 - Train Accuracy: 0.5863, Validation Accuracy: 0.5671, Loss: 0.5914
# Epoch   2 Batch  240/1077 - Train Accuracy: 0.5270, Validation Accuracy: 0.5703, Loss: 0.6661
# Epoch   2 Batch  245/1077 - Train Accuracy: 0.5205, Validation Accuracy: 0.5455, Loss: 0.6127
# Epoch   2 Batch  250/1077 - Train Accuracy: 0.5540, Validation Accuracy: 0.5643, Loss: 0.6323
# Epoch   2 Batch  255/1077 - Train Accuracy: 0.5098, Validation Accuracy: 0.5547, Loss: 0.6412
# Epoch   2 Batch  260/1077 - Train Accuracy: 0.5290, Validation Accuracy: 0.5494, Loss: 0.5881
# Epoch   2 Batch  265/1077 - Train Accuracy: 0.5176, Validation Accuracy: 0.5749, Loss: 0.6421
# Epoch   2 Batch  270/1077 - Train Accuracy: 0.4852, Validation Accuracy: 0.5550, Loss: 0.6905
# Epoch   2 Batch  275/1077 - Train Accuracy: 0.5275, Validation Accuracy: 0.5771, Loss: 0.6375
# Epoch   2 Batch  280/1077 - Train Accuracy: 0.5305, Validation Accuracy: 0.5668, Loss: 0.6659
# Epoch   2 Batch  285/1077 - Train Accuracy: 0.5640, Validation Accuracy: 0.5497, Loss: 0.6737
# Epoch   2 Batch  290/1077 - Train Accuracy: 0.5027, Validation Accuracy: 0.5579, Loss: 0.6998
# Epoch   2 Batch  295/1077 - Train Accuracy: 0.5095, Validation Accuracy: 0.5462, Loss: 0.7752
# Epoch   2 Batch  300/1077 - Train Accuracy: 0.4803, Validation Accuracy: 0.5657, Loss: 0.7228
# Epoch   2 Batch  305/1077 - Train Accuracy: 0.5070, Validation Accuracy: 0.5284, Loss: 0.6714
# Epoch   2 Batch  310/1077 - Train Accuracy: 0.4789, Validation Accuracy: 0.5391, Loss: 0.6859
# Epoch   2 Batch  315/1077 - Train Accuracy: 0.5234, Validation Accuracy: 0.5398, Loss: 0.6393
# Epoch   2 Batch  320/1077 - Train Accuracy: 0.5172, Validation Accuracy: 0.5589, Loss: 0.6734
# Epoch   2 Batch  325/1077 - Train Accuracy: 0.5532, Validation Accuracy: 0.5369, Loss: 0.6590
# Epoch   2 Batch  330/1077 - Train Accuracy: 0.5281, Validation Accuracy: 0.5419, Loss: 0.6952
# Epoch   2 Batch  335/1077 - Train Accuracy: 0.5774, Validation Accuracy: 0.5522, Loss: 0.6533
# Epoch   2 Batch  340/1077 - Train Accuracy: 0.4733, Validation Accuracy: 0.5174, Loss: 0.7187
# Epoch   2 Batch  345/1077 - Train Accuracy: 0.5417, Validation Accuracy: 0.5384, Loss: 0.6415
# Epoch   2 Batch  350/1077 - Train Accuracy: 0.4602, Validation Accuracy: 0.5302, Loss: 0.7516
# Epoch   2 Batch  355/1077 - Train Accuracy: 0.5123, Validation Accuracy: 0.5476, Loss: 0.6434
# Epoch   2 Batch  360/1077 - Train Accuracy: 0.4820, Validation Accuracy: 0.5394, Loss: 0.6751
# Epoch   2 Batch  365/1077 - Train Accuracy: 0.4848, Validation Accuracy: 0.5312, Loss: 0.6651
# Epoch   2 Batch  370/1077 - Train Accuracy: 0.5249, Validation Accuracy: 0.5284, Loss: 0.6484
# Epoch   2 Batch  375/1077 - Train Accuracy: 0.5487, Validation Accuracy: 0.5238, Loss: 0.6202
# Epoch   2 Batch  380/1077 - Train Accuracy: 0.5012, Validation Accuracy: 0.5227, Loss: 0.6681
# Epoch   2 Batch  385/1077 - Train Accuracy: 0.5523, Validation Accuracy: 0.5394, Loss: 0.6618
# Epoch   2 Batch  390/1077 - Train Accuracy: 0.4813, Validation Accuracy: 0.5415, Loss: 0.7266
# Epoch   2 Batch  395/1077 - Train Accuracy: 0.5130, Validation Accuracy: 0.5430, Loss: 0.6515
# Epoch   2 Batch  400/1077 - Train Accuracy: 0.4715, Validation Accuracy: 0.5053, Loss: 0.6971
# Epoch   2 Batch  405/1077 - Train Accuracy: 0.5000, Validation Accuracy: 0.5327, Loss: 0.7499
# Epoch   2 Batch  410/1077 - Train Accuracy: 0.4774, Validation Accuracy: 0.5252, Loss: 0.7172
# Epoch   2 Batch  415/1077 - Train Accuracy: 0.5186, Validation Accuracy: 0.5533, Loss: 0.6498
# Epoch   2 Batch  420/1077 - Train Accuracy: 0.4945, Validation Accuracy: 0.5465, Loss: 0.6468
# Epoch   2 Batch  425/1077 - Train Accuracy: 0.5469, Validation Accuracy: 0.5387, Loss: 0.6625
# Epoch   2 Batch  430/1077 - Train Accuracy: 0.5047, Validation Accuracy: 0.5415, Loss: 0.6690
# Epoch   2 Batch  435/1077 - Train Accuracy: 0.4778, Validation Accuracy: 0.5153, Loss: 0.7312
# Epoch   2 Batch  440/1077 - Train Accuracy: 0.5078, Validation Accuracy: 0.5447, Loss: 0.7050
# Epoch   2 Batch  445/1077 - Train Accuracy: 0.4930, Validation Accuracy: 0.5412, Loss: 0.6816
# Epoch   2 Batch  450/1077 - Train Accuracy: 0.4957, Validation Accuracy: 0.5334, Loss: 0.6497
# Epoch   2 Batch  455/1077 - Train Accuracy: 0.5163, Validation Accuracy: 0.5476, Loss: 0.6453
# Epoch   2 Batch  460/1077 - Train Accuracy: 0.5004, Validation Accuracy: 0.5387, Loss: 0.7358
# Epoch   2 Batch  465/1077 - Train Accuracy: 0.4482, Validation Accuracy: 0.5536, Loss: 0.7707
# Epoch   2 Batch  470/1077 - Train Accuracy: 0.4650, Validation Accuracy: 0.5408, Loss: 0.7446
# Epoch   2 Batch  475/1077 - Train Accuracy: 0.4809, Validation Accuracy: 0.5234, Loss: 0.8783
# Epoch   2 Batch  480/1077 - Train Accuracy: 0.5132, Validation Accuracy: 0.5483, Loss: 0.7204
# Epoch   2 Batch  485/1077 - Train Accuracy: 0.5250, Validation Accuracy: 0.5465, Loss: 0.7062
# Epoch   2 Batch  490/1077 - Train Accuracy: 0.4801, Validation Accuracy: 0.5302, Loss: 0.7071
# Epoch   2 Batch  495/1077 - Train Accuracy: 0.4914, Validation Accuracy: 0.5401, Loss: 0.7028
# Epoch   2 Batch  500/1077 - Train Accuracy: 0.5242, Validation Accuracy: 0.5621, Loss: 0.6875
# Epoch   2 Batch  505/1077 - Train Accuracy: 0.5443, Validation Accuracy: 0.5472, Loss: 0.6389
# Epoch   2 Batch  510/1077 - Train Accuracy: 0.5098, Validation Accuracy: 0.5224, Loss: 0.7214
# Epoch   2 Batch  515/1077 - Train Accuracy: 0.5074, Validation Accuracy: 0.5444, Loss: 0.6961
# Epoch   2 Batch  520/1077 - Train Accuracy: 0.5108, Validation Accuracy: 0.5149, Loss: 0.6400
# Epoch   2 Batch  525/1077 - Train Accuracy: 0.4770, Validation Accuracy: 0.5405, Loss: 0.6791
# Epoch   2 Batch  530/1077 - Train Accuracy: 0.4918, Validation Accuracy: 0.5423, Loss: 0.7235
# Epoch   2 Batch  535/1077 - Train Accuracy: 0.4727, Validation Accuracy: 0.5110, Loss: 0.7280
# Epoch   2 Batch  540/1077 - Train Accuracy: 0.4785, Validation Accuracy: 0.5398, Loss: 0.6439
# Epoch   2 Batch  545/1077 - Train Accuracy: 0.4676, Validation Accuracy: 0.5359, Loss: 0.7334
# Epoch   2 Batch  550/1077 - Train Accuracy: 0.4762, Validation Accuracy: 0.5401, Loss: 0.7357
# Epoch   2 Batch  555/1077 - Train Accuracy: 0.5117, Validation Accuracy: 0.5071, Loss: 0.6953
# Epoch   2 Batch  560/1077 - Train Accuracy: 0.5020, Validation Accuracy: 0.5476, Loss: 0.6544
# Epoch   2 Batch  565/1077 - Train Accuracy: 0.5108, Validation Accuracy: 0.5259, Loss: 0.6930
# Epoch   2 Batch  570/1077 - Train Accuracy: 0.4725, Validation Accuracy: 0.5114, Loss: 0.7433
# Epoch   2 Batch  575/1077 - Train Accuracy: 0.5015, Validation Accuracy: 0.5384, Loss: 0.6865
# Epoch   2 Batch  580/1077 - Train Accuracy: 0.5465, Validation Accuracy: 0.5241, Loss: 0.6426
# Epoch   2 Batch  585/1077 - Train Accuracy: 0.5231, Validation Accuracy: 0.5305, Loss: 0.6406
# Epoch   2 Batch  590/1077 - Train Accuracy: 0.4733, Validation Accuracy: 0.5405, Loss: 0.7354
# Epoch   2 Batch  595/1077 - Train Accuracy: 0.5059, Validation Accuracy: 0.5387, Loss: 0.7052
# Epoch   2 Batch  600/1077 - Train Accuracy: 0.5123, Validation Accuracy: 0.5149, Loss: 0.6619
# Epoch   2 Batch  605/1077 - Train Accuracy: 0.4893, Validation Accuracy: 0.5511, Loss: 0.7778
# Epoch   2 Batch  610/1077 - Train Accuracy: 0.4918, Validation Accuracy: 0.5415, Loss: 0.7150
# Epoch   2 Batch  615/1077 - Train Accuracy: 0.5168, Validation Accuracy: 0.5387, Loss: 0.6872
# Epoch   2 Batch  620/1077 - Train Accuracy: 0.4852, Validation Accuracy: 0.5270, Loss: 0.6818
# Epoch   2 Batch  625/1077 - Train Accuracy: 0.5215, Validation Accuracy: 0.5320, Loss: 0.7202
# Epoch   2 Batch  630/1077 - Train Accuracy: 0.5000, Validation Accuracy: 0.5415, Loss: 0.6865
# Epoch   2 Batch  635/1077 - Train Accuracy: 0.4688, Validation Accuracy: 0.5437, Loss: 0.7545
# Epoch   2 Batch  640/1077 - Train Accuracy: 0.4881, Validation Accuracy: 0.5419, Loss: 0.6804
# Epoch   2 Batch  645/1077 - Train Accuracy: 0.5342, Validation Accuracy: 0.5444, Loss: 0.6526
# Epoch   2 Batch  650/1077 - Train Accuracy: 0.4672, Validation Accuracy: 0.5469, Loss: 0.7231
# Epoch   2 Batch  655/1077 - Train Accuracy: 0.4961, Validation Accuracy: 0.5430, Loss: 0.6982
# Epoch   2 Batch  660/1077 - Train Accuracy: 0.4914, Validation Accuracy: 0.5256, Loss: 0.7059
# Epoch   2 Batch  665/1077 - Train Accuracy: 0.4852, Validation Accuracy: 0.5472, Loss: 0.6894
# Epoch   2 Batch  670/1077 - Train Accuracy: 0.5717, Validation Accuracy: 0.5359, Loss: 0.6650
# Epoch   2 Batch  675/1077 - Train Accuracy: 0.5227, Validation Accuracy: 0.5511, Loss: 0.6721
# Epoch   2 Batch  680/1077 - Train Accuracy: 0.5186, Validation Accuracy: 0.5547, Loss: 0.6574
# Epoch   2 Batch  685/1077 - Train Accuracy: 0.4949, Validation Accuracy: 0.5202, Loss: 0.6760
# Epoch   2 Batch  690/1077 - Train Accuracy: 0.5246, Validation Accuracy: 0.5625, Loss: 0.6862
# Epoch   2 Batch  695/1077 - Train Accuracy: 0.5082, Validation Accuracy: 0.5511, Loss: 0.6594
# Epoch   2 Batch  700/1077 - Train Accuracy: 0.5027, Validation Accuracy: 0.5369, Loss: 0.6820
# Epoch   2 Batch  705/1077 - Train Accuracy: 0.5132, Validation Accuracy: 0.5604, Loss: 0.7626
# Epoch   2 Batch  710/1077 - Train Accuracy: 0.4973, Validation Accuracy: 0.5366, Loss: 0.6677
# Epoch   2 Batch  715/1077 - Train Accuracy: 0.4973, Validation Accuracy: 0.5487, Loss: 0.6709
# Epoch   2 Batch  720/1077 - Train Accuracy: 0.5053, Validation Accuracy: 0.5344, Loss: 0.6973
# Epoch   2 Batch  725/1077 - Train Accuracy: 0.4948, Validation Accuracy: 0.5206, Loss: 0.6745
# Epoch   2 Batch  730/1077 - Train Accuracy: 0.4367, Validation Accuracy: 0.4585, Loss: 0.6964
# Epoch   2 Batch  735/1077 - Train Accuracy: 0.5270, Validation Accuracy: 0.5582, Loss: 0.6531
# Epoch   2 Batch  740/1077 - Train Accuracy: 0.5273, Validation Accuracy: 0.5572, Loss: 0.6746
# Epoch   2 Batch  745/1077 - Train Accuracy: 0.5309, Validation Accuracy: 0.5437, Loss: 0.6694
# Epoch   2 Batch  750/1077 - Train Accuracy: 0.5000, Validation Accuracy: 0.5288, Loss: 0.6641
# Epoch   2 Batch  755/1077 - Train Accuracy: 0.5012, Validation Accuracy: 0.5469, Loss: 0.7323
# Epoch   2 Batch  760/1077 - Train Accuracy: 0.5402, Validation Accuracy: 0.5366, Loss: 0.7069
# Epoch   2 Batch  765/1077 - Train Accuracy: 0.5492, Validation Accuracy: 0.5611, Loss: 0.6468
# Epoch   2 Batch  770/1077 - Train Accuracy: 0.5264, Validation Accuracy: 0.5479, Loss: 0.6165
# Epoch   2 Batch  775/1077 - Train Accuracy: 0.5273, Validation Accuracy: 0.5210, Loss: 0.6828
# Epoch   2 Batch  780/1077 - Train Accuracy: 0.4953, Validation Accuracy: 0.5323, Loss: 0.7000
# Epoch   2 Batch  785/1077 - Train Accuracy: 0.5454, Validation Accuracy: 0.5462, Loss: 0.6254
# Epoch   2 Batch  790/1077 - Train Accuracy: 0.4508, Validation Accuracy: 0.5359, Loss: 0.7304
# Epoch   2 Batch  795/1077 - Train Accuracy: 0.4855, Validation Accuracy: 0.5646, Loss: 0.7307
# Epoch   2 Batch  800/1077 - Train Accuracy: 0.4699, Validation Accuracy: 0.5408, Loss: 0.6842
# Epoch   2 Batch  805/1077 - Train Accuracy: 0.5035, Validation Accuracy: 0.5284, Loss: 0.6708
# Epoch   2 Batch  810/1077 - Train Accuracy: 0.5673, Validation Accuracy: 0.5344, Loss: 0.6322
# Epoch   2 Batch  815/1077 - Train Accuracy: 0.5121, Validation Accuracy: 0.5529, Loss: 0.6987
# Epoch   2 Batch  820/1077 - Train Accuracy: 0.4594, Validation Accuracy: 0.5224, Loss: 0.7154
# Epoch   2 Batch  825/1077 - Train Accuracy: 0.5156, Validation Accuracy: 0.5707, Loss: 0.6524
# Epoch   2 Batch  830/1077 - Train Accuracy: 0.5027, Validation Accuracy: 0.5444, Loss: 0.6691
# Epoch   2 Batch  835/1077 - Train Accuracy: 0.5289, Validation Accuracy: 0.5568, Loss: 0.6908
# Epoch   2 Batch  840/1077 - Train Accuracy: 0.5164, Validation Accuracy: 0.5426, Loss: 0.6713
# Epoch   2 Batch  845/1077 - Train Accuracy: 0.5375, Validation Accuracy: 0.5142, Loss: 0.6600
# Epoch   2 Batch  850/1077 - Train Accuracy: 0.4900, Validation Accuracy: 0.5277, Loss: 0.7582
# Epoch   2 Batch  855/1077 - Train Accuracy: 0.4582, Validation Accuracy: 0.5419, Loss: 0.6642
# Epoch   2 Batch  860/1077 - Train Accuracy: 0.5160, Validation Accuracy: 0.5423, Loss: 0.6857
# Epoch   2 Batch  865/1077 - Train Accuracy: 0.5842, Validation Accuracy: 0.5458, Loss: 0.6057
# Epoch   2 Batch  870/1077 - Train Accuracy: 0.4766, Validation Accuracy: 0.5320, Loss: 0.6916
# Epoch   2 Batch  875/1077 - Train Accuracy: 0.5074, Validation Accuracy: 0.5284, Loss: 0.6771
# Epoch   2 Batch  880/1077 - Train Accuracy: 0.5500, Validation Accuracy: 0.5270, Loss: 0.6599
# Epoch   2 Batch  885/1077 - Train Accuracy: 0.5753, Validation Accuracy: 0.5348, Loss: 0.5805
# Epoch   2 Batch  890/1077 - Train Accuracy: 0.5751, Validation Accuracy: 0.5369, Loss: 0.6330
# Epoch   2 Batch  895/1077 - Train Accuracy: 0.5223, Validation Accuracy: 0.5771, Loss: 0.6688
# Epoch   2 Batch  900/1077 - Train Accuracy: 0.4656, Validation Accuracy: 0.5178, Loss: 0.6977
# Epoch   2 Batch  905/1077 - Train Accuracy: 0.5219, Validation Accuracy: 0.5011, Loss: 0.6320
# Epoch   2 Batch  910/1077 - Train Accuracy: 0.5335, Validation Accuracy: 0.5561, Loss: 0.6672
# Epoch   2 Batch  915/1077 - Train Accuracy: 0.4856, Validation Accuracy: 0.5415, Loss: 0.6918
# Epoch   2 Batch  920/1077 - Train Accuracy: 0.5078, Validation Accuracy: 0.5305, Loss: 0.6735
# Epoch   2 Batch  925/1077 - Train Accuracy: 0.5119, Validation Accuracy: 0.5707, Loss: 0.6400
# Epoch   2 Batch  930/1077 - Train Accuracy: 0.5102, Validation Accuracy: 0.5625, Loss: 0.6688
# Epoch   2 Batch  935/1077 - Train Accuracy: 0.5117, Validation Accuracy: 0.5547, Loss: 0.6866
# Epoch   2 Batch  940/1077 - Train Accuracy: 0.4875, Validation Accuracy: 0.5185, Loss: 0.6407
# Epoch   2 Batch  945/1077 - Train Accuracy: 0.5465, Validation Accuracy: 0.5415, Loss: 0.6207
# Epoch   2 Batch  950/1077 - Train Accuracy: 0.5205, Validation Accuracy: 0.5344, Loss: 0.6380
# Epoch   2 Batch  955/1077 - Train Accuracy: 0.5289, Validation Accuracy: 0.5458, Loss: 0.6979
# Epoch   2 Batch  960/1077 - Train Accuracy: 0.5208, Validation Accuracy: 0.5540, Loss: 0.6629
# Epoch   2 Batch  965/1077 - Train Accuracy: 0.4794, Validation Accuracy: 0.5721, Loss: 0.7256
# Epoch   2 Batch  970/1077 - Train Accuracy: 0.4691, Validation Accuracy: 0.5060, Loss: 1.0179
# Epoch   2 Batch  975/1077 - Train Accuracy: 0.5138, Validation Accuracy: 0.5135, Loss: 0.7322
# Epoch   2 Batch  980/1077 - Train Accuracy: 0.5324, Validation Accuracy: 0.5227, Loss: 0.7596
# Epoch   2 Batch  985/1077 - Train Accuracy: 0.4922, Validation Accuracy: 0.5210, Loss: 0.7099
# Epoch   2 Batch  990/1077 - Train Accuracy: 0.4955, Validation Accuracy: 0.5241, Loss: 0.7498
# Epoch   2 Batch  995/1077 - Train Accuracy: 0.5391, Validation Accuracy: 0.5430, Loss: 0.6986
# Epoch   2 Batch 1000/1077 - Train Accuracy: 0.5521, Validation Accuracy: 0.5316, Loss: 0.6513
# Epoch   2 Batch 1005/1077 - Train Accuracy: 0.4750, Validation Accuracy: 0.5348, Loss: 0.6936
# Epoch   2 Batch 1010/1077 - Train Accuracy: 0.5090, Validation Accuracy: 0.5352, Loss: 0.6900
# Epoch   2 Batch 1015/1077 - Train Accuracy: 0.4883, Validation Accuracy: 0.5309, Loss: 0.7369
# Epoch   2 Batch 1020/1077 - Train Accuracy: 0.5129, Validation Accuracy: 0.5547, Loss: 0.6793
# Epoch   2 Batch 1025/1077 - Train Accuracy: 0.5219, Validation Accuracy: 0.5117, Loss: 0.6630
# Epoch   2 Batch 1030/1077 - Train Accuracy: 0.4785, Validation Accuracy: 0.5146, Loss: 0.6769
# Epoch   2 Batch 1035/1077 - Train Accuracy: 0.5450, Validation Accuracy: 0.5476, Loss: 0.6207
# Epoch   2 Batch 1040/1077 - Train Accuracy: 0.5148, Validation Accuracy: 0.5522, Loss: 0.6909
# Epoch   2 Batch 1045/1077 - Train Accuracy: 0.4801, Validation Accuracy: 0.5469, Loss: 0.6965
# Epoch   2 Batch 1050/1077 - Train Accuracy: 0.4410, Validation Accuracy: 0.5497, Loss: 0.6903
# Epoch   2 Batch 1055/1077 - Train Accuracy: 0.5266, Validation Accuracy: 0.5554, Loss: 0.6632
# Epoch   2 Batch 1060/1077 - Train Accuracy: 0.5090, Validation Accuracy: 0.5291, Loss: 0.6340
# Epoch   2 Batch 1065/1077 - Train Accuracy: 0.5094, Validation Accuracy: 0.5440, Loss: 0.6651
# Epoch   2 Batch 1070/1077 - Train Accuracy: 0.4973, Validation Accuracy: 0.5515, Loss: 0.6744
# Epoch   2 Batch 1075/1077 - Train Accuracy: 0.5086, Validation Accuracy: 0.5437, Loss: 0.7299
# Model Trained and Saved

# %% [markdown]
# ### Save Parameters
# Save the `batch_size` and `save_path` parameters for inference.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# Save parameters for checkpoint
helper.save_params(save_path)

# %% [markdown]
# # Checkpoint

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import tensorflow as tf
import numpy as np
import helper
import problem_unittests as tests

_, (source_vocab_to_int, target_vocab_to_int), (source_int_to_vocab, target_int_to_vocab) = helper.load_preprocess()
load_path = helper.load_params()

# %% [markdown]
# ## Sentence to Sequence
# To feed a sentence into the model for translation, you first need to preprocess it.  Implement the function `sentence_to_seq()` to preprocess new sentences.
#
# - Convert the sentence to lowercase
# - Convert words into ids using `vocab_to_int`
#  - Convert words not in the vocabulary, to the `<UNK>` word id.

# %%
def sentence_to_seq(sentence, vocab_to_int):
    """
    Convert a sentence to a sequence of ids
    :param sentence: String
    :param vocab_to_int: Dictionary to go from the words to an id
    :return: List of word ids
    """
    # TODO: Implement Function
    word_list = []
    
    for word in sentence.lower().split():
        #print (word)
        if word in vocab_to_int.keys():
            word_list.append(vocab_to_int[word])
        else:
            word_list.append(vocab_to_int['<UNK>'])
    
    #print (word_list)
    return word_list


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_sentence_to_seq(sentence_to_seq)
# Out:
# Tests Passed

# %% [markdown]
# ## Translate
# This will translate `translate_sentence` from English to French.

# %%
translate_sentence = 'he saw a old yellow truck .'


"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
translate_sentence = sentence_to_seq(translate_sentence, source_vocab_to_int)

loaded_graph = tf.Graph()
with tf.Session(graph=loaded_graph) as sess:
    # Load saved model
    loader = tf.train.import_meta_graph(load_path + '.meta')
    loader.restore(sess, load_path)

    input_data = loaded_graph.get_tensor_by_name('input:0')
    logits = loaded_graph.get_tensor_by_name('predictions:0')
    target_sequence_length = loaded_graph.get_tensor_by_name('target_sequence_length:0')
    source_sequence_length = loaded_graph.get_tensor_by_name('source_sequence_length:0')
    keep_prob = loaded_graph.get_tensor_by_name('keep_prob:0')

    translate_logits = sess.run(logits, {input_data: [translate_sentence]*batch_size,
                                         target_sequence_length: [len(translate_sentence)*2]*batch_size,
                                         source_sequence_length: [len(translate_sentence)]*batch_size,
                                         keep_prob: 1.0})[0]

print('Input')
print('  Word Ids:      {}'.format([i for i in translate_sentence]))
print('  English Words: {}'.format([source_int_to_vocab[i] for i in translate_sentence]))

print('\nPrediction')
print('  Word Ids:      {}'.format([i for i in translate_logits]))
print('  French Words: {}'.format(" ".join([target_int_to_vocab[i] for i in translate_logits])))
# Out:
# INFO:tensorflow:Restoring parameters from checkpoints/dev
# Input
#   Word Ids:      [188, 141, 194, 159, 131, 146, 115]
#   English Words: ['he', 'saw', 'a', 'old', 'yellow', 'truck', '.']
#
# Prediction
#   Word Ids:      [335, 77, 355, 170, 312, 273, 255, 53, 1]
#   French Words: il a conduit cette vieille voiture noire . <EOS>

# %% [markdown]
# ## Imperfect Translation
# You might notice that some sentences translate better than others.  Since the dataset you're using only has a vocabulary of 227 English words of the thousands that you use, you're only going to see good results using these words.  For this project, you don't need a perfect translation. However, if you want to create a better translation model, you'll need better data.
#
# You can train on the [WMT10 French-English corpus](http://www.statmt.org/wmt10/training-giga-fren.tar).  This dataset has more vocabulary and richer in topics discussed.  However, this will take you days to train, so make sure you've a GPU and the neural network is performing well on dataset we provided.  Just make sure you play with the WMT10 corpus after you've submitted this project.
# ## Submitting This Project
# When submitting this project, make sure to run all the cells before saving the notebook. Save the notebook file as "dlnd_language_translation.ipynb" and save it as a HTML file under "File" -> "Download as". Include the "helper.py" and "problem_unittests.py" files in your submission.
