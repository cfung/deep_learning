# %% [markdown]
# # Language Translation
# In this project, you’re going to take a peek into the realm of neural network machine translation.  You’ll be training a sequence to sequence model on a dataset of English and French sentences that can translate new sentences from English to French.
# ## Get the Data
# Since translating the whole language of English to French will take lots of time to train, we have provided you with a small portion of the English corpus.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import helper
import problem_unittests as tests

source_path = 'data/small_vocab_en'
target_path = 'data/small_vocab_fr'
source_text = helper.load_data(source_path)
target_text = helper.load_data(target_path)

# %% [markdown]
# ## Explore the Data
# Play around with view_sentence_range to view different parts of the data.

# %%
view_sentence_range = (0, 10)

"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import numpy as np

print('Dataset Stats')
print('Roughly the number of unique words: {}'.format(len({word: None for word in source_text.split()})))

sentences = source_text.split('\n')
word_counts = [len(sentence.split()) for sentence in sentences]
print('Number of sentences: {}'.format(len(sentences)))
print('Average number of words in a sentence: {}'.format(np.average(word_counts)))

print()
print('English sentences {} to {}:'.format(*view_sentence_range))
print('\n'.join(source_text.split('\n')[view_sentence_range[0]:view_sentence_range[1]]))
print()
print('French sentences {} to {}:'.format(*view_sentence_range))
print('\n'.join(target_text.split('\n')[view_sentence_range[0]:view_sentence_range[1]]))
# Out:
# Dataset Stats
# Roughly the number of unique words: 227
# Number of sentences: 137861
# Average number of words in a sentence: 13.225277634719028
#
# English sentences 0 to 10:
# new jersey is sometimes quiet during autumn , and it is snowy in april .
# the united states is usually chilly during july , and it is usually freezing in november .
# california is usually quiet during march , and it is usually hot in june .
# the united states is sometimes mild during june , and it is cold in september .
# your least liked fruit is the grape , but my least liked is the apple .
# his favorite fruit is the orange , but my favorite is the grape .
# paris is relaxing during december , but it is usually chilly in july .
# new jersey is busy during spring , and it is never hot in march .
# our least liked fruit is the lemon , but my least liked is the grape .
# the united states is sometimes busy during january , and it is sometimes warm in november .
#
# French sentences 0 to 10:
# new jersey est parfois calme pendant l' automne , et il est neigeux en avril .
# les états-unis est généralement froid en juillet , et il gèle habituellement en novembre .
# california est généralement calme en mars , et il est généralement chaud en juin .
# les états-unis est parfois légère en juin , et il fait froid en septembre .
# votre moins aimé fruit est le raisin , mais mon moins aimé est la pomme .
# son fruit préféré est l'orange , mais mon préféré est le raisin .
# paris est relaxant en décembre , mais il est généralement froid en juillet .
# new jersey est occupé au printemps , et il est jamais chaude en mars .
# notre fruit est moins aimé le citron , mais mon moins aimé est le raisin .
# les états-unis est parfois occupé en janvier , et il est parfois chaud en novembre .

# %% [markdown]
# ## Implement Preprocessing Function
# ### Text to Word Ids
# As you did with other RNNs, you must turn the text into a number so the computer can understand it. In the function `text_to_ids()`, you'll turn `source_text` and `target_text` from words to ids.  However, you need to add the `<EOS>` word id at the end of `target_text`.  This will help the neural network predict when the sentence should end.
#
# You can get the `<EOS>` word id by doing:
# ```python
# target_vocab_to_int['<EOS>']
# ```
# You can get other word ids using `source_vocab_to_int` and `target_vocab_to_int`.

# %%
def text_to_ids(source_text, target_text, source_vocab_to_int, target_vocab_to_int):
    """
    Convert source and target text to proper word ids
    :param source_text: String that contains all the source text.
    :param target_text: String that contains all the target text.
    :param source_vocab_to_int: Dictionary to go from the source words to an id
    :param target_vocab_to_int: Dictionary to go from the target words to an id
    :return: A tuple of lists (source_id_text, target_id_text)
    """
    # TODO: Implement Function

    source_id_text = [[source_vocab_to_int[word] for word in n.split()] for n in source_text.split("\n")]
    target_id_text = [[target_vocab_to_int[word] for word in n.split()]+[target_vocab_to_int['<EOS>']] for n in target_text.split("\n")]
    return source_id_text, target_id_text
    
"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_text_to_ids(text_to_ids)
# Out:
# Tests Passed

# %% [markdown]
# ### Preprocess all the data and save it
# Running the code cell below will preprocess all the data and save it to file.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
helper.preprocess_and_save_data(source_path, target_path, text_to_ids)

# %% [markdown]
# # Check Point
# This is your first checkpoint. If you ever decide to come back to this notebook or have to restart the notebook, you can start from here. The preprocessed data has been saved to disk.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import numpy as np
import helper
import problem_unittests as tests

(source_int_text, target_int_text), (source_vocab_to_int, target_vocab_to_int), _ = helper.load_preprocess()

# %% [markdown]
# ### Check the Version of TensorFlow and Access to GPU
# This will check to make sure you have the correct version of TensorFlow and access to a GPU

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
from distutils.version import LooseVersion
import warnings
import tensorflow as tf
from tensorflow.python.layers.core import Dense

# Check TensorFlow Version
assert LooseVersion(tf.__version__) >= LooseVersion('1.1'), 'Please use TensorFlow version 1.1 or newer'
print('TensorFlow Version: {}'.format(tf.__version__))

# Check for a GPU
if not tf.test.gpu_device_name():
    warnings.warn('No GPU found. Please use a GPU to train your neural network.')
else:
    print('Default GPU Device: {}'.format(tf.test.gpu_device_name()))
# Out:
# TensorFlow Version: 1.1.0
# Default GPU Device: /gpu:0

# %% [markdown]
# ## Build the Neural Network
# You'll build the components necessary to build a Sequence-to-Sequence model by implementing the following functions below:
# - `model_inputs`
# - `process_decoder_input`
# - `encoding_layer`
# - `decoding_layer_train`
# - `decoding_layer_infer`
# - `decoding_layer`
# - `seq2seq_model`
#
# ### Input
# Implement the `model_inputs()` function to create TF Placeholders for the Neural Network. It should create the following placeholders:
#
# - Input text placeholder named "input" using the TF Placeholder name parameter with rank 2.
# - Targets placeholder with rank 2.
# - Learning rate placeholder with rank 0.
# - Keep probability placeholder named "keep_prob" using the TF Placeholder name parameter with rank 0.
# - Target sequence length placeholder named "target_sequence_length" with rank 1
# - Max target sequence length tensor named "max_target_len" getting its value from applying tf.reduce_max on the target_sequence_length placeholder. Rank 0.
# - Source sequence length placeholder named "source_sequence_length" with rank 1
#
# Return the placeholders in the following the tuple (input, targets, learning rate, keep probability, target sequence length, max target sequence length, source sequence length)

# %%
def model_inputs():
    """
    Create TF Placeholders for input, targets, learning rate, and lengths of source and target sequences.
    :return: Tuple (input, targets, learning rate, keep probability, target sequence length,
    max target sequence length, source sequence length)
    """
    # TODO: Implement Function
    Input = tf.placeholder(tf.int32, shape=[None,None],name='input')
    targets = tf.placeholder(tf.int32, shape=[None,None],name='Targets')
    learning_rate = tf.placeholder(tf.float32, name="LearningRate")
    keep_prob = tf.placeholder(tf.float32, name="keep_prob")
    target_seq_length = tf.placeholder(tf.int32, (None,),name="target_sequence_length")
    max_target_seq_length = tf.reduce_max(target_seq_length,name="max_target_len")
    source_seq_length = tf.placeholder(tf.int32, (None,), name="source_sequence_length")
    return (Input, targets, learning_rate, keep_prob, target_seq_length, max_target_seq_length, source_seq_length)

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_model_inputs(model_inputs)
# Out:
# Tests Passed

# %% [markdown]
# ### Process Decoder Input
# Implement `process_decoder_input` by removing the last word id from each batch in `target_data` and concat the GO ID to the begining of each batch.

# %%
def process_decoder_input(target_data, target_vocab_to_int, batch_size):
    """
    Preprocess target data for encoding
    :param target_data: Target Placehoder
    :param target_vocab_to_int: Dictionary to go from the target words to an id
    :param batch_size: Batch Size
    :return: Preprocessed target data
    """
    # TODO: Implement Function
    ending = tf.strided_slice(target_data, [0, 0], [batch_size, -1], [1, 1])
    dec_input = tf.concat([tf.fill([batch_size, 1], target_vocab_to_int['<GO>']), ending], 1)
   
    return dec_input

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_process_encoding_input(process_decoder_input)
# Out:
# Tests Passed

# %% [markdown]
# ### Encoding
# Implement `encoding_layer()` to create a Encoder RNN layer:
#  * Embed the encoder input using [`tf.contrib.layers.embed_sequence`](https://www.tensorflow.org/api_docs/python/tf/contrib/layers/embed_sequence)
#  * Construct a [stacked](https://github.com/tensorflow/tensorflow/blob/6947f65a374ebf29e74bb71e36fd82760056d82c/tensorflow/docs_src/tutorials/recurrent.md#stacking-multiple-lstms) [`tf.contrib.rnn.LSTMCell`](https://www.tensorflow.org/api_docs/python/tf/contrib/rnn/LSTMCell) wrapped in a [`tf.contrib.rnn.DropoutWrapper`](https://www.tensorflow.org/api_docs/python/tf/contrib/rnn/DropoutWrapper)
#  * Pass cell and embedded input to [`tf.nn.dynamic_rnn()`](https://www.tensorflow.org/api_docs/python/tf/nn/dynamic_rnn)

# %%
from imp import reload
reload(tests)

def encoding_layer(rnn_inputs, rnn_size, num_layers, keep_prob, 
                   source_sequence_length, source_vocab_size, 
                   encoding_embedding_size):
    """
    Create encoding layer
    :param rnn_inputs: Inputs for the RNN
    :param rnn_size: RNN Size
    :param num_layers: Number of layers
    :param keep_prob: Dropout keep probability
    :param source_sequence_length: a list of the lengths of each sequence in the batch
    :param source_vocab_size: vocabulary size of source data
    :param encoding_embedding_size: embedding size of source data
    :return: tuple (RNN output, RNN state)
    """
    # TODO: Implement Function
    inputs =tf.contrib.layers.embed_sequence(rnn_inputs,source_vocab_size,encoding_embedding_size)
    cell = tf.contrib.rnn.BasicLSTMCell(rnn_size)
    dropout = tf.contrib.rnn.DropoutWrapper(cell,output_keep_prob=keep_prob)
    cell = tf.contrib.rnn.MultiRNNCell([tf.contrib.rnn.BasicLSTMCell(rnn_size) for _ in range(num_layers)])
    output, state = tf.nn.dynamic_rnn(cell,inputs,dtype=tf.float32)
    return output, state

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_encoding_layer(encoding_layer)
# Out:
# Tests Passed

# %% [markdown]
# ### Decoding - Training
# Create a training decoding layer:
# * Create a [`tf.contrib.seq2seq.TrainingHelper`](https://www.tensorflow.org/api_docs/python/tf/contrib/seq2seq/TrainingHelper)
# * Create a [`tf.contrib.seq2seq.BasicDecoder`](https://www.tensorflow.org/api_docs/python/tf/contrib/seq2seq/BasicDecoder)
# * Obtain the decoder outputs from [`tf.contrib.seq2seq.dynamic_decode`](https://www.tensorflow.org/api_docs/python/tf/contrib/seq2seq/dynamic_decode)

# %%
def decoding_layer_train(encoder_state, dec_cell, dec_embed_input, 
                         target_sequence_length, max_summary_length, 
                         output_layer, keep_prob):
    """
    Create a decoding layer for training
    :param encoder_state: Encoder State
    :param dec_cell: Decoder RNN Cell
    :param dec_embed_input: Decoder embedded input
    :param target_sequence_length: The lengths of each sequence in the target batch
    :param max_summary_length: The length of the longest sequence in the batch
    :param output_layer: Function to apply the output layer
    :param keep_prob: Dropout keep probability
    :return: BasicDecoderOutput containing training logits and sample_id
    """
    # TODO: Implement Function
    training_helper = tf.contrib.seq2seq.TrainingHelper(dec_embed_input, target_sequence_length)
    training_decoder = tf.contrib.seq2seq.BasicDecoder(dec_cell, training_helper, encoder_state, output_layer)
    training_decoder_output = tf.contrib.seq2seq.dynamic_decode(training_decoder, impute_finished=True, maximum_iterations=max_summary_length)[0]
    
    return training_decoder_output




"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_decoding_layer_train(decoding_layer_train)
# Out:
# Tests Passed

# %% [markdown]
# ### Decoding - Inference
# Create inference decoder:
# * Create a [`tf.contrib.seq2seq.GreedyEmbeddingHelper`](https://www.tensorflow.org/api_docs/python/tf/contrib/seq2seq/GreedyEmbeddingHelper)
# * Create a [`tf.contrib.seq2seq.BasicDecoder`](https://www.tensorflow.org/api_docs/python/tf/contrib/seq2seq/BasicDecoder)
# * Obtain the decoder outputs from [`tf.contrib.seq2seq.dynamic_decode`](https://www.tensorflow.org/api_docs/python/tf/contrib/seq2seq/dynamic_decode)

# %%
def decoding_layer_infer(encoder_state, dec_cell, dec_embeddings, start_of_sequence_id,
                         end_of_sequence_id, max_target_sequence_length,
                         vocab_size, output_layer, batch_size, keep_prob):
    """
    Create a decoding layer for inference
    :param encoder_state: Encoder state
    :param dec_cell: Decoder RNN Cell
    :param dec_embeddings: Decoder embeddings
    :param start_of_sequence_id: GO ID
    :param end_of_sequence_id: EOS Id
    :param max_target_sequence_length: Maximum length of target sequences
    :param vocab_size: Size of decoder/target vocabulary
    :param decoding_scope: TenorFlow Variable Scope for decoding
    :param output_layer: Function to apply the output layer
    :param batch_size: Batch size
    :param keep_prob: Dropout keep probability
    :return: BasicDecoderOutput containing inference logits and sample_id
    """
    # TODO: Implement Function
    #with tf.variable_scope("decoding", reuse=None) as decoding_scope:
        # Inference Decoder
    #    infer_decoder_fn = tf.contrib.seq2seq.simple_decoder_fn_inference(
    #        output_fn, encoder_state, dec_embeddings, start_of_sequence_id, end_of_sequence_id,
    #        maximum_length, vocab_size, dtype=tf.int32)
    #    inference_logits, _, _ = tf.contrib.seq2seq.dynamic_rnn_decoder(dec_cell, infer_decoder_fn, scope=decoding_scope)
    #    inference_logits_with_dropout = tf.nn.dropout(inference_logits, keep_prob)
    #return inference_logits_with_dropout


        
    start_tokens = tf.tile(tf.constant([start_of_sequence_id], dtype=tf.int32), [batch_size], name='start_tokens')
        
    # Helper for the inference process.
    inference_helper = tf.contrib.seq2seq.GreedyEmbeddingHelper(dec_embeddings,
                                                                start_tokens,
                                                                end_of_sequence_id)

    # Basic decoder
    inference_decoder = tf.contrib.seq2seq.BasicDecoder(dec_cell,
                                                        inference_helper,
                                                        encoder_state,
                                                        output_layer)
        
    # Perform dynamic decoding using the decoder
    inference_decoder_output, _ = tf.contrib.seq2seq.dynamic_decode(inference_decoder,
                                                                    impute_finished=True,
                                                                    maximum_iterations=max_target_sequence_length)
    
    
    #infer_decoder_fn = tf.contrib.seq2seq.simple_decoder_fn_inference(
    #output_fn, encoder_state, dec_embeddings, start_of_sequence_id, end_of_sequence_id, maximum_length, vocab_size)
    #inference_logits = tf.contrib.seq2seq.dynamicrnn_decoder(dec_cell, infer_decoder_fn, scope=decoding_scope)
    return inference_decoder_output



"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_decoding_layer_infer(decoding_layer_infer)
# Out:
# Tests Passed

# %% [markdown]
# ### Build the Decoding Layer
# Implement `decoding_layer()` to create a Decoder RNN layer.
#
# * Embed the target sequences
# * Construct the decoder LSTM cell (just like you constructed the encoder cell above)
# * Create an output layer to map the outputs of the decoder to the elements of our vocabulary
# * Use the your `decoding_layer_train(encoder_state, dec_cell, dec_embed_input, target_sequence_length, max_target_sequence_length, output_layer, keep_prob)` function to get the training logits.
# * Use your `decoding_layer_infer(encoder_state, dec_cell, dec_embeddings, start_of_sequence_id, end_of_sequence_id, max_target_sequence_length, vocab_size, output_layer, batch_size, keep_prob)` function to get the inference logits.
#
# Note: You'll need to use [tf.variable_scope](https://www.tensorflow.org/api_docs/python/tf/variable_scope) to share variables between training and inference.

# %%
def decoding_layer(dec_input, encoder_state,
               target_sequence_length, max_target_sequence_length,
               rnn_size,
               num_layers, target_vocab_to_int, target_vocab_size,
               batch_size, keep_prob, decoding_embedding_size):
    """
    Create decoding layer
    :param dec_input: Decoder input
    :param encoder_state: Encoder state
    :param target_sequence_length: The lengths of each sequence in the target batch
    :param max_target_sequence_length: Maximum length of target sequences
    :param rnn_size: RNN Size
    :param num_layers: Number of layers
    :param target_vocab_to_int: Dictionary to go from the target words to an id
    :param target_vocab_size: Size of target vocabulary
    :param batch_size: The size of the batch
    :param keep_prob: Dropout keep probability
    :param decoding_embedding_size: Decoding embedding size
    :return: Tuple of (Training BasicDecoderOutput, Inference BasicDecoderOutput)
    """
    # TODO: Implement Function
    #return None, None

    # Decoder embedding
    #target_vocab_size = len(target_vocab_to_int)
    dec_embeddings = tf.Variable(tf.random_uniform([target_vocab_size, decoding_embedding_size]))
    dec_embed_input = tf.nn.embedding_lookup(dec_embeddings, dec_input)  

    # Create decoder cell
    def make_cell(rnn_size):
        dec_cell = tf.contrib.rnn.LSTMCell(rnn_size, \
                                           initializer=tf.random_uniform_initializer(-0.1, 0.1, seed=2))
        return dec_cell
    dec_cell = tf.contrib.rnn.MultiRNNCell([make_cell(rnn_size) for _ in range(num_layers)])   

    # Create Dense layer to translate decoder's output at each time
    output_layer = Dense(target_vocab_size, \
                         kernel_initializer = tf.truncated_normal_initializer(mean=0.0, stddev=0.1))   

    # Training decoder
    with tf.variable_scope("decode") as decoding_scope:

        #output_layer = Dense(target_vocab_size, \
        #                 kernel_initializer = tf.truncated_normal_initializer(mean=0.0, stddev=0.1))

        training_decoder_output = decoding_layer_train(encoder_state, dec_cell, dec_embed_input, 
                         target_sequence_length, max_target_sequence_length, 
                         output_layer, keep_prob)
        
        

    # Inference decoder
    with tf.variable_scope("decode", reuse=True) as decoding_scope:
        start_of_sequence_id = target_vocab_to_int['<GO>']
        end_of_sequence_id = target_vocab_to_int['<EOS>']

        inference_decoder_output = decoding_layer_infer(encoder_state, dec_cell, dec_embeddings, start_of_sequence_id,
                             end_of_sequence_id, max_target_sequence_length,
                             target_vocab_size, output_layer, batch_size, keep_prob)
        
        

    return training_decoder_output, inference_decoder_output

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_decoding_layer(decoding_layer)
# Out:
# Tests Passed

# %% [markdown]
# ### Build the Neural Network
# Apply the functions you implemented above to:
#
# - Encode the input using your `encoding_layer(rnn_inputs, rnn_size, num_layers, keep_prob,  source_sequence_length, source_vocab_size, encoding_embedding_size)`.
# - Process target data using your `process_decoder_input(target_data, target_vocab_to_int, batch_size)` function.
# - Decode the encoded input using your `decoding_layer(dec_input, enc_state, target_sequence_length, max_target_sentence_length, rnn_size, num_layers, target_vocab_to_int, target_vocab_size, batch_size, keep_prob, dec_embedding_size)` function.

# %%
def seq2seq_model(input_data, target_data, keep_prob, batch_size,
                  source_sequence_length, target_sequence_length,
                  max_target_sentence_length,
                  source_vocab_size, target_vocab_size,
                  enc_embedding_size, dec_embedding_size,
                  rnn_size, num_layers, target_vocab_to_int):
    """
    Build the Sequence-to-Sequence part of the neural network
    :param input_data: Input placeholder
    :param target_data: Target placeholder
    :param keep_prob: Dropout keep probability placeholder
    :param batch_size: Batch Size
    :param source_sequence_length: Sequence Lengths of source sequences in the batch
    :param target_sequence_length: Sequence Lengths of target sequences in the batch
    :param source_vocab_size: Source vocabulary size
    :param target_vocab_size: Target vocabulary size
    :param enc_embedding_size: Decoder embedding size
    :param dec_embedding_size: Encoder embedding size
    :param rnn_size: RNN Size
    :param num_layers: Number of layers
    :param target_vocab_to_int: Dictionary to go from the target words to an id
    :return: Tuple of (Training BasicDecoderOutput, Inference BasicDecoderOutput)
    """
    
    # Pass the input data through the encoder. We'll ignore the encoder output, but use the state
    encoder_output, encoder_state = encoding_layer(input_data, rnn_size, num_layers, keep_prob, 
                                                   source_sequence_length, source_vocab_size, enc_embedding_size)
    
    processed_input = process_decoder_input(target_data, target_vocab_to_int, batch_size)
    
    max_target_sequence_length = tf.reduce_max(target_sequence_length)
    output_train, output_inference = decoding_layer(processed_input, encoder_state, 
                                                    target_sequence_length, max_target_sequence_length, 
                                                    rnn_size, num_layers, target_vocab_to_int, 
                                                    target_vocab_size, batch_size, keep_prob, dec_embedding_size)
    
    return output_train, output_inference
"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_seq2seq_model(seq2seq_model)
# Out:
# Tests Passed

# %% [markdown]
# ## Neural Network Training
# ### Hyperparameters
# Tune the following parameters:
#
# - Set `epochs` to the number of epochs.
# - Set `batch_size` to the batch size.
# - Set `rnn_size` to the size of the RNNs.
# - Set `num_layers` to the number of layers.
# - Set `encoding_embedding_size` to the size of the embedding for the encoder.
# - Set `decoding_embedding_size` to the size of the embedding for the decoder.
# - Set `learning_rate` to the learning rate.
# - Set `keep_probability` to the Dropout keep probability
# - Set `display_step` to state how many steps between each debug output statement

# %%
# Number of Epochs
epochs = 7
# Batch Size
batch_size = 128
# RNN Size
rnn_size = 128
# Number of Layers
num_layers = 2
# Embedding Size
encoding_embedding_size = 128
decoding_embedding_size = 128
# Learning Rate
learning_rate = 0.001
# Dropout Keep Probability
keep_probability = 0.65
display_step = 5

# %% [markdown]
# ### Build the Graph
# Build the graph using the neural network you implemented.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
save_path = 'checkpoints/dev'
(source_int_text, target_int_text), (source_vocab_to_int, target_vocab_to_int), _ = helper.load_preprocess()
max_target_sentence_length = max([len(sentence) for sentence in source_int_text])

train_graph = tf.Graph()
with train_graph.as_default():
    input_data, targets, lr, keep_prob, target_sequence_length, max_target_sequence_length, source_sequence_length = model_inputs()

    #sequence_length = tf.placeholder_with_default(max_target_sentence_length, None, name='sequence_length')
    input_shape = tf.shape(input_data)

    train_logits, inference_logits = seq2seq_model(tf.reverse(input_data, [-1]),
                                                   targets,
                                                   keep_prob,
                                                   batch_size,
                                                   source_sequence_length,
                                                   target_sequence_length,
                                                   max_target_sequence_length,
                                                   len(source_vocab_to_int),
                                                   len(target_vocab_to_int),
                                                   encoding_embedding_size,
                                                   decoding_embedding_size,
                                                   rnn_size,
                                                   num_layers,
                                                   target_vocab_to_int)


    training_logits = tf.identity(train_logits.rnn_output, name='logits')
    inference_logits = tf.identity(inference_logits.sample_id, name='predictions')

    masks = tf.sequence_mask(target_sequence_length, max_target_sequence_length, dtype=tf.float32, name='masks')

    with tf.name_scope("optimization"):
        # Loss function
        cost = tf.contrib.seq2seq.sequence_loss(
            training_logits,
            targets,
            masks)

        # Optimizer
        optimizer = tf.train.AdamOptimizer(lr)

        # Gradient Clipping
        gradients = optimizer.compute_gradients(cost)
        capped_gradients = [(tf.clip_by_value(grad, -1., 1.), var) for grad, var in gradients if grad is not None]
        train_op = optimizer.apply_gradients(capped_gradients)

# %% [markdown]
# Batch and pad the source and target sequences

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
def pad_sentence_batch(sentence_batch, pad_int):
    """Pad sentences with <PAD> so that each sentence of a batch has the same length"""
    max_sentence = max([len(sentence) for sentence in sentence_batch])
    return [sentence + [pad_int] * (max_sentence - len(sentence)) for sentence in sentence_batch]


def get_batches(sources, targets, batch_size, source_pad_int, target_pad_int):
    """Batch targets, sources, and the lengths of their sentences together"""
    for batch_i in range(0, len(sources)//batch_size):
        start_i = batch_i * batch_size

        # Slice the right amount for the batch
        sources_batch = sources[start_i:start_i + batch_size]
        targets_batch = targets[start_i:start_i + batch_size]

        # Pad
        pad_sources_batch = np.array(pad_sentence_batch(sources_batch, source_pad_int))
        pad_targets_batch = np.array(pad_sentence_batch(targets_batch, target_pad_int))

        # Need the lengths for the _lengths parameters
        pad_targets_lengths = []
        for target in pad_targets_batch:
            pad_targets_lengths.append(len(target))

        pad_source_lengths = []
        for source in pad_sources_batch:
            pad_source_lengths.append(len(source))

        yield pad_sources_batch, pad_targets_batch, pad_source_lengths, pad_targets_lengths

# %% [markdown]
# ### Train
# Train the neural network on the preprocessed data. If you have a hard time getting a good loss, check the forms to see if anyone is having the same problem.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
def get_accuracy(target, logits):
    """
    Calculate accuracy
    """
    max_seq = max(target.shape[1], logits.shape[1])
    if max_seq - target.shape[1]:
        target = np.pad(
            target,
            [(0,0),(0,max_seq - target.shape[1])],
            'constant')
    if max_seq - logits.shape[1]:
        logits = np.pad(
            logits,
            [(0,0),(0,max_seq - logits.shape[1])],
            'constant')

    return np.mean(np.equal(target, logits))

# Split data to training and validation sets
train_source = source_int_text[batch_size:]
train_target = target_int_text[batch_size:]
valid_source = source_int_text[:batch_size]
valid_target = target_int_text[:batch_size]
(valid_sources_batch, valid_targets_batch, valid_sources_lengths, valid_targets_lengths ) = next(get_batches(valid_source,
                                                                                                             valid_target,
                                                                                                             batch_size,
                                                                                                             source_vocab_to_int['<PAD>'],
                                                                                                             target_vocab_to_int['<PAD>']))                                                                                                  
with tf.Session(graph=train_graph) as sess:
    sess.run(tf.global_variables_initializer())

    for epoch_i in range(epochs):
        for batch_i, (source_batch, target_batch, sources_lengths, targets_lengths) in enumerate(
                get_batches(train_source, train_target, batch_size,
                            source_vocab_to_int['<PAD>'],
                            target_vocab_to_int['<PAD>'])):

            _, loss = sess.run(
                [train_op, cost],
                {input_data: source_batch,
                 targets: target_batch,
                 lr: learning_rate,
                 target_sequence_length: targets_lengths,
                 source_sequence_length: sources_lengths,
                 keep_prob: keep_probability})


            if batch_i % display_step == 0 and batch_i > 0:


                batch_train_logits = sess.run(
                    inference_logits,
                    {input_data: source_batch,
                     source_sequence_length: sources_lengths,
                     target_sequence_length: targets_lengths,
                     keep_prob: 1.0})


                batch_valid_logits = sess.run(
                    inference_logits,
                    {input_data: valid_sources_batch,
                     source_sequence_length: valid_sources_lengths,
                     target_sequence_length: valid_targets_lengths,
                     keep_prob: 1.0})

                train_acc = get_accuracy(target_batch, batch_train_logits)

                valid_acc = get_accuracy(valid_targets_batch, batch_valid_logits)

                print('Epoch {:>3} Batch {:>4}/{} - Train Accuracy: {:>6.4f}, Validation Accuracy: {:>6.4f}, Loss: {:>6.4f}'
                      .format(epoch_i, batch_i, len(source_int_text) // batch_size, train_acc, valid_acc, loss))

    # Save Model
    saver = tf.train.Saver()
    saver.save(sess, save_path)
    print('Model Trained and Saved')
# Out:
# Epoch   0 Batch    5/1077 - Train Accuracy: 0.2605, Validation Accuracy: 0.3050, Loss: 4.9960
# Epoch   0 Batch   10/1077 - Train Accuracy: 0.2356, Validation Accuracy: 0.3356, Loss: 4.4449
# Epoch   0 Batch   15/1077 - Train Accuracy: 0.2734, Validation Accuracy: 0.3370, Loss: 3.7955
# Epoch   0 Batch   20/1077 - Train Accuracy: 0.2750, Validation Accuracy: 0.3438, Loss: 3.4712
# Epoch   0 Batch   25/1077 - Train Accuracy: 0.3184, Validation Accuracy: 0.3786, Loss: 3.3379
# Epoch   0 Batch   30/1077 - Train Accuracy: 0.3074, Validation Accuracy: 0.3711, Loss: 3.1356
# Epoch   0 Batch   35/1077 - Train Accuracy: 0.3684, Validation Accuracy: 0.4205, Loss: 3.0323
# Epoch   0 Batch   40/1077 - Train Accuracy: 0.3715, Validation Accuracy: 0.4322, Loss: 2.9579
# Epoch   0 Batch   45/1077 - Train Accuracy: 0.3742, Validation Accuracy: 0.4375, Loss: 2.9014
# Epoch   0 Batch   50/1077 - Train Accuracy: 0.3605, Validation Accuracy: 0.4205, Loss: 2.8951
# Epoch   0 Batch   55/1077 - Train Accuracy: 0.3988, Validation Accuracy: 0.4389, Loss: 2.7173
# Epoch   0 Batch   60/1077 - Train Accuracy: 0.4152, Validation Accuracy: 0.4528, Loss: 2.6547
# Epoch   0 Batch   65/1077 - Train Accuracy: 0.3754, Validation Accuracy: 0.4595, Loss: 2.8292
# Epoch   0 Batch   70/1077 - Train Accuracy: 0.3590, Validation Accuracy: 0.4499, Loss: 2.7460
# Epoch   0 Batch   75/1077 - Train Accuracy: 0.4336, Validation Accuracy: 0.4691, Loss: 2.5189
# Epoch   0 Batch   80/1077 - Train Accuracy: 0.4227, Validation Accuracy: 0.4719, Loss: 2.5622
# Epoch   0 Batch   85/1077 - Train Accuracy: 0.4359, Validation Accuracy: 0.4705, Loss: 2.4100
# Epoch   0 Batch   90/1077 - Train Accuracy: 0.4184, Validation Accuracy: 0.4798, Loss: 2.5555
# Epoch   0 Batch   95/1077 - Train Accuracy: 0.4680, Validation Accuracy: 0.4886, Loss: 2.3676
# Epoch   0 Batch  100/1077 - Train Accuracy: 0.4473, Validation Accuracy: 0.5004, Loss: 2.4401
# Epoch   0 Batch  105/1077 - Train Accuracy: 0.4527, Validation Accuracy: 0.4982, Loss: 2.3890
# Epoch   0 Batch  110/1077 - Train Accuracy: 0.4621, Validation Accuracy: 0.4957, Loss: 2.3546
# Epoch   0 Batch  115/1077 - Train Accuracy: 0.4285, Validation Accuracy: 0.4950, Loss: 2.3752
# Epoch   0 Batch  120/1077 - Train Accuracy: 0.4230, Validation Accuracy: 0.4844, Loss: 2.3286
# Epoch   0 Batch  125/1077 - Train Accuracy: 0.4561, Validation Accuracy: 0.5064, Loss: 2.2506
# Epoch   0 Batch  130/1077 - Train Accuracy: 0.4602, Validation Accuracy: 0.5071, Loss: 2.1499
# Epoch   0 Batch  135/1077 - Train Accuracy: 0.4264, Validation Accuracy: 0.4979, Loss: 2.2962
# Epoch   0 Batch  140/1077 - Train Accuracy: 0.4067, Validation Accuracy: 0.4911, Loss: 2.3290
# Epoch   0 Batch  145/1077 - Train Accuracy: 0.4590, Validation Accuracy: 0.4961, Loss: 2.1141
# Epoch   0 Batch  150/1077 - Train Accuracy: 0.4688, Validation Accuracy: 0.5025, Loss: 2.0293
# Epoch   0 Batch  155/1077 - Train Accuracy: 0.4523, Validation Accuracy: 0.5096, Loss: 2.0867
# Epoch   0 Batch  160/1077 - Train Accuracy: 0.4605, Validation Accuracy: 0.5082, Loss: 2.0522
# Epoch   0 Batch  165/1077 - Train Accuracy: 0.4070, Validation Accuracy: 0.4869, Loss: 2.0394
# Epoch   0 Batch  170/1077 - Train Accuracy: 0.4195, Validation Accuracy: 0.5032, Loss: 2.0699
# Epoch   0 Batch  175/1077 - Train Accuracy: 0.4555, Validation Accuracy: 0.4876, Loss: 1.9089
# Epoch   0 Batch  180/1077 - Train Accuracy: 0.4277, Validation Accuracy: 0.4787, Loss: 1.9228
# Epoch   0 Batch  185/1077 - Train Accuracy: 0.4062, Validation Accuracy: 0.4773, Loss: 1.9098
# Epoch   0 Batch  190/1077 - Train Accuracy: 0.4465, Validation Accuracy: 0.4922, Loss: 1.8799
# Epoch   0 Batch  195/1077 - Train Accuracy: 0.4262, Validation Accuracy: 0.5085, Loss: 1.8577
# Epoch   0 Batch  200/1077 - Train Accuracy: 0.4492, Validation Accuracy: 0.4986, Loss: 1.8255
# Epoch   0 Batch  205/1077 - Train Accuracy: 0.4723, Validation Accuracy: 0.5028, Loss: 1.8023
# Epoch   0 Batch  210/1077 - Train Accuracy: 0.4751, Validation Accuracy: 0.5057, Loss: 1.7693
# Epoch   0 Batch  215/1077 - Train Accuracy: 0.4613, Validation Accuracy: 0.5202, Loss: 1.7544
# Epoch   0 Batch  220/1077 - Train Accuracy: 0.4408, Validation Accuracy: 0.5082, Loss: 1.7583
# Epoch   0 Batch  225/1077 - Train Accuracy: 0.4598, Validation Accuracy: 0.5270, Loss: 1.7237
# Epoch   0 Batch  230/1077 - Train Accuracy: 0.5056, Validation Accuracy: 0.5277, Loss: 1.5785
# Epoch   0 Batch  235/1077 - Train Accuracy: 0.5145, Validation Accuracy: 0.5107, Loss: 1.5520
# Epoch   0 Batch  240/1077 - Train Accuracy: 0.4758, Validation Accuracy: 0.5266, Loss: 1.6062
# Epoch   0 Batch  245/1077 - Train Accuracy: 0.4773, Validation Accuracy: 0.5224, Loss: 1.5480
# Epoch   0 Batch  250/1077 - Train Accuracy: 0.4663, Validation Accuracy: 0.4876, Loss: 1.4841
# Epoch   0 Batch  255/1077 - Train Accuracy: 0.4531, Validation Accuracy: 0.5167, Loss: 1.5845
# Epoch   0 Batch  260/1077 - Train Accuracy: 0.4959, Validation Accuracy: 0.5245, Loss: 1.4897
# Epoch   0 Batch  265/1077 - Train Accuracy: 0.4660, Validation Accuracy: 0.4922, Loss: 1.5114
# Epoch   0 Batch  270/1077 - Train Accuracy: 0.4477, Validation Accuracy: 0.5252, Loss: 1.5996
# Epoch   0 Batch  275/1077 - Train Accuracy: 0.4609, Validation Accuracy: 0.4972, Loss: 1.4293
# Epoch   0 Batch  280/1077 - Train Accuracy: 0.4680, Validation Accuracy: 0.4911, Loss: 1.5148
# Epoch   0 Batch  285/1077 - Train Accuracy: 0.4993, Validation Accuracy: 0.5089, Loss: 1.3855
# Epoch   0 Batch  290/1077 - Train Accuracy: 0.4402, Validation Accuracy: 0.4719, Loss: 1.4813
# Epoch   0 Batch  295/1077 - Train Accuracy: 0.4556, Validation Accuracy: 0.5138, Loss: 1.5354
# Epoch   0 Batch  300/1077 - Train Accuracy: 0.4141, Validation Accuracy: 0.4787, Loss: 1.5015
# Epoch   0 Batch  305/1077 - Train Accuracy: 0.4758, Validation Accuracy: 0.5000, Loss: 1.4138
# Epoch   0 Batch  310/1077 - Train Accuracy: 0.4422, Validation Accuracy: 0.4993, Loss: 1.3988
# Epoch   0 Batch  315/1077 - Train Accuracy: 0.4859, Validation Accuracy: 0.5131, Loss: 1.3364
# Epoch   0 Batch  320/1077 - Train Accuracy: 0.4586, Validation Accuracy: 0.4922, Loss: 1.3945
# Epoch   0 Batch  325/1077 - Train Accuracy: 0.5022, Validation Accuracy: 0.4897, Loss: 1.2680
# Epoch   0 Batch  330/1077 - Train Accuracy: 0.4973, Validation Accuracy: 0.5099, Loss: 1.3434
# Epoch   0 Batch  335/1077 - Train Accuracy: 0.4885, Validation Accuracy: 0.5138, Loss: 1.2069
# Epoch   0 Batch  340/1077 - Train Accuracy: 0.4091, Validation Accuracy: 0.5004, Loss: 1.3517
# Epoch   0 Batch  345/1077 - Train Accuracy: 0.4472, Validation Accuracy: 0.4819, Loss: 1.2397
# Epoch   0 Batch  350/1077 - Train Accuracy: 0.4117, Validation Accuracy: 0.4798, Loss: 1.3604
# Epoch   0 Batch  355/1077 - Train Accuracy: 0.5048, Validation Accuracy: 0.5078, Loss: 1.2542
# Epoch   0 Batch  360/1077 - Train Accuracy: 0.4504, Validation Accuracy: 0.4794, Loss: 1.2456
# Epoch   0 Batch  365/1077 - Train Accuracy: 0.4707, Validation Accuracy: 0.5316, Loss: 1.2552
# Epoch   0 Batch  370/1077 - Train Accuracy: 0.4799, Validation Accuracy: 0.5192, Loss: 1.1705
# Epoch   0 Batch  375/1077 - Train Accuracy: 0.5252, Validation Accuracy: 0.5135, Loss: 1.1175
# Epoch   0 Batch  380/1077 - Train Accuracy: 0.4746, Validation Accuracy: 0.5224, Loss: 1.1694
# Epoch   0 Batch  385/1077 - Train Accuracy: 0.4758, Validation Accuracy: 0.5273, Loss: 1.2002
# Epoch   0 Batch  390/1077 - Train Accuracy: 0.4754, Validation Accuracy: 0.5373, Loss: 1.2127
# Epoch   0 Batch  395/1077 - Train Accuracy: 0.5141, Validation Accuracy: 0.5312, Loss: 1.0926
# Epoch   0 Batch  400/1077 - Train Accuracy: 0.4918, Validation Accuracy: 0.5249, Loss: 1.1500
# Epoch   0 Batch  405/1077 - Train Accuracy: 0.4720, Validation Accuracy: 0.5437, Loss: 1.1709
# Epoch   0 Batch  410/1077 - Train Accuracy: 0.4507, Validation Accuracy: 0.5408, Loss: 1.1656
# Epoch   0 Batch  415/1077 - Train Accuracy: 0.5275, Validation Accuracy: 0.5433, Loss: 1.0540
# Epoch   0 Batch  420/1077 - Train Accuracy: 0.4648, Validation Accuracy: 0.5103, Loss: 1.0938
# Epoch   0 Batch  425/1077 - Train Accuracy: 0.4468, Validation Accuracy: 0.4773, Loss: 1.0423
# Epoch   0 Batch  430/1077 - Train Accuracy: 0.4566, Validation Accuracy: 0.5075, Loss: 1.0650
# Epoch   0 Batch  435/1077 - Train Accuracy: 0.4712, Validation Accuracy: 0.5234, Loss: 1.1069
# Epoch   0 Batch  440/1077 - Train Accuracy: 0.4676, Validation Accuracy: 0.5202, Loss: 1.0825
# Epoch   0 Batch  445/1077 - Train Accuracy: 0.4404, Validation Accuracy: 0.5163, Loss: 1.1031
# Epoch   0 Batch  450/1077 - Train Accuracy: 0.4695, Validation Accuracy: 0.5185, Loss: 1.0337
# Epoch   0 Batch  455/1077 - Train Accuracy: 0.5057, Validation Accuracy: 0.5089, Loss: 0.9480
# Epoch   0 Batch  460/1077 - Train Accuracy: 0.4844, Validation Accuracy: 0.5586, Loss: 1.0185
# Epoch   0 Batch  465/1077 - Train Accuracy: 0.4470, Validation Accuracy: 0.5266, Loss: 1.0479
# Epoch   0 Batch  470/1077 - Train Accuracy: 0.4350, Validation Accuracy: 0.5185, Loss: 1.0282
# Epoch   0 Batch  475/1077 - Train Accuracy: 0.4738, Validation Accuracy: 0.5153, Loss: 0.9347
# Epoch   0 Batch  480/1077 - Train Accuracy: 0.4873, Validation Accuracy: 0.5259, Loss: 0.9968
# Epoch   0 Batch  485/1077 - Train Accuracy: 0.4809, Validation Accuracy: 0.5170, Loss: 0.9393
# Epoch   0 Batch  490/1077 - Train Accuracy: 0.4664, Validation Accuracy: 0.5288, Loss: 0.9682
# Epoch   0 Batch  495/1077 - Train Accuracy: 0.5133, Validation Accuracy: 0.5636, Loss: 0.9421
# Epoch   0 Batch  500/1077 - Train Accuracy: 0.5270, Validation Accuracy: 0.5593, Loss: 0.9267
# Epoch   0 Batch  505/1077 - Train Accuracy: 0.5164, Validation Accuracy: 0.5330, Loss: 0.8394
# Epoch   0 Batch  510/1077 - Train Accuracy: 0.5535, Validation Accuracy: 0.5756, Loss: 0.9174
# Epoch   0 Batch  515/1077 - Train Accuracy: 0.5258, Validation Accuracy: 0.5767, Loss: 0.9330
# Epoch   0 Batch  520/1077 - Train Accuracy: 0.5502, Validation Accuracy: 0.5781, Loss: 0.8655
# Epoch   0 Batch  525/1077 - Train Accuracy: 0.5211, Validation Accuracy: 0.5604, Loss: 0.8936
# Epoch   0 Batch  530/1077 - Train Accuracy: 0.5312, Validation Accuracy: 0.5732, Loss: 0.8930
# Epoch   0 Batch  535/1077 - Train Accuracy: 0.5137, Validation Accuracy: 0.5863, Loss: 0.8731
# Epoch   0 Batch  540/1077 - Train Accuracy: 0.5129, Validation Accuracy: 0.5813, Loss: 0.8420
# Epoch   0 Batch  545/1077 - Train Accuracy: 0.5340, Validation Accuracy: 0.5810, Loss: 0.9117
# Epoch   0 Batch  550/1077 - Train Accuracy: 0.5375, Validation Accuracy: 0.5923, Loss: 0.8972
# Epoch   0 Batch  555/1077 - Train Accuracy: 0.5629, Validation Accuracy: 0.5909, Loss: 0.8471
# Epoch   0 Batch  560/1077 - Train Accuracy: 0.5473, Validation Accuracy: 0.5906, Loss: 0.8340
# Epoch   0 Batch  565/1077 - Train Accuracy: 0.5584, Validation Accuracy: 0.5845, Loss: 0.8314
# Epoch   0 Batch  570/1077 - Train Accuracy: 0.5329, Validation Accuracy: 0.5906, Loss: 0.8655
# Epoch   0 Batch  575/1077 - Train Accuracy: 0.5718, Validation Accuracy: 0.5863, Loss: 0.8156
# Epoch   0 Batch  580/1077 - Train Accuracy: 0.5938, Validation Accuracy: 0.5916, Loss: 0.7638
# Epoch   0 Batch  585/1077 - Train Accuracy: 0.6157, Validation Accuracy: 0.5969, Loss: 0.7570
# Epoch   0 Batch  590/1077 - Train Accuracy: 0.5600, Validation Accuracy: 0.5934, Loss: 0.8342
# Epoch   0 Batch  595/1077 - Train Accuracy: 0.5633, Validation Accuracy: 0.5920, Loss: 0.8312
# Epoch   0 Batch  600/1077 - Train Accuracy: 0.6001, Validation Accuracy: 0.5927, Loss: 0.7613
# Epoch   0 Batch  605/1077 - Train Accuracy: 0.5567, Validation Accuracy: 0.6048, Loss: 0.8709
# Epoch   0 Batch  610/1077 - Train Accuracy: 0.5707, Validation Accuracy: 0.6005, Loss: 0.8330
# Epoch   0 Batch  615/1077 - Train Accuracy: 0.6055, Validation Accuracy: 0.6062, Loss: 0.7812
# Epoch   0 Batch  620/1077 - Train Accuracy: 0.5613, Validation Accuracy: 0.6040, Loss: 0.7794
# Epoch   0 Batch  625/1077 - Train Accuracy: 0.5992, Validation Accuracy: 0.5998, Loss: 0.7843
# Epoch   0 Batch  630/1077 - Train Accuracy: 0.5988, Validation Accuracy: 0.5969, Loss: 0.7708
# Epoch   0 Batch  635/1077 - Train Accuracy: 0.5600, Validation Accuracy: 0.5994, Loss: 0.8245
# Epoch   0 Batch  640/1077 - Train Accuracy: 0.5688, Validation Accuracy: 0.6048, Loss: 0.7468
# Epoch   0 Batch  645/1077 - Train Accuracy: 0.6142, Validation Accuracy: 0.6019, Loss: 0.7385
# Epoch   0 Batch  650/1077 - Train Accuracy: 0.5434, Validation Accuracy: 0.5827, Loss: 0.7734
# Epoch   0 Batch  655/1077 - Train Accuracy: 0.5887, Validation Accuracy: 0.5991, Loss: 0.7657
# Epoch   0 Batch  660/1077 - Train Accuracy: 0.5738, Validation Accuracy: 0.5966, Loss: 0.7784
# Epoch   0 Batch  665/1077 - Train Accuracy: 0.5727, Validation Accuracy: 0.6033, Loss: 0.7484
# Epoch   0 Batch  670/1077 - Train Accuracy: 0.6225, Validation Accuracy: 0.5969, Loss: 0.6969
# Epoch   0 Batch  675/1077 - Train Accuracy: 0.5744, Validation Accuracy: 0.5984, Loss: 0.7365
# Epoch   0 Batch  680/1077 - Train Accuracy: 0.5759, Validation Accuracy: 0.5838, Loss: 0.7283
# Epoch   0 Batch  685/1077 - Train Accuracy: 0.5844, Validation Accuracy: 0.5866, Loss: 0.7454
# Epoch   0 Batch  690/1077 - Train Accuracy: 0.6078, Validation Accuracy: 0.5991, Loss: 0.7346
# Epoch   0 Batch  695/1077 - Train Accuracy: 0.5859, Validation Accuracy: 0.6044, Loss: 0.7030
# Epoch   0 Batch  700/1077 - Train Accuracy: 0.5684, Validation Accuracy: 0.6040, Loss: 0.7134
# Epoch   0 Batch  705/1077 - Train Accuracy: 0.6077, Validation Accuracy: 0.6037, Loss: 0.7847
# Epoch   0 Batch  710/1077 - Train Accuracy: 0.5492, Validation Accuracy: 0.5923, Loss: 0.7171
# Epoch   0 Batch  715/1077 - Train Accuracy: 0.5777, Validation Accuracy: 0.5692, Loss: 0.8117
# Epoch   0 Batch  720/1077 - Train Accuracy: 0.5806, Validation Accuracy: 0.6001, Loss: 0.7789
# Epoch   0 Batch  725/1077 - Train Accuracy: 0.5629, Validation Accuracy: 0.5902, Loss: 0.6894
# Epoch   0 Batch  730/1077 - Train Accuracy: 0.5648, Validation Accuracy: 0.5863, Loss: 0.7246
# Epoch   0 Batch  735/1077 - Train Accuracy: 0.5746, Validation Accuracy: 0.5895, Loss: 0.6972
# Epoch   0 Batch  740/1077 - Train Accuracy: 0.5898, Validation Accuracy: 0.6001, Loss: 0.6976
# Epoch   0 Batch  745/1077 - Train Accuracy: 0.6027, Validation Accuracy: 0.5948, Loss: 0.6929
# Epoch   0 Batch  750/1077 - Train Accuracy: 0.5887, Validation Accuracy: 0.5941, Loss: 0.6868
# Epoch   0 Batch  755/1077 - Train Accuracy: 0.5848, Validation Accuracy: 0.6037, Loss: 0.6969
# Epoch   0 Batch  760/1077 - Train Accuracy: 0.5938, Validation Accuracy: 0.5902, Loss: 0.6976
# Epoch   0 Batch  765/1077 - Train Accuracy: 0.5906, Validation Accuracy: 0.6009, Loss: 0.6609
# Epoch   0 Batch  770/1077 - Train Accuracy: 0.6172, Validation Accuracy: 0.5930, Loss: 0.6462
# Epoch   0 Batch  775/1077 - Train Accuracy: 0.6047, Validation Accuracy: 0.5927, Loss: 0.6846
# Epoch   0 Batch  780/1077 - Train Accuracy: 0.5750, Validation Accuracy: 0.6037, Loss: 0.7062
# Epoch   0 Batch  785/1077 - Train Accuracy: 0.6302, Validation Accuracy: 0.6037, Loss: 0.6401
# Epoch   0 Batch  790/1077 - Train Accuracy: 0.5379, Validation Accuracy: 0.5987, Loss: 0.7054
# Epoch   0 Batch  795/1077 - Train Accuracy: 0.5645, Validation Accuracy: 0.5969, Loss: 0.6955
# Epoch   0 Batch  800/1077 - Train Accuracy: 0.5820, Validation Accuracy: 0.5980, Loss: 0.6749
# Epoch   0 Batch  805/1077 - Train Accuracy: 0.6012, Validation Accuracy: 0.6009, Loss: 0.6613
# Epoch   0 Batch  810/1077 - Train Accuracy: 0.6012, Validation Accuracy: 0.5987, Loss: 0.6340
# Epoch   0 Batch  815/1077 - Train Accuracy: 0.5750, Validation Accuracy: 0.6037, Loss: 0.6616
# Epoch   0 Batch  820/1077 - Train Accuracy: 0.5742, Validation Accuracy: 0.5945, Loss: 0.6940
# Epoch   0 Batch  825/1077 - Train Accuracy: 0.5750, Validation Accuracy: 0.6044, Loss: 0.6419
# Epoch   0 Batch  830/1077 - Train Accuracy: 0.5922, Validation Accuracy: 0.6065, Loss: 0.6482
# Epoch   0 Batch  835/1077 - Train Accuracy: 0.6086, Validation Accuracy: 0.6094, Loss: 0.6482
# Epoch   0 Batch  840/1077 - Train Accuracy: 0.5891, Validation Accuracy: 0.6193, Loss: 0.6256
# Epoch   0 Batch  845/1077 - Train Accuracy: 0.6113, Validation Accuracy: 0.6158, Loss: 0.6299
# Epoch   0 Batch  850/1077 - Train Accuracy: 0.5699, Validation Accuracy: 0.6101, Loss: 0.6847
# Epoch   0 Batch  855/1077 - Train Accuracy: 0.5605, Validation Accuracy: 0.6165, Loss: 0.6356
# Epoch   0 Batch  860/1077 - Train Accuracy: 0.6019, Validation Accuracy: 0.6001, Loss: 0.6291
# Epoch   0 Batch  865/1077 - Train Accuracy: 0.6705, Validation Accuracy: 0.6026, Loss: 0.5651
# Epoch   0 Batch  870/1077 - Train Accuracy: 0.5736, Validation Accuracy: 0.6058, Loss: 0.6784
# Epoch   0 Batch  875/1077 - Train Accuracy: 0.6023, Validation Accuracy: 0.6140, Loss: 0.6375
# Epoch   0 Batch  880/1077 - Train Accuracy: 0.6336, Validation Accuracy: 0.6193, Loss: 0.6226
# Epoch   0 Batch  885/1077 - Train Accuracy: 0.6197, Validation Accuracy: 0.6218, Loss: 0.5385
# Epoch   0 Batch  890/1077 - Train Accuracy: 0.6488, Validation Accuracy: 0.6019, Loss: 0.5943
# Epoch   0 Batch  895/1077 - Train Accuracy: 0.5930, Validation Accuracy: 0.6090, Loss: 0.6207
# Epoch   0 Batch  900/1077 - Train Accuracy: 0.6285, Validation Accuracy: 0.6300, Loss: 0.6329
# Epoch   0 Batch  905/1077 - Train Accuracy: 0.6379, Validation Accuracy: 0.6175, Loss: 0.5919
# Epoch   0 Batch  910/1077 - Train Accuracy: 0.5863, Validation Accuracy: 0.6211, Loss: 0.6043
# Epoch   0 Batch  915/1077 - Train Accuracy: 0.5851, Validation Accuracy: 0.6179, Loss: 0.6449
# Epoch   0 Batch  920/1077 - Train Accuracy: 0.6105, Validation Accuracy: 0.6172, Loss: 0.6309
# Epoch   0 Batch  925/1077 - Train Accuracy: 0.5856, Validation Accuracy: 0.6090, Loss: 0.5932
# Epoch   0 Batch  930/1077 - Train Accuracy: 0.6160, Validation Accuracy: 0.5930, Loss: 0.5983
# Epoch   0 Batch  935/1077 - Train Accuracy: 0.6152, Validation Accuracy: 0.6172, Loss: 0.6201
# Epoch   0 Batch  940/1077 - Train Accuracy: 0.6004, Validation Accuracy: 0.6254, Loss: 0.5985
# Epoch   0 Batch  945/1077 - Train Accuracy: 0.6426, Validation Accuracy: 0.6165, Loss: 0.5731
# Epoch   0 Batch  950/1077 - Train Accuracy: 0.6138, Validation Accuracy: 0.6211, Loss: 0.5771
# Epoch   0 Batch  955/1077 - Train Accuracy: 0.6359, Validation Accuracy: 0.6229, Loss: 0.5981
# Epoch   0 Batch  960/1077 - Train Accuracy: 0.6057, Validation Accuracy: 0.6183, Loss: 0.5667
# Epoch   0 Batch  965/1077 - Train Accuracy: 0.5769, Validation Accuracy: 0.6172, Loss: 0.6229
# Epoch   0 Batch  970/1077 - Train Accuracy: 0.6453, Validation Accuracy: 0.6211, Loss: 0.5965
# Epoch   0 Batch  975/1077 - Train Accuracy: 0.6473, Validation Accuracy: 0.6207, Loss: 0.5481
# Epoch   0 Batch  980/1077 - Train Accuracy: 0.6258, Validation Accuracy: 0.6378, Loss: 0.5769
# Epoch   0 Batch  985/1077 - Train Accuracy: 0.6262, Validation Accuracy: 0.6332, Loss: 0.5660
# Epoch   0 Batch  990/1077 - Train Accuracy: 0.6036, Validation Accuracy: 0.6385, Loss: 0.6095
# Epoch   0 Batch  995/1077 - Train Accuracy: 0.6469, Validation Accuracy: 0.6445, Loss: 0.5581
# Epoch   0 Batch 1000/1077 - Train Accuracy: 0.6734, Validation Accuracy: 0.6303, Loss: 0.5261
# Epoch   0 Batch 1005/1077 - Train Accuracy: 0.6410, Validation Accuracy: 0.6491, Loss: 0.5644
# Epoch   0 Batch 1010/1077 - Train Accuracy: 0.6469, Validation Accuracy: 0.6424, Loss: 0.5676
# Epoch   0 Batch 1015/1077 - Train Accuracy: 0.6348, Validation Accuracy: 0.6392, Loss: 0.5876
# Epoch   0 Batch 1020/1077 - Train Accuracy: 0.6543, Validation Accuracy: 0.6431, Loss: 0.5367
# Epoch   0 Batch 1025/1077 - Train Accuracy: 0.6529, Validation Accuracy: 0.6406, Loss: 0.5402
# Epoch   0 Batch 1030/1077 - Train Accuracy: 0.6375, Validation Accuracy: 0.6435, Loss: 0.5551
# Epoch   0 Batch 1035/1077 - Train Accuracy: 0.6592, Validation Accuracy: 0.6516, Loss: 0.4953
# Epoch   0 Batch 1040/1077 - Train Accuracy: 0.6419, Validation Accuracy: 0.6491, Loss: 0.5702
# Epoch   0 Batch 1045/1077 - Train Accuracy: 0.6152, Validation Accuracy: 0.6562, Loss: 0.5557
# Epoch   0 Batch 1050/1077 - Train Accuracy: 0.5941, Validation Accuracy: 0.6708, Loss: 0.5428
# Epoch   0 Batch 1055/1077 - Train Accuracy: 0.6051, Validation Accuracy: 0.5540, Loss: 0.5547
# Epoch   0 Batch 1060/1077 - Train Accuracy: 0.6348, Validation Accuracy: 0.6190, Loss: 0.5148
# Epoch   0 Batch 1065/1077 - Train Accuracy: 0.6266, Validation Accuracy: 0.6374, Loss: 0.5517
# Epoch   0 Batch 1070/1077 - Train Accuracy: 0.6211, Validation Accuracy: 0.6463, Loss: 0.5502
# Epoch   0 Batch 1075/1077 - Train Accuracy: 0.6090, Validation Accuracy: 0.6353, Loss: 0.5718
# Epoch   1 Batch    5/1077 - Train Accuracy: 0.6426, Validation Accuracy: 0.6420, Loss: 0.5455
# Epoch   1 Batch   10/1077 - Train Accuracy: 0.6538, Validation Accuracy: 0.6626, Loss: 0.5374
# Epoch   1 Batch   15/1077 - Train Accuracy: 0.7098, Validation Accuracy: 0.6857, Loss: 0.5033
# Epoch   1 Batch   20/1077 - Train Accuracy: 0.6414, Validation Accuracy: 0.6470, Loss: 0.4980
# Epoch   1 Batch   25/1077 - Train Accuracy: 0.6707, Validation Accuracy: 0.6800, Loss: 0.4965
# Epoch   1 Batch   30/1077 - Train Accuracy: 0.6516, Validation Accuracy: 0.6683, Loss: 0.5091
# Epoch   1 Batch   35/1077 - Train Accuracy: 0.7008, Validation Accuracy: 0.6744, Loss: 0.5024
# Epoch   1 Batch   40/1077 - Train Accuracy: 0.6895, Validation Accuracy: 0.6751, Loss: 0.5048
# Epoch   1 Batch   45/1077 - Train Accuracy: 0.6660, Validation Accuracy: 0.6658, Loss: 0.5093
# Epoch   1 Batch   50/1077 - Train Accuracy: 0.6594, Validation Accuracy: 0.6665, Loss: 0.5010
# Epoch   1 Batch   55/1077 - Train Accuracy: 0.6801, Validation Accuracy: 0.6665, Loss: 0.4950
# Epoch   1 Batch   60/1077 - Train Accuracy: 0.7191, Validation Accuracy: 0.6953, Loss: 0.4823
# Epoch   1 Batch   65/1077 - Train Accuracy: 0.6493, Validation Accuracy: 0.6676, Loss: 0.5112
# Epoch   1 Batch   70/1077 - Train Accuracy: 0.6760, Validation Accuracy: 0.6726, Loss: 0.5284
# Epoch   1 Batch   75/1077 - Train Accuracy: 0.6715, Validation Accuracy: 0.6399, Loss: 0.5210
# Epoch   1 Batch   80/1077 - Train Accuracy: 0.6773, Validation Accuracy: 0.6594, Loss: 0.5114
# Epoch   1 Batch   85/1077 - Train Accuracy: 0.6828, Validation Accuracy: 0.6690, Loss: 0.4757
# Epoch   1 Batch   90/1077 - Train Accuracy: 0.6359, Validation Accuracy: 0.6701, Loss: 0.5069
# Epoch   1 Batch   95/1077 - Train Accuracy: 0.6562, Validation Accuracy: 0.6786, Loss: 0.5002
# Epoch   1 Batch  100/1077 - Train Accuracy: 0.6496, Validation Accuracy: 0.6754, Loss: 0.4951
# Epoch   1 Batch  105/1077 - Train Accuracy: 0.6789, Validation Accuracy: 0.7017, Loss: 0.4783
# Epoch   1 Batch  110/1077 - Train Accuracy: 0.7074, Validation Accuracy: 0.6971, Loss: 0.4524
# Epoch   1 Batch  115/1077 - Train Accuracy: 0.6891, Validation Accuracy: 0.6886, Loss: 0.4844
# Epoch   1 Batch  120/1077 - Train Accuracy: 0.6988, Validation Accuracy: 0.6868, Loss: 0.4843
# Epoch   1 Batch  125/1077 - Train Accuracy: 0.7102, Validation Accuracy: 0.7035, Loss: 0.4629
# Epoch   1 Batch  130/1077 - Train Accuracy: 0.6942, Validation Accuracy: 0.6896, Loss: 0.4453
# Epoch   1 Batch  135/1077 - Train Accuracy: 0.7031, Validation Accuracy: 0.6854, Loss: 0.4836
# Epoch   1 Batch  140/1077 - Train Accuracy: 0.6711, Validation Accuracy: 0.6854, Loss: 0.4727
# Epoch   1 Batch  145/1077 - Train Accuracy: 0.7168, Validation Accuracy: 0.6900, Loss: 0.4777
# Epoch   1 Batch  150/1077 - Train Accuracy: 0.7463, Validation Accuracy: 0.7013, Loss: 0.4431
# Epoch   1 Batch  155/1077 - Train Accuracy: 0.7016, Validation Accuracy: 0.6843, Loss: 0.4556
# Epoch   1 Batch  160/1077 - Train Accuracy: 0.6855, Validation Accuracy: 0.7013, Loss: 0.4476
# Epoch   1 Batch  165/1077 - Train Accuracy: 0.6770, Validation Accuracy: 0.7042, Loss: 0.4490
# Epoch   1 Batch  170/1077 - Train Accuracy: 0.6574, Validation Accuracy: 0.6999, Loss: 0.4623
# Epoch   1 Batch  175/1077 - Train Accuracy: 0.7059, Validation Accuracy: 0.6978, Loss: 0.4364
# Epoch   1 Batch  180/1077 - Train Accuracy: 0.6836, Validation Accuracy: 0.6971, Loss: 0.4341
# Epoch   1 Batch  185/1077 - Train Accuracy: 0.6898, Validation Accuracy: 0.7021, Loss: 0.4549
# Epoch   1 Batch  190/1077 - Train Accuracy: 0.7188, Validation Accuracy: 0.6896, Loss: 0.4308
# Epoch   1 Batch  195/1077 - Train Accuracy: 0.6785, Validation Accuracy: 0.6967, Loss: 0.4396
# Epoch   1 Batch  200/1077 - Train Accuracy: 0.7082, Validation Accuracy: 0.7074, Loss: 0.4578
# Epoch   1 Batch  205/1077 - Train Accuracy: 0.6973, Validation Accuracy: 0.6921, Loss: 0.4251
# Epoch   1 Batch  210/1077 - Train Accuracy: 0.6949, Validation Accuracy: 0.6942, Loss: 0.4214
# Epoch   1 Batch  215/1077 - Train Accuracy: 0.6914, Validation Accuracy: 0.7006, Loss: 0.4429
# Epoch   1 Batch  220/1077 - Train Accuracy: 0.6924, Validation Accuracy: 0.7060, Loss: 0.4409
# Epoch   1 Batch  225/1077 - Train Accuracy: 0.7250, Validation Accuracy: 0.7031, Loss: 0.4321
# Epoch   1 Batch  230/1077 - Train Accuracy: 0.6949, Validation Accuracy: 0.7038, Loss: 0.4199
# Epoch   1 Batch  235/1077 - Train Accuracy: 0.7083, Validation Accuracy: 0.6765, Loss: 0.3935
# Epoch   1 Batch  240/1077 - Train Accuracy: 0.7367, Validation Accuracy: 0.7088, Loss: 0.4059
# Epoch   1 Batch  245/1077 - Train Accuracy: 0.7180, Validation Accuracy: 0.7028, Loss: 0.3922
# Epoch   1 Batch  250/1077 - Train Accuracy: 0.6935, Validation Accuracy: 0.7070, Loss: 0.3919
# Epoch   1 Batch  255/1077 - Train Accuracy: 0.7312, Validation Accuracy: 0.7099, Loss: 0.4057
# Epoch   1 Batch  260/1077 - Train Accuracy: 0.7254, Validation Accuracy: 0.7184, Loss: 0.3889
# Epoch   1 Batch  265/1077 - Train Accuracy: 0.6953, Validation Accuracy: 0.7163, Loss: 0.4125
# Epoch   1 Batch  270/1077 - Train Accuracy: 0.6973, Validation Accuracy: 0.7134, Loss: 0.4231
# Epoch   1 Batch  275/1077 - Train Accuracy: 0.7106, Validation Accuracy: 0.7102, Loss: 0.3836
# Epoch   1 Batch  280/1077 - Train Accuracy: 0.7047, Validation Accuracy: 0.7223, Loss: 0.4129
# Epoch   1 Batch  285/1077 - Train Accuracy: 0.7474, Validation Accuracy: 0.7393, Loss: 0.3877
# Epoch   1 Batch  290/1077 - Train Accuracy: 0.7145, Validation Accuracy: 0.7099, Loss: 0.4235
# Epoch   1 Batch  295/1077 - Train Accuracy: 0.7290, Validation Accuracy: 0.7134, Loss: 0.4253
# Epoch   1 Batch  300/1077 - Train Accuracy: 0.7257, Validation Accuracy: 0.7276, Loss: 0.3965
# Epoch   1 Batch  305/1077 - Train Accuracy: 0.7203, Validation Accuracy: 0.7237, Loss: 0.3926
# Epoch   1 Batch  310/1077 - Train Accuracy: 0.7133, Validation Accuracy: 0.7216, Loss: 0.3993
# Epoch   1 Batch  315/1077 - Train Accuracy: 0.7533, Validation Accuracy: 0.7212, Loss: 0.3640
# Epoch   1 Batch  320/1077 - Train Accuracy: 0.7434, Validation Accuracy: 0.7166, Loss: 0.3979
# Epoch   1 Batch  325/1077 - Train Accuracy: 0.7366, Validation Accuracy: 0.7163, Loss: 0.3723
# Epoch   1 Batch  330/1077 - Train Accuracy: 0.7438, Validation Accuracy: 0.7159, Loss: 0.3854
# Epoch   1 Batch  335/1077 - Train Accuracy: 0.7254, Validation Accuracy: 0.7251, Loss: 0.3692
# Epoch   1 Batch  340/1077 - Train Accuracy: 0.7360, Validation Accuracy: 0.7347, Loss: 0.3927
# Epoch   1 Batch  345/1077 - Train Accuracy: 0.7292, Validation Accuracy: 0.7063, Loss: 0.3550
# Epoch   1 Batch  350/1077 - Train Accuracy: 0.6980, Validation Accuracy: 0.7028, Loss: 0.3845
# Epoch   1 Batch  355/1077 - Train Accuracy: 0.7340, Validation Accuracy: 0.6946, Loss: 0.3725
# Epoch   1 Batch  360/1077 - Train Accuracy: 0.7094, Validation Accuracy: 0.7333, Loss: 0.3677
# Epoch   1 Batch  365/1077 - Train Accuracy: 0.7410, Validation Accuracy: 0.7230, Loss: 0.3552
# Epoch   1 Batch  370/1077 - Train Accuracy: 0.7582, Validation Accuracy: 0.7315, Loss: 0.3497
# Epoch   1 Batch  375/1077 - Train Accuracy: 0.7585, Validation Accuracy: 0.7191, Loss: 0.3498
# Epoch   1 Batch  380/1077 - Train Accuracy: 0.7301, Validation Accuracy: 0.7330, Loss: 0.3626
# Epoch   1 Batch  385/1077 - Train Accuracy: 0.7559, Validation Accuracy: 0.7273, Loss: 0.3562
# Epoch   1 Batch  390/1077 - Train Accuracy: 0.6836, Validation Accuracy: 0.6928, Loss: 0.3764
# Epoch   1 Batch  395/1077 - Train Accuracy: 0.7247, Validation Accuracy: 0.7589, Loss: 0.3400
# Epoch   1 Batch  400/1077 - Train Accuracy: 0.7762, Validation Accuracy: 0.7475, Loss: 0.3646
# Epoch   1 Batch  405/1077 - Train Accuracy: 0.7545, Validation Accuracy: 0.7418, Loss: 0.3817
# Epoch   1 Batch  410/1077 - Train Accuracy: 0.7434, Validation Accuracy: 0.7511, Loss: 0.3626
# Epoch   1 Batch  415/1077 - Train Accuracy: 0.7102, Validation Accuracy: 0.7440, Loss: 0.3445
# Epoch   1 Batch  420/1077 - Train Accuracy: 0.7594, Validation Accuracy: 0.7322, Loss: 0.3335
# Epoch   1 Batch  425/1077 - Train Accuracy: 0.7463, Validation Accuracy: 0.7223, Loss: 0.3379
# Epoch   1 Batch  430/1077 - Train Accuracy: 0.7281, Validation Accuracy: 0.7152, Loss: 0.3338
# Epoch   1 Batch  435/1077 - Train Accuracy: 0.7812, Validation Accuracy: 0.7628, Loss: 0.3630
# Epoch   1 Batch  440/1077 - Train Accuracy: 0.7289, Validation Accuracy: 0.7557, Loss: 0.3619
# Epoch   1 Batch  445/1077 - Train Accuracy: 0.7381, Validation Accuracy: 0.7393, Loss: 0.3597
# Epoch   1 Batch  450/1077 - Train Accuracy: 0.7371, Validation Accuracy: 0.6900, Loss: 0.3354
# Epoch   1 Batch  455/1077 - Train Accuracy: 0.7688, Validation Accuracy: 0.6946, Loss: 0.3196
# Epoch   1 Batch  460/1077 - Train Accuracy: 0.7668, Validation Accuracy: 0.7354, Loss: 0.3455
# Epoch   1 Batch  465/1077 - Train Accuracy: 0.7599, Validation Accuracy: 0.7539, Loss: 0.3631
# Epoch   1 Batch  470/1077 - Train Accuracy: 0.7660, Validation Accuracy: 0.7653, Loss: 0.3542
# Epoch   1 Batch  475/1077 - Train Accuracy: 0.7785, Validation Accuracy: 0.7436, Loss: 0.3289
# Epoch   1 Batch  480/1077 - Train Accuracy: 0.7623, Validation Accuracy: 0.7472, Loss: 0.3388
# Epoch   1 Batch  485/1077 - Train Accuracy: 0.7746, Validation Accuracy: 0.7369, Loss: 0.3342
# Epoch   1 Batch  490/1077 - Train Accuracy: 0.7664, Validation Accuracy: 0.7528, Loss: 0.3308
# Epoch   1 Batch  495/1077 - Train Accuracy: 0.7715, Validation Accuracy: 0.7266, Loss: 0.3123
# Epoch   1 Batch  500/1077 - Train Accuracy: 0.7547, Validation Accuracy: 0.7099, Loss: 0.3188
# Epoch   1 Batch  505/1077 - Train Accuracy: 0.7824, Validation Accuracy: 0.7610, Loss: 0.3033
# Epoch   1 Batch  510/1077 - Train Accuracy: 0.7461, Validation Accuracy: 0.7337, Loss: 0.3110
# Epoch   1 Batch  515/1077 - Train Accuracy: 0.7289, Validation Accuracy: 0.7553, Loss: 0.3428
# Epoch   1 Batch  520/1077 - Train Accuracy: 0.7950, Validation Accuracy: 0.7560, Loss: 0.2943
# Epoch   1 Batch  525/1077 - Train Accuracy: 0.7812, Validation Accuracy: 0.7486, Loss: 0.3064
# Epoch   1 Batch  530/1077 - Train Accuracy: 0.7699, Validation Accuracy: 0.7450, Loss: 0.3114
# Epoch   1 Batch  535/1077 - Train Accuracy: 0.7875, Validation Accuracy: 0.7713, Loss: 0.3014
# Epoch   1 Batch  540/1077 - Train Accuracy: 0.7793, Validation Accuracy: 0.7457, Loss: 0.2843
# Epoch   1 Batch  545/1077 - Train Accuracy: 0.7812, Validation Accuracy: 0.7695, Loss: 0.3321
# Epoch   1 Batch  550/1077 - Train Accuracy: 0.7426, Validation Accuracy: 0.7649, Loss: 0.3235
# Epoch   1 Batch  555/1077 - Train Accuracy: 0.7703, Validation Accuracy: 0.7518, Loss: 0.3077
# Epoch   1 Batch  560/1077 - Train Accuracy: 0.7762, Validation Accuracy: 0.7511, Loss: 0.2851
# Epoch   1 Batch  565/1077 - Train Accuracy: 0.7612, Validation Accuracy: 0.7546, Loss: 0.3003
# Epoch   1 Batch  570/1077 - Train Accuracy: 0.7290, Validation Accuracy: 0.7443, Loss: 0.3192
# Epoch   1 Batch  575/1077 - Train Accuracy: 0.7932, Validation Accuracy: 0.7567, Loss: 0.2988
# Epoch   1 Batch  580/1077 - Train Accuracy: 0.8263, Validation Accuracy: 0.7674, Loss: 0.2657
# Epoch   1 Batch  585/1077 - Train Accuracy: 0.8259, Validation Accuracy: 0.7646, Loss: 0.2514
# Epoch   1 Batch  590/1077 - Train Accuracy: 0.7681, Validation Accuracy: 0.7841, Loss: 0.3021
# Epoch   1 Batch  595/1077 - Train Accuracy: 0.8094, Validation Accuracy: 0.7908, Loss: 0.2876
# Epoch   1 Batch  600/1077 - Train Accuracy: 0.8095, Validation Accuracy: 0.7809, Loss: 0.2650
# Epoch   1 Batch  605/1077 - Train Accuracy: 0.8331, Validation Accuracy: 0.7962, Loss: 0.2992
# Epoch   1 Batch  610/1077 - Train Accuracy: 0.7504, Validation Accuracy: 0.7663, Loss: 0.2911
# Epoch   1 Batch  615/1077 - Train Accuracy: 0.7887, Validation Accuracy: 0.7674, Loss: 0.2717
# Epoch   1 Batch  620/1077 - Train Accuracy: 0.7887, Validation Accuracy: 0.7624, Loss: 0.2703
# Epoch   1 Batch  625/1077 - Train Accuracy: 0.7910, Validation Accuracy: 0.7702, Loss: 0.2843
# Epoch   1 Batch  630/1077 - Train Accuracy: 0.7656, Validation Accuracy: 0.7717, Loss: 0.2975
# Epoch   1 Batch  635/1077 - Train Accuracy: 0.7500, Validation Accuracy: 0.7688, Loss: 0.3028
# Epoch   1 Batch  640/1077 - Train Accuracy: 0.7861, Validation Accuracy: 0.7905, Loss: 0.2758
# Epoch   1 Batch  645/1077 - Train Accuracy: 0.8278, Validation Accuracy: 0.7873, Loss: 0.2672
# Epoch   1 Batch  650/1077 - Train Accuracy: 0.8301, Validation Accuracy: 0.7873, Loss: 0.2783
# Epoch   1 Batch  655/1077 - Train Accuracy: 0.8129, Validation Accuracy: 0.7731, Loss: 0.2701
# Epoch   1 Batch  660/1077 - Train Accuracy: 0.7937, Validation Accuracy: 0.7670, Loss: 0.2805
# Epoch   1 Batch  665/1077 - Train Accuracy: 0.7867, Validation Accuracy: 0.7770, Loss: 0.2679
# Epoch   1 Batch  670/1077 - Train Accuracy: 0.8221, Validation Accuracy: 0.7894, Loss: 0.2521
# Epoch   1 Batch  675/1077 - Train Accuracy: 0.8028, Validation Accuracy: 0.7770, Loss: 0.2584
# Epoch   1 Batch  680/1077 - Train Accuracy: 0.7920, Validation Accuracy: 0.7667, Loss: 0.2558
# Epoch   1 Batch  685/1077 - Train Accuracy: 0.7863, Validation Accuracy: 0.7614, Loss: 0.2588
# Epoch   1 Batch  690/1077 - Train Accuracy: 0.8148, Validation Accuracy: 0.7823, Loss: 0.2554
# Epoch   1 Batch  695/1077 - Train Accuracy: 0.8410, Validation Accuracy: 0.7830, Loss: 0.2325
# Epoch   1 Batch  700/1077 - Train Accuracy: 0.8176, Validation Accuracy: 0.7766, Loss: 0.2359
# Epoch   1 Batch  705/1077 - Train Accuracy: 0.8421, Validation Accuracy: 0.7912, Loss: 0.2758
# Epoch   1 Batch  710/1077 - Train Accuracy: 0.7941, Validation Accuracy: 0.7944, Loss: 0.2377
# Epoch   1 Batch  715/1077 - Train Accuracy: 0.7922, Validation Accuracy: 0.7678, Loss: 0.2635
# Epoch   1 Batch  720/1077 - Train Accuracy: 0.8154, Validation Accuracy: 0.7823, Loss: 0.2648
# Epoch   1 Batch  725/1077 - Train Accuracy: 0.8497, Validation Accuracy: 0.7809, Loss: 0.2175
# Epoch   1 Batch  730/1077 - Train Accuracy: 0.8395, Validation Accuracy: 0.7898, Loss: 0.2483
# Epoch   1 Batch  735/1077 - Train Accuracy: 0.8215, Validation Accuracy: 0.7976, Loss: 0.2397
# Epoch   1 Batch  740/1077 - Train Accuracy: 0.8176, Validation Accuracy: 0.7788, Loss: 0.2354
# Epoch   1 Batch  745/1077 - Train Accuracy: 0.8207, Validation Accuracy: 0.8029, Loss: 0.2389
# Epoch   1 Batch  750/1077 - Train Accuracy: 0.8309, Validation Accuracy: 0.7869, Loss: 0.2307
# Epoch   1 Batch  755/1077 - Train Accuracy: 0.8488, Validation Accuracy: 0.8061, Loss: 0.2336
# Epoch   1 Batch  760/1077 - Train Accuracy: 0.8145, Validation Accuracy: 0.8157, Loss: 0.2530
# Epoch   1 Batch  765/1077 - Train Accuracy: 0.8324, Validation Accuracy: 0.8097, Loss: 0.2232
# Epoch   1 Batch  770/1077 - Train Accuracy: 0.8054, Validation Accuracy: 0.8253, Loss: 0.2187
# Epoch   1 Batch  775/1077 - Train Accuracy: 0.8332, Validation Accuracy: 0.8058, Loss: 0.2393
# Epoch   1 Batch  780/1077 - Train Accuracy: 0.8078, Validation Accuracy: 0.8107, Loss: 0.2410
# Epoch   1 Batch  785/1077 - Train Accuracy: 0.8571, Validation Accuracy: 0.8178, Loss: 0.2184
# Epoch   1 Batch  790/1077 - Train Accuracy: 0.7508, Validation Accuracy: 0.8121, Loss: 0.2463
# Epoch   1 Batch  795/1077 - Train Accuracy: 0.8398, Validation Accuracy: 0.8114, Loss: 0.2393
# Epoch   1 Batch  800/1077 - Train Accuracy: 0.7988, Validation Accuracy: 0.7905, Loss: 0.2231
# Epoch   1 Batch  805/1077 - Train Accuracy: 0.8223, Validation Accuracy: 0.7990, Loss: 0.2290
# Epoch   1 Batch  810/1077 - Train Accuracy: 0.8147, Validation Accuracy: 0.7923, Loss: 0.2053
# Epoch   1 Batch  815/1077 - Train Accuracy: 0.8652, Validation Accuracy: 0.8075, Loss: 0.2091
# Epoch   1 Batch  820/1077 - Train Accuracy: 0.8234, Validation Accuracy: 0.8107, Loss: 0.2404
# Epoch   1 Batch  825/1077 - Train Accuracy: 0.8465, Validation Accuracy: 0.8033, Loss: 0.2057
# Epoch   1 Batch  830/1077 - Train Accuracy: 0.8262, Validation Accuracy: 0.8164, Loss: 0.2147
# Epoch   1 Batch  835/1077 - Train Accuracy: 0.8523, Validation Accuracy: 0.8097, Loss: 0.2122
# Epoch   1 Batch  840/1077 - Train Accuracy: 0.8695, Validation Accuracy: 0.8171, Loss: 0.1956
# Epoch   1 Batch  845/1077 - Train Accuracy: 0.8566, Validation Accuracy: 0.7951, Loss: 0.1969
# Epoch   1 Batch  850/1077 - Train Accuracy: 0.8311, Validation Accuracy: 0.8136, Loss: 0.2367
# Epoch   1 Batch  855/1077 - Train Accuracy: 0.8238, Validation Accuracy: 0.8402, Loss: 0.2100
# Epoch   1 Batch  860/1077 - Train Accuracy: 0.8497, Validation Accuracy: 0.8576, Loss: 0.2039
# Epoch   1 Batch  865/1077 - Train Accuracy: 0.8853, Validation Accuracy: 0.8349, Loss: 0.1872
# Epoch   1 Batch  870/1077 - Train Accuracy: 0.7821, Validation Accuracy: 0.8267, Loss: 0.2259
# Epoch   1 Batch  875/1077 - Train Accuracy: 0.8473, Validation Accuracy: 0.8342, Loss: 0.2148
# Epoch   1 Batch  880/1077 - Train Accuracy: 0.8652, Validation Accuracy: 0.8292, Loss: 0.2032
# Epoch   1 Batch  885/1077 - Train Accuracy: 0.8601, Validation Accuracy: 0.8278, Loss: 0.1694
# Epoch   1 Batch  890/1077 - Train Accuracy: 0.8731, Validation Accuracy: 0.8118, Loss: 0.2031
# Epoch   1 Batch  895/1077 - Train Accuracy: 0.8430, Validation Accuracy: 0.8338, Loss: 0.2003
# Epoch   1 Batch  900/1077 - Train Accuracy: 0.8434, Validation Accuracy: 0.8295, Loss: 0.2118
# Epoch   1 Batch  905/1077 - Train Accuracy: 0.8410, Validation Accuracy: 0.8381, Loss: 0.1833
# Epoch   1 Batch  910/1077 - Train Accuracy: 0.8616, Validation Accuracy: 0.8207, Loss: 0.1990
# Epoch   1 Batch  915/1077 - Train Accuracy: 0.8368, Validation Accuracy: 0.8263, Loss: 0.2027
# Epoch   1 Batch  920/1077 - Train Accuracy: 0.8695, Validation Accuracy: 0.8263, Loss: 0.2077
# Epoch   1 Batch  925/1077 - Train Accuracy: 0.8512, Validation Accuracy: 0.8519, Loss: 0.1942
# Epoch   1 Batch  930/1077 - Train Accuracy: 0.8648, Validation Accuracy: 0.8313, Loss: 0.1861
# Epoch   1 Batch  935/1077 - Train Accuracy: 0.8660, Validation Accuracy: 0.8182, Loss: 0.1969
# Epoch   1 Batch  940/1077 - Train Accuracy: 0.8578, Validation Accuracy: 0.8072, Loss: 0.1814
# Epoch   1 Batch  945/1077 - Train Accuracy: 0.8719, Validation Accuracy: 0.8118, Loss: 0.1748
# Epoch   1 Batch  950/1077 - Train Accuracy: 0.8497, Validation Accuracy: 0.8263, Loss: 0.1762
# Epoch   1 Batch  955/1077 - Train Accuracy: 0.8125, Validation Accuracy: 0.8395, Loss: 0.1929
# Epoch   1 Batch  960/1077 - Train Accuracy: 0.8575, Validation Accuracy: 0.8356, Loss: 0.1789
# Epoch   1 Batch  965/1077 - Train Accuracy: 0.8228, Validation Accuracy: 0.8434, Loss: 0.1996
# Epoch   1 Batch  970/1077 - Train Accuracy: 0.9059, Validation Accuracy: 0.8402, Loss: 0.1900
# Epoch   1 Batch  975/1077 - Train Accuracy: 0.8609, Validation Accuracy: 0.8299, Loss: 0.1740
# Epoch   1 Batch  980/1077 - Train Accuracy: 0.8406, Validation Accuracy: 0.8377, Loss: 0.1894
# Epoch   1 Batch  985/1077 - Train Accuracy: 0.8711, Validation Accuracy: 0.8455, Loss: 0.1798
# Epoch   1 Batch  990/1077 - Train Accuracy: 0.8549, Validation Accuracy: 0.8555, Loss: 0.1825
# Epoch   1 Batch  995/1077 - Train Accuracy: 0.8612, Validation Accuracy: 0.8526, Loss: 0.1771
# Epoch   1 Batch 1000/1077 - Train Accuracy: 0.8638, Validation Accuracy: 0.8438, Loss: 0.1597
# Epoch   1 Batch 1005/1077 - Train Accuracy: 0.8574, Validation Accuracy: 0.8452, Loss: 0.1772
# Epoch   1 Batch 1010/1077 - Train Accuracy: 0.9000, Validation Accuracy: 0.8647, Loss: 0.1730
# Epoch   1 Batch 1015/1077 - Train Accuracy: 0.8555, Validation Accuracy: 0.8388, Loss: 0.1980
# Epoch   1 Batch 1020/1077 - Train Accuracy: 0.8855, Validation Accuracy: 0.8569, Loss: 0.1593
# Epoch   1 Batch 1025/1077 - Train Accuracy: 0.8545, Validation Accuracy: 0.8661, Loss: 0.1676
# Epoch   1 Batch 1030/1077 - Train Accuracy: 0.8555, Validation Accuracy: 0.8537, Loss: 0.1762
# Epoch   1 Batch 1035/1077 - Train Accuracy: 0.9126, Validation Accuracy: 0.8409, Loss: 0.1465
# Epoch   1 Batch 1040/1077 - Train Accuracy: 0.8647, Validation Accuracy: 0.8523, Loss: 0.1767
# Epoch   1 Batch 1045/1077 - Train Accuracy: 0.8520, Validation Accuracy: 0.8530, Loss: 0.1697
# Epoch   1 Batch 1050/1077 - Train Accuracy: 0.8336, Validation Accuracy: 0.8530, Loss: 0.1632
# Epoch   1 Batch 1055/1077 - Train Accuracy: 0.8602, Validation Accuracy: 0.8448, Loss: 0.1809
# Epoch   1 Batch 1060/1077 - Train Accuracy: 0.8672, Validation Accuracy: 0.8540, Loss: 0.1550
# Epoch   1 Batch 1065/1077 - Train Accuracy: 0.8477, Validation Accuracy: 0.8473, Loss: 0.1664
# Epoch   1 Batch 1070/1077 - Train Accuracy: 0.8266, Validation Accuracy: 0.8164, Loss: 0.1605
# Epoch   1 Batch 1075/1077 - Train Accuracy: 0.8553, Validation Accuracy: 0.8523, Loss: 0.1825
# Epoch   2 Batch    5/1077 - Train Accuracy: 0.8742, Validation Accuracy: 0.8789, Loss: 0.1797
# Epoch   2 Batch   10/1077 - Train Accuracy: 0.8914, Validation Accuracy: 0.8587, Loss: 0.1648
# Epoch   2 Batch   15/1077 - Train Accuracy: 0.9059, Validation Accuracy: 0.8633, Loss: 0.1550
# Epoch   2 Batch   20/1077 - Train Accuracy: 0.8617, Validation Accuracy: 0.8473, Loss: 0.1376
# Epoch   2 Batch   25/1077 - Train Accuracy: 0.8805, Validation Accuracy: 0.8736, Loss: 0.1394
# Epoch   2 Batch   30/1077 - Train Accuracy: 0.8824, Validation Accuracy: 0.8533, Loss: 0.1497
# Epoch   2 Batch   35/1077 - Train Accuracy: 0.8840, Validation Accuracy: 0.8565, Loss: 0.1430
# Epoch   2 Batch   40/1077 - Train Accuracy: 0.9020, Validation Accuracy: 0.8629, Loss: 0.1471
# Epoch   2 Batch   45/1077 - Train Accuracy: 0.8363, Validation Accuracy: 0.8516, Loss: 0.1570
# Epoch   2 Batch   50/1077 - Train Accuracy: 0.8977, Validation Accuracy: 0.8750, Loss: 0.1419
# Epoch   2 Batch   55/1077 - Train Accuracy: 0.8441, Validation Accuracy: 0.8697, Loss: 0.1450
# Epoch   2 Batch   60/1077 - Train Accuracy: 0.8783, Validation Accuracy: 0.8626, Loss: 0.1408
# Epoch   2 Batch   65/1077 - Train Accuracy: 0.8668, Validation Accuracy: 0.8725, Loss: 0.1437
# Epoch   2 Batch   70/1077 - Train Accuracy: 0.8664, Validation Accuracy: 0.8739, Loss: 0.1508
# Epoch   2 Batch   75/1077 - Train Accuracy: 0.8797, Validation Accuracy: 0.8835, Loss: 0.1679
# Epoch   2 Batch   80/1077 - Train Accuracy: 0.8941, Validation Accuracy: 0.8722, Loss: 0.1365
# Epoch   2 Batch   85/1077 - Train Accuracy: 0.8816, Validation Accuracy: 0.8931, Loss: 0.1367
# Epoch   2 Batch   90/1077 - Train Accuracy: 0.8617, Validation Accuracy: 0.8725, Loss: 0.1552
# Epoch   2 Batch   95/1077 - Train Accuracy: 0.8951, Validation Accuracy: 0.8977, Loss: 0.1541
# Epoch   2 Batch  100/1077 - Train Accuracy: 0.9047, Validation Accuracy: 0.8860, Loss: 0.1326
# Epoch   2 Batch  105/1077 - Train Accuracy: 0.8617, Validation Accuracy: 0.8700, Loss: 0.1407
# Epoch   2 Batch  110/1077 - Train Accuracy: 0.9051, Validation Accuracy: 0.8910, Loss: 0.1163
# Epoch   2 Batch  115/1077 - Train Accuracy: 0.8699, Validation Accuracy: 0.8764, Loss: 0.1489
# Epoch   2 Batch  120/1077 - Train Accuracy: 0.9055, Validation Accuracy: 0.8938, Loss: 0.1522
# Epoch   2 Batch  125/1077 - Train Accuracy: 0.8802, Validation Accuracy: 0.8778, Loss: 0.1409
# Epoch   2 Batch  130/1077 - Train Accuracy: 0.8828, Validation Accuracy: 0.8587, Loss: 0.1242
# Epoch   2 Batch  135/1077 - Train Accuracy: 0.8614, Validation Accuracy: 0.8860, Loss: 0.1482
# Epoch   2 Batch  140/1077 - Train Accuracy: 0.8787, Validation Accuracy: 0.8800, Loss: 0.1342
# Epoch   2 Batch  145/1077 - Train Accuracy: 0.9027, Validation Accuracy: 0.8981, Loss: 0.1381
# Epoch   2 Batch  150/1077 - Train Accuracy: 0.8862, Validation Accuracy: 0.8768, Loss: 0.1305
# Epoch   2 Batch  155/1077 - Train Accuracy: 0.9125, Validation Accuracy: 0.8842, Loss: 0.1362
# Epoch   2 Batch  160/1077 - Train Accuracy: 0.8824, Validation Accuracy: 0.8881, Loss: 0.1295
# Epoch   2 Batch  165/1077 - Train Accuracy: 0.8633, Validation Accuracy: 0.8807, Loss: 0.1265
# Epoch   2 Batch  170/1077 - Train Accuracy: 0.8703, Validation Accuracy: 0.8881, Loss: 0.1354
# Epoch   2 Batch  175/1077 - Train Accuracy: 0.9059, Validation Accuracy: 0.8828, Loss: 0.1300
# Epoch   2 Batch  180/1077 - Train Accuracy: 0.8688, Validation Accuracy: 0.8817, Loss: 0.1183
# Epoch   2 Batch  185/1077 - Train Accuracy: 0.8812, Validation Accuracy: 0.8832, Loss: 0.1284
# Epoch   2 Batch  190/1077 - Train Accuracy: 0.9129, Validation Accuracy: 0.8789, Loss: 0.1089
# Epoch   2 Batch  195/1077 - Train Accuracy: 0.8969, Validation Accuracy: 0.8800, Loss: 0.1126
# Epoch   2 Batch  200/1077 - Train Accuracy: 0.8469, Validation Accuracy: 0.8892, Loss: 0.1331
# Epoch   2 Batch  205/1077 - Train Accuracy: 0.8984, Validation Accuracy: 0.8888, Loss: 0.1302
# Epoch   2 Batch  210/1077 - Train Accuracy: 0.8728, Validation Accuracy: 0.8867, Loss: 0.1284
# Epoch   2 Batch  215/1077 - Train Accuracy: 0.8367, Validation Accuracy: 0.8725, Loss: 0.1262
# Epoch   2 Batch  220/1077 - Train Accuracy: 0.8947, Validation Accuracy: 0.8839, Loss: 0.1176
# Epoch   2 Batch  225/1077 - Train Accuracy: 0.9113, Validation Accuracy: 0.8945, Loss: 0.1293
# Epoch   2 Batch  230/1077 - Train Accuracy: 0.9144, Validation Accuracy: 0.8835, Loss: 0.1118
# Epoch   2 Batch  235/1077 - Train Accuracy: 0.8776, Validation Accuracy: 0.8810, Loss: 0.1111
# Epoch   2 Batch  240/1077 - Train Accuracy: 0.9406, Validation Accuracy: 0.8722, Loss: 0.1039
# Epoch   2 Batch  245/1077 - Train Accuracy: 0.9215, Validation Accuracy: 0.9031, Loss: 0.0996
# Epoch   2 Batch  250/1077 - Train Accuracy: 0.8871, Validation Accuracy: 0.8945, Loss: 0.1025
# Epoch   2 Batch  255/1077 - Train Accuracy: 0.9027, Validation Accuracy: 0.9023, Loss: 0.1183
# Epoch   2 Batch  260/1077 - Train Accuracy: 0.8850, Validation Accuracy: 0.8878, Loss: 0.1033
# Epoch   2 Batch  265/1077 - Train Accuracy: 0.8492, Validation Accuracy: 0.8920, Loss: 0.1146
# Epoch   2 Batch  270/1077 - Train Accuracy: 0.8695, Validation Accuracy: 0.9034, Loss: 0.1230
# Epoch   2 Batch  275/1077 - Train Accuracy: 0.9048, Validation Accuracy: 0.8924, Loss: 0.1158
# Epoch   2 Batch  280/1077 - Train Accuracy: 0.8625, Validation Accuracy: 0.8960, Loss: 0.1215
# Epoch   2 Batch  285/1077 - Train Accuracy: 0.8929, Validation Accuracy: 0.8956, Loss: 0.1172
# Epoch   2 Batch  290/1077 - Train Accuracy: 0.8832, Validation Accuracy: 0.8967, Loss: 0.1312
# Epoch   2 Batch  295/1077 - Train Accuracy: 0.9005, Validation Accuracy: 0.8878, Loss: 0.1243
# Epoch   2 Batch  300/1077 - Train Accuracy: 0.9132, Validation Accuracy: 0.9105, Loss: 0.1010
# Epoch   2 Batch  305/1077 - Train Accuracy: 0.9023, Validation Accuracy: 0.8913, Loss: 0.1087
# Epoch   2 Batch  310/1077 - Train Accuracy: 0.8816, Validation Accuracy: 0.8974, Loss: 0.1127
# Epoch   2 Batch  315/1077 - Train Accuracy: 0.9312, Validation Accuracy: 0.9034, Loss: 0.1009
# Epoch   2 Batch  320/1077 - Train Accuracy: 0.9109, Validation Accuracy: 0.8960, Loss: 0.1122
# Epoch   2 Batch  325/1077 - Train Accuracy: 0.8798, Validation Accuracy: 0.8764, Loss: 0.1053
# Epoch   2 Batch  330/1077 - Train Accuracy: 0.8895, Validation Accuracy: 0.8803, Loss: 0.1050
# Epoch   2 Batch  335/1077 - Train Accuracy: 0.9237, Validation Accuracy: 0.8643, Loss: 0.0987
# Epoch   2 Batch  340/1077 - Train Accuracy: 0.8956, Validation Accuracy: 0.8867, Loss: 0.0991
# Epoch   2 Batch  345/1077 - Train Accuracy: 0.8910, Validation Accuracy: 0.8931, Loss: 0.0990
# Epoch   2 Batch  350/1077 - Train Accuracy: 0.8957, Validation Accuracy: 0.8956, Loss: 0.1057
# Epoch   2 Batch  355/1077 - Train Accuracy: 0.8798, Validation Accuracy: 0.8828, Loss: 0.1099
# Epoch   2 Batch  360/1077 - Train Accuracy: 0.9020, Validation Accuracy: 0.9119, Loss: 0.0961
# Epoch   2 Batch  365/1077 - Train Accuracy: 0.9242, Validation Accuracy: 0.9045, Loss: 0.0895
# Epoch   2 Batch  370/1077 - Train Accuracy: 0.9040, Validation Accuracy: 0.8878, Loss: 0.0992
# Epoch   2 Batch  375/1077 - Train Accuracy: 0.9350, Validation Accuracy: 0.9009, Loss: 0.0944
# Epoch   2 Batch  380/1077 - Train Accuracy: 0.9070, Validation Accuracy: 0.8981, Loss: 0.0891
# Epoch   2 Batch  385/1077 - Train Accuracy: 0.8918, Validation Accuracy: 0.8935, Loss: 0.0865
# Epoch   2 Batch  390/1077 - Train Accuracy: 0.8777, Validation Accuracy: 0.9027, Loss: 0.1132
# Epoch   2 Batch  395/1077 - Train Accuracy: 0.9096, Validation Accuracy: 0.9055, Loss: 0.1018
# Epoch   2 Batch  400/1077 - Train Accuracy: 0.9094, Validation Accuracy: 0.8888, Loss: 0.1031
# ...
# Epoch   6 Batch  235/1077 - Train Accuracy: 0.9598, Validation Accuracy: 0.9620, Loss: 0.0208
# Epoch   6 Batch  240/1077 - Train Accuracy: 0.9836, Validation Accuracy: 0.9691, Loss: 0.0136
# Epoch   6 Batch  245/1077 - Train Accuracy: 0.9635, Validation Accuracy: 0.9723, Loss: 0.0168
# Epoch   6 Batch  250/1077 - Train Accuracy: 0.9506, Validation Accuracy: 0.9748, Loss: 0.0194
# Epoch   6 Batch  255/1077 - Train Accuracy: 0.9766, Validation Accuracy: 0.9698, Loss: 0.0144
# Epoch   6 Batch  260/1077 - Train Accuracy: 0.9661, Validation Accuracy: 0.9688, Loss: 0.0154
# Epoch   6 Batch  265/1077 - Train Accuracy: 0.9633, Validation Accuracy: 0.9688, Loss: 0.0194
# Epoch   6 Batch  270/1077 - Train Accuracy: 0.9535, Validation Accuracy: 0.9645, Loss: 0.0226
# Epoch   6 Batch  275/1077 - Train Accuracy: 0.9892, Validation Accuracy: 0.9673, Loss: 0.0160
# Epoch   6 Batch  280/1077 - Train Accuracy: 0.9551, Validation Accuracy: 0.9666, Loss: 0.0216
# Epoch   6 Batch  285/1077 - Train Accuracy: 0.9721, Validation Accuracy: 0.9766, Loss: 0.0185
# Epoch   6 Batch  290/1077 - Train Accuracy: 0.9727, Validation Accuracy: 0.9680, Loss: 0.0292
# Epoch   6 Batch  295/1077 - Train Accuracy: 0.9741, Validation Accuracy: 0.9634, Loss: 0.0195
# Epoch   6 Batch  300/1077 - Train Accuracy: 0.9646, Validation Accuracy: 0.9833, Loss: 0.0153
# Epoch   6 Batch  305/1077 - Train Accuracy: 0.9691, Validation Accuracy: 0.9869, Loss: 0.0148
# Epoch   6 Batch  310/1077 - Train Accuracy: 0.9727, Validation Accuracy: 0.9606, Loss: 0.0210
# Epoch   6 Batch  315/1077 - Train Accuracy: 0.9810, Validation Accuracy: 0.9819, Loss: 0.0161
# Epoch   6 Batch  320/1077 - Train Accuracy: 0.9816, Validation Accuracy: 0.9741, Loss: 0.0208
# Epoch   6 Batch  325/1077 - Train Accuracy: 0.9617, Validation Accuracy: 0.9656, Loss: 0.0214
# Epoch   6 Batch  330/1077 - Train Accuracy: 0.9695, Validation Accuracy: 0.9645, Loss: 0.0199
# Epoch   6 Batch  335/1077 - Train Accuracy: 0.9829, Validation Accuracy: 0.9581, Loss: 0.0188
# Epoch   6 Batch  340/1077 - Train Accuracy: 0.9877, Validation Accuracy: 0.9719, Loss: 0.0177
# Epoch   6 Batch  345/1077 - Train Accuracy: 0.9810, Validation Accuracy: 0.9585, Loss: 0.0151
# Epoch   6 Batch  350/1077 - Train Accuracy: 0.9746, Validation Accuracy: 0.9524, Loss: 0.0160
# Epoch   6 Batch  355/1077 - Train Accuracy: 0.9613, Validation Accuracy: 0.9652, Loss: 0.0160
# Epoch   6 Batch  360/1077 - Train Accuracy: 0.9820, Validation Accuracy: 0.9609, Loss: 0.0118
# Epoch   6 Batch  365/1077 - Train Accuracy: 0.9734, Validation Accuracy: 0.9656, Loss: 0.0157
# Epoch   6 Batch  370/1077 - Train Accuracy: 0.9684, Validation Accuracy: 0.9666, Loss: 0.0201
# Epoch   6 Batch  375/1077 - Train Accuracy: 0.9798, Validation Accuracy: 0.9670, Loss: 0.0181
# Epoch   6 Batch  380/1077 - Train Accuracy: 0.9867, Validation Accuracy: 0.9744, Loss: 0.0151
# Epoch   6 Batch  385/1077 - Train Accuracy: 0.9707, Validation Accuracy: 0.9684, Loss: 0.0157
# Epoch   6 Batch  390/1077 - Train Accuracy: 0.9465, Validation Accuracy: 0.9833, Loss: 0.0271
# Epoch   6 Batch  395/1077 - Train Accuracy: 0.9803, Validation Accuracy: 0.9737, Loss: 0.0168
# Epoch   6 Batch  400/1077 - Train Accuracy: 0.9680, Validation Accuracy: 0.9542, Loss: 0.0227
# Epoch   6 Batch  405/1077 - Train Accuracy: 0.9597, Validation Accuracy: 0.9652, Loss: 0.0220
# Epoch   6 Batch  410/1077 - Train Accuracy: 0.9576, Validation Accuracy: 0.9641, Loss: 0.0299
# Epoch   6 Batch  415/1077 - Train Accuracy: 0.9773, Validation Accuracy: 0.9759, Loss: 0.0224
# Epoch   6 Batch  420/1077 - Train Accuracy: 0.9844, Validation Accuracy: 0.9755, Loss: 0.0134
# Epoch   6 Batch  425/1077 - Train Accuracy: 0.9818, Validation Accuracy: 0.9553, Loss: 0.0132
# Epoch   6 Batch  430/1077 - Train Accuracy: 0.9699, Validation Accuracy: 0.9567, Loss: 0.0155
# Epoch   6 Batch  435/1077 - Train Accuracy: 0.9864, Validation Accuracy: 0.9592, Loss: 0.0247
# Epoch   6 Batch  440/1077 - Train Accuracy: 0.9680, Validation Accuracy: 0.9538, Loss: 0.0192
# Epoch   6 Batch  445/1077 - Train Accuracy: 0.9823, Validation Accuracy: 0.9609, Loss: 0.0165
# Epoch   6 Batch  450/1077 - Train Accuracy: 0.9676, Validation Accuracy: 0.9585, Loss: 0.0222
# Epoch   6 Batch  455/1077 - Train Accuracy: 0.9631, Validation Accuracy: 0.9741, Loss: 0.0220
# Epoch   6 Batch  460/1077 - Train Accuracy: 0.9688, Validation Accuracy: 0.9673, Loss: 0.0201
# Epoch   6 Batch  465/1077 - Train Accuracy: 0.9593, Validation Accuracy: 0.9631, Loss: 0.0206
# Epoch   6 Batch  470/1077 - Train Accuracy: 0.9741, Validation Accuracy: 0.9680, Loss: 0.0175
# Epoch   6 Batch  475/1077 - Train Accuracy: 0.9625, Validation Accuracy: 0.9748, Loss: 0.0168
# Epoch   6 Batch  480/1077 - Train Accuracy: 0.9626, Validation Accuracy: 0.9570, Loss: 0.0180
# Epoch   6 Batch  485/1077 - Train Accuracy: 0.9770, Validation Accuracy: 0.9634, Loss: 0.0190
# Epoch   6 Batch  490/1077 - Train Accuracy: 0.9730, Validation Accuracy: 0.9627, Loss: 0.0194
# Epoch   6 Batch  495/1077 - Train Accuracy: 0.9504, Validation Accuracy: 0.9570, Loss: 0.0164
# Epoch   6 Batch  500/1077 - Train Accuracy: 0.9699, Validation Accuracy: 0.9606, Loss: 0.0129
# Epoch   6 Batch  505/1077 - Train Accuracy: 0.9773, Validation Accuracy: 0.9645, Loss: 0.0123
# Epoch   6 Batch  510/1077 - Train Accuracy: 0.9699, Validation Accuracy: 0.9656, Loss: 0.0171
# Epoch   6 Batch  515/1077 - Train Accuracy: 0.9750, Validation Accuracy: 0.9748, Loss: 0.0163
# Epoch   6 Batch  520/1077 - Train Accuracy: 0.9810, Validation Accuracy: 0.9624, Loss: 0.0126
# Epoch   6 Batch  525/1077 - Train Accuracy: 0.9637, Validation Accuracy: 0.9702, Loss: 0.0242
# Epoch   6 Batch  530/1077 - Train Accuracy: 0.9781, Validation Accuracy: 0.9705, Loss: 0.0254
# Epoch   6 Batch  535/1077 - Train Accuracy: 0.9648, Validation Accuracy: 0.9563, Loss: 0.0180
# Epoch   6 Batch  540/1077 - Train Accuracy: 0.9734, Validation Accuracy: 0.9659, Loss: 0.0152
# Epoch   6 Batch  545/1077 - Train Accuracy: 0.9809, Validation Accuracy: 0.9652, Loss: 0.0185
# Epoch   6 Batch  550/1077 - Train Accuracy: 0.9641, Validation Accuracy: 0.9521, Loss: 0.0151
# Epoch   6 Batch  555/1077 - Train Accuracy: 0.9910, Validation Accuracy: 0.9624, Loss: 0.0120
# Epoch   6 Batch  560/1077 - Train Accuracy: 0.9477, Validation Accuracy: 0.9723, Loss: 0.0199
# Epoch   6 Batch  565/1077 - Train Accuracy: 0.9781, Validation Accuracy: 0.9723, Loss: 0.0188
# Epoch   6 Batch  570/1077 - Train Accuracy: 0.9449, Validation Accuracy: 0.9542, Loss: 0.0215
# Epoch   6 Batch  575/1077 - Train Accuracy: 0.9795, Validation Accuracy: 0.9531, Loss: 0.0128
# Epoch   6 Batch  580/1077 - Train Accuracy: 0.9769, Validation Accuracy: 0.9638, Loss: 0.0153
# Epoch   6 Batch  585/1077 - Train Accuracy: 0.9892, Validation Accuracy: 0.9709, Loss: 0.0122
# Epoch   6 Batch  590/1077 - Train Accuracy: 0.9712, Validation Accuracy: 0.9677, Loss: 0.0180
# Epoch   6 Batch  595/1077 - Train Accuracy: 0.9906, Validation Accuracy: 0.9542, Loss: 0.0138
# Epoch   6 Batch  600/1077 - Train Accuracy: 0.9714, Validation Accuracy: 0.9673, Loss: 0.0215
# Epoch   6 Batch  605/1077 - Train Accuracy: 0.9741, Validation Accuracy: 0.9645, Loss: 0.0257
# Epoch   6 Batch  610/1077 - Train Accuracy: 0.9568, Validation Accuracy: 0.9663, Loss: 0.0205
# Epoch   6 Batch  615/1077 - Train Accuracy: 0.9699, Validation Accuracy: 0.9645, Loss: 0.0121
# Epoch   6 Batch  620/1077 - Train Accuracy: 0.9863, Validation Accuracy: 0.9695, Loss: 0.0124
# Epoch   6 Batch  625/1077 - Train Accuracy: 0.9730, Validation Accuracy: 0.9762, Loss: 0.0156
# Epoch   6 Batch  630/1077 - Train Accuracy: 0.9816, Validation Accuracy: 0.9602, Loss: 0.0177
# Epoch   6 Batch  635/1077 - Train Accuracy: 0.9671, Validation Accuracy: 0.9659, Loss: 0.0213
# Epoch   6 Batch  640/1077 - Train Accuracy: 0.9699, Validation Accuracy: 0.9833, Loss: 0.0189
# Epoch   6 Batch  645/1077 - Train Accuracy: 0.9717, Validation Accuracy: 0.9723, Loss: 0.0193
# Epoch   6 Batch  650/1077 - Train Accuracy: 0.9785, Validation Accuracy: 0.9695, Loss: 0.0182
# Epoch   6 Batch  655/1077 - Train Accuracy: 0.9773, Validation Accuracy: 0.9705, Loss: 0.0198
# Epoch   6 Batch  660/1077 - Train Accuracy: 0.9875, Validation Accuracy: 0.9641, Loss: 0.0155
# Epoch   6 Batch  665/1077 - Train Accuracy: 0.9789, Validation Accuracy: 0.9652, Loss: 0.0131
# Epoch   6 Batch  670/1077 - Train Accuracy: 0.9798, Validation Accuracy: 0.9716, Loss: 0.0158
# Epoch   6 Batch  675/1077 - Train Accuracy: 0.9717, Validation Accuracy: 0.9560, Loss: 0.0208
# Epoch   6 Batch  680/1077 - Train Accuracy: 0.9621, Validation Accuracy: 0.9574, Loss: 0.0170
# Epoch   6 Batch  685/1077 - Train Accuracy: 0.9559, Validation Accuracy: 0.9737, Loss: 0.0218
# Epoch   6 Batch  690/1077 - Train Accuracy: 0.9684, Validation Accuracy: 0.9673, Loss: 0.0172
# Epoch   6 Batch  695/1077 - Train Accuracy: 0.9793, Validation Accuracy: 0.9606, Loss: 0.0175
# Epoch   6 Batch  700/1077 - Train Accuracy: 0.9777, Validation Accuracy: 0.9719, Loss: 0.0147
# Epoch   6 Batch  705/1077 - Train Accuracy: 0.9609, Validation Accuracy: 0.9773, Loss: 0.0261
# Epoch   6 Batch  710/1077 - Train Accuracy: 0.9836, Validation Accuracy: 0.9723, Loss: 0.0113
# Epoch   6 Batch  715/1077 - Train Accuracy: 0.9578, Validation Accuracy: 0.9545, Loss: 0.0214
# Epoch   6 Batch  720/1077 - Train Accuracy: 0.9860, Validation Accuracy: 0.9666, Loss: 0.0190
# Epoch   6 Batch  725/1077 - Train Accuracy: 0.9795, Validation Accuracy: 0.9677, Loss: 0.0133
# Epoch   6 Batch  730/1077 - Train Accuracy: 0.9770, Validation Accuracy: 0.9624, Loss: 0.0220
# Epoch   6 Batch  735/1077 - Train Accuracy: 0.9789, Validation Accuracy: 0.9588, Loss: 0.0147
# Epoch   6 Batch  740/1077 - Train Accuracy: 0.9750, Validation Accuracy: 0.9567, Loss: 0.0144
# Epoch   6 Batch  745/1077 - Train Accuracy: 0.9719, Validation Accuracy: 0.9627, Loss: 0.0186
# Epoch   6 Batch  750/1077 - Train Accuracy: 0.9742, Validation Accuracy: 0.9695, Loss: 0.0165
# Epoch   6 Batch  755/1077 - Train Accuracy: 0.9793, Validation Accuracy: 0.9592, Loss: 0.0221
# Epoch   6 Batch  760/1077 - Train Accuracy: 0.9781, Validation Accuracy: 0.9592, Loss: 0.0167
# Epoch   6 Batch  765/1077 - Train Accuracy: 0.9641, Validation Accuracy: 0.9759, Loss: 0.0214
# Epoch   6 Batch  770/1077 - Train Accuracy: 0.9721, Validation Accuracy: 0.9585, Loss: 0.0195
# Epoch   6 Batch  775/1077 - Train Accuracy: 0.9441, Validation Accuracy: 0.9606, Loss: 0.0166
# Epoch   6 Batch  780/1077 - Train Accuracy: 0.9520, Validation Accuracy: 0.9673, Loss: 0.0241
# Epoch   6 Batch  785/1077 - Train Accuracy: 0.9807, Validation Accuracy: 0.9698, Loss: 0.0126
# Epoch   6 Batch  790/1077 - Train Accuracy: 0.9582, Validation Accuracy: 0.9755, Loss: 0.0198
# Epoch   6 Batch  795/1077 - Train Accuracy: 0.9504, Validation Accuracy: 0.9631, Loss: 0.0194
# Epoch   6 Batch  800/1077 - Train Accuracy: 0.9645, Validation Accuracy: 0.9766, Loss: 0.0165
# Epoch   6 Batch  805/1077 - Train Accuracy: 0.9715, Validation Accuracy: 0.9624, Loss: 0.0161
# Epoch   6 Batch  810/1077 - Train Accuracy: 0.9773, Validation Accuracy: 0.9705, Loss: 0.0148
# Epoch   6 Batch  815/1077 - Train Accuracy: 0.9652, Validation Accuracy: 0.9766, Loss: 0.0217
# Epoch   6 Batch  820/1077 - Train Accuracy: 0.9871, Validation Accuracy: 0.9719, Loss: 0.0153
# Epoch   6 Batch  825/1077 - Train Accuracy: 0.9922, Validation Accuracy: 0.9695, Loss: 0.0086
# Epoch   6 Batch  830/1077 - Train Accuracy: 0.9520, Validation Accuracy: 0.9684, Loss: 0.0182
# Epoch   6 Batch  835/1077 - Train Accuracy: 0.9793, Validation Accuracy: 0.9659, Loss: 0.0177
# Epoch   6 Batch  840/1077 - Train Accuracy: 0.9770, Validation Accuracy: 0.9560, Loss: 0.0192
# Epoch   6 Batch  845/1077 - Train Accuracy: 0.9703, Validation Accuracy: 0.9808, Loss: 0.0126
# Epoch   6 Batch  850/1077 - Train Accuracy: 0.9572, Validation Accuracy: 0.9766, Loss: 0.0332
# Epoch   6 Batch  855/1077 - Train Accuracy: 0.9738, Validation Accuracy: 0.9815, Loss: 0.0148
# Epoch   6 Batch  860/1077 - Train Accuracy: 0.9702, Validation Accuracy: 0.9862, Loss: 0.0236
# Epoch   6 Batch  865/1077 - Train Accuracy: 0.9759, Validation Accuracy: 0.9549, Loss: 0.0185
# Epoch   6 Batch  870/1077 - Train Accuracy: 0.9646, Validation Accuracy: 0.9361, Loss: 0.0166
# Epoch   6 Batch  875/1077 - Train Accuracy: 0.9859, Validation Accuracy: 0.9432, Loss: 0.0192
# Epoch   6 Batch  880/1077 - Train Accuracy: 0.9664, Validation Accuracy: 0.9677, Loss: 0.0253
# Epoch   6 Batch  885/1077 - Train Accuracy: 0.9759, Validation Accuracy: 0.9616, Loss: 0.0141
# Epoch   6 Batch  890/1077 - Train Accuracy: 0.9706, Validation Accuracy: 0.9727, Loss: 0.0193
# Epoch   6 Batch  895/1077 - Train Accuracy: 0.9730, Validation Accuracy: 0.9627, Loss: 0.0158
# Epoch   6 Batch  900/1077 - Train Accuracy: 0.9742, Validation Accuracy: 0.9677, Loss: 0.0219
# Epoch   6 Batch  905/1077 - Train Accuracy: 0.9770, Validation Accuracy: 0.9670, Loss: 0.0168
# Epoch   6 Batch  910/1077 - Train Accuracy: 0.9557, Validation Accuracy: 0.9769, Loss: 0.0183
# Epoch   6 Batch  915/1077 - Train Accuracy: 0.9741, Validation Accuracy: 0.9627, Loss: 0.0142
# Epoch   6 Batch  920/1077 - Train Accuracy: 0.9859, Validation Accuracy: 0.9677, Loss: 0.0138
# Epoch   6 Batch  925/1077 - Train Accuracy: 0.9792, Validation Accuracy: 0.9677, Loss: 0.0146
# Epoch   6 Batch  930/1077 - Train Accuracy: 0.9734, Validation Accuracy: 0.9666, Loss: 0.0144
# Epoch   6 Batch  935/1077 - Train Accuracy: 0.9910, Validation Accuracy: 0.9677, Loss: 0.0120
# Epoch   6 Batch  940/1077 - Train Accuracy: 0.9703, Validation Accuracy: 0.9684, Loss: 0.0156
# Epoch   6 Batch  945/1077 - Train Accuracy: 0.9914, Validation Accuracy: 0.9766, Loss: 0.0119
# Epoch   6 Batch  950/1077 - Train Accuracy: 0.9792, Validation Accuracy: 0.9659, Loss: 0.0141
# Epoch   6 Batch  955/1077 - Train Accuracy: 0.9723, Validation Accuracy: 0.9755, Loss: 0.0185
# Epoch   6 Batch  960/1077 - Train Accuracy: 0.9691, Validation Accuracy: 0.9741, Loss: 0.0159
# Epoch   6 Batch  965/1077 - Train Accuracy: 0.9622, Validation Accuracy: 0.9730, Loss: 0.0205
# Epoch   6 Batch  970/1077 - Train Accuracy: 0.9750, Validation Accuracy: 0.9641, Loss: 0.0186
# Epoch   6 Batch  975/1077 - Train Accuracy: 0.9914, Validation Accuracy: 0.9766, Loss: 0.0136
# Epoch   6 Batch  980/1077 - Train Accuracy: 0.9703, Validation Accuracy: 0.9751, Loss: 0.0183
# Epoch   6 Batch  985/1077 - Train Accuracy: 0.9852, Validation Accuracy: 0.9652, Loss: 0.0122
# Epoch   6 Batch  990/1077 - Train Accuracy: 0.9762, Validation Accuracy: 0.9684, Loss: 0.0162
# Epoch   6 Batch  995/1077 - Train Accuracy: 0.9740, Validation Accuracy: 0.9766, Loss: 0.0180
# Epoch   6 Batch 1000/1077 - Train Accuracy: 0.9691, Validation Accuracy: 0.9563, Loss: 0.0166
# Epoch   6 Batch 1005/1077 - Train Accuracy: 0.9660, Validation Accuracy: 0.9478, Loss: 0.0159
# Epoch   6 Batch 1010/1077 - Train Accuracy: 0.9883, Validation Accuracy: 0.9656, Loss: 0.0133
# Epoch   6 Batch 1015/1077 - Train Accuracy: 0.9789, Validation Accuracy: 0.9798, Loss: 0.0193
# Epoch   6 Batch 1020/1077 - Train Accuracy: 0.9836, Validation Accuracy: 0.9677, Loss: 0.0142
# Epoch   6 Batch 1025/1077 - Train Accuracy: 0.9688, Validation Accuracy: 0.9755, Loss: 0.0170
# Epoch   6 Batch 1030/1077 - Train Accuracy: 0.9773, Validation Accuracy: 0.9691, Loss: 0.0162
# Epoch   6 Batch 1035/1077 - Train Accuracy: 0.9829, Validation Accuracy: 0.9819, Loss: 0.0110
# Epoch   6 Batch 1040/1077 - Train Accuracy: 0.9601, Validation Accuracy: 0.9759, Loss: 0.0175
# Epoch   6 Batch 1045/1077 - Train Accuracy: 0.9727, Validation Accuracy: 0.9716, Loss: 0.0144
# Epoch   6 Batch 1050/1077 - Train Accuracy: 0.9840, Validation Accuracy: 0.9613, Loss: 0.0105
# Epoch   6 Batch 1055/1077 - Train Accuracy: 0.9781, Validation Accuracy: 0.9648, Loss: 0.0183
# Epoch   6 Batch 1060/1077 - Train Accuracy: 0.9746, Validation Accuracy: 0.9702, Loss: 0.0163
# Epoch   6 Batch 1065/1077 - Train Accuracy: 0.9609, Validation Accuracy: 0.9670, Loss: 0.0136
# Epoch   6 Batch 1070/1077 - Train Accuracy: 0.9719, Validation Accuracy: 0.9670, Loss: 0.0149
# Epoch   6 Batch 1075/1077 - Train Accuracy: 0.9490, Validation Accuracy: 0.9631, Loss: 0.0228
# Model Trained and Saved

# %% [markdown]
# ### Save Parameters
# Save the `batch_size` and `save_path` parameters for inference.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# Save parameters for checkpoint
helper.save_params(save_path)

# %% [markdown]
# # Checkpoint

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import tensorflow as tf
import numpy as np
import helper
import problem_unittests as tests

_, (source_vocab_to_int, target_vocab_to_int), (source_int_to_vocab, target_int_to_vocab) = helper.load_preprocess()
load_path = helper.load_params()

# %% [markdown]
# ## Sentence to Sequence
# To feed a sentence into the model for translation, you first need to preprocess it.  Implement the function `sentence_to_seq()` to preprocess new sentences.
#
# - Convert the sentence to lowercase
# - Convert words into ids using `vocab_to_int`
#  - Convert words not in the vocabulary, to the `<UNK>` word id.

# %%
def sentence_to_seq(sentence, vocab_to_int):
    """
    Convert a sentence to a sequence of ids
    :param sentence: String
    :param vocab_to_int: Dictionary to go from the words to an id
    :return: List of word ids
    """
    # TODO: Implement Function
    word_list = []
    
    for word in sentence.lower().split():
        #print (word)
        if word in vocab_to_int.keys():
            word_list.append(vocab_to_int[word])
        else:
            word_list.append(vocab_to_int['<UNK>'])
    
    #print (word_list)
    return word_list


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_sentence_to_seq(sentence_to_seq)
# Out:
# Tests Passed

# %% [markdown]
# ## Translate
# This will translate `translate_sentence` from English to French.

# %%
translate_sentence = 'he saw a old yellow truck .'


"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
translate_sentence = sentence_to_seq(translate_sentence, source_vocab_to_int)

loaded_graph = tf.Graph()
with tf.Session(graph=loaded_graph) as sess:
    # Load saved model
    loader = tf.train.import_meta_graph(load_path + '.meta')
    loader.restore(sess, load_path)

    input_data = loaded_graph.get_tensor_by_name('input:0')
    logits = loaded_graph.get_tensor_by_name('predictions:0')
    target_sequence_length = loaded_graph.get_tensor_by_name('target_sequence_length:0')
    source_sequence_length = loaded_graph.get_tensor_by_name('source_sequence_length:0')
    keep_prob = loaded_graph.get_tensor_by_name('keep_prob:0')

    translate_logits = sess.run(logits, {input_data: [translate_sentence]*batch_size,
                                         target_sequence_length: [len(translate_sentence)*2]*batch_size,
                                         source_sequence_length: [len(translate_sentence)]*batch_size,
                                         keep_prob: 1.0})[0]

print('Input')
print('  Word Ids:      {}'.format([i for i in translate_sentence]))
print('  English Words: {}'.format([source_int_to_vocab[i] for i in translate_sentence]))

print('\nPrediction')
print('  Word Ids:      {}'.format([i for i in translate_logits]))
print('  French Words: {}'.format(" ".join([target_int_to_vocab[i] for i in translate_logits])))
# Out:
# INFO:tensorflow:Restoring parameters from checkpoints/dev
# Input
#   Word Ids:      [113, 148, 200, 187, 70, 204, 47]
#   English Words: ['he', 'saw', 'a', 'old', 'yellow', 'truck', '.']
#
# Prediction
#   Word Ids:      [256, 263, 91, 176, 307, 106, 186, 1]
#   French Words: il est pluvieux au plus noir . <EOS>

# %% [markdown]
# ## Imperfect Translation
# You might notice that some sentences translate better than others.  Since the dataset you're using only has a vocabulary of 227 English words of the thousands that you use, you're only going to see good results using these words.  For this project, you don't need a perfect translation. However, if you want to create a better translation model, you'll need better data.
#
# You can train on the [WMT10 French-English corpus](http://www.statmt.org/wmt10/training-giga-fren.tar).  This dataset has more vocabulary and richer in topics discussed.  However, this will take you days to train, so make sure you've a GPU and the neural network is performing well on dataset we provided.  Just make sure you play with the WMT10 corpus after you've submitted this project.
# ## Submitting This Project
# When submitting this project, make sure to run all the cells before saving the notebook. Save the notebook file as "dlnd_language_translation.ipynb" and save it as a HTML file under "File" -> "Download as". Include the "helper.py" and "problem_unittests.py" files in your submission.
