# %% [markdown]
# # Language Translation
# In this project, you’re going to take a peek into the realm of neural network machine translation.  You’ll be training a sequence to sequence model on a dataset of English and French sentences that can translate new sentences from English to French.
# ## Get the Data
# Since translating the whole language of English to French will take lots of time to train, we have provided you with a small portion of the English corpus.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import helper
import problem_unittests as tests

source_path = 'data/small_vocab_en'
target_path = 'data/small_vocab_fr'
source_text = helper.load_data(source_path)
target_text = helper.load_data(target_path)

# %% [markdown]
# ## Explore the Data
# Play around with view_sentence_range to view different parts of the data.

# %%
view_sentence_range = (0, 10)

"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import numpy as np

print('Dataset Stats')
print('Roughly the number of unique words: {}'.format(len({word: None for word in source_text.split()})))

sentences = source_text.split('\n')
word_counts = [len(sentence.split()) for sentence in sentences]
print('Number of sentences: {}'.format(len(sentences)))
print('Average number of words in a sentence: {}'.format(np.average(word_counts)))

print()
print('English sentences {} to {}:'.format(*view_sentence_range))
print('\n'.join(source_text.split('\n')[view_sentence_range[0]:view_sentence_range[1]]))
print()
print('French sentences {} to {}:'.format(*view_sentence_range))
print('\n'.join(target_text.split('\n')[view_sentence_range[0]:view_sentence_range[1]]))
# Out:
# Dataset Stats
# Roughly the number of unique words: 227
# Number of sentences: 137861
# Average number of words in a sentence: 13.225277634719028
#
# English sentences 0 to 10:
# new jersey is sometimes quiet during autumn , and it is snowy in april .
# the united states is usually chilly during july , and it is usually freezing in november .
# california is usually quiet during march , and it is usually hot in june .
# the united states is sometimes mild during june , and it is cold in september .
# your least liked fruit is the grape , but my least liked is the apple .
# his favorite fruit is the orange , but my favorite is the grape .
# paris is relaxing during december , but it is usually chilly in july .
# new jersey is busy during spring , and it is never hot in march .
# our least liked fruit is the lemon , but my least liked is the grape .
# the united states is sometimes busy during january , and it is sometimes warm in november .
#
# French sentences 0 to 10:
# new jersey est parfois calme pendant l' automne , et il est neigeux en avril .
# les états-unis est généralement froid en juillet , et il gèle habituellement en novembre .
# california est généralement calme en mars , et il est généralement chaud en juin .
# les états-unis est parfois légère en juin , et il fait froid en septembre .
# votre moins aimé fruit est le raisin , mais mon moins aimé est la pomme .
# son fruit préféré est l'orange , mais mon préféré est le raisin .
# paris est relaxant en décembre , mais il est généralement froid en juillet .
# new jersey est occupé au printemps , et il est jamais chaude en mars .
# notre fruit est moins aimé le citron , mais mon moins aimé est le raisin .
# les états-unis est parfois occupé en janvier , et il est parfois chaud en novembre .

# %% [markdown]
# ## Implement Preprocessing Function
# ### Text to Word Ids
# As you did with other RNNs, you must turn the text into a number so the computer can understand it. In the function `text_to_ids()`, you'll turn `source_text` and `target_text` from words to ids.  However, you need to add the `<EOS>` word id at the end of `target_text`.  This will help the neural network predict when the sentence should end.
#
# You can get the `<EOS>` word id by doing:
# ```python
# target_vocab_to_int['<EOS>']
# ```
# You can get other word ids using `source_vocab_to_int` and `target_vocab_to_int`.

# %%
def text_to_ids(source_text, target_text, source_vocab_to_int, target_vocab_to_int):
    """
    Convert source and target text to proper word ids
    :param source_text: String that contains all the source text.
    :param target_text: String that contains all the target text.
    :param source_vocab_to_int: Dictionary to go from the source words to an id
    :param target_vocab_to_int: Dictionary to go from the target words to an id
    :return: A tuple of lists (source_id_text, target_id_text)
    """
    # TODO: Implement Function

    source_id_text = [[source_vocab_to_int[word] for word in n.split()] for n in source_text.split("\n")]
    target_id_text = [[target_vocab_to_int[word] for word in n.split()]+[target_vocab_to_int['<EOS>']] for n in target_text.split("\n")]
    return source_id_text, target_id_text
    
"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_text_to_ids(text_to_ids)
# Out:
# Tests Passed

# %% [markdown]
# ### Preprocess all the data and save it
# Running the code cell below will preprocess all the data and save it to file.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
helper.preprocess_and_save_data(source_path, target_path, text_to_ids)

# %% [markdown]
# # Check Point
# This is your first checkpoint. If you ever decide to come back to this notebook or have to restart the notebook, you can start from here. The preprocessed data has been saved to disk.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import numpy as np
import helper
import problem_unittests as tests

(source_int_text, target_int_text), (source_vocab_to_int, target_vocab_to_int), _ = helper.load_preprocess()

# %% [markdown]
# ### Check the Version of TensorFlow and Access to GPU
# This will check to make sure you have the correct version of TensorFlow and access to a GPU

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
from distutils.version import LooseVersion
import warnings
import tensorflow as tf
from tensorflow.python.layers.core import Dense

# Check TensorFlow Version
assert LooseVersion(tf.__version__) >= LooseVersion('1.1'), 'Please use TensorFlow version 1.1 or newer'
print('TensorFlow Version: {}'.format(tf.__version__))

# Check for a GPU
if not tf.test.gpu_device_name():
    warnings.warn('No GPU found. Please use a GPU to train your neural network.')
else:
    print('Default GPU Device: {}'.format(tf.test.gpu_device_name()))
# Out:
# TensorFlow Version: 1.1.0
# Default GPU Device: /gpu:0

# %% [markdown]
# ## Build the Neural Network
# You'll build the components necessary to build a Sequence-to-Sequence model by implementing the following functions below:
# - `model_inputs`
# - `process_decoder_input`
# - `encoding_layer`
# - `decoding_layer_train`
# - `decoding_layer_infer`
# - `decoding_layer`
# - `seq2seq_model`
#
# ### Input
# Implement the `model_inputs()` function to create TF Placeholders for the Neural Network. It should create the following placeholders:
#
# - Input text placeholder named "input" using the TF Placeholder name parameter with rank 2.
# - Targets placeholder with rank 2.
# - Learning rate placeholder with rank 0.
# - Keep probability placeholder named "keep_prob" using the TF Placeholder name parameter with rank 0.
# - Target sequence length placeholder named "target_sequence_length" with rank 1
# - Max target sequence length tensor named "max_target_len" getting its value from applying tf.reduce_max on the target_sequence_length placeholder. Rank 0.
# - Source sequence length placeholder named "source_sequence_length" with rank 1
#
# Return the placeholders in the following the tuple (input, targets, learning rate, keep probability, target sequence length, max target sequence length, source sequence length)

# %%
def model_inputs():
    """
    Create TF Placeholders for input, targets, learning rate, and lengths of source and target sequences.
    :return: Tuple (input, targets, learning rate, keep probability, target sequence length,
    max target sequence length, source sequence length)
    """
    # TODO: Implement Function
    Input = tf.placeholder(tf.int32, shape=[None,None],name='input')
    targets = tf.placeholder(tf.int32, shape=[None,None],name='Targets')
    learning_rate = tf.placeholder(tf.float32, name="LearningRate")
    keep_prob = tf.placeholder(tf.float32, name="keep_prob")
    target_seq_length = tf.placeholder(tf.int32, (None,),name="target_sequence_length")
    max_target_seq_length = tf.reduce_max(target_seq_length,name="max_target_len")
    source_seq_length = tf.placeholder(tf.int32, (None,), name="source_sequence_length")
    return (Input, targets, learning_rate, keep_prob, target_seq_length, max_target_seq_length, source_seq_length)

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_model_inputs(model_inputs)
# Out:
# Tests Passed

# %% [markdown]
# ### Process Decoder Input
# Implement `process_decoder_input` by removing the last word id from each batch in `target_data` and concat the GO ID to the begining of each batch.

# %%
def process_decoder_input(target_data, target_vocab_to_int, batch_size):
    """
    Preprocess target data for encoding
    :param target_data: Target Placehoder
    :param target_vocab_to_int: Dictionary to go from the target words to an id
    :param batch_size: Batch Size
    :return: Preprocessed target data
    """
    # TODO: Implement Function
    ending = tf.strided_slice(target_data, [0, 0], [batch_size, -1], [1, 1])
    dec_input = tf.concat([tf.fill([batch_size, 1], target_vocab_to_int['<GO>']), ending], 1)
   
    return dec_input

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_process_encoding_input(process_decoder_input)
# Out:
# Tests Passed

# %% [markdown]
# ### Encoding
# Implement `encoding_layer()` to create a Encoder RNN layer:
#  * Embed the encoder input using [`tf.contrib.layers.embed_sequence`](https://www.tensorflow.org/api_docs/python/tf/contrib/layers/embed_sequence)
#  * Construct a [stacked](https://github.com/tensorflow/tensorflow/blob/6947f65a374ebf29e74bb71e36fd82760056d82c/tensorflow/docs_src/tutorials/recurrent.md#stacking-multiple-lstms) [`tf.contrib.rnn.LSTMCell`](https://www.tensorflow.org/api_docs/python/tf/contrib/rnn/LSTMCell) wrapped in a [`tf.contrib.rnn.DropoutWrapper`](https://www.tensorflow.org/api_docs/python/tf/contrib/rnn/DropoutWrapper)
#  * Pass cell and embedded input to [`tf.nn.dynamic_rnn()`](https://www.tensorflow.org/api_docs/python/tf/nn/dynamic_rnn)

# %%
from imp import reload
reload(tests)

def encoding_layer(rnn_inputs, rnn_size, num_layers, keep_prob, 
                   source_sequence_length, source_vocab_size, 
                   encoding_embedding_size):
    """
    Create encoding layer
    :param rnn_inputs: Inputs for the RNN
    :param rnn_size: RNN Size
    :param num_layers: Number of layers
    :param keep_prob: Dropout keep probability
    :param source_sequence_length: a list of the lengths of each sequence in the batch
    :param source_vocab_size: vocabulary size of source data
    :param encoding_embedding_size: embedding size of source data
    :return: tuple (RNN output, RNN state)
    """
    # TODO: Implement Function
    inputs =tf.contrib.layers.embed_sequence(rnn_inputs,source_vocab_size,encoding_embedding_size)
    cell = tf.contrib.rnn.BasicLSTMCell(rnn_size)
    dropout = tf.contrib.rnn.DropoutWrapper(cell,output_keep_prob=keep_prob)
    cell = tf.contrib.rnn.MultiRNNCell([tf.contrib.rnn.BasicLSTMCell(rnn_size) for _ in range(num_layers)])
    output, state = tf.nn.dynamic_rnn(cell,inputs,dtype=tf.float32)
    return output, state

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_encoding_layer(encoding_layer)
# Out:
# Tests Passed

# %% [markdown]
# ### Decoding - Training
# Create a training decoding layer:
# * Create a [`tf.contrib.seq2seq.TrainingHelper`](https://www.tensorflow.org/api_docs/python/tf/contrib/seq2seq/TrainingHelper)
# * Create a [`tf.contrib.seq2seq.BasicDecoder`](https://www.tensorflow.org/api_docs/python/tf/contrib/seq2seq/BasicDecoder)
# * Obtain the decoder outputs from [`tf.contrib.seq2seq.dynamic_decode`](https://www.tensorflow.org/api_docs/python/tf/contrib/seq2seq/dynamic_decode)

# %%
def decoding_layer_train(encoder_state, dec_cell, dec_embed_input, 
                         target_sequence_length, max_summary_length, 
                         output_layer, keep_prob):
    """
    Create a decoding layer for training
    :param encoder_state: Encoder State
    :param dec_cell: Decoder RNN Cell
    :param dec_embed_input: Decoder embedded input
    :param target_sequence_length: The lengths of each sequence in the target batch
    :param max_summary_length: The length of the longest sequence in the batch
    :param output_layer: Function to apply the output layer
    :param keep_prob: Dropout keep probability
    :return: BasicDecoderOutput containing training logits and sample_id
    """
    # TODO: Implement Function
    training_helper = tf.contrib.seq2seq.TrainingHelper(dec_embed_input, target_sequence_length)
    training_decoder = tf.contrib.seq2seq.BasicDecoder(dec_cell, training_helper, encoder_state, output_layer)
    training_decoder_output = tf.contrib.seq2seq.dynamic_decode(training_decoder, impute_finished=True, maximum_iterations=max_summary_length)[0]
    
    return training_decoder_output




"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_decoding_layer_train(decoding_layer_train)
# Out:
# Tests Passed

# %% [markdown]
# ### Decoding - Inference
# Create inference decoder:
# * Create a [`tf.contrib.seq2seq.GreedyEmbeddingHelper`](https://www.tensorflow.org/api_docs/python/tf/contrib/seq2seq/GreedyEmbeddingHelper)
# * Create a [`tf.contrib.seq2seq.BasicDecoder`](https://www.tensorflow.org/api_docs/python/tf/contrib/seq2seq/BasicDecoder)
# * Obtain the decoder outputs from [`tf.contrib.seq2seq.dynamic_decode`](https://www.tensorflow.org/api_docs/python/tf/contrib/seq2seq/dynamic_decode)

# %%
def decoding_layer_infer(encoder_state, dec_cell, dec_embeddings, start_of_sequence_id,
                         end_of_sequence_id, max_target_sequence_length,
                         vocab_size, output_layer, batch_size, keep_prob):
    """
    Create a decoding layer for inference
    :param encoder_state: Encoder state
    :param dec_cell: Decoder RNN Cell
    :param dec_embeddings: Decoder embeddings
    :param start_of_sequence_id: GO ID
    :param end_of_sequence_id: EOS Id
    :param max_target_sequence_length: Maximum length of target sequences
    :param vocab_size: Size of decoder/target vocabulary
    :param decoding_scope: TenorFlow Variable Scope for decoding
    :param output_layer: Function to apply the output layer
    :param batch_size: Batch size
    :param keep_prob: Dropout keep probability
    :return: BasicDecoderOutput containing inference logits and sample_id
    """
    # TODO: Implement Function
    #with tf.variable_scope("decoding", reuse=None) as decoding_scope:
        # Inference Decoder
    #    infer_decoder_fn = tf.contrib.seq2seq.simple_decoder_fn_inference(
    #        output_fn, encoder_state, dec_embeddings, start_of_sequence_id, end_of_sequence_id,
    #        maximum_length, vocab_size, dtype=tf.int32)
    #    inference_logits, _, _ = tf.contrib.seq2seq.dynamic_rnn_decoder(dec_cell, infer_decoder_fn, scope=decoding_scope)
    #    inference_logits_with_dropout = tf.nn.dropout(inference_logits, keep_prob)
    #return inference_logits_with_dropout


        
    start_tokens = tf.tile(tf.constant([start_of_sequence_id], dtype=tf.int32), [batch_size], name='start_tokens')
        
    # Helper for the inference process.
    inference_helper = tf.contrib.seq2seq.GreedyEmbeddingHelper(dec_embeddings,
                                                                start_tokens,
                                                                end_of_sequence_id)

    # Basic decoder
    inference_decoder = tf.contrib.seq2seq.BasicDecoder(dec_cell,
                                                        inference_helper,
                                                        encoder_state,
                                                        output_layer)
        
    # Perform dynamic decoding using the decoder
    inference_decoder_output, _ = tf.contrib.seq2seq.dynamic_decode(inference_decoder,
                                                                    impute_finished=True,
                                                                    maximum_iterations=max_target_sequence_length)
    
    
    #infer_decoder_fn = tf.contrib.seq2seq.simple_decoder_fn_inference(
    #output_fn, encoder_state, dec_embeddings, start_of_sequence_id, end_of_sequence_id, maximum_length, vocab_size)
    #inference_logits = tf.contrib.seq2seq.dynamicrnn_decoder(dec_cell, infer_decoder_fn, scope=decoding_scope)
    return inference_decoder_output



"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_decoding_layer_infer(decoding_layer_infer)
# Out:
# Tests Passed

# %% [markdown]
# ### Build the Decoding Layer
# Implement `decoding_layer()` to create a Decoder RNN layer.
#
# * Embed the target sequences
# * Construct the decoder LSTM cell (just like you constructed the encoder cell above)
# * Create an output layer to map the outputs of the decoder to the elements of our vocabulary
# * Use the your `decoding_layer_train(encoder_state, dec_cell, dec_embed_input, target_sequence_length, max_target_sequence_length, output_layer, keep_prob)` function to get the training logits.
# * Use your `decoding_layer_infer(encoder_state, dec_cell, dec_embeddings, start_of_sequence_id, end_of_sequence_id, max_target_sequence_length, vocab_size, output_layer, batch_size, keep_prob)` function to get the inference logits.
#
# Note: You'll need to use [tf.variable_scope](https://www.tensorflow.org/api_docs/python/tf/variable_scope) to share variables between training and inference.

# %%
def decoding_layer(dec_input, encoder_state,
               target_sequence_length, max_target_sequence_length,
               rnn_size,
               num_layers, target_vocab_to_int, target_vocab_size,
               batch_size, keep_prob, decoding_embedding_size):
    """
    Create decoding layer
    :param dec_input: Decoder input
    :param encoder_state: Encoder state
    :param target_sequence_length: The lengths of each sequence in the target batch
    :param max_target_sequence_length: Maximum length of target sequences
    :param rnn_size: RNN Size
    :param num_layers: Number of layers
    :param target_vocab_to_int: Dictionary to go from the target words to an id
    :param target_vocab_size: Size of target vocabulary
    :param batch_size: The size of the batch
    :param keep_prob: Dropout keep probability
    :param decoding_embedding_size: Decoding embedding size
    :return: Tuple of (Training BasicDecoderOutput, Inference BasicDecoderOutput)
    """
    # TODO: Implement Function
    #return None, None

    # Decoder embedding
    #target_vocab_size = len(target_vocab_to_int)
    dec_embeddings = tf.Variable(tf.random_uniform([target_vocab_size, decoding_embedding_size]))
    dec_embed_input = tf.nn.embedding_lookup(dec_embeddings, dec_input)  

    # Create decoder cell
    def make_cell(rnn_size):
        dec_cell = tf.contrib.rnn.LSTMCell(rnn_size, \
                                           initializer=tf.random_uniform_initializer(-0.1, 0.1, seed=2))
        return dec_cell
    dec_cell = tf.contrib.rnn.MultiRNNCell([make_cell(rnn_size) for _ in range(num_layers)])   

    # Create Dense layer to translate decoder's output at each time
    output_layer = Dense(target_vocab_size, \
                         kernel_initializer = tf.truncated_normal_initializer(mean=0.0, stddev=0.1))   

    # Training decoder
    with tf.variable_scope("decode") as decoding_scope:

        #output_layer = Dense(target_vocab_size, \
        #                 kernel_initializer = tf.truncated_normal_initializer(mean=0.0, stddev=0.1))

        training_decoder_output = decoding_layer_train(encoder_state, dec_cell, dec_embed_input, 
                         target_sequence_length, max_target_sequence_length, 
                         output_layer, keep_prob)
        
        

    # Inference decoder
    with tf.variable_scope("decode", reuse=True) as decoding_scope:
        start_of_sequence_id = target_vocab_to_int['<GO>']
        end_of_sequence_id = target_vocab_to_int['<EOS>']

        inference_decoder_output = decoding_layer_infer(encoder_state, dec_cell, dec_embeddings, start_of_sequence_id,
                             end_of_sequence_id, max_target_sequence_length,
                             target_vocab_size, output_layer, batch_size, keep_prob)
        
        

    return training_decoder_output, inference_decoder_output

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_decoding_layer(decoding_layer)
# Out:
# Tests Passed

# %% [markdown]
# ### Build the Neural Network
# Apply the functions you implemented above to:
#
# - Encode the input using your `encoding_layer(rnn_inputs, rnn_size, num_layers, keep_prob,  source_sequence_length, source_vocab_size, encoding_embedding_size)`.
# - Process target data using your `process_decoder_input(target_data, target_vocab_to_int, batch_size)` function.
# - Decode the encoded input using your `decoding_layer(dec_input, enc_state, target_sequence_length, max_target_sentence_length, rnn_size, num_layers, target_vocab_to_int, target_vocab_size, batch_size, keep_prob, dec_embedding_size)` function.

# %%
def seq2seq_model(input_data, target_data, keep_prob, batch_size,
                  source_sequence_length, target_sequence_length,
                  max_target_sentence_length,
                  source_vocab_size, target_vocab_size,
                  enc_embedding_size, dec_embedding_size,
                  rnn_size, num_layers, target_vocab_to_int):
    """
    Build the Sequence-to-Sequence part of the neural network
    :param input_data: Input placeholder
    :param target_data: Target placeholder
    :param keep_prob: Dropout keep probability placeholder
    :param batch_size: Batch Size
    :param source_sequence_length: Sequence Lengths of source sequences in the batch
    :param target_sequence_length: Sequence Lengths of target sequences in the batch
    :param source_vocab_size: Source vocabulary size
    :param target_vocab_size: Target vocabulary size
    :param enc_embedding_size: Decoder embedding size
    :param dec_embedding_size: Encoder embedding size
    :param rnn_size: RNN Size
    :param num_layers: Number of layers
    :param target_vocab_to_int: Dictionary to go from the target words to an id
    :return: Tuple of (Training BasicDecoderOutput, Inference BasicDecoderOutput)
    """
    
    # Pass the input data through the encoder. We'll ignore the encoder output, but use the state
    encoder_output, encoder_state = encoding_layer(input_data, rnn_size, num_layers, keep_prob, 
                                                   source_sequence_length, source_vocab_size, enc_embedding_size)
    
    processed_input = process_decoder_input(target_data, target_vocab_to_int, batch_size)
    
    max_target_sequence_length = tf.reduce_max(target_sequence_length)
    output_train, output_inference = decoding_layer(processed_input, encoder_state, 
                                                    target_sequence_length, max_target_sequence_length, 
                                                    rnn_size, num_layers, target_vocab_to_int, 
                                                    target_vocab_size, batch_size, keep_prob, dec_embedding_size)
    
    return output_train, output_inference
"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_seq2seq_model(seq2seq_model)
# Out:
# Tests Passed

# %% [markdown]
# ## Neural Network Training
# ### Hyperparameters
# Tune the following parameters:
#
# - Set `epochs` to the number of epochs.
# - Set `batch_size` to the batch size.
# - Set `rnn_size` to the size of the RNNs.
# - Set `num_layers` to the number of layers.
# - Set `encoding_embedding_size` to the size of the embedding for the encoder.
# - Set `decoding_embedding_size` to the size of the embedding for the decoder.
# - Set `learning_rate` to the learning rate.
# - Set `keep_probability` to the Dropout keep probability
# - Set `display_step` to state how many steps between each debug output statement

# %%
# Number of Epochs
epochs = 3
# Batch Size
batch_size = 128
# RNN Size
rnn_size = 50
# Number of Layers
num_layers = 2
# Embedding Size
encoding_embedding_size = 15
decoding_embedding_size = 15
# Learning Rate
learning_rate = 0.1
# Dropout Keep Probability
keep_probability = 0.65
display_step = 5

# %% [markdown]
# ### Build the Graph
# Build the graph using the neural network you implemented.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
save_path = 'checkpoints/dev'
(source_int_text, target_int_text), (source_vocab_to_int, target_vocab_to_int), _ = helper.load_preprocess()
max_target_sentence_length = max([len(sentence) for sentence in source_int_text])

train_graph = tf.Graph()
with train_graph.as_default():
    input_data, targets, lr, keep_prob, target_sequence_length, max_target_sequence_length, source_sequence_length = model_inputs()

    #sequence_length = tf.placeholder_with_default(max_target_sentence_length, None, name='sequence_length')
    input_shape = tf.shape(input_data)

    train_logits, inference_logits = seq2seq_model(tf.reverse(input_data, [-1]),
                                                   targets,
                                                   keep_prob,
                                                   batch_size,
                                                   source_sequence_length,
                                                   target_sequence_length,
                                                   max_target_sequence_length,
                                                   len(source_vocab_to_int),
                                                   len(target_vocab_to_int),
                                                   encoding_embedding_size,
                                                   decoding_embedding_size,
                                                   rnn_size,
                                                   num_layers,
                                                   target_vocab_to_int)


    training_logits = tf.identity(train_logits.rnn_output, name='logits')
    inference_logits = tf.identity(inference_logits.sample_id, name='predictions')

    masks = tf.sequence_mask(target_sequence_length, max_target_sequence_length, dtype=tf.float32, name='masks')

    with tf.name_scope("optimization"):
        # Loss function
        cost = tf.contrib.seq2seq.sequence_loss(
            training_logits,
            targets,
            masks)

        # Optimizer
        optimizer = tf.train.AdamOptimizer(lr)

        # Gradient Clipping
        gradients = optimizer.compute_gradients(cost)
        capped_gradients = [(tf.clip_by_value(grad, -1., 1.), var) for grad, var in gradients if grad is not None]
        train_op = optimizer.apply_gradients(capped_gradients)

# %% [markdown]
# Batch and pad the source and target sequences

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
def pad_sentence_batch(sentence_batch, pad_int):
    """Pad sentences with <PAD> so that each sentence of a batch has the same length"""
    max_sentence = max([len(sentence) for sentence in sentence_batch])
    return [sentence + [pad_int] * (max_sentence - len(sentence)) for sentence in sentence_batch]


def get_batches(sources, targets, batch_size, source_pad_int, target_pad_int):
    """Batch targets, sources, and the lengths of their sentences together"""
    for batch_i in range(0, len(sources)//batch_size):
        start_i = batch_i * batch_size

        # Slice the right amount for the batch
        sources_batch = sources[start_i:start_i + batch_size]
        targets_batch = targets[start_i:start_i + batch_size]

        # Pad
        pad_sources_batch = np.array(pad_sentence_batch(sources_batch, source_pad_int))
        pad_targets_batch = np.array(pad_sentence_batch(targets_batch, target_pad_int))

        # Need the lengths for the _lengths parameters
        pad_targets_lengths = []
        for target in pad_targets_batch:
            pad_targets_lengths.append(len(target))

        pad_source_lengths = []
        for source in pad_sources_batch:
            pad_source_lengths.append(len(source))

        yield pad_sources_batch, pad_targets_batch, pad_source_lengths, pad_targets_lengths

# %% [markdown]
# ### Train
# Train the neural network on the preprocessed data. If you have a hard time getting a good loss, check the forms to see if anyone is having the same problem.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
def get_accuracy(target, logits):
    """
    Calculate accuracy
    """
    max_seq = max(target.shape[1], logits.shape[1])
    if max_seq - target.shape[1]:
        target = np.pad(
            target,
            [(0,0),(0,max_seq - target.shape[1])],
            'constant')
    if max_seq - logits.shape[1]:
        logits = np.pad(
            logits,
            [(0,0),(0,max_seq - logits.shape[1])],
            'constant')

    return np.mean(np.equal(target, logits))

# Split data to training and validation sets
train_source = source_int_text[batch_size:]
train_target = target_int_text[batch_size:]
valid_source = source_int_text[:batch_size]
valid_target = target_int_text[:batch_size]
(valid_sources_batch, valid_targets_batch, valid_sources_lengths, valid_targets_lengths ) = next(get_batches(valid_source,
                                                                                                             valid_target,
                                                                                                             batch_size,
                                                                                                             source_vocab_to_int['<PAD>'],
                                                                                                             target_vocab_to_int['<PAD>']))                                                                                                  
with tf.Session(graph=train_graph) as sess:
    sess.run(tf.global_variables_initializer())

    for epoch_i in range(epochs):
        for batch_i, (source_batch, target_batch, sources_lengths, targets_lengths) in enumerate(
                get_batches(train_source, train_target, batch_size,
                            source_vocab_to_int['<PAD>'],
                            target_vocab_to_int['<PAD>'])):

            _, loss = sess.run(
                [train_op, cost],
                {input_data: source_batch,
                 targets: target_batch,
                 lr: learning_rate,
                 target_sequence_length: targets_lengths,
                 source_sequence_length: sources_lengths,
                 keep_prob: keep_probability})


            if batch_i % display_step == 0 and batch_i > 0:


                batch_train_logits = sess.run(
                    inference_logits,
                    {input_data: source_batch,
                     source_sequence_length: sources_lengths,
                     target_sequence_length: targets_lengths,
                     keep_prob: 1.0})


                batch_valid_logits = sess.run(
                    inference_logits,
                    {input_data: valid_sources_batch,
                     source_sequence_length: valid_sources_lengths,
                     target_sequence_length: valid_targets_lengths,
                     keep_prob: 1.0})

                train_acc = get_accuracy(target_batch, batch_train_logits)

                valid_acc = get_accuracy(valid_targets_batch, batch_valid_logits)

                print('Epoch {:>3} Batch {:>4}/{} - Train Accuracy: {:>6.4f}, Validation Accuracy: {:>6.4f}, Loss: {:>6.4f}'
                      .format(epoch_i, batch_i, len(source_int_text) // batch_size, train_acc, valid_acc, loss))

    # Save Model
    saver = tf.train.Saver()
    saver.save(sess, save_path)
    print('Model Trained and Saved')
# Out:
# Epoch   0 Batch    5/1077 - Train Accuracy: 0.2961, Validation Accuracy: 0.3366, Loss: 3.9087
# Epoch   0 Batch   10/1077 - Train Accuracy: 0.2541, Validation Accuracy: 0.3484, Loss: 3.5053
# Epoch   0 Batch   15/1077 - Train Accuracy: 0.3172, Validation Accuracy: 0.3764, Loss: 3.0830
# Epoch   0 Batch   20/1077 - Train Accuracy: 0.3391, Validation Accuracy: 0.3878, Loss: 2.8422
# Epoch   0 Batch   25/1077 - Train Accuracy: 0.3453, Validation Accuracy: 0.4052, Loss: 2.7937
# Epoch   0 Batch   30/1077 - Train Accuracy: 0.3828, Validation Accuracy: 0.4364, Loss: 2.5436
# Epoch   0 Batch   35/1077 - Train Accuracy: 0.3898, Validation Accuracy: 0.4336, Loss: 2.4277
# Epoch   0 Batch   40/1077 - Train Accuracy: 0.4023, Validation Accuracy: 0.4553, Loss: 2.2953
# Epoch   0 Batch   45/1077 - Train Accuracy: 0.3949, Validation Accuracy: 0.4492, Loss: 2.2066
# Epoch   0 Batch   50/1077 - Train Accuracy: 0.3766, Validation Accuracy: 0.4517, Loss: 2.2018
# Epoch   0 Batch   55/1077 - Train Accuracy: 0.4590, Validation Accuracy: 0.4826, Loss: 1.9489
# Epoch   0 Batch   60/1077 - Train Accuracy: 0.4453, Validation Accuracy: 0.4769, Loss: 1.9187
# Epoch   0 Batch   65/1077 - Train Accuracy: 0.4141, Validation Accuracy: 0.4975, Loss: 1.9514
# Epoch   0 Batch   70/1077 - Train Accuracy: 0.4095, Validation Accuracy: 0.4844, Loss: 1.8776
# Epoch   0 Batch   75/1077 - Train Accuracy: 0.4402, Validation Accuracy: 0.4734, Loss: 1.6579
# Epoch   0 Batch   80/1077 - Train Accuracy: 0.4250, Validation Accuracy: 0.4769, Loss: 1.6114
# Epoch   0 Batch   85/1077 - Train Accuracy: 0.4488, Validation Accuracy: 0.4755, Loss: 1.4541
# Epoch   0 Batch   90/1077 - Train Accuracy: 0.4289, Validation Accuracy: 0.4727, Loss: 1.5333
# Epoch   0 Batch   95/1077 - Train Accuracy: 0.4847, Validation Accuracy: 0.4883, Loss: 1.3518
# Epoch   0 Batch  100/1077 - Train Accuracy: 0.4773, Validation Accuracy: 0.5032, Loss: 1.2514
# Epoch   0 Batch  105/1077 - Train Accuracy: 0.4926, Validation Accuracy: 0.4936, Loss: 1.1596
# Epoch   0 Batch  110/1077 - Train Accuracy: 0.5066, Validation Accuracy: 0.5302, Loss: 1.0679
# Epoch   0 Batch  115/1077 - Train Accuracy: 0.4570, Validation Accuracy: 0.5039, Loss: 1.1257
# Epoch   0 Batch  120/1077 - Train Accuracy: 0.4668, Validation Accuracy: 0.5305, Loss: 1.0861
# Epoch   0 Batch  125/1077 - Train Accuracy: 0.5045, Validation Accuracy: 0.5192, Loss: 0.9822
# Epoch   0 Batch  130/1077 - Train Accuracy: 0.5167, Validation Accuracy: 0.5249, Loss: 0.9051
# Epoch   0 Batch  135/1077 - Train Accuracy: 0.4774, Validation Accuracy: 0.5011, Loss: 0.9704
# Epoch   0 Batch  140/1077 - Train Accuracy: 0.4420, Validation Accuracy: 0.5312, Loss: 1.0041
# Epoch   0 Batch  145/1077 - Train Accuracy: 0.5254, Validation Accuracy: 0.5266, Loss: 0.8986
# Epoch   0 Batch  150/1077 - Train Accuracy: 0.5294, Validation Accuracy: 0.5270, Loss: 0.8838
# Epoch   0 Batch  155/1077 - Train Accuracy: 0.4559, Validation Accuracy: 0.5231, Loss: 0.8942
# Epoch   0 Batch  160/1077 - Train Accuracy: 0.5004, Validation Accuracy: 0.5220, Loss: 0.8597
# Epoch   0 Batch  165/1077 - Train Accuracy: 0.4633, Validation Accuracy: 0.5195, Loss: 0.8430
# Epoch   0 Batch  170/1077 - Train Accuracy: 0.4770, Validation Accuracy: 0.5277, Loss: 0.8891
# Epoch   0 Batch  175/1077 - Train Accuracy: 0.5008, Validation Accuracy: 0.5273, Loss: 0.8351
# Epoch   0 Batch  180/1077 - Train Accuracy: 0.4789, Validation Accuracy: 0.5053, Loss: 0.8607
# Epoch   0 Batch  185/1077 - Train Accuracy: 0.4852, Validation Accuracy: 0.5369, Loss: 0.8529
# Epoch   0 Batch  190/1077 - Train Accuracy: 0.5086, Validation Accuracy: 0.5312, Loss: 0.8316
# Epoch   0 Batch  195/1077 - Train Accuracy: 0.4883, Validation Accuracy: 0.5330, Loss: 0.7939
# Epoch   0 Batch  200/1077 - Train Accuracy: 0.4789, Validation Accuracy: 0.5376, Loss: 0.8200
# Epoch   0 Batch  205/1077 - Train Accuracy: 0.4992, Validation Accuracy: 0.5259, Loss: 0.8035
# Epoch   0 Batch  210/1077 - Train Accuracy: 0.4974, Validation Accuracy: 0.5302, Loss: 0.7952
# Epoch   0 Batch  215/1077 - Train Accuracy: 0.4750, Validation Accuracy: 0.5234, Loss: 0.7970
# Epoch   0 Batch  220/1077 - Train Accuracy: 0.4901, Validation Accuracy: 0.5270, Loss: 0.8043
# Epoch   0 Batch  225/1077 - Train Accuracy: 0.5113, Validation Accuracy: 0.5256, Loss: 0.8038
# Epoch   0 Batch  230/1077 - Train Accuracy: 0.5376, Validation Accuracy: 0.5334, Loss: 0.7822
# Epoch   0 Batch  235/1077 - Train Accuracy: 0.5004, Validation Accuracy: 0.5220, Loss: 0.7082
# Epoch   0 Batch  240/1077 - Train Accuracy: 0.5234, Validation Accuracy: 0.5249, Loss: 0.7523
# Epoch   0 Batch  245/1077 - Train Accuracy: 0.5193, Validation Accuracy: 0.5249, Loss: 0.7377
# Epoch   0 Batch  250/1077 - Train Accuracy: 0.5163, Validation Accuracy: 0.5483, Loss: 0.7170
# Epoch   0 Batch  255/1077 - Train Accuracy: 0.5102, Validation Accuracy: 0.5405, Loss: 0.8009
# Epoch   0 Batch  260/1077 - Train Accuracy: 0.5193, Validation Accuracy: 0.5430, Loss: 0.7711
# Epoch   0 Batch  265/1077 - Train Accuracy: 0.4746, Validation Accuracy: 0.5277, Loss: 0.8044
# Epoch   0 Batch  270/1077 - Train Accuracy: 0.4715, Validation Accuracy: 0.5245, Loss: 0.8057
# Epoch   0 Batch  275/1077 - Train Accuracy: 0.5033, Validation Accuracy: 0.5281, Loss: 0.7413
# Epoch   0 Batch  280/1077 - Train Accuracy: 0.5230, Validation Accuracy: 0.5362, Loss: 0.7717
# Epoch   0 Batch  285/1077 - Train Accuracy: 0.5193, Validation Accuracy: 0.5199, Loss: 0.7374
# Epoch   0 Batch  290/1077 - Train Accuracy: 0.4895, Validation Accuracy: 0.5554, Loss: 0.7814
# Epoch   0 Batch  295/1077 - Train Accuracy: 0.5000, Validation Accuracy: 0.5284, Loss: 0.7850
# Epoch   0 Batch  300/1077 - Train Accuracy: 0.4498, Validation Accuracy: 0.4922, Loss: 0.7482
# Epoch   0 Batch  305/1077 - Train Accuracy: 0.5160, Validation Accuracy: 0.5430, Loss: 0.7123
# Epoch   0 Batch  310/1077 - Train Accuracy: 0.4762, Validation Accuracy: 0.5504, Loss: 0.7500
# Epoch   0 Batch  315/1077 - Train Accuracy: 0.5346, Validation Accuracy: 0.5494, Loss: 0.6830
# Epoch   0 Batch  320/1077 - Train Accuracy: 0.5422, Validation Accuracy: 0.5579, Loss: 0.7421
# Epoch   0 Batch  325/1077 - Train Accuracy: 0.5327, Validation Accuracy: 0.5277, Loss: 0.7264
# Epoch   0 Batch  330/1077 - Train Accuracy: 0.5395, Validation Accuracy: 0.5401, Loss: 0.7135
# Epoch   0 Batch  335/1077 - Train Accuracy: 0.5632, Validation Accuracy: 0.5217, Loss: 0.6908
# Epoch   0 Batch  340/1077 - Train Accuracy: 0.5090, Validation Accuracy: 0.5511, Loss: 0.7454
# Epoch   0 Batch  345/1077 - Train Accuracy: 0.5242, Validation Accuracy: 0.5455, Loss: 0.7115
# Epoch   0 Batch  350/1077 - Train Accuracy: 0.4766, Validation Accuracy: 0.5359, Loss: 0.7529
# Epoch   0 Batch  355/1077 - Train Accuracy: 0.5041, Validation Accuracy: 0.5561, Loss: 0.7431
# Epoch   0 Batch  360/1077 - Train Accuracy: 0.4980, Validation Accuracy: 0.5511, Loss: 0.7152
# Epoch   0 Batch  365/1077 - Train Accuracy: 0.4832, Validation Accuracy: 0.5405, Loss: 0.7313
# Epoch   0 Batch  370/1077 - Train Accuracy: 0.5138, Validation Accuracy: 0.5415, Loss: 0.7010
# Epoch   0 Batch  375/1077 - Train Accuracy: 0.5550, Validation Accuracy: 0.5568, Loss: 0.6713
# Epoch   0 Batch  380/1077 - Train Accuracy: 0.5328, Validation Accuracy: 0.5579, Loss: 0.6974
# Epoch   0 Batch  385/1077 - Train Accuracy: 0.5328, Validation Accuracy: 0.5472, Loss: 0.6993
# Epoch   0 Batch  390/1077 - Train Accuracy: 0.4848, Validation Accuracy: 0.5568, Loss: 0.7494
# Epoch   0 Batch  395/1077 - Train Accuracy: 0.5379, Validation Accuracy: 0.5309, Loss: 0.6945
# Epoch   0 Batch  400/1077 - Train Accuracy: 0.5062, Validation Accuracy: 0.5426, Loss: 0.7283
# Epoch   0 Batch  405/1077 - Train Accuracy: 0.5103, Validation Accuracy: 0.5650, Loss: 0.7766
# Epoch   0 Batch  410/1077 - Train Accuracy: 0.4100, Validation Accuracy: 0.4624, Loss: 0.7345
# Epoch   0 Batch  415/1077 - Train Accuracy: 0.5264, Validation Accuracy: 0.5256, Loss: 0.6691
# Epoch   0 Batch  420/1077 - Train Accuracy: 0.4695, Validation Accuracy: 0.4631, Loss: 0.6667
# Epoch   0 Batch  425/1077 - Train Accuracy: 0.5677, Validation Accuracy: 0.5664, Loss: 0.7017
# Epoch   0 Batch  430/1077 - Train Accuracy: 0.4934, Validation Accuracy: 0.5479, Loss: 0.6925
# Epoch   0 Batch  435/1077 - Train Accuracy: 0.5095, Validation Accuracy: 0.5749, Loss: 0.7480
# Epoch   0 Batch  440/1077 - Train Accuracy: 0.5289, Validation Accuracy: 0.5444, Loss: 0.7305
# Epoch   0 Batch  445/1077 - Train Accuracy: 0.5066, Validation Accuracy: 0.5359, Loss: 0.7165
# Epoch   0 Batch  450/1077 - Train Accuracy: 0.5055, Validation Accuracy: 0.5568, Loss: 0.6729
# Epoch   0 Batch  455/1077 - Train Accuracy: 0.5508, Validation Accuracy: 0.5536, Loss: 0.6747
# Epoch   0 Batch  460/1077 - Train Accuracy: 0.5254, Validation Accuracy: 0.5739, Loss: 0.7252
# Epoch   0 Batch  465/1077 - Train Accuracy: 0.4576, Validation Accuracy: 0.5536, Loss: 0.7425
# Epoch   0 Batch  470/1077 - Train Accuracy: 0.5058, Validation Accuracy: 0.5526, Loss: 0.7351
# Epoch   0 Batch  475/1077 - Train Accuracy: 0.5605, Validation Accuracy: 0.5526, Loss: 0.6870
# Epoch   0 Batch  480/1077 - Train Accuracy: 0.5259, Validation Accuracy: 0.5334, Loss: 0.6965
# Epoch   0 Batch  485/1077 - Train Accuracy: 0.5430, Validation Accuracy: 0.5611, Loss: 0.7124
# Epoch   0 Batch  490/1077 - Train Accuracy: 0.5234, Validation Accuracy: 0.5426, Loss: 0.7105
# Epoch   0 Batch  495/1077 - Train Accuracy: 0.5109, Validation Accuracy: 0.5384, Loss: 0.6797
# Epoch   0 Batch  500/1077 - Train Accuracy: 0.5469, Validation Accuracy: 0.5753, Loss: 0.6663
# Epoch   0 Batch  505/1077 - Train Accuracy: 0.5461, Validation Accuracy: 0.5476, Loss: 0.6398
# Epoch   0 Batch  510/1077 - Train Accuracy: 0.5500, Validation Accuracy: 0.5732, Loss: 0.7082
# Epoch   0 Batch  515/1077 - Train Accuracy: 0.5363, Validation Accuracy: 0.5636, Loss: 0.7031
# Epoch   0 Batch  520/1077 - Train Accuracy: 0.5469, Validation Accuracy: 0.5565, Loss: 0.6538
# Epoch   0 Batch  525/1077 - Train Accuracy: 0.5277, Validation Accuracy: 0.5465, Loss: 0.6664
# Epoch   0 Batch  530/1077 - Train Accuracy: 0.5223, Validation Accuracy: 0.5696, Loss: 0.6934
# Epoch   0 Batch  535/1077 - Train Accuracy: 0.5203, Validation Accuracy: 0.5600, Loss: 0.6891
# Epoch   0 Batch  540/1077 - Train Accuracy: 0.5371, Validation Accuracy: 0.5256, Loss: 0.6327
# Epoch   0 Batch  545/1077 - Train Accuracy: 0.5105, Validation Accuracy: 0.5540, Loss: 0.7214
# Epoch   0 Batch  550/1077 - Train Accuracy: 0.5250, Validation Accuracy: 0.5728, Loss: 0.7052
# Epoch   0 Batch  555/1077 - Train Accuracy: 0.5395, Validation Accuracy: 0.5561, Loss: 0.6780
# Epoch   0 Batch  560/1077 - Train Accuracy: 0.5543, Validation Accuracy: 0.5451, Loss: 0.6670
# Epoch   0 Batch  565/1077 - Train Accuracy: 0.5283, Validation Accuracy: 0.5312, Loss: 0.6880
# Epoch   0 Batch  570/1077 - Train Accuracy: 0.5317, Validation Accuracy: 0.5529, Loss: 0.7038
# Epoch   0 Batch  575/1077 - Train Accuracy: 0.5495, Validation Accuracy: 0.5593, Loss: 0.6856
# Epoch   0 Batch  580/1077 - Train Accuracy: 0.5562, Validation Accuracy: 0.5426, Loss: 0.6241
# Epoch   0 Batch  585/1077 - Train Accuracy: 0.5595, Validation Accuracy: 0.5501, Loss: 0.6287
# Epoch   0 Batch  590/1077 - Train Accuracy: 0.4877, Validation Accuracy: 0.5447, Loss: 0.7231
# Epoch   0 Batch  595/1077 - Train Accuracy: 0.5176, Validation Accuracy: 0.5575, Loss: 0.6944
# Epoch   0 Batch  600/1077 - Train Accuracy: 0.5472, Validation Accuracy: 0.5614, Loss: 0.6397
# Epoch   0 Batch  605/1077 - Train Accuracy: 0.5222, Validation Accuracy: 0.5376, Loss: 0.7244
# Epoch   0 Batch  610/1077 - Train Accuracy: 0.5465, Validation Accuracy: 0.5582, Loss: 0.6807
# Epoch   0 Batch  615/1077 - Train Accuracy: 0.5648, Validation Accuracy: 0.5639, Loss: 0.6683
# Epoch   0 Batch  620/1077 - Train Accuracy: 0.4723, Validation Accuracy: 0.4968, Loss: 0.6331
# Epoch   0 Batch  625/1077 - Train Accuracy: 0.5621, Validation Accuracy: 0.5739, Loss: 0.6933
# Epoch   0 Batch  630/1077 - Train Accuracy: 0.5410, Validation Accuracy: 0.5692, Loss: 0.6571
# Epoch   0 Batch  635/1077 - Train Accuracy: 0.4947, Validation Accuracy: 0.5529, Loss: 0.7148
# Epoch   0 Batch  640/1077 - Train Accuracy: 0.5487, Validation Accuracy: 0.5717, Loss: 0.6500
# Epoch   0 Batch  645/1077 - Train Accuracy: 0.5502, Validation Accuracy: 0.5767, Loss: 0.6461
# Epoch   0 Batch  650/1077 - Train Accuracy: 0.5125, Validation Accuracy: 0.5384, Loss: 0.6942
# Epoch   0 Batch  655/1077 - Train Accuracy: 0.5203, Validation Accuracy: 0.5522, Loss: 0.6744
# Epoch   0 Batch  660/1077 - Train Accuracy: 0.5414, Validation Accuracy: 0.5742, Loss: 0.7277
# Epoch   0 Batch  665/1077 - Train Accuracy: 0.5188, Validation Accuracy: 0.5518, Loss: 0.6783
# Epoch   0 Batch  670/1077 - Train Accuracy: 0.5980, Validation Accuracy: 0.5614, Loss: 0.6287
# Epoch   0 Batch  675/1077 - Train Accuracy: 0.5614, Validation Accuracy: 0.5494, Loss: 0.6555
# Epoch   0 Batch  680/1077 - Train Accuracy: 0.5179, Validation Accuracy: 0.5433, Loss: 0.6305
# Epoch   0 Batch  685/1077 - Train Accuracy: 0.5328, Validation Accuracy: 0.5515, Loss: 0.6625
# Epoch   0 Batch  690/1077 - Train Accuracy: 0.5359, Validation Accuracy: 0.5398, Loss: 0.6583
# Epoch   0 Batch  695/1077 - Train Accuracy: 0.5332, Validation Accuracy: 0.5682, Loss: 0.6329
# Epoch   0 Batch  700/1077 - Train Accuracy: 0.5074, Validation Accuracy: 0.5575, Loss: 0.6639
# Epoch   0 Batch  705/1077 - Train Accuracy: 0.5271, Validation Accuracy: 0.5543, Loss: 0.7367
# Epoch   0 Batch  710/1077 - Train Accuracy: 0.4938, Validation Accuracy: 0.5437, Loss: 0.6451
# Epoch   0 Batch  715/1077 - Train Accuracy: 0.5316, Validation Accuracy: 0.5437, Loss: 0.6757
# Epoch   0 Batch  720/1077 - Train Accuracy: 0.5201, Validation Accuracy: 0.5309, Loss: 0.7258
# Epoch   0 Batch  725/1077 - Train Accuracy: 0.5458, Validation Accuracy: 0.5586, Loss: 0.6231
# Epoch   0 Batch  730/1077 - Train Accuracy: 0.4555, Validation Accuracy: 0.4560, Loss: 0.6586
# Epoch   0 Batch  735/1077 - Train Accuracy: 0.5379, Validation Accuracy: 0.5547, Loss: 0.6452
# Epoch   0 Batch  740/1077 - Train Accuracy: 0.5277, Validation Accuracy: 0.5501, Loss: 0.6439
# Epoch   0 Batch  745/1077 - Train Accuracy: 0.5609, Validation Accuracy: 0.5817, Loss: 0.6429
# Epoch   0 Batch  750/1077 - Train Accuracy: 0.5199, Validation Accuracy: 0.5430, Loss: 0.6625
# Epoch   0 Batch  755/1077 - Train Accuracy: 0.5477, Validation Accuracy: 0.5419, Loss: 0.6515
# Epoch   0 Batch  760/1077 - Train Accuracy: 0.5605, Validation Accuracy: 0.5550, Loss: 0.6420
# Epoch   0 Batch  765/1077 - Train Accuracy: 0.5832, Validation Accuracy: 0.5703, Loss: 0.6177
# Epoch   0 Batch  770/1077 - Train Accuracy: 0.5792, Validation Accuracy: 0.5550, Loss: 0.6041
# Epoch   0 Batch  775/1077 - Train Accuracy: 0.5543, Validation Accuracy: 0.5902, Loss: 0.7157
# Epoch   0 Batch  780/1077 - Train Accuracy: 0.5051, Validation Accuracy: 0.5586, Loss: 0.6923
# Epoch   0 Batch  785/1077 - Train Accuracy: 0.5621, Validation Accuracy: 0.5465, Loss: 0.6381
# Epoch   0 Batch  790/1077 - Train Accuracy: 0.4750, Validation Accuracy: 0.5707, Loss: 0.7001
# Epoch   0 Batch  795/1077 - Train Accuracy: 0.5570, Validation Accuracy: 0.5930, Loss: 0.6952
# Epoch   0 Batch  800/1077 - Train Accuracy: 0.5266, Validation Accuracy: 0.5692, Loss: 0.6476
# Epoch   0 Batch  805/1077 - Train Accuracy: 0.5598, Validation Accuracy: 0.5600, Loss: 0.6193
# Epoch   0 Batch  810/1077 - Train Accuracy: 0.5662, Validation Accuracy: 0.5689, Loss: 0.6212
# Epoch   0 Batch  815/1077 - Train Accuracy: 0.5484, Validation Accuracy: 0.5760, Loss: 0.7759
# Epoch   0 Batch  820/1077 - Train Accuracy: 0.5160, Validation Accuracy: 0.5653, Loss: 0.7197
# Epoch   0 Batch  825/1077 - Train Accuracy: 0.5168, Validation Accuracy: 0.5742, Loss: 0.6948
# Epoch   0 Batch  830/1077 - Train Accuracy: 0.5098, Validation Accuracy: 0.5455, Loss: 0.6646
# Epoch   0 Batch  835/1077 - Train Accuracy: 0.5609, Validation Accuracy: 0.5927, Loss: 0.6823
# Epoch   0 Batch  840/1077 - Train Accuracy: 0.5352, Validation Accuracy: 0.5739, Loss: 0.6314
# Epoch   0 Batch  845/1077 - Train Accuracy: 0.5586, Validation Accuracy: 0.5632, Loss: 0.6430
# Epoch   0 Batch  850/1077 - Train Accuracy: 0.5599, Validation Accuracy: 0.5774, Loss: 0.7086
# Epoch   0 Batch  855/1077 - Train Accuracy: 0.5188, Validation Accuracy: 0.5678, Loss: 0.6511
# Epoch   0 Batch  860/1077 - Train Accuracy: 0.5792, Validation Accuracy: 0.5614, Loss: 0.6266
# Epoch   0 Batch  865/1077 - Train Accuracy: 0.5895, Validation Accuracy: 0.5558, Loss: 0.5901
# Epoch   0 Batch  870/1077 - Train Accuracy: 0.5082, Validation Accuracy: 0.5795, Loss: 0.6871
# Epoch   0 Batch  875/1077 - Train Accuracy: 0.5441, Validation Accuracy: 0.5835, Loss: 0.6575
# Epoch   0 Batch  880/1077 - Train Accuracy: 0.5793, Validation Accuracy: 0.5785, Loss: 0.6555
# Epoch   0 Batch  885/1077 - Train Accuracy: 0.5501, Validation Accuracy: 0.5146, Loss: 0.5698
# Epoch   0 Batch  890/1077 - Train Accuracy: 0.6097, Validation Accuracy: 0.5710, Loss: 0.5998
# Epoch   0 Batch  895/1077 - Train Accuracy: 0.5441, Validation Accuracy: 0.5508, Loss: 0.6210
# Epoch   0 Batch  900/1077 - Train Accuracy: 0.5363, Validation Accuracy: 0.5852, Loss: 0.6790
# Epoch   0 Batch  905/1077 - Train Accuracy: 0.5523, Validation Accuracy: 0.5501, Loss: 0.6219
# Epoch   0 Batch  910/1077 - Train Accuracy: 0.5573, Validation Accuracy: 0.5774, Loss: 0.6569
# Epoch   0 Batch  915/1077 - Train Accuracy: 0.5169, Validation Accuracy: 0.5788, Loss: 0.6696
# Epoch   0 Batch  920/1077 - Train Accuracy: 0.5578, Validation Accuracy: 0.5810, Loss: 0.6602
# Epoch   0 Batch  925/1077 - Train Accuracy: 0.5711, Validation Accuracy: 0.5803, Loss: 0.6009
# Epoch   0 Batch  930/1077 - Train Accuracy: 0.5715, Validation Accuracy: 0.5799, Loss: 0.6158
# Epoch   0 Batch  935/1077 - Train Accuracy: 0.5676, Validation Accuracy: 0.5717, Loss: 0.6375
# Epoch   0 Batch  940/1077 - Train Accuracy: 0.5531, Validation Accuracy: 0.5767, Loss: 0.6449
# Epoch   0 Batch  945/1077 - Train Accuracy: 0.5855, Validation Accuracy: 0.5849, Loss: 0.6178
# Epoch   0 Batch  950/1077 - Train Accuracy: 0.5365, Validation Accuracy: 0.5831, Loss: 0.6145
# Epoch   0 Batch  955/1077 - Train Accuracy: 0.5586, Validation Accuracy: 0.5671, Loss: 0.7014
# Epoch   0 Batch  960/1077 - Train Accuracy: 0.5830, Validation Accuracy: 0.5859, Loss: 0.6202
# Epoch   0 Batch  965/1077 - Train Accuracy: 0.5033, Validation Accuracy: 0.5803, Loss: 0.6735
# Epoch   0 Batch  970/1077 - Train Accuracy: 0.5695, Validation Accuracy: 0.5661, Loss: 0.6722
# Epoch   0 Batch  975/1077 - Train Accuracy: 0.6053, Validation Accuracy: 0.5692, Loss: 0.6173
# Epoch   0 Batch  980/1077 - Train Accuracy: 0.5691, Validation Accuracy: 0.6048, Loss: 0.6426
# Epoch   0 Batch  985/1077 - Train Accuracy: 0.5699, Validation Accuracy: 0.5661, Loss: 0.6204
# Epoch   0 Batch  990/1077 - Train Accuracy: 0.5296, Validation Accuracy: 0.5781, Loss: 0.6724
# Epoch   0 Batch  995/1077 - Train Accuracy: 0.5815, Validation Accuracy: 0.5856, Loss: 0.6335
# Epoch   0 Batch 1000/1077 - Train Accuracy: 0.5402, Validation Accuracy: 0.5291, Loss: 0.5746
# Epoch   0 Batch 1005/1077 - Train Accuracy: 0.5340, Validation Accuracy: 0.6044, Loss: 0.6399
# Epoch   0 Batch 1010/1077 - Train Accuracy: 0.5496, Validation Accuracy: 0.5664, Loss: 0.6357
# Epoch   0 Batch 1015/1077 - Train Accuracy: 0.5461, Validation Accuracy: 0.5824, Loss: 0.6678
# Epoch   0 Batch 1020/1077 - Train Accuracy: 0.5512, Validation Accuracy: 0.5763, Loss: 0.6160
# Epoch   0 Batch 1025/1077 - Train Accuracy: 0.5387, Validation Accuracy: 0.5877, Loss: 0.5917
# Epoch   0 Batch 1030/1077 - Train Accuracy: 0.5195, Validation Accuracy: 0.5881, Loss: 0.6676
# Epoch   0 Batch 1035/1077 - Train Accuracy: 0.5506, Validation Accuracy: 0.5614, Loss: 0.5819
# Epoch   0 Batch 1040/1077 - Train Accuracy: 0.5452, Validation Accuracy: 0.5792, Loss: 0.6658
# Epoch   0 Batch 1045/1077 - Train Accuracy: 0.5414, Validation Accuracy: 0.5859, Loss: 0.6747
# Epoch   0 Batch 1050/1077 - Train Accuracy: 0.4785, Validation Accuracy: 0.5884, Loss: 0.6482
# Epoch   0 Batch 1055/1077 - Train Accuracy: 0.5730, Validation Accuracy: 0.5973, Loss: 0.6339
# Epoch   0 Batch 1060/1077 - Train Accuracy: 0.5715, Validation Accuracy: 0.5909, Loss: 0.5971
# Epoch   0 Batch 1065/1077 - Train Accuracy: 0.5445, Validation Accuracy: 0.5813, Loss: 0.6181
# Epoch   0 Batch 1070/1077 - Train Accuracy: 0.5215, Validation Accuracy: 0.5835, Loss: 0.6371
# Epoch   0 Batch 1075/1077 - Train Accuracy: 0.5280, Validation Accuracy: 0.5863, Loss: 0.6671
# Epoch   1 Batch    5/1077 - Train Accuracy: 0.5457, Validation Accuracy: 0.6012, Loss: 0.6596
# Epoch   1 Batch   10/1077 - Train Accuracy: 0.5506, Validation Accuracy: 0.5763, Loss: 0.6667
# Epoch   1 Batch   15/1077 - Train Accuracy: 0.5402, Validation Accuracy: 0.5838, Loss: 0.6402
# Epoch   1 Batch   20/1077 - Train Accuracy: 0.5449, Validation Accuracy: 0.5852, Loss: 0.5978
# Epoch   1 Batch   25/1077 - Train Accuracy: 0.5379, Validation Accuracy: 0.5994, Loss: 0.6119
# Epoch   1 Batch   30/1077 - Train Accuracy: 0.5594, Validation Accuracy: 0.5682, Loss: 0.6386
# Epoch   1 Batch   35/1077 - Train Accuracy: 0.5621, Validation Accuracy: 0.5930, Loss: 0.6120
# Epoch   1 Batch   40/1077 - Train Accuracy: 0.5441, Validation Accuracy: 0.5842, Loss: 0.6378
# Epoch   1 Batch   45/1077 - Train Accuracy: 0.5719, Validation Accuracy: 0.5703, Loss: 0.6269
# Epoch   1 Batch   50/1077 - Train Accuracy: 0.5117, Validation Accuracy: 0.5888, Loss: 0.6477
# Epoch   1 Batch   55/1077 - Train Accuracy: 0.5754, Validation Accuracy: 0.5685, Loss: 0.6074
# Epoch   1 Batch   60/1077 - Train Accuracy: 0.5770, Validation Accuracy: 0.5838, Loss: 0.5841
# Epoch   1 Batch   65/1077 - Train Accuracy: 0.5288, Validation Accuracy: 0.5746, Loss: 0.6389
# Epoch   1 Batch   70/1077 - Train Accuracy: 0.5641, Validation Accuracy: 0.5795, Loss: 0.6453
# Epoch   1 Batch   75/1077 - Train Accuracy: 0.5762, Validation Accuracy: 0.5732, Loss: 0.6542
# Epoch   1 Batch   80/1077 - Train Accuracy: 0.5469, Validation Accuracy: 0.5856, Loss: 0.6284
# Epoch   1 Batch   85/1077 - Train Accuracy: 0.5867, Validation Accuracy: 0.5831, Loss: 0.6141
# Epoch   1 Batch   90/1077 - Train Accuracy: 0.5348, Validation Accuracy: 0.5771, Loss: 0.6645
# Epoch   1 Batch   95/1077 - Train Accuracy: 0.5588, Validation Accuracy: 0.5813, Loss: 0.6641
# Epoch   1 Batch  100/1077 - Train Accuracy: 0.5492, Validation Accuracy: 0.5618, Loss: 0.6286
# Epoch   1 Batch  105/1077 - Train Accuracy: 0.5480, Validation Accuracy: 0.5405, Loss: 0.6396
# Epoch   1 Batch  110/1077 - Train Accuracy: 0.5762, Validation Accuracy: 0.5881, Loss: 0.6031
# Epoch   1 Batch  115/1077 - Train Accuracy: 0.4805, Validation Accuracy: 0.4780, Loss: 0.6840
# Epoch   1 Batch  120/1077 - Train Accuracy: 0.5422, Validation Accuracy: 0.5955, Loss: 0.6902
# Epoch   1 Batch  125/1077 - Train Accuracy: 0.5629, Validation Accuracy: 0.5902, Loss: 0.6449
# Epoch   1 Batch  130/1077 - Train Accuracy: 0.5640, Validation Accuracy: 0.5977, Loss: 0.6161
# Epoch   1 Batch  135/1077 - Train Accuracy: 0.5308, Validation Accuracy: 0.5597, Loss: 0.6788
# Epoch   1 Batch  140/1077 - Train Accuracy: 0.5317, Validation Accuracy: 0.5717, Loss: 0.6705
# Epoch   1 Batch  145/1077 - Train Accuracy: 0.5809, Validation Accuracy: 0.5845, Loss: 0.6665
# Epoch   1 Batch  150/1077 - Train Accuracy: 0.6008, Validation Accuracy: 0.5934, Loss: 0.6321
# Epoch   1 Batch  155/1077 - Train Accuracy: 0.5449, Validation Accuracy: 0.5618, Loss: 0.6663
# Epoch   1 Batch  160/1077 - Train Accuracy: 0.5539, Validation Accuracy: 0.5810, Loss: 0.6178
# Epoch   1 Batch  165/1077 - Train Accuracy: 0.5141, Validation Accuracy: 0.5849, Loss: 0.6273
# Epoch   1 Batch  170/1077 - Train Accuracy: 0.5410, Validation Accuracy: 0.5934, Loss: 0.6700
# Epoch   1 Batch  175/1077 - Train Accuracy: 0.5848, Validation Accuracy: 0.5831, Loss: 0.6174
# Epoch   1 Batch  180/1077 - Train Accuracy: 0.5527, Validation Accuracy: 0.5817, Loss: 0.6787
# Epoch   1 Batch  185/1077 - Train Accuracy: 0.5379, Validation Accuracy: 0.5810, Loss: 0.6466
# Epoch   1 Batch  190/1077 - Train Accuracy: 0.5820, Validation Accuracy: 0.5916, Loss: 0.6001
# Epoch   1 Batch  195/1077 - Train Accuracy: 0.5168, Validation Accuracy: 0.5781, Loss: 0.6193
# Epoch   1 Batch  200/1077 - Train Accuracy: 0.5402, Validation Accuracy: 0.5870, Loss: 0.6629
# Epoch   1 Batch  205/1077 - Train Accuracy: 0.5797, Validation Accuracy: 0.5930, Loss: 0.6402
# Epoch   1 Batch  210/1077 - Train Accuracy: 0.5699, Validation Accuracy: 0.5756, Loss: 0.6099
# Epoch   1 Batch  215/1077 - Train Accuracy: 0.5336, Validation Accuracy: 0.5945, Loss: 0.6207
# Epoch   1 Batch  220/1077 - Train Accuracy: 0.5255, Validation Accuracy: 0.5721, Loss: 0.6408
# Epoch   1 Batch  225/1077 - Train Accuracy: 0.5563, Validation Accuracy: 0.6076, Loss: 0.6335
# Epoch   1 Batch  230/1077 - Train Accuracy: 0.5711, Validation Accuracy: 0.5767, Loss: 0.6353
# Epoch   1 Batch  235/1077 - Train Accuracy: 0.5725, Validation Accuracy: 0.5817, Loss: 0.5754
# Epoch   1 Batch  240/1077 - Train Accuracy: 0.5625, Validation Accuracy: 0.5707, Loss: 0.6248
# Epoch   1 Batch  245/1077 - Train Accuracy: 0.5603, Validation Accuracy: 0.5511, Loss: 0.5979
# Epoch   1 Batch  250/1077 - Train Accuracy: 0.5795, Validation Accuracy: 0.5888, Loss: 0.5827
# Epoch   1 Batch  255/1077 - Train Accuracy: 0.5301, Validation Accuracy: 0.5767, Loss: 0.6205
# Epoch   1 Batch  260/1077 - Train Accuracy: 0.5588, Validation Accuracy: 0.5795, Loss: 0.5819
# Epoch   1 Batch  265/1077 - Train Accuracy: 0.5469, Validation Accuracy: 0.6016, Loss: 0.6187
# Epoch   1 Batch  270/1077 - Train Accuracy: 0.5207, Validation Accuracy: 0.5415, Loss: 0.6519
# Epoch   1 Batch  275/1077 - Train Accuracy: 0.5595, Validation Accuracy: 0.5966, Loss: 0.5931
# Epoch   1 Batch  280/1077 - Train Accuracy: 0.5781, Validation Accuracy: 0.5927, Loss: 0.6443
# Epoch   1 Batch  285/1077 - Train Accuracy: 0.5569, Validation Accuracy: 0.5455, Loss: 0.6091
# Epoch   1 Batch  290/1077 - Train Accuracy: 0.5500, Validation Accuracy: 0.5998, Loss: 0.6733
# Epoch   1 Batch  295/1077 - Train Accuracy: 0.5456, Validation Accuracy: 0.5739, Loss: 0.6774
# Epoch   1 Batch  300/1077 - Train Accuracy: 0.5502, Validation Accuracy: 0.5685, Loss: 0.6530
# Epoch   1 Batch  305/1077 - Train Accuracy: 0.5672, Validation Accuracy: 0.5643, Loss: 0.5967
# Epoch   1 Batch  310/1077 - Train Accuracy: 0.5270, Validation Accuracy: 0.5703, Loss: 0.6288
# Epoch   1 Batch  315/1077 - Train Accuracy: 0.5699, Validation Accuracy: 0.5934, Loss: 0.5811
# Epoch   1 Batch  320/1077 - Train Accuracy: 0.5848, Validation Accuracy: 0.5838, Loss: 0.6559
# Epoch   1 Batch  325/1077 - Train Accuracy: 0.6045, Validation Accuracy: 0.5614, Loss: 0.6300
# Epoch   1 Batch  330/1077 - Train Accuracy: 0.5566, Validation Accuracy: 0.5664, Loss: 0.6332
# Epoch   1 Batch  335/1077 - Train Accuracy: 0.6049, Validation Accuracy: 0.5771, Loss: 0.6304
# Epoch   1 Batch  340/1077 - Train Accuracy: 0.5284, Validation Accuracy: 0.5465, Loss: 0.6758
# Epoch   1 Batch  345/1077 - Train Accuracy: 0.5696, Validation Accuracy: 0.5792, Loss: 0.6246
# Epoch   1 Batch  350/1077 - Train Accuracy: 0.5047, Validation Accuracy: 0.5692, Loss: 0.6919
# Epoch   1 Batch  355/1077 - Train Accuracy: 0.5413, Validation Accuracy: 0.5618, Loss: 0.6788
# Epoch   1 Batch  360/1077 - Train Accuracy: 0.5250, Validation Accuracy: 0.5582, Loss: 0.6529
# Epoch   1 Batch  365/1077 - Train Accuracy: 0.5168, Validation Accuracy: 0.5639, Loss: 0.6544
# Epoch   1 Batch  370/1077 - Train Accuracy: 0.5502, Validation Accuracy: 0.5714, Loss: 0.6349
# Epoch   1 Batch  375/1077 - Train Accuracy: 0.5920, Validation Accuracy: 0.5831, Loss: 0.5908
# Epoch   1 Batch  380/1077 - Train Accuracy: 0.5488, Validation Accuracy: 0.5636, Loss: 0.6325
# Epoch   1 Batch  385/1077 - Train Accuracy: 0.5648, Validation Accuracy: 0.5799, Loss: 0.6267
# Epoch   1 Batch  390/1077 - Train Accuracy: 0.5090, Validation Accuracy: 0.5714, Loss: 0.6810
# Epoch   1 Batch  395/1077 - Train Accuracy: 0.5331, Validation Accuracy: 0.5735, Loss: 0.6127
# Epoch   1 Batch  400/1077 - Train Accuracy: 0.5676, Validation Accuracy: 0.5913, Loss: 0.6360
# Epoch   1 Batch  405/1077 - Train Accuracy: 0.5469, Validation Accuracy: 0.5866, Loss: 0.6933
# Epoch   1 Batch  410/1077 - Train Accuracy: 0.4482, Validation Accuracy: 0.4869, Loss: 0.6526
# Epoch   1 Batch  415/1077 - Train Accuracy: 0.5636, Validation Accuracy: 0.5817, Loss: 0.6255
# Epoch   1 Batch  420/1077 - Train Accuracy: 0.5305, Validation Accuracy: 0.4890, Loss: 0.5872
# Epoch   1 Batch  425/1077 - Train Accuracy: 0.5800, Validation Accuracy: 0.5909, Loss: 0.6054
# Epoch   1 Batch  430/1077 - Train Accuracy: 0.5188, Validation Accuracy: 0.5732, Loss: 0.6591
# Epoch   1 Batch  435/1077 - Train Accuracy: 0.5288, Validation Accuracy: 0.5550, Loss: 0.6657
# Epoch   1 Batch  440/1077 - Train Accuracy: 0.5559, Validation Accuracy: 0.5820, Loss: 0.6827
# Epoch   1 Batch  445/1077 - Train Accuracy: 0.5403, Validation Accuracy: 0.5352, Loss: 0.6565
# Epoch   1 Batch  450/1077 - Train Accuracy: 0.5121, Validation Accuracy: 0.5607, Loss: 0.6467
# Epoch   1 Batch  455/1077 - Train Accuracy: 0.5898, Validation Accuracy: 0.5760, Loss: 0.6351
# Epoch   1 Batch  460/1077 - Train Accuracy: 0.5078, Validation Accuracy: 0.5114, Loss: 0.6542
# Epoch   1 Batch  465/1077 - Train Accuracy: 0.5111, Validation Accuracy: 0.5540, Loss: 0.6695
# Epoch   1 Batch  470/1077 - Train Accuracy: 0.5284, Validation Accuracy: 0.5835, Loss: 0.6669
# Epoch   1 Batch  475/1077 - Train Accuracy: 0.5777, Validation Accuracy: 0.5735, Loss: 0.6529
# Epoch   1 Batch  480/1077 - Train Accuracy: 0.5366, Validation Accuracy: 0.5703, Loss: 0.6507
# Epoch   1 Batch  485/1077 - Train Accuracy: 0.5922, Validation Accuracy: 0.5689, Loss: 0.6416
# Epoch   1 Batch  490/1077 - Train Accuracy: 0.5512, Validation Accuracy: 0.5455, Loss: 0.6365
# Epoch   1 Batch  495/1077 - Train Accuracy: 0.5637, Validation Accuracy: 0.5739, Loss: 0.5926
# Epoch   1 Batch  500/1077 - Train Accuracy: 0.5746, Validation Accuracy: 0.5898, Loss: 0.6245
# Epoch   1 Batch  505/1077 - Train Accuracy: 0.5562, Validation Accuracy: 0.5668, Loss: 0.6004
# Epoch   1 Batch  510/1077 - Train Accuracy: 0.5246, Validation Accuracy: 0.5600, Loss: 0.6314
# Epoch   1 Batch  515/1077 - Train Accuracy: 0.5301, Validation Accuracy: 0.5781, Loss: 0.7069
# Epoch   1 Batch  520/1077 - Train Accuracy: 0.5644, Validation Accuracy: 0.5760, Loss: 0.6218
# Epoch   1 Batch  525/1077 - Train Accuracy: 0.4953, Validation Accuracy: 0.4762, Loss: 0.6925
# Epoch   1 Batch  530/1077 - Train Accuracy: 0.5250, Validation Accuracy: 0.5547, Loss: 0.7013
# Epoch   1 Batch  535/1077 - Train Accuracy: 0.5328, Validation Accuracy: 0.5710, Loss: 0.6677
# Epoch   1 Batch  540/1077 - Train Accuracy: 0.5566, Validation Accuracy: 0.5643, Loss: 0.6269
# Epoch   1 Batch  545/1077 - Train Accuracy: 0.5246, Validation Accuracy: 0.5749, Loss: 0.6970
# Epoch   1 Batch  550/1077 - Train Accuracy: 0.4848, Validation Accuracy: 0.5469, Loss: 0.6706
# Epoch   1 Batch  555/1077 - Train Accuracy: 0.5590, Validation Accuracy: 0.5611, Loss: 0.6408
# Epoch   1 Batch  560/1077 - Train Accuracy: 0.5043, Validation Accuracy: 0.5600, Loss: 0.6424
# Epoch   1 Batch  565/1077 - Train Accuracy: 0.5424, Validation Accuracy: 0.5575, Loss: 0.6885
# Epoch   1 Batch  570/1077 - Train Accuracy: 0.5292, Validation Accuracy: 0.5714, Loss: 0.6833
# Epoch   1 Batch  575/1077 - Train Accuracy: 0.5923, Validation Accuracy: 0.5774, Loss: 0.6228
# Epoch   1 Batch  580/1077 - Train Accuracy: 0.6023, Validation Accuracy: 0.5639, Loss: 0.5758
# Epoch   1 Batch  585/1077 - Train Accuracy: 0.5893, Validation Accuracy: 0.5703, Loss: 0.5876
# Epoch   1 Batch  590/1077 - Train Accuracy: 0.5086, Validation Accuracy: 0.5806, Loss: 0.6495
# Epoch   1 Batch  595/1077 - Train Accuracy: 0.5031, Validation Accuracy: 0.5689, Loss: 0.6724
# Epoch   1 Batch  600/1077 - Train Accuracy: 0.5811, Validation Accuracy: 0.5909, Loss: 0.5992
# Epoch   1 Batch  605/1077 - Train Accuracy: 0.5543, Validation Accuracy: 0.5760, Loss: 0.6804
# Epoch   1 Batch  610/1077 - Train Accuracy: 0.5049, Validation Accuracy: 0.5433, Loss: 0.6551
# Epoch   1 Batch  615/1077 - Train Accuracy: 0.5949, Validation Accuracy: 0.5991, Loss: 0.6165
# Epoch   1 Batch  620/1077 - Train Accuracy: 0.4754, Validation Accuracy: 0.4961, Loss: 0.6127
# Epoch   1 Batch  625/1077 - Train Accuracy: 0.6027, Validation Accuracy: 0.6016, Loss: 0.6291
# Epoch   1 Batch  630/1077 - Train Accuracy: 0.5473, Validation Accuracy: 0.5941, Loss: 0.6356
# Epoch   1 Batch  635/1077 - Train Accuracy: 0.5095, Validation Accuracy: 0.5685, Loss: 0.6830
# Epoch   1 Batch  640/1077 - Train Accuracy: 0.5502, Validation Accuracy: 0.5756, Loss: 0.6202
# Epoch   1 Batch  645/1077 - Train Accuracy: 0.5811, Validation Accuracy: 0.5749, Loss: 0.6063
# Epoch   1 Batch  650/1077 - Train Accuracy: 0.5402, Validation Accuracy: 0.5895, Loss: 0.6702
# Epoch   1 Batch  655/1077 - Train Accuracy: 0.5590, Validation Accuracy: 0.5774, Loss: 0.6375
# Epoch   1 Batch  660/1077 - Train Accuracy: 0.5410, Validation Accuracy: 0.5611, Loss: 0.6563
# Epoch   1 Batch  665/1077 - Train Accuracy: 0.5504, Validation Accuracy: 0.5760, Loss: 0.6228
# Epoch   1 Batch  670/1077 - Train Accuracy: 0.6126, Validation Accuracy: 0.5806, Loss: 0.6047
# Epoch   1 Batch  675/1077 - Train Accuracy: 0.5711, Validation Accuracy: 0.5810, Loss: 0.6388
# Epoch   1 Batch  680/1077 - Train Accuracy: 0.5216, Validation Accuracy: 0.5522, Loss: 0.6022
# Epoch   1 Batch  685/1077 - Train Accuracy: 0.5359, Validation Accuracy: 0.5771, Loss: 0.6619
# Epoch   1 Batch  690/1077 - Train Accuracy: 0.5715, Validation Accuracy: 0.5785, Loss: 0.6180
# Epoch   1 Batch  695/1077 - Train Accuracy: 0.5590, Validation Accuracy: 0.5827, Loss: 0.6321
# Epoch   1 Batch  700/1077 - Train Accuracy: 0.4980, Validation Accuracy: 0.5778, Loss: 0.6307
# Epoch   1 Batch  705/1077 - Train Accuracy: 0.5794, Validation Accuracy: 0.5646, Loss: 0.7121
# Epoch   1 Batch  710/1077 - Train Accuracy: 0.5215, Validation Accuracy: 0.5863, Loss: 0.5992
# Epoch   1 Batch  715/1077 - Train Accuracy: 0.5895, Validation Accuracy: 0.5803, Loss: 0.6398
# Epoch   1 Batch  720/1077 - Train Accuracy: 0.5115, Validation Accuracy: 0.5497, Loss: 0.7017
# Epoch   1 Batch  725/1077 - Train Accuracy: 0.5525, Validation Accuracy: 0.5515, Loss: 0.5959
# Epoch   1 Batch  730/1077 - Train Accuracy: 0.4809, Validation Accuracy: 0.5039, Loss: 0.6398
# Epoch   1 Batch  735/1077 - Train Accuracy: 0.5180, Validation Accuracy: 0.5522, Loss: 0.6186
# Epoch   1 Batch  740/1077 - Train Accuracy: 0.5457, Validation Accuracy: 0.5852, Loss: 0.6097
# Epoch   1 Batch  745/1077 - Train Accuracy: 0.5770, Validation Accuracy: 0.5785, Loss: 0.5868
# Epoch   1 Batch  750/1077 - Train Accuracy: 0.5469, Validation Accuracy: 0.5689, Loss: 0.6140
# Epoch   1 Batch  755/1077 - Train Accuracy: 0.5691, Validation Accuracy: 0.5774, Loss: 0.6176
# Epoch   1 Batch  760/1077 - Train Accuracy: 0.5727, Validation Accuracy: 0.5845, Loss: 0.6165
# Epoch   1 Batch  765/1077 - Train Accuracy: 0.5863, Validation Accuracy: 0.5906, Loss: 0.5886
# Epoch   1 Batch  770/1077 - Train Accuracy: 0.5517, Validation Accuracy: 0.5490, Loss: 0.5852
# Epoch   1 Batch  775/1077 - Train Accuracy: 0.5746, Validation Accuracy: 0.5969, Loss: 0.6257
# Epoch   1 Batch  780/1077 - Train Accuracy: 0.5676, Validation Accuracy: 0.5746, Loss: 0.6150
# Epoch   1 Batch  785/1077 - Train Accuracy: 0.5692, Validation Accuracy: 0.5710, Loss: 0.5843
# Epoch   1 Batch  790/1077 - Train Accuracy: 0.5094, Validation Accuracy: 0.5710, Loss: 0.6294
# Epoch   1 Batch  795/1077 - Train Accuracy: 0.5746, Validation Accuracy: 0.5845, Loss: 0.6225
# Epoch   1 Batch  800/1077 - Train Accuracy: 0.5383, Validation Accuracy: 0.5707, Loss: 0.6092
# Epoch   1 Batch  805/1077 - Train Accuracy: 0.5797, Validation Accuracy: 0.5966, Loss: 0.6128
# Epoch   1 Batch  810/1077 - Train Accuracy: 0.5971, Validation Accuracy: 0.5859, Loss: 0.5834
# Epoch   1 Batch  815/1077 - Train Accuracy: 0.5734, Validation Accuracy: 0.5792, Loss: 0.6233
# Epoch   1 Batch  820/1077 - Train Accuracy: 0.5188, Validation Accuracy: 0.5671, Loss: 0.6638
# Epoch   1 Batch  825/1077 - Train Accuracy: 0.5125, Validation Accuracy: 0.5799, Loss: 0.6159
# Epoch   1 Batch  830/1077 - Train Accuracy: 0.5594, Validation Accuracy: 0.5717, Loss: 0.5898
# Epoch   1 Batch  835/1077 - Train Accuracy: 0.5977, Validation Accuracy: 0.5909, Loss: 0.6064
# Epoch   1 Batch  840/1077 - Train Accuracy: 0.5461, Validation Accuracy: 0.5813, Loss: 0.5798
# Epoch   1 Batch  845/1077 - Train Accuracy: 0.5832, Validation Accuracy: 0.6009, Loss: 0.6018
# Epoch   1 Batch  850/1077 - Train Accuracy: 0.5286, Validation Accuracy: 0.5838, Loss: 0.6809
# Epoch   1 Batch  855/1077 - Train Accuracy: 0.5359, Validation Accuracy: 0.5732, Loss: 0.6089
# Epoch   1 Batch  860/1077 - Train Accuracy: 0.5725, Validation Accuracy: 0.5781, Loss: 0.5869
# Epoch   1 Batch  865/1077 - Train Accuracy: 0.6133, Validation Accuracy: 0.5682, Loss: 0.5385
# Epoch   1 Batch  870/1077 - Train Accuracy: 0.5370, Validation Accuracy: 0.5803, Loss: 0.6319
# Epoch   1 Batch  875/1077 - Train Accuracy: 0.5730, Validation Accuracy: 0.5955, Loss: 0.5997
# Epoch   1 Batch  880/1077 - Train Accuracy: 0.5934, Validation Accuracy: 0.5732, Loss: 0.6063
# Epoch   1 Batch  885/1077 - Train Accuracy: 0.5575, Validation Accuracy: 0.4968, Loss: 0.5223
# Epoch   1 Batch  890/1077 - Train Accuracy: 0.6380, Validation Accuracy: 0.5948, Loss: 0.5517
# Epoch   1 Batch  895/1077 - Train Accuracy: 0.5609, Validation Accuracy: 0.6087, Loss: 0.5850
# Epoch   1 Batch  900/1077 - Train Accuracy: 0.5645, Validation Accuracy: 0.5795, Loss: 0.6325
# Epoch   1 Batch  905/1077 - Train Accuracy: 0.6008, Validation Accuracy: 0.5916, Loss: 0.5627
# Epoch   1 Batch  910/1077 - Train Accuracy: 0.5580, Validation Accuracy: 0.5799, Loss: 0.5813
# Epoch   1 Batch  915/1077 - Train Accuracy: 0.5107, Validation Accuracy: 0.5717, Loss: 0.6172
# Epoch   1 Batch  920/1077 - Train Accuracy: 0.5527, Validation Accuracy: 0.5969, Loss: 0.6450
# Epoch   1 Batch  925/1077 - Train Accuracy: 0.5692, Validation Accuracy: 0.5685, Loss: 0.5862
# Epoch   1 Batch  930/1077 - Train Accuracy: 0.5719, Validation Accuracy: 0.5806, Loss: 0.5835
# Epoch   1 Batch  935/1077 - Train Accuracy: 0.5727, Validation Accuracy: 0.5969, Loss: 0.6189
# Epoch   1 Batch  940/1077 - Train Accuracy: 0.5684, Validation Accuracy: 0.5838, Loss: 0.5913
# Epoch   1 Batch  945/1077 - Train Accuracy: 0.6176, Validation Accuracy: 0.5916, Loss: 0.5739
# Epoch   1 Batch  950/1077 - Train Accuracy: 0.5283, Validation Accuracy: 0.5646, Loss: 0.5686
# Epoch   1 Batch  955/1077 - Train Accuracy: 0.5820, Validation Accuracy: 0.5845, Loss: 0.6412
# Epoch   1 Batch  960/1077 - Train Accuracy: 0.5874, Validation Accuracy: 0.5984, Loss: 0.5880
# Epoch   1 Batch  965/1077 - Train Accuracy: 0.5275, Validation Accuracy: 0.6097, Loss: 0.6393
# Epoch   1 Batch  970/1077 - Train Accuracy: 0.5676, Validation Accuracy: 0.5600, Loss: 0.6094
# Epoch   1 Batch  975/1077 - Train Accuracy: 0.6075, Validation Accuracy: 0.5849, Loss: 0.5834
# Epoch   1 Batch  980/1077 - Train Accuracy: 0.5969, Validation Accuracy: 0.6119, Loss: 0.5959
# Epoch   1 Batch  985/1077 - Train Accuracy: 0.6055, Validation Accuracy: 0.5760, Loss: 0.6049
# Epoch   1 Batch  990/1077 - Train Accuracy: 0.5691, Validation Accuracy: 0.6154, Loss: 0.6601
# Epoch   1 Batch  995/1077 - Train Accuracy: 0.6060, Validation Accuracy: 0.6055, Loss: 0.6009
# Epoch   1 Batch 1000/1077 - Train Accuracy: 0.5826, Validation Accuracy: 0.5866, Loss: 0.5629
# Epoch   1 Batch 1005/1077 - Train Accuracy: 0.5719, Validation Accuracy: 0.5927, Loss: 0.6052
# Epoch   1 Batch 1010/1077 - Train Accuracy: 0.5551, Validation Accuracy: 0.5877, Loss: 0.5850
# Epoch   1 Batch 1015/1077 - Train Accuracy: 0.5586, Validation Accuracy: 0.5977, Loss: 0.6301
# Epoch   1 Batch 1020/1077 - Train Accuracy: 0.5453, Validation Accuracy: 0.5724, Loss: 0.6101
# Epoch   1 Batch 1025/1077 - Train Accuracy: 0.5878, Validation Accuracy: 0.5948, Loss: 0.5662
# Epoch   1 Batch 1030/1077 - Train Accuracy: 0.5578, Validation Accuracy: 0.5884, Loss: 0.6061
# Epoch   1 Batch 1035/1077 - Train Accuracy: 0.5610, Validation Accuracy: 0.6062, Loss: 0.5377
# Epoch   1 Batch 1040/1077 - Train Accuracy: 0.5617, Validation Accuracy: 0.5927, Loss: 0.6089
# Epoch   1 Batch 1045/1077 - Train Accuracy: 0.5246, Validation Accuracy: 0.5820, Loss: 0.6009
# Epoch   1 Batch 1050/1077 - Train Accuracy: 0.5047, Validation Accuracy: 0.5820, Loss: 0.5946
# Epoch   1 Batch 1055/1077 - Train Accuracy: 0.6070, Validation Accuracy: 0.6133, Loss: 0.5989
# Epoch   1 Batch 1060/1077 - Train Accuracy: 0.5645, Validation Accuracy: 0.5838, Loss: 0.5435
# Epoch   1 Batch 1065/1077 - Train Accuracy: 0.5469, Validation Accuracy: 0.5785, Loss: 0.5808
# Epoch   1 Batch 1070/1077 - Train Accuracy: 0.5621, Validation Accuracy: 0.6129, Loss: 0.5989
# Epoch   1 Batch 1075/1077 - Train Accuracy: 0.5637, Validation Accuracy: 0.5763, Loss: 0.6275
# Epoch   2 Batch    5/1077 - Train Accuracy: 0.5551, Validation Accuracy: 0.5934, Loss: 0.6273
# Epoch   2 Batch   10/1077 - Train Accuracy: 0.5535, Validation Accuracy: 0.5792, Loss: 0.6434
# Epoch   2 Batch   15/1077 - Train Accuracy: 0.5641, Validation Accuracy: 0.5742, Loss: 0.5835
# Epoch   2 Batch   20/1077 - Train Accuracy: 0.5617, Validation Accuracy: 0.6218, Loss: 0.5973
# Epoch   2 Batch   25/1077 - Train Accuracy: 0.5613, Validation Accuracy: 0.6087, Loss: 0.5737
# Epoch   2 Batch   30/1077 - Train Accuracy: 0.5738, Validation Accuracy: 0.5767, Loss: 0.5952
# Epoch   2 Batch   35/1077 - Train Accuracy: 0.5617, Validation Accuracy: 0.5810, Loss: 0.6032
# Epoch   2 Batch   40/1077 - Train Accuracy: 0.5668, Validation Accuracy: 0.6037, Loss: 0.6017
# Epoch   2 Batch   45/1077 - Train Accuracy: 0.5727, Validation Accuracy: 0.5973, Loss: 0.6001
# Epoch   2 Batch   50/1077 - Train Accuracy: 0.5270, Validation Accuracy: 0.5920, Loss: 0.6062
# Epoch   2 Batch   55/1077 - Train Accuracy: 0.5449, Validation Accuracy: 0.5721, Loss: 0.5820
# Epoch   2 Batch   60/1077 - Train Accuracy: 0.5763, Validation Accuracy: 0.5856, Loss: 0.5785
# Epoch   2 Batch   65/1077 - Train Accuracy: 0.5440, Validation Accuracy: 0.5636, Loss: 0.6269
# Epoch   2 Batch   70/1077 - Train Accuracy: 0.5646, Validation Accuracy: 0.5966, Loss: 0.6171
# Epoch   2 Batch   75/1077 - Train Accuracy: 0.5680, Validation Accuracy: 0.5717, Loss: 0.6346
# Epoch   2 Batch   80/1077 - Train Accuracy: 0.5762, Validation Accuracy: 0.5909, Loss: 0.6059
# Epoch   2 Batch   85/1077 - Train Accuracy: 0.5813, Validation Accuracy: 0.6033, Loss: 0.6046
# Epoch   2 Batch   90/1077 - Train Accuracy: 0.5445, Validation Accuracy: 0.5930, Loss: 0.6166
# Epoch   2 Batch   95/1077 - Train Accuracy: 0.5759, Validation Accuracy: 0.6062, Loss: 0.6327
# Epoch   2 Batch  100/1077 - Train Accuracy: 0.5953, Validation Accuracy: 0.6037, Loss: 0.5964
# Epoch   2 Batch  105/1077 - Train Accuracy: 0.5621, Validation Accuracy: 0.5721, Loss: 0.6052
# Epoch   2 Batch  110/1077 - Train Accuracy: 0.5953, Validation Accuracy: 0.5991, Loss: 0.5602
# Epoch   2 Batch  115/1077 - Train Accuracy: 0.4953, Validation Accuracy: 0.4872, Loss: 0.6547
# Epoch   2 Batch  120/1077 - Train Accuracy: 0.5176, Validation Accuracy: 0.5920, Loss: 0.6524
# Epoch   2 Batch  125/1077 - Train Accuracy: 0.5725, Validation Accuracy: 0.5923, Loss: 0.6262
# Epoch   2 Batch  130/1077 - Train Accuracy: 0.5759, Validation Accuracy: 0.5689, Loss: 0.5862
# Epoch   2 Batch  135/1077 - Train Accuracy: 0.5366, Validation Accuracy: 0.5540, Loss: 0.6478
# Epoch   2 Batch  140/1077 - Train Accuracy: 0.5535, Validation Accuracy: 0.6009, Loss: 0.6211
# Epoch   2 Batch  145/1077 - Train Accuracy: 0.5930, Validation Accuracy: 0.5874, Loss: 0.6183
# Epoch   2 Batch  150/1077 - Train Accuracy: 0.6090, Validation Accuracy: 0.5938, Loss: 0.6070
# Epoch   2 Batch  155/1077 - Train Accuracy: 0.5500, Validation Accuracy: 0.5703, Loss: 0.6353
# Epoch   2 Batch  160/1077 - Train Accuracy: 0.5512, Validation Accuracy: 0.5763, Loss: 0.6109
# Epoch   2 Batch  165/1077 - Train Accuracy: 0.5223, Validation Accuracy: 0.5611, Loss: 0.5913
# Epoch   2 Batch  170/1077 - Train Accuracy: 0.5277, Validation Accuracy: 0.5884, Loss: 0.6485
# Epoch   2 Batch  175/1077 - Train Accuracy: 0.5980, Validation Accuracy: 0.6019, Loss: 0.6069
# Epoch   2 Batch  180/1077 - Train Accuracy: 0.5535, Validation Accuracy: 0.5746, Loss: 0.6264
# Epoch   2 Batch  185/1077 - Train Accuracy: 0.5441, Validation Accuracy: 0.5685, Loss: 0.6735
# Epoch   2 Batch  190/1077 - Train Accuracy: 0.5773, Validation Accuracy: 0.5813, Loss: 0.5952
# Epoch   2 Batch  195/1077 - Train Accuracy: 0.5301, Validation Accuracy: 0.5927, Loss: 0.6062
# Epoch   2 Batch  200/1077 - Train Accuracy: 0.5414, Validation Accuracy: 0.5611, Loss: 0.6457
# Epoch   2 Batch  205/1077 - Train Accuracy: 0.5574, Validation Accuracy: 0.5700, Loss: 0.6332
# Epoch   2 Batch  210/1077 - Train Accuracy: 0.5725, Validation Accuracy: 0.5852, Loss: 0.6069
# Epoch   2 Batch  215/1077 - Train Accuracy: 0.5352, Validation Accuracy: 0.5859, Loss: 0.6109
# Epoch   2 Batch  220/1077 - Train Accuracy: 0.5551, Validation Accuracy: 0.5778, Loss: 0.6353
# Epoch   2 Batch  225/1077 - Train Accuracy: 0.5805, Validation Accuracy: 0.6016, Loss: 0.6247
# Epoch   2 Batch  230/1077 - Train Accuracy: 0.5714, Validation Accuracy: 0.5700, Loss: 0.6233
# Epoch   2 Batch  235/1077 - Train Accuracy: 0.5919, Validation Accuracy: 0.5639, Loss: 0.5549
# Epoch   2 Batch  240/1077 - Train Accuracy: 0.5980, Validation Accuracy: 0.5902, Loss: 0.5902
# Epoch   2 Batch  245/1077 - Train Accuracy: 0.5305, Validation Accuracy: 0.5178, Loss: 0.5768
# Epoch   2 Batch  250/1077 - Train Accuracy: 0.5803, Validation Accuracy: 0.5781, Loss: 0.5855
# Epoch   2 Batch  255/1077 - Train Accuracy: 0.5316, Validation Accuracy: 0.5714, Loss: 0.6385
# Epoch   2 Batch  260/1077 - Train Accuracy: 0.5629, Validation Accuracy: 0.5753, Loss: 0.5708
# Epoch   2 Batch  265/1077 - Train Accuracy: 0.5363, Validation Accuracy: 0.5817, Loss: 0.6343
# Epoch   2 Batch  270/1077 - Train Accuracy: 0.4730, Validation Accuracy: 0.4901, Loss: 0.6336
# Epoch   2 Batch  275/1077 - Train Accuracy: 0.5484, Validation Accuracy: 0.5813, Loss: 0.5961
# Epoch   2 Batch  280/1077 - Train Accuracy: 0.5797, Validation Accuracy: 0.5859, Loss: 0.6050
# Epoch   2 Batch  285/1077 - Train Accuracy: 0.5487, Validation Accuracy: 0.5852, Loss: 0.5999
# Epoch   2 Batch  290/1077 - Train Accuracy: 0.5750, Validation Accuracy: 0.6048, Loss: 0.6247
# Epoch   2 Batch  295/1077 - Train Accuracy: 0.5551, Validation Accuracy: 0.5895, Loss: 0.6439
# Epoch   2 Batch  300/1077 - Train Accuracy: 0.5070, Validation Accuracy: 0.5167, Loss: 0.6148
# Epoch   2 Batch  305/1077 - Train Accuracy: 0.5641, Validation Accuracy: 0.5909, Loss: 0.5890
# Epoch   2 Batch  310/1077 - Train Accuracy: 0.5113, Validation Accuracy: 0.5572, Loss: 0.6121
# Epoch   2 Batch  315/1077 - Train Accuracy: 0.5781, Validation Accuracy: 0.5934, Loss: 0.5554
# Epoch   2 Batch  320/1077 - Train Accuracy: 0.5879, Validation Accuracy: 0.5991, Loss: 0.5956
# Epoch   2 Batch  325/1077 - Train Accuracy: 0.6146, Validation Accuracy: 0.5877, Loss: 0.6062
# Epoch   2 Batch  330/1077 - Train Accuracy: 0.5797, Validation Accuracy: 0.5778, Loss: 0.6253
# Epoch   2 Batch  335/1077 - Train Accuracy: 0.5837, Validation Accuracy: 0.5859, Loss: 0.5881
# Epoch   2 Batch  340/1077 - Train Accuracy: 0.5391, Validation Accuracy: 0.5856, Loss: 0.6291
# Epoch   2 Batch  345/1077 - Train Accuracy: 0.5796, Validation Accuracy: 0.5884, Loss: 0.5759
# Epoch   2 Batch  350/1077 - Train Accuracy: 0.5262, Validation Accuracy: 0.4961, Loss: 0.6245
# Epoch   2 Batch  355/1077 - Train Accuracy: 0.5387, Validation Accuracy: 0.5760, Loss: 0.5981
# Epoch   2 Batch  360/1077 - Train Accuracy: 0.5406, Validation Accuracy: 0.5611, Loss: 0.5916
# Epoch   2 Batch  365/1077 - Train Accuracy: 0.5285, Validation Accuracy: 0.5760, Loss: 0.5983
# Epoch   2 Batch  370/1077 - Train Accuracy: 0.5513, Validation Accuracy: 0.5526, Loss: 0.5800
# Epoch   2 Batch  375/1077 - Train Accuracy: 0.5806, Validation Accuracy: 0.5778, Loss: 0.5709
# Epoch   2 Batch  380/1077 - Train Accuracy: 0.5789, Validation Accuracy: 0.5923, Loss: 0.5892
# Epoch   2 Batch  385/1077 - Train Accuracy: 0.5922, Validation Accuracy: 0.5845, Loss: 0.5855
# Epoch   2 Batch  390/1077 - Train Accuracy: 0.5301, Validation Accuracy: 0.5788, Loss: 0.6400
# Epoch   2 Batch  395/1077 - Train Accuracy: 0.6071, Validation Accuracy: 0.5863, Loss: 0.5874
# Epoch   2 Batch  400/1077 - Train Accuracy: 0.5723, Validation Accuracy: 0.5774, Loss: 0.6087
# Epoch   2 Batch  405/1077 - Train Accuracy: 0.5399, Validation Accuracy: 0.5724, Loss: 0.6532
# Epoch   2 Batch  410/1077 - Train Accuracy: 0.4889, Validation Accuracy: 0.5085, Loss: 0.6489
# Epoch   2 Batch  415/1077 - Train Accuracy: 0.5737, Validation Accuracy: 0.5746, Loss: 0.5759
# Epoch   2 Batch  420/1077 - Train Accuracy: 0.5207, Validation Accuracy: 0.5014, Loss: 0.5578
# Epoch   2 Batch  425/1077 - Train Accuracy: 0.5889, Validation Accuracy: 0.5852, Loss: 0.5843
# Epoch   2 Batch  430/1077 - Train Accuracy: 0.5613, Validation Accuracy: 0.5955, Loss: 0.5818
# Epoch   2 Batch  435/1077 - Train Accuracy: 0.4293, Validation Accuracy: 0.5142, Loss: 0.6227
# Epoch   2 Batch  440/1077 - Train Accuracy: 0.5539, Validation Accuracy: 0.5792, Loss: 0.6273
# Epoch   2 Batch  445/1077 - Train Accuracy: 0.5366, Validation Accuracy: 0.5756, Loss: 0.6063
# Epoch   2 Batch  450/1077 - Train Accuracy: 0.5121, Validation Accuracy: 0.5650, Loss: 0.5770
# Epoch   2 Batch  455/1077 - Train Accuracy: 0.6058, Validation Accuracy: 0.6030, Loss: 0.5662
# Epoch   2 Batch  460/1077 - Train Accuracy: 0.4785, Validation Accuracy: 0.5163, Loss: 0.6507
# Epoch   2 Batch  465/1077 - Train Accuracy: 0.5296, Validation Accuracy: 0.5717, Loss: 0.6479
# Epoch   2 Batch  470/1077 - Train Accuracy: 0.5156, Validation Accuracy: 0.5593, Loss: 0.6213
# Epoch   2 Batch  475/1077 - Train Accuracy: 0.5207, Validation Accuracy: 0.5110, Loss: 0.5952
# Epoch   2 Batch  480/1077 - Train Accuracy: 0.5872, Validation Accuracy: 0.5842, Loss: 0.6153
# Epoch   2 Batch  485/1077 - Train Accuracy: 0.5508, Validation Accuracy: 0.5668, Loss: 0.6300
# Epoch   2 Batch  490/1077 - Train Accuracy: 0.5500, Validation Accuracy: 0.5788, Loss: 0.6073
# Epoch   2 Batch  495/1077 - Train Accuracy: 0.5574, Validation Accuracy: 0.5813, Loss: 0.5773
# Epoch   2 Batch  500/1077 - Train Accuracy: 0.5879, Validation Accuracy: 0.6033, Loss: 0.5849
# Epoch   2 Batch  505/1077 - Train Accuracy: 0.5967, Validation Accuracy: 0.5849, Loss: 0.5562
# Epoch   2 Batch  510/1077 - Train Accuracy: 0.5551, Validation Accuracy: 0.5969, Loss: 0.6116
# Epoch   2 Batch  515/1077 - Train Accuracy: 0.5602, Validation Accuracy: 0.6108, Loss: 0.6205
# Epoch   2 Batch  520/1077 - Train Accuracy: 0.6008, Validation Accuracy: 0.5952, Loss: 0.5738
# Epoch   2 Batch  525/1077 - Train Accuracy: 0.5473, Validation Accuracy: 0.5629, Loss: 0.5844
# Epoch   2 Batch  530/1077 - Train Accuracy: 0.5680, Validation Accuracy: 0.5792, Loss: 0.5947
# Epoch   2 Batch  535/1077 - Train Accuracy: 0.5891, Validation Accuracy: 0.5920, Loss: 0.6119
# Epoch   2 Batch  540/1077 - Train Accuracy: 0.5703, Validation Accuracy: 0.5884, Loss: 0.5673
# Epoch   2 Batch  545/1077 - Train Accuracy: 0.5348, Validation Accuracy: 0.5859, Loss: 0.6421
# Epoch   2 Batch  550/1077 - Train Accuracy: 0.5375, Validation Accuracy: 0.5827, Loss: 0.6365
# Epoch   2 Batch  555/1077 - Train Accuracy: 0.5711, Validation Accuracy: 0.5710, Loss: 0.5920
# Epoch   2 Batch  560/1077 - Train Accuracy: 0.5375, Validation Accuracy: 0.5724, Loss: 0.5804
# Epoch   2 Batch  565/1077 - Train Accuracy: 0.5737, Validation Accuracy: 0.5785, Loss: 0.5989
# Epoch   2 Batch  570/1077 - Train Accuracy: 0.5658, Validation Accuracy: 0.5863, Loss: 0.6371
# Epoch   2 Batch  575/1077 - Train Accuracy: 0.5997, Validation Accuracy: 0.5682, Loss: 0.6111
# Epoch   2 Batch  580/1077 - Train Accuracy: 0.5833, Validation Accuracy: 0.5522, Loss: 0.5347
# Epoch   2 Batch  585/1077 - Train Accuracy: 0.5923, Validation Accuracy: 0.5746, Loss: 0.5663
# Epoch   2 Batch  590/1077 - Train Accuracy: 0.4918, Validation Accuracy: 0.5494, Loss: 0.6248
# Epoch   2 Batch  595/1077 - Train Accuracy: 0.5480, Validation Accuracy: 0.5813, Loss: 0.5954
# Epoch   2 Batch  600/1077 - Train Accuracy: 0.5964, Validation Accuracy: 0.5895, Loss: 0.5587
# Epoch   2 Batch  605/1077 - Train Accuracy: 0.5621, Validation Accuracy: 0.5767, Loss: 0.6272
# Epoch   2 Batch  610/1077 - Train Accuracy: 0.5563, Validation Accuracy: 0.5600, Loss: 0.6037
# Epoch   2 Batch  615/1077 - Train Accuracy: 0.6035, Validation Accuracy: 0.5721, Loss: 0.5825
# Epoch   2 Batch  620/1077 - Train Accuracy: 0.5086, Validation Accuracy: 0.5071, Loss: 0.5513
# Epoch   2 Batch  625/1077 - Train Accuracy: 0.5801, Validation Accuracy: 0.5852, Loss: 0.5969
# Epoch   2 Batch  630/1077 - Train Accuracy: 0.5840, Validation Accuracy: 0.5877, Loss: 0.5818
# Epoch   2 Batch  635/1077 - Train Accuracy: 0.5078, Validation Accuracy: 0.5664, Loss: 0.6930
# Epoch   2 Batch  640/1077 - Train Accuracy: 0.5216, Validation Accuracy: 0.5611, Loss: 0.6154
# Epoch   2 Batch  645/1077 - Train Accuracy: 0.5688, Validation Accuracy: 0.5987, Loss: 0.5730
# Epoch   2 Batch  650/1077 - Train Accuracy: 0.5512, Validation Accuracy: 0.5771, Loss: 0.6091
# Epoch   2 Batch  655/1077 - Train Accuracy: 0.5598, Validation Accuracy: 0.5739, Loss: 0.6329
# Epoch   2 Batch  660/1077 - Train Accuracy: 0.5324, Validation Accuracy: 0.5675, Loss: 0.6641
# Epoch   2 Batch  665/1077 - Train Accuracy: 0.5355, Validation Accuracy: 0.5639, Loss: 0.6319
# Epoch   2 Batch  670/1077 - Train Accuracy: 0.6044, Validation Accuracy: 0.5621, Loss: 0.5892
# Epoch   2 Batch  675/1077 - Train Accuracy: 0.5484, Validation Accuracy: 0.5813, Loss: 0.6210
# Epoch   2 Batch  680/1077 - Train Accuracy: 0.5234, Validation Accuracy: 0.5490, Loss: 0.5843
# Epoch   2 Batch  685/1077 - Train Accuracy: 0.5371, Validation Accuracy: 0.5753, Loss: 0.6188
# Epoch   2 Batch  690/1077 - Train Accuracy: 0.5523, Validation Accuracy: 0.5646, Loss: 0.6017
# Epoch   2 Batch  695/1077 - Train Accuracy: 0.5777, Validation Accuracy: 0.5977, Loss: 0.5928
# Epoch   2 Batch  700/1077 - Train Accuracy: 0.5066, Validation Accuracy: 0.4911, Loss: 0.6176
# Epoch   2 Batch  705/1077 - Train Accuracy: 0.5789, Validation Accuracy: 0.5735, Loss: 0.6610
# Epoch   2 Batch  710/1077 - Train Accuracy: 0.4973, Validation Accuracy: 0.5661, Loss: 0.6042
# Epoch   2 Batch  715/1077 - Train Accuracy: 0.5445, Validation Accuracy: 0.5845, Loss: 0.6189
# Epoch   2 Batch  720/1077 - Train Accuracy: 0.5522, Validation Accuracy: 0.5742, Loss: 0.6402
# Epoch   2 Batch  725/1077 - Train Accuracy: 0.5472, Validation Accuracy: 0.5604, Loss: 0.5767
# Epoch   2 Batch  730/1077 - Train Accuracy: 0.5453, Validation Accuracy: 0.5827, Loss: 0.5989
# Epoch   2 Batch  735/1077 - Train Accuracy: 0.5813, Validation Accuracy: 0.6044, Loss: 0.5792
# Epoch   2 Batch  740/1077 - Train Accuracy: 0.5742, Validation Accuracy: 0.5785, Loss: 0.5889
# Epoch   2 Batch  745/1077 - Train Accuracy: 0.5813, Validation Accuracy: 0.5824, Loss: 0.5854
# Epoch   2 Batch  750/1077 - Train Accuracy: 0.5363, Validation Accuracy: 0.5558, Loss: 0.6074
# Epoch   2 Batch  755/1077 - Train Accuracy: 0.5813, Validation Accuracy: 0.5849, Loss: 0.6166
# Epoch   2 Batch  760/1077 - Train Accuracy: 0.5160, Validation Accuracy: 0.5124, Loss: 0.6196
# Epoch   2 Batch  765/1077 - Train Accuracy: 0.5762, Validation Accuracy: 0.5675, Loss: 0.5846
# Epoch   2 Batch  770/1077 - Train Accuracy: 0.5465, Validation Accuracy: 0.5646, Loss: 0.5607
# Epoch   2 Batch  775/1077 - Train Accuracy: 0.5645, Validation Accuracy: 0.5930, Loss: 0.5918
# Epoch   2 Batch  780/1077 - Train Accuracy: 0.5570, Validation Accuracy: 0.6005, Loss: 0.6322
# Epoch   2 Batch  785/1077 - Train Accuracy: 0.6031, Validation Accuracy: 0.5611, Loss: 0.5576
# Epoch   2 Batch  790/1077 - Train Accuracy: 0.5215, Validation Accuracy: 0.5756, Loss: 0.6192
# Epoch   2 Batch  795/1077 - Train Accuracy: 0.5508, Validation Accuracy: 0.5923, Loss: 0.6442
# Epoch   2 Batch  800/1077 - Train Accuracy: 0.5621, Validation Accuracy: 0.5966, Loss: 0.6202
# Epoch   2 Batch  805/1077 - Train Accuracy: 0.5887, Validation Accuracy: 0.5799, Loss: 0.6139
# Epoch   2 Batch  810/1077 - Train Accuracy: 0.5149, Validation Accuracy: 0.5167, Loss: 0.5931
# Epoch   2 Batch  815/1077 - Train Accuracy: 0.5539, Validation Accuracy: 0.5792, Loss: 0.6208
# Epoch   2 Batch  820/1077 - Train Accuracy: 0.5418, Validation Accuracy: 0.5874, Loss: 0.6590
# Epoch   2 Batch  825/1077 - Train Accuracy: 0.5191, Validation Accuracy: 0.5792, Loss: 0.5968
# Epoch   2 Batch  830/1077 - Train Accuracy: 0.5281, Validation Accuracy: 0.5749, Loss: 0.6242
# Epoch   2 Batch  835/1077 - Train Accuracy: 0.5574, Validation Accuracy: 0.5962, Loss: 0.6343
# Epoch   2 Batch  840/1077 - Train Accuracy: 0.5141, Validation Accuracy: 0.5646, Loss: 0.6120
# Epoch   2 Batch  845/1077 - Train Accuracy: 0.5617, Validation Accuracy: 0.5849, Loss: 0.6213
# Epoch   2 Batch  850/1077 - Train Accuracy: 0.5495, Validation Accuracy: 0.5682, Loss: 0.6598
# Epoch   2 Batch  855/1077 - Train Accuracy: 0.5219, Validation Accuracy: 0.5668, Loss: 0.6402
# Epoch   2 Batch  860/1077 - Train Accuracy: 0.5461, Validation Accuracy: 0.4904, Loss: 0.5884
# Epoch   2 Batch  865/1077 - Train Accuracy: 0.5991, Validation Accuracy: 0.5771, Loss: 0.5727
# Epoch   2 Batch  870/1077 - Train Accuracy: 0.5111, Validation Accuracy: 0.5657, Loss: 0.6618
# Epoch   2 Batch  875/1077 - Train Accuracy: 0.5523, Validation Accuracy: 0.5934, Loss: 0.6152
# Epoch   2 Batch  880/1077 - Train Accuracy: 0.5844, Validation Accuracy: 0.5877, Loss: 0.5931
# Epoch   2 Batch  885/1077 - Train Accuracy: 0.5604, Validation Accuracy: 0.5604, Loss: 0.5201
# Epoch   2 Batch  890/1077 - Train Accuracy: 0.6239, Validation Accuracy: 0.5973, Loss: 0.5654
# Epoch   2 Batch  895/1077 - Train Accuracy: 0.5797, Validation Accuracy: 0.5845, Loss: 0.5923
# Epoch   2 Batch  900/1077 - Train Accuracy: 0.5336, Validation Accuracy: 0.5756, Loss: 0.6368
# Epoch   2 Batch  905/1077 - Train Accuracy: 0.6031, Validation Accuracy: 0.5810, Loss: 0.5692
# Epoch   2 Batch  910/1077 - Train Accuracy: 0.5461, Validation Accuracy: 0.5774, Loss: 0.5775
# Epoch   2 Batch  915/1077 - Train Accuracy: 0.5481, Validation Accuracy: 0.5884, Loss: 0.6228
# Epoch   2 Batch  920/1077 - Train Accuracy: 0.5719, Validation Accuracy: 0.5913, Loss: 0.6240
# Epoch   2 Batch  925/1077 - Train Accuracy: 0.5100, Validation Accuracy: 0.5231, Loss: 0.5748
# Epoch   2 Batch  930/1077 - Train Accuracy: 0.5703, Validation Accuracy: 0.5739, Loss: 0.5797
# Epoch   2 Batch  935/1077 - Train Accuracy: 0.5508, Validation Accuracy: 0.5934, Loss: 0.6184
# Epoch   2 Batch  940/1077 - Train Accuracy: 0.5277, Validation Accuracy: 0.5724, Loss: 0.6161
# Epoch   2 Batch  945/1077 - Train Accuracy: 0.5879, Validation Accuracy: 0.5941, Loss: 0.5944
# Epoch   2 Batch  950/1077 - Train Accuracy: 0.5249, Validation Accuracy: 0.5781, Loss: 0.5762
# Epoch   2 Batch  955/1077 - Train Accuracy: 0.5422, Validation Accuracy: 0.5785, Loss: 0.6198
# Epoch   2 Batch  960/1077 - Train Accuracy: 0.5778, Validation Accuracy: 0.6072, Loss: 0.5767
# Epoch   2 Batch  965/1077 - Train Accuracy: 0.5140, Validation Accuracy: 0.6058, Loss: 0.6581
# Epoch   2 Batch  970/1077 - Train Accuracy: 0.5758, Validation Accuracy: 0.5763, Loss: 0.6427
# Epoch   2 Batch  975/1077 - Train Accuracy: 0.5982, Validation Accuracy: 0.6183, Loss: 0.5922
# Epoch   2 Batch  980/1077 - Train Accuracy: 0.6102, Validation Accuracy: 0.6154, Loss: 0.5980
# Epoch   2 Batch  985/1077 - Train Accuracy: 0.5766, Validation Accuracy: 0.5795, Loss: 0.5920
# Epoch   2 Batch  990/1077 - Train Accuracy: 0.5744, Validation Accuracy: 0.6115, Loss: 0.6358
# Epoch   2 Batch  995/1077 - Train Accuracy: 0.6023, Validation Accuracy: 0.6037, Loss: 0.5910
# Epoch   2 Batch 1000/1077 - Train Accuracy: 0.5182, Validation Accuracy: 0.5359, Loss: 0.5467
# Epoch   2 Batch 1005/1077 - Train Accuracy: 0.5668, Validation Accuracy: 0.6143, Loss: 0.5860
# Epoch   2 Batch 1010/1077 - Train Accuracy: 0.5555, Validation Accuracy: 0.5962, Loss: 0.5891
# Epoch   2 Batch 1015/1077 - Train Accuracy: 0.5465, Validation Accuracy: 0.5884, Loss: 0.6272
# Epoch   2 Batch 1020/1077 - Train Accuracy: 0.5512, Validation Accuracy: 0.5817, Loss: 0.5775
# Epoch   2 Batch 1025/1077 - Train Accuracy: 0.5755, Validation Accuracy: 0.5987, Loss: 0.5619
# Epoch   2 Batch 1030/1077 - Train Accuracy: 0.5699, Validation Accuracy: 0.5827, Loss: 0.6427
# Epoch   2 Batch 1035/1077 - Train Accuracy: 0.5201, Validation Accuracy: 0.5099, Loss: 0.5437
# Epoch   2 Batch 1040/1077 - Train Accuracy: 0.5559, Validation Accuracy: 0.5668, Loss: 0.6874
# Epoch   2 Batch 1045/1077 - Train Accuracy: 0.5328, Validation Accuracy: 0.5827, Loss: 0.6333
# Epoch   2 Batch 1050/1077 - Train Accuracy: 0.4996, Validation Accuracy: 0.5778, Loss: 0.6093
# Epoch   2 Batch 1055/1077 - Train Accuracy: 0.5320, Validation Accuracy: 0.5923, Loss: 0.6100
# Epoch   2 Batch 1060/1077 - Train Accuracy: 0.5660, Validation Accuracy: 0.5678, Loss: 0.5851
# Epoch   2 Batch 1065/1077 - Train Accuracy: 0.5375, Validation Accuracy: 0.5859, Loss: 0.6141
# Epoch   2 Batch 1070/1077 - Train Accuracy: 0.5152, Validation Accuracy: 0.5852, Loss: 0.6487
# Epoch   2 Batch 1075/1077 - Train Accuracy: 0.5350, Validation Accuracy: 0.5803, Loss: 0.6644
# Model Trained and Saved

# %% [markdown]
# ### Save Parameters
# Save the `batch_size` and `save_path` parameters for inference.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# Save parameters for checkpoint
helper.save_params(save_path)

# %% [markdown]
# # Checkpoint

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import tensorflow as tf
import numpy as np
import helper
import problem_unittests as tests

_, (source_vocab_to_int, target_vocab_to_int), (source_int_to_vocab, target_int_to_vocab) = helper.load_preprocess()
load_path = helper.load_params()

# %% [markdown]
# ## Sentence to Sequence
# To feed a sentence into the model for translation, you first need to preprocess it.  Implement the function `sentence_to_seq()` to preprocess new sentences.
#
# - Convert the sentence to lowercase
# - Convert words into ids using `vocab_to_int`
#  - Convert words not in the vocabulary, to the `<UNK>` word id.

# %%
def sentence_to_seq(sentence, vocab_to_int):
    """
    Convert a sentence to a sequence of ids
    :param sentence: String
    :param vocab_to_int: Dictionary to go from the words to an id
    :return: List of word ids
    """
    # TODO: Implement Function
    word_list = []
    
    for word in sentence.lower().split():
        print (word)
        word_list.append(vocab_to_int[word])
        
    return word_list


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_sentence_to_seq(sentence_to_seq)
# Out:
# this
# is
# a
# test
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-65-7bff5474ba0a> in <module>()
#      19 DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
#      20 """
# ---> 21 tests.test_sentence_to_seq(sentence_to_seq)
#
# /home/carnd/deep_learning/project4_language_translation/problem_unittests.py in test_sentence_to_seq(sentence_to_seq)
#     265     vocab_to_int = {'<PAD>': 0, '<EOS>': 1, '<UNK>': 2, 'this': 3, 'is': 6, 'a': 5, 'sentence': 4}
#     266
# --> 267     output = sentence_to_seq(sentence, vocab_to_int)
#     268
#     269     assert len(output) == 5,\
#
# <ipython-input-65-7bff5474ba0a> in sentence_to_seq(sentence, vocab_to_int)
#      11     for word in sentence.lower().split():
#      12         print (word)
# ---> 13         word_list.append(vocab_to_int[word])
#      14
#      15     return word_list
#
# KeyError: 'test'

# %% [markdown]
# ## Translate
# This will translate `translate_sentence` from English to French.

# %%
translate_sentence = 'he saw a old yellow truck .'


"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
translate_sentence = sentence_to_seq(translate_sentence, source_vocab_to_int)

loaded_graph = tf.Graph()
with tf.Session(graph=loaded_graph) as sess:
    # Load saved model
    loader = tf.train.import_meta_graph(load_path + '.meta')
    loader.restore(sess, load_path)

    input_data = loaded_graph.get_tensor_by_name('input:0')
    logits = loaded_graph.get_tensor_by_name('predictions:0')
    target_sequence_length = loaded_graph.get_tensor_by_name('target_sequence_length:0')
    source_sequence_length = loaded_graph.get_tensor_by_name('source_sequence_length:0')
    keep_prob = loaded_graph.get_tensor_by_name('keep_prob:0')

    translate_logits = sess.run(logits, {input_data: [translate_sentence]*batch_size,
                                         target_sequence_length: [len(translate_sentence)*2]*batch_size,
                                         source_sequence_length: [len(translate_sentence)]*batch_size,
                                         keep_prob: 1.0})[0]

print('Input')
print('  Word Ids:      {}'.format([i for i in translate_sentence]))
print('  English Words: {}'.format([source_int_to_vocab[i] for i in translate_sentence]))

print('\nPrediction')
print('  Word Ids:      {}'.format([i for i in translate_logits]))
print('  French Words: {}'.format(" ".join([target_int_to_vocab[i] for i in translate_logits])))

# %% [markdown]
# ## Imperfect Translation
# You might notice that some sentences translate better than others.  Since the dataset you're using only has a vocabulary of 227 English words of the thousands that you use, you're only going to see good results using these words.  For this project, you don't need a perfect translation. However, if you want to create a better translation model, you'll need better data.
#
# You can train on the [WMT10 French-English corpus](http://www.statmt.org/wmt10/training-giga-fren.tar).  This dataset has more vocabulary and richer in topics discussed.  However, this will take you days to train, so make sure you've a GPU and the neural network is performing well on dataset we provided.  Just make sure you play with the WMT10 corpus after you've submitted this project.
# ## Submitting This Project
# When submitting this project, make sure to run all the cells before saving the notebook. Save the notebook file as "dlnd_language_translation.ipynb" and save it as a HTML file under "File" -> "Download as". Include the "helper.py" and "problem_unittests.py" files in your submission.
